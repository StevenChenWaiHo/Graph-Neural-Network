# %% [markdown]
# # Question 3: Investigating Topology in Node-Based Classification Using GNNs
#
# In this section, we will explore the impact of graph topology on node-based classification using GNNs. The experiments will focus on analyzing different topological measures, visualizing their distributions, and evaluating GCN performance on 2 graphs with different topologies.

# %%
import json
import torch
import os
import random
import torch.nn as nn
import torch.optim as optim
import torch.nn.functional as F
import networkx as nx
import numpy as np
from sklearn.manifold import TSNE
import matplotlib.pyplot as plt
from graph_ricci_curvature import GraphRicciCurvature

# %% [markdown]
# ## Helper function and code for loading data

# %%
G1_TRAIN_FILE_NAME = "q3_G1_train.json"
G1_EVAL_FILE_NAME = "q3_G1_eval.json"

G1_TRAIN_DATA_PATH = os.path.join("data",G1_TRAIN_FILE_NAME)
G1_EVAL_DATA_PATH = os.path.join("data",G1_EVAL_FILE_NAME)

G2_TRAIN_FILE_NAME = "q3_G2_train.json"
G2_EVAL_FILE_NAME = "q3_G2_eval.json"

G2_TRAIN_DATA_PATH = os.path.join("data",G2_TRAIN_FILE_NAME)
G2_EVAL_DATA_PATH = os.path.join("data",G2_EVAL_FILE_NAME)

# %%
# Functions to load the data
def create_Adj_matrix(N, edge_index):
    """Creates the adjacency matrix"""
    A = torch.zeros((N, N), dtype=torch.float)
    for idx, jdx in edge_index:
        A[idx, jdx] = 1
        A[jdx, idx] = 1
    return A

def read_json_data(file_path, has_label=True):
    with open(file_path, 'r') as f:
        data = json.load(f)
    
    if not type(data) == list:
        item = data
        X = torch.tensor(item['features'], dtype=torch.float)
        N = len(X)
        A = create_Adj_matrix(N, item['edge_index'])
        if has_label:
            y = torch.tensor(item['label'], dtype=torch.long)
        else:
            y = None
        return (X,A,y)

    graph_data = []
    for item in data:
        X = torch.tensor(item['features'], dtype=torch.float)
        N = len(X)
        A = create_Adj_matrix(N, item['edge_index'])
        if has_label:
            y = torch.tensor(item['label'], dtype=torch.long)
        else:
            y = None
        
        graph_data.append((X,A,y))
    
    return graph_data

# %% [markdown]
# ## Question 3.1 - Analyzing the Graphs

# %% [markdown]
# ### Q3.1.b Visualizing and Comparing Topological and Geometric Measures of Two Graphs
#
# Implement the following three functions to visualize and compare structural properties of two given graphs:
#
# - `plot_node_degree_distribution_two_graphs`
# - `plot_betweenness_centrality_distribution_two_graphs`
# - `plot_ollivier_ricci_curvature_distribution_two_graphs`

# %%
def compute_node_degree(A):
    """
    Given an adjacency matrix A of shape (N, N),
    return the degree (row sum) for each of the N nodes.
    """
    degrees = A.sum(dim=1)  # sum across columns
    return degrees

# ####################################################
# MODIFY THE CODE BELOW 
# ####################################################  


def plot_node_degree_distribution_two_graphs(A1, A2):
    """
    Plots the node degree distributions of two graphs
    with adjacency matrices A1 and A2 (each of shape (N, N))
    in a single figure.
    
    """
    # Compute node degrees
    degrees_G1 = compute_node_degree(A1).numpy()
    degrees_G2 = compute_node_degree(A2).numpy()

    # Plot the distributions
    plt.figure(figsize=(12, 6))
    plt.hist(degrees_G1, bins=30, alpha=0.5, label='Graph 1')
    plt.hist(degrees_G2, bins=30, alpha=0.5, label='Graph 2')
    plt.xlabel('Node Degree')
    plt.ylabel('Frequency')
    plt.title('Node Degree Distribution')
    plt.legend()
    plt.show()

# %%
# ####################################################
# MODIFY THE CODE BELOW 
# ####################################################  

def plot_betweenness_distribution_two_graphs(A1, A2):
    """
    Plots the betweenness centrality distributions of two graphs
    defined by adjacency matrices A1 and A2 (each of shape (N, N)) 
    in a single figure.
    """
    # Convert PyTorch adjacency -> NumPy -> NetworkX Graph
    A1_np = A1.numpy()
    A2_np = A2.numpy()

    G1 = nx.from_numpy_array(A1_np)
    G2 = nx.from_numpy_array(A2_np)

    # Compute betweenness centrality for each graph
    betweenness_G1 = nx.betweenness_centrality(G1)
    betweenness_G2 = nx.betweenness_centrality(G2)

    # Extract betweenness centrality values
    betweenness_values_G1 = list(betweenness_G1.values())
    betweenness_values_G2 = list(betweenness_G2.values())

    # Plot the distributions
    plt.figure(figsize=(12, 6))
    plt.hist(betweenness_values_G1, bins=30, alpha=0.5, label='Graph 1')
    plt.hist(betweenness_values_G2, bins=30, alpha=0.5, label='Graph 2')
    plt.xlabel('Betweenness Centrality')
    plt.ylabel('Frequency')
    plt.title('Betweenness Centrality Distribution')
    plt.legend()
    plt.show()

# %%
# ####################################################
# MODIFY THE CODE BELOW 
# ####################################################  

def plot_ricci_curvature_distribution_two_graphs(A1, A2):
    """
    Plots the Ollivier-Ricci curvature distributions for two graphs
    defined by adjacency matrices A1 and A2 (PyTorch tensors).
    
    Parameters
    ----------
    A1, A2 : torch.Tensor
        Adjacency matrices for two undirected graphs (NxN).
    """
    # 1) Convert PyTorch adjacency -> NumPy -> NetworkX Graph
    A1_np = A1.numpy()
    A2_np = A2.numpy()

    G1 = nx.from_numpy_array(A1_np)
    G2 = nx.from_numpy_array(A2_np)

    # 2) Instantiate OllivierRicci object for each graph
    ricci_calculator_G1 = GraphRicciCurvature(G1)
    ricci_calculator_G2 = GraphRicciCurvature(G2)

    # 3) Compute the Ricci curvature
    curvatures1 = ricci_calculator_G1.compute_ricci_curvatures()
    curvatures2 = ricci_calculator_G2.compute_ricci_curvatures()

    # After computation, the Ricci curvature for each edge is stored in G[u][v]["ricciCurvature"]

    # 4) Gather edge-level Ricci curvature values
    ricci_values_G1 = []
    for (u, v), val in curvatures1.items():
        ricci_values_G1.append(val)

    ricci_values_G2 = []
    for (u, v), val in curvatures2.items():
        ricci_values_G2.append(val)

    # Continue with plotting ...

    # Plot the distributions
    plt.figure(figsize=(12, 6))
    plt.hist(ricci_values_G1, bins=20, alpha=0.5, label='Graph 1')
    plt.hist(ricci_values_G2, bins=20, alpha=0.5, label='Graph 2')
    plt.xlabel('Ollivier-Ricci Curvature')
    plt.ylabel('Frequency')
    plt.title('Ollivier-Ricci Curvature Distribution')
    plt.legend()
    plt.show()

# %%
G1_train = read_json_data(G1_TRAIN_DATA_PATH, has_label=True) #returns a list of (X,A,y) - features, Adj Matrix, per Graph label
G2_train = read_json_data(G2_TRAIN_DATA_PATH, has_label=True) #returns a list of (X,A,y) - features, Adj Matrix, per Graph label

# %%
plot_node_degree_distribution_two_graphs(G1_train[1], G2_train[1])

# %%
plot_betweenness_distribution_two_graphs(G1_train[1], G2_train[1])

# %%
plot_ricci_curvature_distribution_two_graphs(G1_train[1], G2_train[1])

# %% [markdown]
# ### Q3.1.c Visualizing the Graphs
#
# Implement the `plot_graph` function to generate visual representations of both graphs. Ensure that the plots are clear and well-formatted.

# %%
def plot_graph(A):
    """
    Plots a graph defined by adjacency matrix A.
    Parameters
    ----------
    A : torch.Tensor
        Adjacency matrix of shape (N, N).
    """
    # Convert PyTorch adjacency matrix to NumPy array
    A_np = A.numpy()

    # Create a NetworkX graph from the adjacency matrix
    G = nx.from_numpy_array(A_np)

    # Draw the graph
    plt.figure(figsize=(8, 8))
    pos = nx.spring_layout(G)  # positions for all nodes
    nx.draw(G, pos, with_labels=True, node_color='skyblue', edge_color='gray', node_size=500, font_size=10)
    plt.title('Graph Visualization')
    plt.show()

# %%
plot_graph(G1_train[1])

# %%
plot_graph(G2_train[1])

# %% [markdown]
# ### Q3.1.d Visualizing Node Feature Distributions
#
# - Implement the function `plot_node_feature_dist_by_class_two_graphs` to visualize the average node feature distribution per class for two given graphs.
#
# - Do not consider the distribution of a specific feature $ x_i $, consider the mean of the feature vector $ \mathbf{x} $ for each node.
#
# - The function should generate a plot similar to Figure 3 in the Coursework Desciription PDF.

# %%
def plot_node_feature_dist_by_class_two_graphs(Xa, ya, Xb, yb):
    """
    Plots the distribution of the average node features by class for two graphs.

    """

    Xa = Xa.cpu().numpy()
    Xb = Xb.cpu().numpy()
    ya = ya.cpu().numpy()
    yb = yb.cpu().numpy()

     # Calculate the average feature
    average_A = np.mean(Xa, axis=1)
    average_B = np.mean(Xb, axis=1)

    class_0_A = average_A[ya == 0]
    class_1_A = average_A[ya == 1]
    class_0_B = average_B[yb == 0]
    class_1_B = average_B[yb == 1]

    # Plot the distributions for graph A and B as overlapping bar graphs
    fig, axes = plt.subplots(1, 2, figsize=(10, 6))

    axes[0].hist(class_0_A, alpha=0.5, bins=25, label="Class 0", color="blue")
    axes[0].hist(class_1_A, alpha=0.5, bins=25, label="Class 1", color="orange")

    axes[1].hist(class_0_B, alpha=0.5, bins=25, label="Class 0", color="blue")
    axes[1].hist(class_1_B, alpha=0.5, bins=25, label="Class 1", color="orange")

    # Set Titles and Labels
    axes[0].set_title("Average Feature Distribution of Graph 1")
    axes[0].set_xlabel("Mean Feature Value")
    axes[0].set_ylabel("Count")
    axes[0].legend()

    axes[1].set_title("Average Feature Distribution of Graph 2")
    axes[1].set_xlabel("Mean Feature Value")
    axes[1].set_ylabel("Count")
    axes[1].legend()

    plt.tight_layout()
    plt.show()

# %%
X1, A1, y1 = G1_train
X2, A2, y2 = G2_train
plot_node_feature_dist_by_class_two_graphs(X1, y1, X2, y2)

# %% [markdown]
# ## Question 3.2 -  Evaluating GCN Performance on Different Graph Structures

# %% [markdown]
# ### Helper functions for normalising the A matrix.

# %%
# Helper function to normalise the A matrix
def symmetric_normalize(A_tilde):
    """
    Performs symmetric normalization of A_tilde (Adj. matrix with self loops):
      A_norm = D^{-1/2} * A_tilde * D^{-1/2}
    Where D_{ii} = sum of row i in A_tilde.

    A_tilde (N, N): Adj. matrix with self loops
    Returns:
      A_norm : (N, N)
    """

    eps = 1e-5
    d = A_tilde.sum(dim=1) + eps
    D_inv = torch.diag(torch.pow(d, -0.5))
    return D_inv @ A_tilde @ D_inv


def patch_A_matrix(A):
    """Patches the A matrix"""
    A = A + torch.eye(A.size(0))
    A = symmetric_normalize(A)
    return A

def patch_A_for_dataset(dataset):
    """Patches the A matrix for a dataset (list)"""
    dataset = [ (X, patch_A_matrix(A), y) for X,A,y in dataset]
    return dataset

# %% [markdown]
# ### Helper function for plotting training runs.

# %%
# Helper function for plotting:

def plot_training_and_validation(training_losses, validation_losses, aggregation="mean", graph1_label="Training Accuracy", graph2_label="Validation Accuracy", x_label="Epoch",title=None):
    """
    Plots the validation accuracy and training loss over epochs.
    Args:
        validation_losses: List of validation accuracies (or losses)
        training_losses: List of training accuracies (or losses)
        aggregation: Aggregation method used (default: "mean")
    """
    plt.figure(figsize=(10, 6))
    
    # Create figure with two y-axes
    fig, ax1 = plt.subplots(figsize=(10, 6))
    ax2 = ax1.twinx()
    
    # Plot training loss on the first y-axis
    epochs = range(1, len(training_losses) + 1)
    line1 = ax1.plot(epochs, training_losses, 'r-', label=f'{graph1_label}')
    ax1.set_xlabel(f"x_label")
    ax1.set_ylabel(f'{graph1_label}', color='r')
    ax1.tick_params(axis='y', labelcolor='r')
    
    # Plot validation accuracy on the second y-axis
    line2 = ax2.plot(epochs, validation_losses, 'b-', label=f'{graph2_label}')
    ax2.set_ylabel(f'{graph2_label}', color='b')
    ax2.tick_params(axis='y', labelcolor='b')
    
    # Add title and grid
    if not title:
        title = f'Training Accuracy and Validation Accuracy Over Time\nAggregation: {aggregation}'
    plt.title(title)

    ax1.grid(True)
    
    # Add legend
    lines = line1 + line2
    labels = [l.get_label() for l in lines]
    ax1.legend(lines, labels, loc='upper right')
    
    plt.tight_layout()
    plt.show()

# %% [markdown]
# ### Provided GCN Code

# %%
#Provided GCN Implementation
class GCNLayer(nn.Module):
    """
    A single layer of a Graph Convolutional Network (GCN).
    """
    def __init__(self, input_dim, output_dim, use_nonlinearity=True):
        super(GCNLayer, self).__init__()
        self.use_nonlinearity = use_nonlinearity
        self.Omega = nn.Parameter(torch.randn(input_dim, output_dim) * torch.sqrt(torch.tensor(2.0) / (input_dim + output_dim)))
        self.beta = nn.Parameter(torch.zeros(output_dim))

    def forward(self, H_k, A_normalized):
        agg = torch.matmul(A_normalized, H_k) # local agg
        H_k_next = torch.matmul(agg, self.Omega) + self.beta
        return F.relu(H_k_next) if self.use_nonlinearity else H_k_next

class GraphNeuralNetwork(nn.Module):
    """
    A simple Graph Neural Network model using two layers of Graph Convolutional Network (GCN)
    for binary classification. The sigmoid activation is applied in the output layer only if
    use_nonlinearity is set to True.
    """
    def __init__(self, input_dim, hidden_dim):
        super(GraphNeuralNetwork, self).__init__()

        # Define GCN layers
        self.gcn1 = GCNLayer(input_dim, hidden_dim, True)
        self.gcn2 = GCNLayer(hidden_dim, 1, False)

    def forward(self, A, X, **kwargs):
        # Pass through GCN layers
        H1 = self.gcn1(X, A)
        H2 = self.gcn2(H1, A)  # Output shape: (num_nodes, 1)

        output = torch.sigmoid(H2)  # Sigmoid activation per node
        if torch.isnan(output).any():
            output = torch.where(torch.isnan(output), torch.zeros_like(output), output)

        if kwargs.get("return_embeddings", None):
            return output, (H1, H2)
        else:
            return output

# %% [markdown]
# ### Helper functions for training GCN on a graph

# %%
import torch
import torch.optim as optim
import torch.nn as nn
from torch.nn.functional import binary_cross_entropy
from sklearn.metrics import accuracy_score, classification_report,precision_recall_fscore_support

def train_model(
    model,
    G_train,
    G_val,
    num_epochs=10,
    lr=0.0001,
    verbose=True,
    **kwargs,
):
    """
    Train the model, validate every 'validate_every' epochs, and pick the 
    checkpoint with best validation accuracy.

    Parameters:
    -----------
    model : torch.nn.Module
        The PyTorch model to train.
    G_train  = (X_train,A_train,y_train) : input
        the Graph 1
    Y_train = (X_val,A_val,y_val)
        the Graph 2
    num_epochs : int
        Number of training epochs.
    lr : float
        Learning rate for the optimizer.
    verbose: bool
        whether to display the loss, f1 and val_f1


    Returns:
    --------
    loss_history : list
        The training loss history across epochs.
    f1_train_history : list
        train F1s during training
    f1_val_history : list
        val F1s during training
    """
    X_train, A_train, y_train = G_train
    X_val, A_val, y_val = G_val

    model.train()
    optimizer = optim.AdamW(model.parameters(), lr=lr)
    loss_history = []
    train_f1_history = []
    validation_f1_history = []

    for epoch in range(num_epochs):
        # A single Epoch training.
        # TRAINING
        model.train()
        optimizer.zero_grad()
        if kwargs.get("return_embeddings", None):
            out, embeddings= model(A_train, X_train, **kwargs)
        else:
            out = model(A_train, X_train, **kwargs)
        out = out.squeeze(-1)  # shape: (N,) if needed
        y_float = y_train.float()  # for BCE

        # Compute training loss
        loss = binary_cross_entropy(out, y_float)
        loss.backward()

        # torch.nn.utils.clip_grad_norm_(model.parameters(), max_norm=1.0)
        optimizer.step()

        # Record training loss
        loss_value = loss.item()
        
        # EVALUATION
        loss_history.append(loss_value)
        train_prec, train_rec, train_f1, _ = evaluate_model(model, X_train, A_train, y_train)
        val_prec, val_rec, val_f1, _ = evaluate_model(model,  X_val, A_val, y_val)

        train_f1_history.append(train_f1)
        validation_f1_history.append(val_f1)                     
        # Evaluating the model
        if verbose:
            print(f"Epoch {epoch+1}, Training Loss: {loss_value}, Train F1: {train_f1:.4f}, Validation F1: {val_f1:.4f}")
            
    if kwargs.get("return_embeddings", None):
        return loss_history, train_f1_history, validation_f1_history, embeddings
    else:
        return loss_history, train_f1_history, validation_f1_history


@torch.no_grad()
def evaluate_model(model, X,A,y, **kwargs):
    """
    Runs forward pass, calculates binary predictions (threshold=0.5),
    and returns the accuracy score.
    """
    model.eval()
    if kwargs.get("return_embeddings", None):
        out,_ = model(A,X,**kwargs)  # shape: (N, 1)
    else:
        out = model(A,X,**kwargs)  # shape: (N, 1)
    out = out.squeeze(-1)  # shape: (N,)
    preds = (out >= 0.5).long()

    y_true = y.cpu().numpy()
    y_pred = preds.cpu().numpy()

    return precision_recall_fscore_support(y_true, y_pred, average="micro")

# %% [markdown]
# ### Q3.2.a - Implementation of Layered GCN
#
#
# • Implement a GCN where layers can be passed as input parameter and that can return all
# embedding layers. (If you will not be able to do so, to get results implement one class per
# layer).
#
# • Train the GCN on G1 and G2 independently. Plot your results. (Note: you don’t need to
# get a high performance at this stage, just make sure it trains).

# %%
# SOLUTION Q3.2.a
# ####################################################
# MODIFY THE CODE BELOW 
# ####################################################  
class LayeredGCN(nn.Module):
    """
    A simple Graph Neural Network model using two layers of Graph Convolutional Network (GCN)
    for binary classification. The sigmoid activation is applied in the output layer only if
    use_nonlinearity is set to True.
    """
    def __init__(self, input_dim, hidden_dim, num_layers=2, output_dim=2):
        super(LayeredGCN, self).__init__()
        self.num_layers = num_layers
        self.layers = nn.ModuleList()
        
        # Input layer
        self.layers.append(GCNLayer(input_dim, hidden_dim, True))
        
        # Hidden layers
        for _ in range(num_layers - 2):
            self.layers.append(GCNLayer(hidden_dim, hidden_dim, True))
        
        # Final layer
        self.layers.append(GCNLayer(hidden_dim, output_dim, True))

        self.output_layer = GCNLayer(output_dim, 1, False)

    def forward(self, A, X, **kwargs):

        # Forward pass through each layer
        graph_embedding = []
        H = X
        for layer in self.layers:
            H = layer(H, A)
            graph_embedding.append(H)

        H = self.output_layer(H, A)

        # Sigmoid activation
        graph_output = torch.sigmoid(H)

        if kwargs.get("return_embeddings", None):
            return graph_output, graph_embedding
        else:
            return graph_output

# ####################################################
# END OF MODIFICATION
# ####################################################

# %% [markdown]
# ### Code to run the training and evaluation of the model with different number of layers.
#
# Adapt it as needed.

# %%
SEED = 42

def set_seed(seed=42):
    random.seed(seed)
    np.random.seed(seed)
    torch.manual_seed(seed)
    if torch.cuda.is_available():
        torch.cuda.manual_seed_all(seed)

    torch.backends.cudnn.deterministic = True
    torch.backends.cudnn.benchmark = False
    
set_seed(SEED)

# Load data
G1_train = read_json_data(G1_TRAIN_DATA_PATH, has_label=True) #returns a list of (X,A,y) - features, Adj Matrix, per Graph label
G1_eval = read_json_data(G1_EVAL_DATA_PATH, has_label=True) #returns a list of (X,A,y) - features, Adj Matrix, per Graph label

G2_train = read_json_data(G2_TRAIN_DATA_PATH, has_label=True) #returns a list of (X,A,y) - features, Adj Matrix, per Graph label
G2_eval = read_json_data(G2_EVAL_DATA_PATH, has_label=True) #returns a list of (X,A,y) - features, Adj Matrix, per Graph label


# Patch A
G1_train = (G1_train[0], patch_A_matrix(G1_train[1]), G1_train[2])
G1_eval = (G1_eval[0], patch_A_matrix(G1_eval[1]), G1_eval[2])

G2_train = (G2_train[0], patch_A_matrix(G2_train[1]), G2_train[2])
G2_eval = (G2_eval[0], patch_A_matrix(G2_eval[1]), G2_eval[2])

# Initialising the model
input_dim = 10
hidden_dim = 8
for num_layers in [2, 3, 4, 5, 6]:
    model = LayeredGCN(input_dim, hidden_dim, num_layers=num_layers)

    losses, train_f1, val_f1 = train_model(
        model,
        G1_train,
        G1_eval,
        num_epochs=200,
        lr=0.0005,
        verbose=False,
    )
    plot_training_and_validation(losses, val_f1, graph1_label="Training Loss", graph2_label="Validation F1-score", title=f"Training Loss and Validation F1 Over Time for Graph 1; Number of Layers{num_layers}", x_label="Epoch")


    model = LayeredGCN(input_dim, hidden_dim, num_layers=num_layers)

    losses, train_f2, val_f2 = train_model(
        model,
        G2_train,
        G2_eval,
        num_epochs=200,
        lr=0.0005,
        verbose=False,
    )
    plot_training_and_validation(losses, val_f2, graph1_label="Training Loss", graph2_label="Validation F1-score", title=f"Training Loss and Validation F1 Over Time for Graph 2; Number of Layers{num_layers}", x_label="Epoch")

# %% [markdown]
# ### Q3.2.b - Plotting of t-SNE Embeddings for Graph Neural Networks
#
# • Use t-SNE to visualize the node embeddings for the final layer of the GCN for each graph
# for both training and evaluation data, use the labels as class labels for the tsne plot.

# %%
# SOLUTION Q3.5.b
# ####################################################
# MODIFY THE CODE BELOW 
# ####################################################  

def plot_tsne(embeddings, labels=None, layer_to_plot=-1, subject="Node Embeddings"):
    """
    embeddings (list):
        list of embeddings (layer 2, ..., layer N)
        NOTE: for num_layer = 1 there is no embedding (as it is just the input)
    
    labels (list):
        list of labels
    
    layer_to_plot (int):
        which layer to plot (default -1, i.e. the last layer)
    """
    if not embeddings:
        raise ValueError("Embeddings list is empty.")
    
    # Select the embedding for the chosen layer
    chosen_embedding = embeddings[layer_to_plot]
    
    if isinstance(chosen_embedding, torch.Tensor):
        chosen_embedding = chosen_embedding.detach().cpu().numpy()
    
    # Adjust perplexity dynamically
    perplexity = min(30, len(chosen_embedding) - 1)
    
    # Perform t-SNE dimensionality reduction
    tsne = TSNE(n_components=2, random_state=42, perplexity=perplexity)
    reduced_embeddings = tsne.fit_transform(chosen_embedding)
    
    # Plot the embeddings
    plt.figure(figsize=(8, 6))
    
    if labels is not None:
        labels = np.array(labels)
        scatter = plt.scatter(reduced_embeddings[:, 0], reduced_embeddings[:, 1], c=labels, cmap='jet', alpha=0.7)
        plt.colorbar(scatter, label="Labels")
    else:
        plt.scatter(reduced_embeddings[:, 0], reduced_embeddings[:, 1], alpha=0.7)
    
    plt.title(f"t-SNE Visualization of {subject} (Layer {layer_to_plot})")
    plt.xlabel("t-SNE Dim 1")
    plt.ylabel("t-SNE Dim 2")
    plt.show()

# ####################################################
# END OF MODIFICATION
# ####################################################

# %% [markdown]
# ### Plotting the t-SNE embeddings
#
# Adapt as needed.

# %%
set_seed(42)

# Load data
G1_train = read_json_data(G1_TRAIN_DATA_PATH, has_label=True) #returns a list of (X,A,y) - features, Adj Matrix, per Graph label
G1_eval = read_json_data(G1_EVAL_DATA_PATH, has_label=True) #returns a list of (X,A,y) - features, Adj Matrix, per Graph label

G2_train = read_json_data(G2_TRAIN_DATA_PATH, has_label=True) #returns a list of (X,A,y) - features, Adj Matrix, per Graph label
G2_eval = read_json_data(G2_EVAL_DATA_PATH, has_label=True) #returns a list of (X,A,y) - features, Adj Matrix, per Graph label

# Initialising the model
input_dim = 10
hidden_dim = 8
num_layers = 3
model = LayeredGCN(input_dim, hidden_dim, num_layers=num_layers)

losses, _, val_f1, last_embeddings_g1_train = train_model(
    model,
    G1_train,
    G1_eval,
    num_epochs=200,
    lr=0.0005,
    verbose=True,
    return_embeddings = True #NOTE we added this parameter
)

with torch.no_grad():
    _, last_embeddings_g1_eval = model(A=G1_eval[1], X=G1_eval[0], return_embeddings=True)

# plot_training_and_validation(losses, val_f1)

model = LayeredGCN(input_dim, hidden_dim, num_layers=num_layers)

_, _, _, last_embeddings_g2_train = train_model(model, G2_train, G2_eval, num_epochs=200, lr=0.0005, verbose=False, return_embeddings=True)

with torch.no_grad():
    _, last_embeddings_g2_eval = model(A=G2_eval[1], X=G2_eval[0], return_embeddings=True)



_,_,y_g1_train = G1_train
_,_,y_g1_eval = G1_eval
_,_,y_g2_train = G2_train
_,_,y_g2_eval = G2_eval

plot_tsne(last_embeddings_g1_train, y_g1_train, layer_to_plot=-2, subject="Node Embeddings in Graph 1 at Training")
plot_tsne(last_embeddings_g1_eval, y_g1_eval, layer_to_plot=-2, subject="Node Embeddings in Graph 1 at Evaulation")
plot_tsne(last_embeddings_g2_train, y_g2_train, layer_to_plot=-2, subject="Node Embeddings in Graph 2 at Training")
plot_tsne(last_embeddings_g2_eval, y_g2_eval, layer_to_plot=-2, subject="Node Embeddings in Graph 2 at Evaluation")
# Out:
# Epoch 1, Training Loss: 6.331419467926025, Train F1: 0.4625, Validation F1: 0.5000
# Epoch 2, Training Loss: 6.273720741271973, Train F1: 0.4625, Validation F1: 0.5000
# Epoch 3, Training Loss: 6.216290473937988, Train F1: 0.4625, Validation F1: 0.5000
# Epoch 4, Training Loss: 6.159153938293457, Train F1: 0.4625, Validation F1: 0.5000
# Epoch 5, Training Loss: 6.1024065017700195, Train F1: 0.4625, Validation F1: 0.5000
# Epoch 6, Training Loss: 6.045904636383057, Train F1: 0.4625, Validation F1: 0.5000
# Epoch 7, Training Loss: 5.989638328552246, Train F1: 0.4625, Validation F1: 0.5000
# Epoch 8, Training Loss: 5.933669567108154, Train F1: 0.4625, Validation F1: 0.5000
# Epoch 9, Training Loss: 5.878208637237549, Train F1: 0.4625, Validation F1: 0.5000
# Epoch 10, Training Loss: 5.823331356048584, Train F1: 0.4625, Validation F1: 0.5000
# Epoch 11, Training Loss: 5.7688493728637695, Train F1: 0.4625, Validation F1: 0.5000
# Epoch 12, Training Loss: 5.714608669281006, Train F1: 0.4625, Validation F1: 0.5000
# Epoch 13, Training Loss: 5.660593032836914, Train F1: 0.4625, Validation F1: 0.5000
# Epoch 14, Training Loss: 5.606849670410156, Train F1: 0.4625, Validation F1: 0.5000
# Epoch 15, Training Loss: 5.553359031677246, Train F1: 0.4625, Validation F1: 0.5000
# Epoch 16, Training Loss: 5.500158309936523, Train F1: 0.4625, Validation F1: 0.5000
# Epoch 17, Training Loss: 5.447449207305908, Train F1: 0.4625, Validation F1: 0.5000
# Epoch 18, Training Loss: 5.395316123962402, Train F1: 0.4625, Validation F1: 0.5000
# Epoch 19, Training Loss: 5.343501091003418, Train F1: 0.4625, Validation F1: 0.5000
# Epoch 20, Training Loss: 5.291937828063965, Train F1: 0.4625, Validation F1: 0.5000
# Epoch 21, Training Loss: 5.240793704986572, Train F1: 0.4625, Validation F1: 0.5000
# Epoch 22, Training Loss: 5.189947605133057, Train F1: 0.4625, Validation F1: 0.5000
# Epoch 23, Training Loss: 5.139595985412598, Train F1: 0.4625, Validation F1: 0.5000
# Epoch 24, Training Loss: 5.089592933654785, Train F1: 0.4625, Validation F1: 0.5000
# Epoch 25, Training Loss: 5.039951801300049, Train F1: 0.4625, Validation F1: 0.5000
# Epoch 26, Training Loss: 4.990766525268555, Train F1: 0.4625, Validation F1: 0.5000
# Epoch 27, Training Loss: 4.942238807678223, Train F1: 0.4625, Validation F1: 0.5000
# Epoch 28, Training Loss: 4.894205570220947, Train F1: 0.4625, Validation F1: 0.5000
# Epoch 29, Training Loss: 4.846501350402832, Train F1: 0.4625, Validation F1: 0.5000
# Epoch 30, Training Loss: 4.7990522384643555, Train F1: 0.4625, Validation F1: 0.5000
# Epoch 31, Training Loss: 4.751908779144287, Train F1: 0.4625, Validation F1: 0.5000
# Epoch 32, Training Loss: 4.705065727233887, Train F1: 0.4625, Validation F1: 0.5000
# Epoch 33, Training Loss: 4.658573150634766, Train F1: 0.4625, Validation F1: 0.5000
# Epoch 34, Training Loss: 4.612439155578613, Train F1: 0.4625, Validation F1: 0.5000
# Epoch 35, Training Loss: 4.566652297973633, Train F1: 0.4625, Validation F1: 0.5000
# Epoch 36, Training Loss: 4.521157741546631, Train F1: 0.4625, Validation F1: 0.5000
# Epoch 37, Training Loss: 4.475935935974121, Train F1: 0.4625, Validation F1: 0.5000
# Epoch 38, Training Loss: 4.431262016296387, Train F1: 0.4625, Validation F1: 0.5000
# Epoch 39, Training Loss: 4.386948585510254, Train F1: 0.4625, Validation F1: 0.5000
# Epoch 40, Training Loss: 4.342888832092285, Train F1: 0.4625, Validation F1: 0.5000
# Epoch 41, Training Loss: 4.2990827560424805, Train F1: 0.4625, Validation F1: 0.5000
# Epoch 42, Training Loss: 4.255533695220947, Train F1: 0.4625, Validation F1: 0.5000
# Epoch 43, Training Loss: 4.21225118637085, Train F1: 0.4625, Validation F1: 0.5000
# Epoch 44, Training Loss: 4.169231414794922, Train F1: 0.4625, Validation F1: 0.5000
# Epoch 45, Training Loss: 4.126458168029785, Train F1: 0.4625, Validation F1: 0.5000
# Epoch 46, Training Loss: 4.083874702453613, Train F1: 0.4625, Validation F1: 0.5000
# Epoch 47, Training Loss: 4.041519641876221, Train F1: 0.4625, Validation F1: 0.5000
# Epoch 48, Training Loss: 3.9995059967041016, Train F1: 0.4625, Validation F1: 0.5000
# Epoch 49, Training Loss: 3.9578685760498047, Train F1: 0.4625, Validation F1: 0.5000
# Epoch 50, Training Loss: 3.916456937789917, Train F1: 0.4625, Validation F1: 0.5000
# Epoch 51, Training Loss: 3.875279664993286, Train F1: 0.4625, Validation F1: 0.5000
# Epoch 52, Training Loss: 3.8343358039855957, Train F1: 0.4625, Validation F1: 0.5000
# Epoch 53, Training Loss: 3.793586254119873, Train F1: 0.4625, Validation F1: 0.5000
# Epoch 54, Training Loss: 3.753136396408081, Train F1: 0.4625, Validation F1: 0.5000
# Epoch 55, Training Loss: 3.7130637168884277, Train F1: 0.4625, Validation F1: 0.5000
# Epoch 56, Training Loss: 3.673313617706299, Train F1: 0.4625, Validation F1: 0.5000
# Epoch 57, Training Loss: 3.634014129638672, Train F1: 0.4625, Validation F1: 0.5000
# Epoch 58, Training Loss: 3.5950686931610107, Train F1: 0.4625, Validation F1: 0.5000
# Epoch 59, Training Loss: 3.556612014770508, Train F1: 0.4625, Validation F1: 0.5000
# Epoch 60, Training Loss: 3.518658399581909, Train F1: 0.4625, Validation F1: 0.5000
# Epoch 61, Training Loss: 3.4812088012695312, Train F1: 0.4625, Validation F1: 0.5000
# Epoch 62, Training Loss: 3.4440155029296875, Train F1: 0.4625, Validation F1: 0.5000
# Epoch 63, Training Loss: 3.4070892333984375, Train F1: 0.4625, Validation F1: 0.5000
# Epoch 64, Training Loss: 3.3705172538757324, Train F1: 0.4625, Validation F1: 0.5000
# Epoch 65, Training Loss: 3.334196090698242, Train F1: 0.4625, Validation F1: 0.5000
# Epoch 66, Training Loss: 3.298114776611328, Train F1: 0.4625, Validation F1: 0.5000
# Epoch 67, Training Loss: 3.2622885704040527, Train F1: 0.4625, Validation F1: 0.5000
# Epoch 68, Training Loss: 3.2266488075256348, Train F1: 0.4625, Validation F1: 0.5000
# Epoch 69, Training Loss: 3.1911778450012207, Train F1: 0.4625, Validation F1: 0.5000
# Epoch 70, Training Loss: 3.156033992767334, Train F1: 0.4625, Validation F1: 0.5000
# Epoch 71, Training Loss: 3.121166229248047, Train F1: 0.4625, Validation F1: 0.5000
# Epoch 72, Training Loss: 3.0865776538848877, Train F1: 0.4625, Validation F1: 0.5000
# Epoch 73, Training Loss: 3.052229404449463, Train F1: 0.4625, Validation F1: 0.5000
# Epoch 74, Training Loss: 3.0181994438171387, Train F1: 0.4625, Validation F1: 0.5000
# Epoch 75, Training Loss: 2.9845473766326904, Train F1: 0.4625, Validation F1: 0.5000
# Epoch 76, Training Loss: 2.9511818885803223, Train F1: 0.4625, Validation F1: 0.5000
# Epoch 77, Training Loss: 2.918013095855713, Train F1: 0.4625, Validation F1: 0.5000
# Epoch 78, Training Loss: 2.885040521621704, Train F1: 0.4625, Validation F1: 0.5000
# Epoch 79, Training Loss: 2.852313756942749, Train F1: 0.4625, Validation F1: 0.5000
# Epoch 80, Training Loss: 2.8199658393859863, Train F1: 0.4625, Validation F1: 0.5000
# Epoch 81, Training Loss: 2.787848711013794, Train F1: 0.4625, Validation F1: 0.5000
# Epoch 82, Training Loss: 2.7561802864074707, Train F1: 0.4625, Validation F1: 0.5000
# Epoch 83, Training Loss: 2.7247583866119385, Train F1: 0.4625, Validation F1: 0.5000
# Epoch 84, Training Loss: 2.6935551166534424, Train F1: 0.4625, Validation F1: 0.5000
# Epoch 85, Training Loss: 2.662602424621582, Train F1: 0.4625, Validation F1: 0.5000
# Epoch 86, Training Loss: 2.6318769454956055, Train F1: 0.4625, Validation F1: 0.5000
# Epoch 87, Training Loss: 2.6013612747192383, Train F1: 0.4625, Validation F1: 0.5000
# Epoch 88, Training Loss: 2.571052074432373, Train F1: 0.4625, Validation F1: 0.5000
# Epoch 89, Training Loss: 2.5409858226776123, Train F1: 0.4625, Validation F1: 0.5000
# Epoch 90, Training Loss: 2.5112152099609375, Train F1: 0.4625, Validation F1: 0.5000
# Epoch 91, Training Loss: 2.481693744659424, Train F1: 0.4625, Validation F1: 0.5000
# Epoch 92, Training Loss: 2.4523777961730957, Train F1: 0.4625, Validation F1: 0.5000
# Epoch 93, Training Loss: 2.4232850074768066, Train F1: 0.4625, Validation F1: 0.5000
# Epoch 94, Training Loss: 2.3944895267486572, Train F1: 0.4625, Validation F1: 0.5000
# Epoch 95, Training Loss: 2.3659169673919678, Train F1: 0.4625, Validation F1: 0.5000
# Epoch 96, Training Loss: 2.3375449180603027, Train F1: 0.4625, Validation F1: 0.5000
# Epoch 97, Training Loss: 2.3093433380126953, Train F1: 0.4625, Validation F1: 0.5000
# Epoch 98, Training Loss: 2.281364917755127, Train F1: 0.4625, Validation F1: 0.5000
# Epoch 99, Training Loss: 2.253580331802368, Train F1: 0.4625, Validation F1: 0.5000
# Epoch 100, Training Loss: 2.225964069366455, Train F1: 0.4625, Validation F1: 0.5000
# Epoch 101, Training Loss: 2.198448896408081, Train F1: 0.4625, Validation F1: 0.5000
# Epoch 102, Training Loss: 2.1711230278015137, Train F1: 0.4625, Validation F1: 0.5000
# Epoch 103, Training Loss: 2.144066572189331, Train F1: 0.4625, Validation F1: 0.5000
# Epoch 104, Training Loss: 2.1172335147857666, Train F1: 0.4625, Validation F1: 0.5000
# Epoch 105, Training Loss: 2.0906128883361816, Train F1: 0.4625, Validation F1: 0.5000
# Epoch 106, Training Loss: 2.0641627311706543, Train F1: 0.4625, Validation F1: 0.5000
# Epoch 107, Training Loss: 2.037914514541626, Train F1: 0.4625, Validation F1: 0.5000
# Epoch 108, Training Loss: 2.011958360671997, Train F1: 0.4625, Validation F1: 0.5000
# Epoch 109, Training Loss: 1.9862388372421265, Train F1: 0.4625, Validation F1: 0.5000
# Epoch 110, Training Loss: 1.9607385396957397, Train F1: 0.4625, Validation F1: 0.5000
# Epoch 111, Training Loss: 1.9354616403579712, Train F1: 0.4625, Validation F1: 0.5000
# Epoch 112, Training Loss: 1.9104207754135132, Train F1: 0.4625, Validation F1: 0.5000
# Epoch 113, Training Loss: 1.8856298923492432, Train F1: 0.4625, Validation F1: 0.5000
# Epoch 114, Training Loss: 1.8610541820526123, Train F1: 0.4625, Validation F1: 0.5000
# Epoch 115, Training Loss: 1.836683988571167, Train F1: 0.4625, Validation F1: 0.5000
# Epoch 116, Training Loss: 1.8125814199447632, Train F1: 0.4625, Validation F1: 0.5000
# Epoch 117, Training Loss: 1.788770318031311, Train F1: 0.4625, Validation F1: 0.5000
# Epoch 118, Training Loss: 1.765148401260376, Train F1: 0.4625, Validation F1: 0.5000
# Epoch 119, Training Loss: 1.741755485534668, Train F1: 0.4625, Validation F1: 0.5000
# Epoch 120, Training Loss: 1.7185465097427368, Train F1: 0.4625, Validation F1: 0.5000
# Epoch 121, Training Loss: 1.6956068277359009, Train F1: 0.4625, Validation F1: 0.5000
# Epoch 122, Training Loss: 1.6728875637054443, Train F1: 0.4625, Validation F1: 0.5000
# Epoch 123, Training Loss: 1.6503959894180298, Train F1: 0.4625, Validation F1: 0.5000
# Epoch 124, Training Loss: 1.6281484365463257, Train F1: 0.4625, Validation F1: 0.5000
# Epoch 125, Training Loss: 1.6061279773712158, Train F1: 0.4625, Validation F1: 0.5000
# Epoch 126, Training Loss: 1.5843541622161865, Train F1: 0.4625, Validation F1: 0.5000
# Epoch 127, Training Loss: 1.5628459453582764, Train F1: 0.4625, Validation F1: 0.5000
# Epoch 128, Training Loss: 1.541725516319275, Train F1: 0.4625, Validation F1: 0.5000
# Epoch 129, Training Loss: 1.5208574533462524, Train F1: 0.4625, Validation F1: 0.5000
# Epoch 130, Training Loss: 1.5001394748687744, Train F1: 0.4625, Validation F1: 0.5000
# Epoch 131, Training Loss: 1.4796607494354248, Train F1: 0.4625, Validation F1: 0.5000
# Epoch 132, Training Loss: 1.459320306777954, Train F1: 0.4625, Validation F1: 0.5000
# Epoch 133, Training Loss: 1.439203143119812, Train F1: 0.4625, Validation F1: 0.5000
# Epoch 134, Training Loss: 1.4191868305206299, Train F1: 0.4625, Validation F1: 0.5000
# Epoch 135, Training Loss: 1.3994107246398926, Train F1: 0.4625, Validation F1: 0.5000
# Epoch 136, Training Loss: 1.3798773288726807, Train F1: 0.4625, Validation F1: 0.5000
# Epoch 137, Training Loss: 1.3605942726135254, Train F1: 0.4625, Validation F1: 0.5000
# Epoch 138, Training Loss: 1.3415685892105103, Train F1: 0.4625, Validation F1: 0.5000
# Epoch 139, Training Loss: 1.322816014289856, Train F1: 0.4625, Validation F1: 0.5000
# Epoch 140, Training Loss: 1.3042628765106201, Train F1: 0.4625, Validation F1: 0.5000
# Epoch 141, Training Loss: 1.2859716415405273, Train F1: 0.4625, Validation F1: 0.5000
# Epoch 142, Training Loss: 1.2680262327194214, Train F1: 0.4625, Validation F1: 0.5000
# Epoch 143, Training Loss: 1.2503708600997925, Train F1: 0.4625, Validation F1: 0.5000
# Epoch 144, Training Loss: 1.233018159866333, Train F1: 0.4625, Validation F1: 0.5000
# Epoch 145, Training Loss: 1.2160123586654663, Train F1: 0.4625, Validation F1: 0.5000
# Epoch 146, Training Loss: 1.1991262435913086, Train F1: 0.4625, Validation F1: 0.5000
# Epoch 147, Training Loss: 1.1822564601898193, Train F1: 0.4625, Validation F1: 0.5000
# Epoch 148, Training Loss: 1.1656023263931274, Train F1: 0.4625, Validation F1: 0.5000
# Epoch 149, Training Loss: 1.1492704153060913, Train F1: 0.4625, Validation F1: 0.5000
# Epoch 150, Training Loss: 1.1332905292510986, Train F1: 0.4625, Validation F1: 0.5000
# Epoch 151, Training Loss: 1.1176007986068726, Train F1: 0.4625, Validation F1: 0.5000
# Epoch 152, Training Loss: 1.1022212505340576, Train F1: 0.4625, Validation F1: 0.5000
# Epoch 153, Training Loss: 1.0872292518615723, Train F1: 0.4625, Validation F1: 0.5000
# Epoch 154, Training Loss: 1.0725194215774536, Train F1: 0.4625, Validation F1: 0.5000
# Epoch 155, Training Loss: 1.0580637454986572, Train F1: 0.4625, Validation F1: 0.5000
# Epoch 156, Training Loss: 1.0439484119415283, Train F1: 0.4625, Validation F1: 0.5000
# Epoch 157, Training Loss: 1.0301777124404907, Train F1: 0.4625, Validation F1: 0.5000
# Epoch 158, Training Loss: 1.0168330669403076, Train F1: 0.4625, Validation F1: 0.5000
# Epoch 159, Training Loss: 1.0038131475448608, Train F1: 0.4625, Validation F1: 0.5000
# Epoch 160, Training Loss: 0.9910483360290527, Train F1: 0.4500, Validation F1: 0.5000
# Epoch 161, Training Loss: 0.978512167930603, Train F1: 0.4625, Validation F1: 0.5000
# Epoch 162, Training Loss: 0.9662879109382629, Train F1: 0.4625, Validation F1: 0.5000
# Epoch 163, Training Loss: 0.9544006586074829, Train F1: 0.4625, Validation F1: 0.5000
# Epoch 164, Training Loss: 0.942621111869812, Train F1: 0.4625, Validation F1: 0.5000
# Epoch 165, Training Loss: 0.9310539364814758, Train F1: 0.4625, Validation F1: 0.5000
# Epoch 166, Training Loss: 0.9197770953178406, Train F1: 0.4625, Validation F1: 0.5000
# Epoch 167, Training Loss: 0.908782958984375, Train F1: 0.4625, Validation F1: 0.5000
# Epoch 168, Training Loss: 0.8980919122695923, Train F1: 0.4625, Validation F1: 0.5000
# Epoch 169, Training Loss: 0.8877040147781372, Train F1: 0.4625, Validation F1: 0.5000
# Epoch 170, Training Loss: 0.8776715397834778, Train F1: 0.4625, Validation F1: 0.5000
# Epoch 171, Training Loss: 0.8679190874099731, Train F1: 0.4625, Validation F1: 0.5000
# Epoch 172, Training Loss: 0.858435332775116, Train F1: 0.4625, Validation F1: 0.5000
# Epoch 173, Training Loss: 0.8492180705070496, Train F1: 0.4625, Validation F1: 0.5000
# Epoch 174, Training Loss: 0.8402680158615112, Train F1: 0.4625, Validation F1: 0.5000
# Epoch 175, Training Loss: 0.8315767049789429, Train F1: 0.4750, Validation F1: 0.5000
# Epoch 176, Training Loss: 0.8231662511825562, Train F1: 0.4750, Validation F1: 0.5000
# Epoch 177, Training Loss: 0.8150109052658081, Train F1: 0.4750, Validation F1: 0.5000
# Epoch 178, Training Loss: 0.8071222305297852, Train F1: 0.4750, Validation F1: 0.5000
# Epoch 179, Training Loss: 0.7995675802230835, Train F1: 0.4750, Validation F1: 0.5000
# Epoch 180, Training Loss: 0.7922462224960327, Train F1: 0.4625, Validation F1: 0.5000
# Epoch 181, Training Loss: 0.7851325869560242, Train F1: 0.4500, Validation F1: 0.5000
# Epoch 182, Training Loss: 0.7782295346260071, Train F1: 0.4500, Validation F1: 0.5000
# Epoch 183, Training Loss: 0.7716143131256104, Train F1: 0.4500, Validation F1: 0.5000
# Epoch 184, Training Loss: 0.7651259303092957, Train F1: 0.4500, Validation F1: 0.5000
# Epoch 185, Training Loss: 0.7587963938713074, Train F1: 0.4500, Validation F1: 0.5000
# Epoch 186, Training Loss: 0.7526339888572693, Train F1: 0.4625, Validation F1: 0.5000
# Epoch 187, Training Loss: 0.7466399669647217, Train F1: 0.4500, Validation F1: 0.4667
# Epoch 188, Training Loss: 0.7408368587493896, Train F1: 0.4500, Validation F1: 0.4667
# Epoch 189, Training Loss: 0.7352156043052673, Train F1: 0.4500, Validation F1: 0.4667
# Epoch 190, Training Loss: 0.729738712310791, Train F1: 0.4500, Validation F1: 0.5000
# Epoch 191, Training Loss: 0.724386990070343, Train F1: 0.4500, Validation F1: 0.5000
# Epoch 192, Training Loss: 0.71916663646698, Train F1: 0.4500, Validation F1: 0.5000
# Epoch 193, Training Loss: 0.7141517400741577, Train F1: 0.4500, Validation F1: 0.5000
# Epoch 194, Training Loss: 0.7092453241348267, Train F1: 0.4500, Validation F1: 0.5000
# Epoch 195, Training Loss: 0.7044351100921631, Train F1: 0.4625, Validation F1: 0.5000
# Epoch 196, Training Loss: 0.6998096704483032, Train F1: 0.4625, Validation F1: 0.5000
# Epoch 197, Training Loss: 0.6952940225601196, Train F1: 0.4625, Validation F1: 0.5000
# Epoch 198, Training Loss: 0.6908362507820129, Train F1: 0.4625, Validation F1: 0.5000
# Epoch 199, Training Loss: 0.686458170413971, Train F1: 0.4875, Validation F1: 0.5000
# Epoch 200, Training Loss: 0.6821668148040771, Train F1: 0.5000, Validation F1: 0.5000

# %% [markdown]
# ### Q3.2.c - Training the Model on Merged Graphs G = G1 ∪ G
#
# • Implement a GCN that trains on both graphs at once. Plot the training curve.
#
# • Compare the performance of G = G1 ∪ G2 against training on G1 and G2, respectively.
#
# • Plot TSNE plots.

# %%
# SOLUTION Q3.2.c
# ####################################################
# MODIFY THE CODE BELOW 
# ####################################################  

# Implement the training of G = {G1 U G2}
def combine_graphs(G1, G2):
    X1, A1, y1 = G1
    X2, A2, y2 = G2

    X_combined = torch.cat([X1, X2], dim=0)

    # Combine the adjacency matrices
    size1, size2 = A1.shape[0], A2.shape[0]
    new_size = size1 + size2  # Assuming nodes are indexed 0,1,2,...

    # Expand matrices to the new unified size
    expanded_A = torch.zeros((new_size, new_size))

    expanded_A[:size1, :size1] = A1
    expanded_A[size1:, size1:] = A2

    y_combined = torch.cat([y1, y2], dim=0)

    return X_combined, expanded_A, y_combined

# In the end return a single function:
def train_G1UG2(G1_train, G1_eval, G2_train, G2_eval, num_epochs=200, lr=0.001, verbose=True, return_embeddings=False):
    """"""
    G_train_combined = combine_graphs(G1_train, G2_train)
    G_eval_combined = combine_graphs(G1_eval, G2_eval)

    input_dim = G_train_combined[0].shape[1]
    hidden_dim = 8
    num_layers = 3

    model = LayeredGCN(input_dim, hidden_dim, num_layers=num_layers)
    results = train_model(
        model,
        G_train_combined,
        G_eval_combined,
        num_epochs=num_epochs,
        lr=lr,
        verbose=verbose,
        return_embeddings = return_embeddings
    )

    return results



# ####################################################
# END OF MODIFICATION
# ####################################################

# %% [markdown]
# ### Running the evaluation.

# %%
# Load data
set_seed(42)
G1_train = read_json_data(G1_TRAIN_DATA_PATH, has_label=True) #returns a list of (X,A,y) - features, Adj Matrix, per Graph label
G1_eval = read_json_data(G1_EVAL_DATA_PATH, has_label=True) #returns a list of (X,A,y) - features, Adj Matrix, per Graph label

G2_train = read_json_data(G2_TRAIN_DATA_PATH, has_label=True) #returns a list of (X,A,y) - features, Adj Matrix, per Graph label
G2_eval = read_json_data(G2_EVAL_DATA_PATH, has_label=True) #returns a list of (X,A,y) - features, Adj Matrix, per Graph label

losses, train_f1, val_f1 = train_G1UG2(G1_train, G1_eval, G2_train, G2_eval, num_epochs=200, lr=0.001, verbose=True)

plot_training_and_validation(losses, val_f1, title="Training Loss and Validation F1 Over Time for G1 U G2", x_label="Epoch")
# Out:
# Epoch 1, Training Loss: 27.54071044921875, Train F1: 0.4875, Validation F1: 0.4333
# Epoch 2, Training Loss: 27.483142852783203, Train F1: 0.4875, Validation F1: 0.4333
# Epoch 3, Training Loss: 27.42618751525879, Train F1: 0.4875, Validation F1: 0.4333
# Epoch 4, Training Loss: 27.369770050048828, Train F1: 0.4875, Validation F1: 0.4333
# Epoch 5, Training Loss: 27.314001083374023, Train F1: 0.4875, Validation F1: 0.4333
# Epoch 6, Training Loss: 27.259225845336914, Train F1: 0.4875, Validation F1: 0.4333
# Epoch 7, Training Loss: 27.2049560546875, Train F1: 0.4875, Validation F1: 0.4333
# Epoch 8, Training Loss: 27.15115737915039, Train F1: 0.4875, Validation F1: 0.4333
# Epoch 9, Training Loss: 27.097991943359375, Train F1: 0.4875, Validation F1: 0.4333
# Epoch 10, Training Loss: 27.04574966430664, Train F1: 0.4875, Validation F1: 0.4333
# Epoch 11, Training Loss: 26.9940242767334, Train F1: 0.4875, Validation F1: 0.4333
# Epoch 12, Training Loss: 26.943042755126953, Train F1: 0.4875, Validation F1: 0.4333
# Epoch 13, Training Loss: 26.892803192138672, Train F1: 0.4875, Validation F1: 0.4333
# Epoch 14, Training Loss: 26.843502044677734, Train F1: 0.4875, Validation F1: 0.4333
# Epoch 15, Training Loss: 26.795085906982422, Train F1: 0.4875, Validation F1: 0.4333
# Epoch 16, Training Loss: 26.74716567993164, Train F1: 0.4875, Validation F1: 0.4333
# Epoch 17, Training Loss: 26.699844360351562, Train F1: 0.4875, Validation F1: 0.4333
# Epoch 18, Training Loss: 26.65311622619629, Train F1: 0.4875, Validation F1: 0.4333
# Epoch 19, Training Loss: 26.607120513916016, Train F1: 0.4875, Validation F1: 0.4333
# Epoch 20, Training Loss: 26.5618896484375, Train F1: 0.4875, Validation F1: 0.4333
# Epoch 21, Training Loss: 26.51715660095215, Train F1: 0.4875, Validation F1: 0.4333
# Epoch 22, Training Loss: 26.472915649414062, Train F1: 0.4875, Validation F1: 0.4333
# Epoch 23, Training Loss: 26.429183959960938, Train F1: 0.4875, Validation F1: 0.4333
# Epoch 24, Training Loss: 26.385961532592773, Train F1: 0.4875, Validation F1: 0.4333
# Epoch 25, Training Loss: 26.343395233154297, Train F1: 0.4875, Validation F1: 0.4333
# Epoch 26, Training Loss: 26.301319122314453, Train F1: 0.4875, Validation F1: 0.4333
# Epoch 27, Training Loss: 26.259765625, Train F1: 0.4875, Validation F1: 0.4333
# Epoch 28, Training Loss: 26.2189884185791, Train F1: 0.4875, Validation F1: 0.4333
# Epoch 29, Training Loss: 26.178701400756836, Train F1: 0.4813, Validation F1: 0.4333
# Epoch 30, Training Loss: 21.025110244750977, Train F1: 0.3875, Validation F1: 0.4333
# Epoch 31, Training Loss: 19.400423049926758, Train F1: 0.3875, Validation F1: 0.4333
# Epoch 32, Training Loss: 19.371387481689453, Train F1: 0.3875, Validation F1: 0.4333
# Epoch 33, Training Loss: 19.343074798583984, Train F1: 0.3875, Validation F1: 0.4333
# Epoch 34, Training Loss: 19.31548500061035, Train F1: 0.3875, Validation F1: 0.4333
# Epoch 35, Training Loss: 19.288599014282227, Train F1: 0.3875, Validation F1: 0.4333
# Epoch 36, Training Loss: 19.262386322021484, Train F1: 0.3875, Validation F1: 0.4333
# Epoch 37, Training Loss: 19.23672866821289, Train F1: 0.3875, Validation F1: 0.4333
# Epoch 38, Training Loss: 19.211776733398438, Train F1: 0.3875, Validation F1: 0.4333
# Epoch 39, Training Loss: 19.187543869018555, Train F1: 0.3875, Validation F1: 0.3833
# Epoch 40, Training Loss: 19.163909912109375, Train F1: 0.3875, Validation F1: 0.3833
# Epoch 41, Training Loss: 19.14089012145996, Train F1: 0.3875, Validation F1: 0.3833
# Epoch 42, Training Loss: 19.118492126464844, Train F1: 0.3875, Validation F1: 0.3833
# Epoch 43, Training Loss: 19.096691131591797, Train F1: 0.3875, Validation F1: 0.3833
# Epoch 44, Training Loss: 19.07539939880371, Train F1: 0.3875, Validation F1: 0.3833
# Epoch 45, Training Loss: 19.054454803466797, Train F1: 0.3875, Validation F1: 0.3833
# Epoch 46, Training Loss: 19.033817291259766, Train F1: 0.3875, Validation F1: 0.3833
# Epoch 47, Training Loss: 19.013463973999023, Train F1: 0.3875, Validation F1: 0.3833
# Epoch 48, Training Loss: 18.993379592895508, Train F1: 0.3875, Validation F1: 0.3833
# Epoch 49, Training Loss: 18.97364616394043, Train F1: 0.3875, Validation F1: 0.3833
# Epoch 50, Training Loss: 18.954242706298828, Train F1: 0.3875, Validation F1: 0.3833
# Epoch 51, Training Loss: 18.93507957458496, Train F1: 0.3875, Validation F1: 0.3833
# Epoch 52, Training Loss: 18.91616439819336, Train F1: 0.3875, Validation F1: 0.3833
# Epoch 53, Training Loss: 18.897634506225586, Train F1: 0.3875, Validation F1: 0.3833
# Epoch 54, Training Loss: 18.879379272460938, Train F1: 0.3875, Validation F1: 0.3833
# Epoch 55, Training Loss: 18.861408233642578, Train F1: 0.3875, Validation F1: 0.3833
# Epoch 56, Training Loss: 18.843719482421875, Train F1: 0.3875, Validation F1: 0.3833
# Epoch 57, Training Loss: 18.826343536376953, Train F1: 0.3875, Validation F1: 0.3833
# Epoch 58, Training Loss: 18.809192657470703, Train F1: 0.3875, Validation F1: 0.3833
# Epoch 59, Training Loss: 18.792282104492188, Train F1: 0.3875, Validation F1: 0.3833
# Epoch 60, Training Loss: 18.775615692138672, Train F1: 0.3875, Validation F1: 0.3833
# Epoch 61, Training Loss: 18.759185791015625, Train F1: 0.3875, Validation F1: 0.3833
# Epoch 62, Training Loss: 18.74291229248047, Train F1: 0.3875, Validation F1: 0.3833
# Epoch 63, Training Loss: 18.72682762145996, Train F1: 0.3875, Validation F1: 0.3833
# Epoch 64, Training Loss: 18.710939407348633, Train F1: 0.3875, Validation F1: 0.3833
# Epoch 65, Training Loss: 18.695205688476562, Train F1: 0.3875, Validation F1: 0.3833
# Epoch 66, Training Loss: 18.679630279541016, Train F1: 0.3875, Validation F1: 0.3833
# Epoch 67, Training Loss: 18.664203643798828, Train F1: 0.3875, Validation F1: 0.3833
# Epoch 68, Training Loss: 18.649005889892578, Train F1: 0.3875, Validation F1: 0.3833
# Epoch 69, Training Loss: 18.634010314941406, Train F1: 0.3875, Validation F1: 0.3833
# Epoch 70, Training Loss: 18.619216918945312, Train F1: 0.3875, Validation F1: 0.3833
# Epoch 71, Training Loss: 18.604568481445312, Train F1: 0.3875, Validation F1: 0.3833
# Epoch 72, Training Loss: 18.59006118774414, Train F1: 0.3875, Validation F1: 0.3833
# Epoch 73, Training Loss: 18.57575035095215, Train F1: 0.3875, Validation F1: 0.3833
# Epoch 74, Training Loss: 18.561626434326172, Train F1: 0.3875, Validation F1: 0.3833
# Epoch 75, Training Loss: 18.54766845703125, Train F1: 0.3875, Validation F1: 0.3833
# Epoch 76, Training Loss: 18.533843994140625, Train F1: 0.3875, Validation F1: 0.3833
# Epoch 77, Training Loss: 18.520160675048828, Train F1: 0.3875, Validation F1: 0.3833
# Epoch 78, Training Loss: 18.506650924682617, Train F1: 0.3875, Validation F1: 0.3833
# Epoch 79, Training Loss: 18.49332618713379, Train F1: 0.3875, Validation F1: 0.3833
# Epoch 80, Training Loss: 18.48019790649414, Train F1: 0.3875, Validation F1: 0.3833
# Epoch 81, Training Loss: 18.467214584350586, Train F1: 0.3875, Validation F1: 0.3833
# Epoch 82, Training Loss: 18.45441246032715, Train F1: 0.3875, Validation F1: 0.3833
# Epoch 83, Training Loss: 18.441781997680664, Train F1: 0.3875, Validation F1: 0.3833
# Epoch 84, Training Loss: 18.429296493530273, Train F1: 0.3875, Validation F1: 0.3833
# Epoch 85, Training Loss: 18.41697120666504, Train F1: 0.3875, Validation F1: 0.3833
# Epoch 86, Training Loss: 18.404794692993164, Train F1: 0.3875, Validation F1: 0.3833
# Epoch 87, Training Loss: 18.392772674560547, Train F1: 0.3875, Validation F1: 0.3833
# Epoch 88, Training Loss: 18.38092803955078, Train F1: 0.3875, Validation F1: 0.3833
# Epoch 89, Training Loss: 18.369232177734375, Train F1: 0.3875, Validation F1: 0.3833
# Epoch 90, Training Loss: 18.357694625854492, Train F1: 0.3875, Validation F1: 0.3833
# Epoch 91, Training Loss: 18.3463134765625, Train F1: 0.3875, Validation F1: 0.3833
# Epoch 92, Training Loss: 18.33511734008789, Train F1: 0.3875, Validation F1: 0.3833
# Epoch 93, Training Loss: 18.324142456054688, Train F1: 0.3875, Validation F1: 0.3833
# Epoch 94, Training Loss: 18.313396453857422, Train F1: 0.3875, Validation F1: 0.3833
# Epoch 95, Training Loss: 18.302831649780273, Train F1: 0.3875, Validation F1: 0.3833
# Epoch 96, Training Loss: 18.29244613647461, Train F1: 0.3875, Validation F1: 0.3833
# Epoch 97, Training Loss: 18.282268524169922, Train F1: 0.3875, Validation F1: 0.3833
# Epoch 98, Training Loss: 18.27228355407715, Train F1: 0.3875, Validation F1: 0.3833
# Epoch 99, Training Loss: 18.262481689453125, Train F1: 0.3875, Validation F1: 0.3833
# Epoch 100, Training Loss: 18.252849578857422, Train F1: 0.3875, Validation F1: 0.3833
# Epoch 101, Training Loss: 18.24339485168457, Train F1: 0.3875, Validation F1: 0.3833
# Epoch 102, Training Loss: 18.234127044677734, Train F1: 0.3875, Validation F1: 0.3833
# Epoch 103, Training Loss: 18.225032806396484, Train F1: 0.3875, Validation F1: 0.3833
# Epoch 104, Training Loss: 18.216176986694336, Train F1: 0.3875, Validation F1: 0.3833
# Epoch 105, Training Loss: 18.207508087158203, Train F1: 0.3875, Validation F1: 0.3833
# Epoch 106, Training Loss: 18.19902229309082, Train F1: 0.3875, Validation F1: 0.3833
# Epoch 107, Training Loss: 18.19071388244629, Train F1: 0.3875, Validation F1: 0.3833
# Epoch 108, Training Loss: 18.182621002197266, Train F1: 0.3875, Validation F1: 0.3833
# Epoch 109, Training Loss: 18.174715042114258, Train F1: 0.3875, Validation F1: 0.3833
# Epoch 110, Training Loss: 18.1669864654541, Train F1: 0.3875, Validation F1: 0.3833
# Epoch 111, Training Loss: 18.159440994262695, Train F1: 0.3875, Validation F1: 0.3833
# Epoch 112, Training Loss: 18.152122497558594, Train F1: 0.3875, Validation F1: 0.3833
# Epoch 113, Training Loss: 18.145034790039062, Train F1: 0.3875, Validation F1: 0.3833
# Epoch 114, Training Loss: 18.13811683654785, Train F1: 0.3875, Validation F1: 0.3833
# Epoch 115, Training Loss: 18.131366729736328, Train F1: 0.3875, Validation F1: 0.3833
# Epoch 116, Training Loss: 18.124849319458008, Train F1: 0.3875, Validation F1: 0.3833
# Epoch 117, Training Loss: 18.118515014648438, Train F1: 0.3875, Validation F1: 0.3833
# Epoch 118, Training Loss: 18.112354278564453, Train F1: 0.3875, Validation F1: 0.3833
# Epoch 119, Training Loss: 18.106380462646484, Train F1: 0.3875, Validation F1: 0.3833
# Epoch 120, Training Loss: 18.10059928894043, Train F1: 0.3875, Validation F1: 0.3833
# Epoch 121, Training Loss: 18.095048904418945, Train F1: 0.3875, Validation F1: 0.3833
# Epoch 122, Training Loss: 18.089704513549805, Train F1: 0.3875, Validation F1: 0.3833
# Epoch 123, Training Loss: 18.084556579589844, Train F1: 0.3875, Validation F1: 0.3833
# Epoch 124, Training Loss: 18.079607009887695, Train F1: 0.3875, Validation F1: 0.3833
# Epoch 125, Training Loss: 18.074817657470703, Train F1: 0.3875, Validation F1: 0.3833
# Epoch 126, Training Loss: 18.070194244384766, Train F1: 0.3875, Validation F1: 0.3833
# Epoch 127, Training Loss: 18.065784454345703, Train F1: 0.3875, Validation F1: 0.3833
# Epoch 128, Training Loss: 18.061511993408203, Train F1: 0.3875, Validation F1: 0.3833
# Epoch 129, Training Loss: 18.057382583618164, Train F1: 0.3875, Validation F1: 0.3833
# Epoch 130, Training Loss: 18.053409576416016, Train F1: 0.3875, Validation F1: 0.3833
# Epoch 131, Training Loss: 18.049564361572266, Train F1: 0.3875, Validation F1: 0.3833
# Epoch 132, Training Loss: 18.04586410522461, Train F1: 0.3875, Validation F1: 0.3833
# Epoch 133, Training Loss: 18.042268753051758, Train F1: 0.3875, Validation F1: 0.3833
# Epoch 134, Training Loss: 18.038782119750977, Train F1: 0.3875, Validation F1: 0.3833
# Epoch 135, Training Loss: 18.035396575927734, Train F1: 0.3875, Validation F1: 0.3833
# Epoch 136, Training Loss: 18.032115936279297, Train F1: 0.3875, Validation F1: 0.3833
# Epoch 137, Training Loss: 18.028947830200195, Train F1: 0.3875, Validation F1: 0.3833
# Epoch 138, Training Loss: 18.025861740112305, Train F1: 0.3812, Validation F1: 0.3833
# Epoch 139, Training Loss: 18.022846221923828, Train F1: 0.3812, Validation F1: 0.3833
# Epoch 140, Training Loss: 18.01993751525879, Train F1: 0.3812, Validation F1: 0.3833
# Epoch 141, Training Loss: 18.01711082458496, Train F1: 0.3812, Validation F1: 0.3833
# Epoch 142, Training Loss: 18.014368057250977, Train F1: 0.3812, Validation F1: 0.3833
# Epoch 143, Training Loss: 18.011707305908203, Train F1: 0.3812, Validation F1: 0.3833
# Epoch 144, Training Loss: 18.009105682373047, Train F1: 0.3812, Validation F1: 0.3833
# Epoch 145, Training Loss: 18.00657081604004, Train F1: 0.3875, Validation F1: 0.3833
# Epoch 146, Training Loss: 18.004100799560547, Train F1: 0.3875, Validation F1: 0.3833
# Epoch 147, Training Loss: 18.001708984375, Train F1: 0.3875, Validation F1: 0.3833
# Epoch 148, Training Loss: 17.999372482299805, Train F1: 0.4000, Validation F1: 0.3833
# Epoch 149, Training Loss: 17.997066497802734, Train F1: 0.4000, Validation F1: 0.3833
# Epoch 150, Training Loss: 17.994787216186523, Train F1: 0.4000, Validation F1: 0.3833
# Epoch 151, Training Loss: 17.992572784423828, Train F1: 0.3937, Validation F1: 0.4000
# Epoch 152, Training Loss: 17.990427017211914, Train F1: 0.4000, Validation F1: 0.4000
# Epoch 153, Training Loss: 17.988323211669922, Train F1: 0.4125, Validation F1: 0.4000
# Epoch 154, Training Loss: 17.98625946044922, Train F1: 0.4188, Validation F1: 0.3833
# Epoch 155, Training Loss: 17.984233856201172, Train F1: 0.4188, Validation F1: 0.3833
# Epoch 156, Training Loss: 17.982242584228516, Train F1: 0.4313, Validation F1: 0.4000
# Epoch 157, Training Loss: 17.98031234741211, Train F1: 0.4375, Validation F1: 0.4000
# Epoch 158, Training Loss: 17.97844696044922, Train F1: 0.4437, Validation F1: 0.4000
# Epoch 159, Training Loss: 17.976654052734375, Train F1: 0.4750, Validation F1: 0.4000
# Epoch 160, Training Loss: 17.97492027282715, Train F1: 0.4813, Validation F1: 0.4000
# Epoch 161, Training Loss: 17.973270416259766, Train F1: 0.4875, Validation F1: 0.3833
# Epoch 162, Training Loss: 17.971736907958984, Train F1: 0.4938, Validation F1: 0.3833
# Epoch 163, Training Loss: 17.970333099365234, Train F1: 0.4938, Validation F1: 0.3833
# Epoch 164, Training Loss: 17.96900749206543, Train F1: 0.5062, Validation F1: 0.3833
# Epoch 165, Training Loss: 17.9677677154541, Train F1: 0.5062, Validation F1: 0.4000
# Epoch 166, Training Loss: 17.966569900512695, Train F1: 0.5250, Validation F1: 0.4000
# Epoch 167, Training Loss: 17.96544647216797, Train F1: 0.5312, Validation F1: 0.4000
# Epoch 168, Training Loss: 17.964481353759766, Train F1: 0.5375, Validation F1: 0.4333
# Epoch 169, Training Loss: 17.963672637939453, Train F1: 0.5437, Validation F1: 0.4333
# Epoch 170, Training Loss: 17.962974548339844, Train F1: 0.5437, Validation F1: 0.4500
# Epoch 171, Training Loss: 17.962331771850586, Train F1: 0.5500, Validation F1: 0.4667
# Epoch 172, Training Loss: 17.961793899536133, Train F1: 0.5500, Validation F1: 0.4667
# Epoch 173, Training Loss: 17.961328506469727, Train F1: 0.5563, Validation F1: 0.4667
# Epoch 174, Training Loss: 17.960905075073242, Train F1: 0.5625, Validation F1: 0.4667
# Epoch 175, Training Loss: 17.96050453186035, Train F1: 0.5625, Validation F1: 0.4667
# Epoch 176, Training Loss: 17.96014976501465, Train F1: 0.5625, Validation F1: 0.4500
# Epoch 177, Training Loss: 17.9598445892334, Train F1: 0.5625, Validation F1: 0.4500
# Epoch 178, Training Loss: 17.959592819213867, Train F1: 0.5625, Validation F1: 0.4667
# Epoch 179, Training Loss: 17.9593505859375, Train F1: 0.5625, Validation F1: 0.4667
# Epoch 180, Training Loss: 17.95911979675293, Train F1: 0.5625, Validation F1: 0.4667
# Epoch 181, Training Loss: 17.95889663696289, Train F1: 0.5625, Validation F1: 0.4667
# Epoch 182, Training Loss: 17.958711624145508, Train F1: 0.5625, Validation F1: 0.4667
# Epoch 183, Training Loss: 17.958566665649414, Train F1: 0.5625, Validation F1: 0.4667
# Epoch 184, Training Loss: 17.958477020263672, Train F1: 0.5625, Validation F1: 0.4667
# Epoch 185, Training Loss: 17.958389282226562, Train F1: 0.5625, Validation F1: 0.4667
# Epoch 186, Training Loss: 17.958301544189453, Train F1: 0.5687, Validation F1: 0.4667
# Epoch 187, Training Loss: 17.95821762084961, Train F1: 0.5687, Validation F1: 0.4667
# Epoch 188, Training Loss: 17.9581356048584, Train F1: 0.5687, Validation F1: 0.4833
# Epoch 189, Training Loss: 17.95806121826172, Train F1: 0.5687, Validation F1: 0.4833
# Epoch 190, Training Loss: 17.95799446105957, Train F1: 0.5687, Validation F1: 0.4833
# Epoch 191, Training Loss: 17.95792007446289, Train F1: 0.5687, Validation F1: 0.4833
# Epoch 192, Training Loss: 17.957847595214844, Train F1: 0.5687, Validation F1: 0.5000
# Epoch 193, Training Loss: 17.957778930664062, Train F1: 0.5687, Validation F1: 0.5000
# Epoch 194, Training Loss: 17.957714080810547, Train F1: 0.5687, Validation F1: 0.5000
# Epoch 195, Training Loss: 17.95764923095703, Train F1: 0.5687, Validation F1: 0.5000
# Epoch 196, Training Loss: 17.957584381103516, Train F1: 0.5687, Validation F1: 0.5000
# Epoch 197, Training Loss: 17.957523345947266, Train F1: 0.5687, Validation F1: 0.5000
# Epoch 198, Training Loss: 17.957462310791016, Train F1: 0.5687, Validation F1: 0.5000
# Epoch 199, Training Loss: 17.9574031829834, Train F1: 0.5687, Validation F1: 0.5000
# Epoch 200, Training Loss: 17.957345962524414, Train F1: 0.5687, Validation F1: 0.5000

# %%
# Comparing Performance
set_seed(42)
G1_train = read_json_data(G1_TRAIN_DATA_PATH, has_label=True) #returns a list of (X,A,y) - features, Adj Matrix, per Graph label
G1_eval = read_json_data(G1_EVAL_DATA_PATH, has_label=True) #returns a list of (X,A,y) - features, Adj Matrix, per Graph label

G2_train = read_json_data(G2_TRAIN_DATA_PATH, has_label=True) #returns a list of (X,A,y) - features, Adj Matrix, per Graph label
G2_eval = read_json_data(G2_EVAL_DATA_PATH, has_label=True) #returns a list of (X,A,y) - features, Adj Matrix, per Graph label

G1UG2_results=[]
G1_results_final=[]
G2_results_final=[]

num_layers = 3

for i in range(10):

    losses, train_f1, val_f1 = train_G1UG2(G1_train, G1_eval, G2_train, G2_eval, num_epochs=200, lr=0.001, verbose=False)
    
    print(f"Iteration {i}: G1UG2 Results: f1={val_f1[-1]}")
    G1UG2_results.append([losses, train_f1, val_f1])

    model = LayeredGCN(input_dim, hidden_dim, num_layers=num_layers)

    losses, train_f1, val_f1 = train_model(
        model,
        G1_train,
        G1_eval,
        num_epochs=200,
        lr=0.0005,
        verbose=False,
    )

    print(f"Iteration {i}: G1 Results: f1={val_f1[-1]}")
    G1_results_final.append([losses, train_f1, val_f1])

    model = LayeredGCN(input_dim, hidden_dim, num_layers=num_layers)

    losses, train_f2, val_f2 = train_model(
        model,
        G2_train,
        G2_eval,
        num_epochs=200,
        lr=0.0005,
        verbose=False,
    )

    print(f"Iteration {i}: G2 Results: f1={val_f1[-1]}")
    G2_results_final.append([losses, train_f1, val_f1])
# Out:
# Iteration 0: G1UG2 Results: f1=0.5
# Iteration 0: G1 Results: f1=0.7666666666666667
# Iteration 0: G2 Results: f1=0.7666666666666667
# Iteration 1: G1UG2 Results: f1=0.6666666666666666
# Iteration 1: G1 Results: f1=0.7
# Iteration 1: G2 Results: f1=0.7
# Iteration 2: G1UG2 Results: f1=0.4666666666666667
# Iteration 2: G1 Results: f1=0.7333333333333333
# Iteration 2: G2 Results: f1=0.7333333333333333
# Iteration 3: G1UG2 Results: f1=0.5666666666666667
# Iteration 3: G1 Results: f1=0.7333333333333333
# Iteration 3: G2 Results: f1=0.7333333333333333
# Iteration 4: G1UG2 Results: f1=0.7666666666666667
# Iteration 4: G1 Results: f1=0.7333333333333333
# Iteration 4: G2 Results: f1=0.7333333333333333
# Iteration 5: G1UG2 Results: f1=0.6
# Iteration 5: G1 Results: f1=0.7666666666666667
# Iteration 5: G2 Results: f1=0.7666666666666667
# Iteration 6: G1UG2 Results: f1=0.6833333333333333
# Iteration 6: G1 Results: f1=0.5
# Iteration 6: G2 Results: f1=0.5
# Iteration 7: G1UG2 Results: f1=0.4666666666666667
# Iteration 7: G1 Results: f1=0.7333333333333333
# Iteration 7: G2 Results: f1=0.7333333333333333
# Iteration 8: G1UG2 Results: f1=0.6833333333333333
# Iteration 8: G1 Results: f1=0.7666666666666667
# Iteration 8: G2 Results: f1=0.7666666666666667
# Iteration 9: G1UG2 Results: f1=0.6833333333333333
# Iteration 9: G1 Results: f1=0.7
# Iteration 9: G2 Results: f1=0.7

# %%
# Get the mean of their train loss and val_f1
mean_G1UG2_results = np.mean(G1UG2_results, axis=0)
mean_G1_results = np.mean(G1_results_final, axis=0)
mean_G2_results = np.mean(G2_results_final, axis=0)

mean_G1UG2_losses = mean_G1UG2_results[0]
mean_G1UG2_val_f1 = mean_G1UG2_results[2]

mean_G1_losses = mean_G1_results[0]
mean_G1_val_f1 = mean_G1_results[2]

mean_G2_losses = mean_G2_results[0]
mean_G2_val_f1 = mean_G2_results[2]

plot_training_and_validation(mean_G1UG2_losses, mean_G1UG2_val_f1, title="Training Loss and Validation F1 Over Time for G1 U G2 over 10 runs", x_label="Epoch")
plot_training_and_validation(mean_G1_losses, mean_G1_val_f1, title="Training Loss and Validation F1 Over Time for G1 only over 10 runs", x_label="Epoch")
plot_training_and_validation(mean_G2_losses, mean_G2_val_f1, title="Training Loss and Validation F1 Over Time for G2 only over 10 runs", x_label="Epoch")

# %% [markdown]
# ### Q3.2.d Implement & discuss what you observe.
#
# • Compare training results, embeddings, and overall observations between independent and
# merged training.
#
# • Formulate a hypothesis explaining your observations.
#
# • Discuss different implementation options for training on both graphs, including your choice.
# (e.g. what model modifications are possible; what training modifications are possible?)
#
# • Provide relevant plots and tables where appropriate.
#
# • Bonus: Implement a modification (or alternative approach) for training on G1 ∪ G2 and
# compare outcomes.

# %%
# SOLUTION Q3.2.d
# ####################################################
# MODIFY THE CODE BELOW 
# ####################################################  

# Implement the training of G = {G1 U G2}

# In the end return a single function:
# def train_G1UG2_v2(G1_train, G1_eval, G2_train, G2_eval, num_epochs=200, lr=0.001, verbose=True):
#     """"""
#     # INSERT necessary things
    
#     return losses, train_f1, val_f1

set_seed(40)

_,_,y_g1_train = G1_train
_,_,y_g1_eval = G1_eval
_,_,y_g2_train = G2_train
_,_,y_g2_eval = G2_eval

y_combined_train = torch.cat([y_g1_train, y_g2_train], dim=0)

_, _, _, last_embeddings_combined_train = train_G1UG2(G1_train, G1_eval, G2_train, G2_eval, num_epochs=200, lr=0.001, verbose=False, return_embeddings=True)

plot_tsne(last_embeddings_combined_train, y_combined_train, layer_to_plot=-1, subject="Node Embeddings in G1UG2 at Training")

    
X_combined, expanded_A, y_combined_eval = combine_graphs(G1_train, G2_train)

with torch.no_grad():
    _, last_embeddings_combined_eval = model(A=expanded_A, X=X_combined, return_embeddings=True)

plot_tsne(last_embeddings_combined_eval, y_combined_eval, layer_to_plot=-1, subject="Node Embeddings in G1UG2 at Evalutaion")

# ####################################################
# END OF MODIFICATION
# ####################################################

# %% [markdown]
# ### Runnning the evaluation.
#
# Note: It is optional to run this particular evaluation. You can modify it as needed.

# %%
# Load data
set_seed(10)
G1_train = read_json_data(G1_TRAIN_DATA_PATH, has_label=True) #returns a list of (X,A,y) - features, Adj Matrix, per Graph label
G1_eval = read_json_data(G1_EVAL_DATA_PATH, has_label=True) #returns a list of (X,A,y) - features, Adj Matrix, per Graph label

G2_train = read_json_data(G2_TRAIN_DATA_PATH, has_label=True) #returns a list of (X,A,y) - features, Adj Matrix, per Graph label
G2_eval = read_json_data(G2_EVAL_DATA_PATH, has_label=True) #returns a list of (X,A,y) - features, Adj Matrix, per Graph label

losses, train_f1, val_f1 = train_G1UG2(G1_train, G1_eval, G2_train, G2_eval, num_epochs=200, lr=0.001, verbose=True)

plot_training_and_validation(losses, val_f1)
# Out:
# Epoch 1, Training Loss: 9.494964599609375, Train F1: 0.6062, Validation F1: 0.6167
# Epoch 2, Training Loss: 9.468145370483398, Train F1: 0.6062, Validation F1: 0.6167
# Epoch 3, Training Loss: 9.442100524902344, Train F1: 0.6062, Validation F1: 0.6167
# Epoch 4, Training Loss: 9.416891098022461, Train F1: 0.6062, Validation F1: 0.6167
# Epoch 5, Training Loss: 9.3925199508667, Train F1: 0.6062, Validation F1: 0.6167
# Epoch 6, Training Loss: 9.369119644165039, Train F1: 0.6062, Validation F1: 0.6167
# Epoch 7, Training Loss: 9.347074508666992, Train F1: 0.6062, Validation F1: 0.6333
# Epoch 8, Training Loss: 9.326177597045898, Train F1: 0.6125, Validation F1: 0.6167
# Epoch 9, Training Loss: 9.306788444519043, Train F1: 0.6125, Validation F1: 0.6167
# Epoch 10, Training Loss: 9.289131164550781, Train F1: 0.6312, Validation F1: 0.6167
# Epoch 11, Training Loss: 9.273874282836914, Train F1: 0.6312, Validation F1: 0.6167
# Epoch 12, Training Loss: 9.260430335998535, Train F1: 0.6375, Validation F1: 0.6167
# Epoch 13, Training Loss: 9.248586654663086, Train F1: 0.6375, Validation F1: 0.6167
# Epoch 14, Training Loss: 9.23802661895752, Train F1: 0.6562, Validation F1: 0.6500
# Epoch 15, Training Loss: 9.22851276397705, Train F1: 0.6750, Validation F1: 0.6333
# Epoch 16, Training Loss: 9.220492362976074, Train F1: 0.6750, Validation F1: 0.6667
# Epoch 17, Training Loss: 9.213807106018066, Train F1: 0.6937, Validation F1: 0.7000
# Epoch 18, Training Loss: 9.20787239074707, Train F1: 0.7000, Validation F1: 0.7333
# Epoch 19, Training Loss: 9.203332901000977, Train F1: 0.7063, Validation F1: 0.7667
# Epoch 20, Training Loss: 9.199506759643555, Train F1: 0.7000, Validation F1: 0.7667
# Epoch 21, Training Loss: 9.196455001831055, Train F1: 0.7125, Validation F1: 0.7667
# Epoch 22, Training Loss: 9.193633079528809, Train F1: 0.7125, Validation F1: 0.7667
# Epoch 23, Training Loss: 9.191404342651367, Train F1: 0.7125, Validation F1: 0.7667
# Epoch 24, Training Loss: 9.189275741577148, Train F1: 0.7188, Validation F1: 0.7667
# Epoch 25, Training Loss: 9.187522888183594, Train F1: 0.7188, Validation F1: 0.7667
# Epoch 26, Training Loss: 9.186120986938477, Train F1: 0.7188, Validation F1: 0.7667
# Epoch 27, Training Loss: 9.184792518615723, Train F1: 0.7188, Validation F1: 0.7667
# Epoch 28, Training Loss: 9.183526039123535, Train F1: 0.7375, Validation F1: 0.7667
# Epoch 29, Training Loss: 9.182368278503418, Train F1: 0.7375, Validation F1: 0.7667
# Epoch 30, Training Loss: 9.181594848632812, Train F1: 0.7438, Validation F1: 0.7667
# Epoch 31, Training Loss: 9.18084716796875, Train F1: 0.7438, Validation F1: 0.7667
# Epoch 32, Training Loss: 9.18011474609375, Train F1: 0.7375, Validation F1: 0.7667
# Epoch 33, Training Loss: 9.179483413696289, Train F1: 0.7375, Validation F1: 0.7667
# Epoch 34, Training Loss: 9.178887367248535, Train F1: 0.7375, Validation F1: 0.7667
# Epoch 35, Training Loss: 9.178296089172363, Train F1: 0.7375, Validation F1: 0.7667
# Epoch 36, Training Loss: 9.177713394165039, Train F1: 0.7375, Validation F1: 0.7667
# Epoch 37, Training Loss: 9.177141189575195, Train F1: 0.7375, Validation F1: 0.7667
# Epoch 38, Training Loss: 9.17658805847168, Train F1: 0.7375, Validation F1: 0.7667
# Epoch 39, Training Loss: 9.176055908203125, Train F1: 0.7375, Validation F1: 0.7667
# Epoch 40, Training Loss: 9.17554759979248, Train F1: 0.7375, Validation F1: 0.7667
# Epoch 41, Training Loss: 9.175065040588379, Train F1: 0.7375, Validation F1: 0.7667
# Epoch 42, Training Loss: 9.174604415893555, Train F1: 0.7375, Validation F1: 0.7667
# Epoch 43, Training Loss: 9.174165725708008, Train F1: 0.7375, Validation F1: 0.7667
# Epoch 44, Training Loss: 9.173746109008789, Train F1: 0.7375, Validation F1: 0.7667
# Epoch 45, Training Loss: 9.173344612121582, Train F1: 0.7375, Validation F1: 0.7667
# Epoch 46, Training Loss: 9.17296028137207, Train F1: 0.7375, Validation F1: 0.7667
# Epoch 47, Training Loss: 9.172587394714355, Train F1: 0.7375, Validation F1: 0.7667
# Epoch 48, Training Loss: 9.172229766845703, Train F1: 0.7375, Validation F1: 0.7667
# Epoch 49, Training Loss: 9.17188549041748, Train F1: 0.7375, Validation F1: 0.7667
# Epoch 50, Training Loss: 9.171545028686523, Train F1: 0.7500, Validation F1: 0.7667
# Epoch 51, Training Loss: 9.171209335327148, Train F1: 0.7500, Validation F1: 0.7667
# Epoch 52, Training Loss: 9.170858383178711, Train F1: 0.7500, Validation F1: 0.7667
# Epoch 53, Training Loss: 9.170516967773438, Train F1: 0.7500, Validation F1: 0.7667
# Epoch 54, Training Loss: 9.170191764831543, Train F1: 0.7500, Validation F1: 0.7667
# Epoch 55, Training Loss: 9.16992473602295, Train F1: 0.7500, Validation F1: 0.7667
# Epoch 56, Training Loss: 9.169636726379395, Train F1: 0.7500, Validation F1: 0.7667
# Epoch 57, Training Loss: 9.169346809387207, Train F1: 0.7500, Validation F1: 0.7667
# Epoch 58, Training Loss: 9.169059753417969, Train F1: 0.7500, Validation F1: 0.7833
# Epoch 59, Training Loss: 9.16871452331543, Train F1: 0.7500, Validation F1: 0.7833
# Epoch 60, Training Loss: 9.168354034423828, Train F1: 0.7500, Validation F1: 0.7500
# Epoch 61, Training Loss: 9.168020248413086, Train F1: 0.7500, Validation F1: 0.5667
# Epoch 62, Training Loss: 9.167799949645996, Train F1: 0.7500, Validation F1: 0.5667
# Epoch 63, Training Loss: 9.167593955993652, Train F1: 0.7500, Validation F1: 0.5667
# Epoch 64, Training Loss: 9.167365074157715, Train F1: 0.7500, Validation F1: 0.5667
# Epoch 65, Training Loss: 9.167128562927246, Train F1: 0.7500, Validation F1: 0.5667
# Epoch 66, Training Loss: 9.166873931884766, Train F1: 0.7500, Validation F1: 0.5667
# Epoch 67, Training Loss: 9.16661262512207, Train F1: 0.7500, Validation F1: 0.5667
# Epoch 68, Training Loss: 9.166333198547363, Train F1: 0.7500, Validation F1: 0.5667
# Epoch 69, Training Loss: 9.16604232788086, Train F1: 0.7500, Validation F1: 0.5667
# Epoch 70, Training Loss: 9.165760040283203, Train F1: 0.7500, Validation F1: 0.5667
# Epoch 71, Training Loss: 9.165557861328125, Train F1: 0.7500, Validation F1: 0.5667
# Epoch 72, Training Loss: 9.165363311767578, Train F1: 0.7500, Validation F1: 0.5667
# Epoch 73, Training Loss: 9.165176391601562, Train F1: 0.7500, Validation F1: 0.5667
# Epoch 74, Training Loss: 9.164994239807129, Train F1: 0.7500, Validation F1: 0.5667
# Epoch 75, Training Loss: 9.164813041687012, Train F1: 0.7500, Validation F1: 0.5667
# Epoch 76, Training Loss: 9.164632797241211, Train F1: 0.7500, Validation F1: 0.5667
# Epoch 77, Training Loss: 9.164454460144043, Train F1: 0.7500, Validation F1: 0.5667
# Epoch 78, Training Loss: 9.164260864257812, Train F1: 0.7500, Validation F1: 0.5667
# Epoch 79, Training Loss: 9.164058685302734, Train F1: 0.7562, Validation F1: 0.5667
# Epoch 80, Training Loss: 9.163851737976074, Train F1: 0.7562, Validation F1: 0.5667
# Epoch 81, Training Loss: 9.163642883300781, Train F1: 0.7625, Validation F1: 0.5667
# Epoch 82, Training Loss: 9.163433074951172, Train F1: 0.7625, Validation F1: 0.5500
# Epoch 83, Training Loss: 9.163225173950195, Train F1: 0.7625, Validation F1: 0.5500
# Epoch 84, Training Loss: 9.163019180297852, Train F1: 0.7625, Validation F1: 0.5500
# Epoch 85, Training Loss: 9.162816047668457, Train F1: 0.7625, Validation F1: 0.5500
# Epoch 86, Training Loss: 9.162617683410645, Train F1: 0.7625, Validation F1: 0.5500
# Epoch 87, Training Loss: 9.162421226501465, Train F1: 0.7625, Validation F1: 0.5500
# Epoch 88, Training Loss: 9.162260055541992, Train F1: 0.7625, Validation F1: 0.5500
# Epoch 89, Training Loss: 9.162078857421875, Train F1: 0.7625, Validation F1: 0.5500
# Epoch 90, Training Loss: 9.161870956420898, Train F1: 0.7625, Validation F1: 0.5500
# Epoch 91, Training Loss: 9.161667823791504, Train F1: 0.7625, Validation F1: 0.5500
# Epoch 92, Training Loss: 9.161483764648438, Train F1: 0.7625, Validation F1: 0.5500
# Epoch 93, Training Loss: 9.161300659179688, Train F1: 0.7625, Validation F1: 0.5500
# Epoch 94, Training Loss: 9.161123275756836, Train F1: 0.7625, Validation F1: 0.5500
# Epoch 95, Training Loss: 9.1609468460083, Train F1: 0.7625, Validation F1: 0.5500
# Epoch 96, Training Loss: 9.160771369934082, Train F1: 0.7625, Validation F1: 0.5500
# Epoch 97, Training Loss: 9.16059684753418, Train F1: 0.7625, Validation F1: 0.5500
# Epoch 98, Training Loss: 9.16042423248291, Train F1: 0.7625, Validation F1: 0.5500
# Epoch 99, Training Loss: 9.160250663757324, Train F1: 0.7625, Validation F1: 0.5500
# Epoch 100, Training Loss: 9.160078048706055, Train F1: 0.7625, Validation F1: 0.5500
# Epoch 101, Training Loss: 9.159902572631836, Train F1: 0.7625, Validation F1: 0.5500
# Epoch 102, Training Loss: 9.159729957580566, Train F1: 0.7625, Validation F1: 0.5500
# Epoch 103, Training Loss: 9.159555435180664, Train F1: 0.7625, Validation F1: 0.5500
# Epoch 104, Training Loss: 8.608861923217773, Train F1: 0.7625, Validation F1: 0.5500
# Epoch 105, Training Loss: 8.542879104614258, Train F1: 0.6750, Validation F1: 0.5500
# Epoch 106, Training Loss: 0.5951772332191467, Train F1: 0.6750, Validation F1: 0.5500
# Epoch 107, Training Loss: 0.5950552225112915, Train F1: 0.6750, Validation F1: 0.5500
# Epoch 108, Training Loss: 0.5949400067329407, Train F1: 0.6750, Validation F1: 0.5500
# Epoch 109, Training Loss: 0.5948280096054077, Train F1: 0.6750, Validation F1: 0.5500
# Epoch 110, Training Loss: 0.5947262048721313, Train F1: 0.6750, Validation F1: 0.5500
# Epoch 111, Training Loss: 0.5946336984634399, Train F1: 0.6750, Validation F1: 0.5500
# Epoch 112, Training Loss: 0.5945423245429993, Train F1: 0.6750, Validation F1: 0.5500
# Epoch 113, Training Loss: 0.5944508910179138, Train F1: 0.6750, Validation F1: 0.5500
# Epoch 114, Training Loss: 0.5943607687950134, Train F1: 0.6750, Validation F1: 0.5500
# Epoch 115, Training Loss: 0.5942705273628235, Train F1: 0.6750, Validation F1: 0.5500
# Epoch 116, Training Loss: 0.5941828489303589, Train F1: 0.6750, Validation F1: 0.5500
# Epoch 117, Training Loss: 0.5940982699394226, Train F1: 0.6750, Validation F1: 0.5500
# Epoch 118, Training Loss: 0.5940132737159729, Train F1: 0.6750, Validation F1: 0.5500
# Epoch 119, Training Loss: 0.5939277410507202, Train F1: 0.6750, Validation F1: 0.5500
# Epoch 120, Training Loss: 0.5938416123390198, Train F1: 0.6750, Validation F1: 0.5500
# Epoch 121, Training Loss: 0.5937541127204895, Train F1: 0.6750, Validation F1: 0.5500
# Epoch 122, Training Loss: 0.5936660766601562, Train F1: 0.6750, Validation F1: 0.5500
# Epoch 123, Training Loss: 0.593582808971405, Train F1: 0.6750, Validation F1: 0.5500
# Epoch 124, Training Loss: 0.5934996604919434, Train F1: 0.6750, Validation F1: 0.5500
# Epoch 125, Training Loss: 0.5934159755706787, Train F1: 0.6750, Validation F1: 0.5500
# Epoch 126, Training Loss: 0.5933316946029663, Train F1: 0.6750, Validation F1: 0.5500
# Epoch 127, Training Loss: 0.5932474136352539, Train F1: 0.6750, Validation F1: 0.5500
# Epoch 128, Training Loss: 0.5931645631790161, Train F1: 0.6750, Validation F1: 0.5500
# Epoch 129, Training Loss: 0.593082070350647, Train F1: 0.6750, Validation F1: 0.5500
# Epoch 130, Training Loss: 0.5930005311965942, Train F1: 0.6750, Validation F1: 0.5500
# Epoch 131, Training Loss: 0.592919647693634, Train F1: 0.6750, Validation F1: 0.5500
# Epoch 132, Training Loss: 0.5928388237953186, Train F1: 0.6750, Validation F1: 0.5500
# Epoch 133, Training Loss: 0.5927579998970032, Train F1: 0.6750, Validation F1: 0.5500
# Epoch 134, Training Loss: 0.5926763415336609, Train F1: 0.6750, Validation F1: 0.5500
# Epoch 135, Training Loss: 0.5925990343093872, Train F1: 0.6750, Validation F1: 0.5500
# Epoch 136, Training Loss: 0.5925225019454956, Train F1: 0.6750, Validation F1: 0.5500
# Epoch 137, Training Loss: 0.5924457907676697, Train F1: 0.6750, Validation F1: 0.5500
# Epoch 138, Training Loss: 0.5923690795898438, Train F1: 0.6750, Validation F1: 0.5500
# Epoch 139, Training Loss: 0.5922935009002686, Train F1: 0.6750, Validation F1: 0.5500
# Epoch 140, Training Loss: 0.592218816280365, Train F1: 0.6750, Validation F1: 0.5500
# Epoch 141, Training Loss: 0.5921440720558167, Train F1: 0.6750, Validation F1: 0.5500
# Epoch 142, Training Loss: 0.5920690894126892, Train F1: 0.6750, Validation F1: 0.5500
# Epoch 143, Training Loss: 0.5919939279556274, Train F1: 0.6750, Validation F1: 0.5500
# Epoch 144, Training Loss: 0.5919184684753418, Train F1: 0.6750, Validation F1: 0.5500
# Epoch 145, Training Loss: 0.5918431282043457, Train F1: 0.6750, Validation F1: 0.5500
# Epoch 146, Training Loss: 0.5917679071426392, Train F1: 0.6750, Validation F1: 0.5500
# Epoch 147, Training Loss: 0.591693103313446, Train F1: 0.6750, Validation F1: 0.5500
# Epoch 148, Training Loss: 0.591618537902832, Train F1: 0.6750, Validation F1: 0.5500
# Epoch 149, Training Loss: 0.5915441513061523, Train F1: 0.6750, Validation F1: 0.5500
# Epoch 150, Training Loss: 0.5914700031280518, Train F1: 0.6750, Validation F1: 0.5500
# Epoch 151, Training Loss: 0.5913945436477661, Train F1: 0.6750, Validation F1: 0.5500
# Epoch 152, Training Loss: 0.5913199186325073, Train F1: 0.6750, Validation F1: 0.5500
# Epoch 153, Training Loss: 0.5912455320358276, Train F1: 0.6750, Validation F1: 0.5500
# Epoch 154, Training Loss: 0.591171145439148, Train F1: 0.6750, Validation F1: 0.5500
# Epoch 155, Training Loss: 0.5910967588424683, Train F1: 0.6750, Validation F1: 0.5500
# Epoch 156, Training Loss: 0.5910221338272095, Train F1: 0.6750, Validation F1: 0.5500
# Epoch 157, Training Loss: 0.5909472703933716, Train F1: 0.6750, Validation F1: 0.5500
# Epoch 158, Training Loss: 0.5908727645874023, Train F1: 0.6750, Validation F1: 0.5500
# Epoch 159, Training Loss: 0.5907986760139465, Train F1: 0.6750, Validation F1: 0.5500
# Epoch 160, Training Loss: 0.5907241106033325, Train F1: 0.6750, Validation F1: 0.5500
# Epoch 161, Training Loss: 0.5906499624252319, Train F1: 0.6750, Validation F1: 0.5500
# Epoch 162, Training Loss: 0.5905759930610657, Train F1: 0.6750, Validation F1: 0.5500
# Epoch 163, Training Loss: 0.5905043482780457, Train F1: 0.6750, Validation F1: 0.5500
# Epoch 164, Training Loss: 0.5904322862625122, Train F1: 0.6750, Validation F1: 0.5500
# Epoch 165, Training Loss: 0.5903601050376892, Train F1: 0.6750, Validation F1: 0.5500
# Epoch 166, Training Loss: 0.5902881622314453, Train F1: 0.6750, Validation F1: 0.5500
# Epoch 167, Training Loss: 0.5902163982391357, Train F1: 0.6750, Validation F1: 0.5500
# Epoch 168, Training Loss: 0.5901447534561157, Train F1: 0.6750, Validation F1: 0.5500
# Epoch 169, Training Loss: 0.5900732278823853, Train F1: 0.6750, Validation F1: 0.5500
# Epoch 170, Training Loss: 0.5900017023086548, Train F1: 0.6750, Validation F1: 0.5500
# Epoch 171, Training Loss: 0.5899301767349243, Train F1: 0.6750, Validation F1: 0.5500
# Epoch 172, Training Loss: 0.5898586511611938, Train F1: 0.6750, Validation F1: 0.5500
# Epoch 173, Training Loss: 0.5897873640060425, Train F1: 0.6750, Validation F1: 0.5500
# Epoch 174, Training Loss: 0.589715838432312, Train F1: 0.6750, Validation F1: 0.5500
# Epoch 175, Training Loss: 0.5896444916725159, Train F1: 0.6750, Validation F1: 0.5500
# Epoch 176, Training Loss: 0.5895730257034302, Train F1: 0.6750, Validation F1: 0.5500
# Epoch 177, Training Loss: 0.5895013809204102, Train F1: 0.6750, Validation F1: 0.5500
# Epoch 178, Training Loss: 0.5894296169281006, Train F1: 0.6750, Validation F1: 0.5500
# Epoch 179, Training Loss: 0.5893644094467163, Train F1: 0.6750, Validation F1: 0.5500
# Epoch 180, Training Loss: 0.589290201663971, Train F1: 0.6750, Validation F1: 0.5500
# Epoch 181, Training Loss: 0.5892214775085449, Train F1: 0.6750, Validation F1: 0.5500
# Epoch 182, Training Loss: 0.5891523957252502, Train F1: 0.6750, Validation F1: 0.5500
# Epoch 183, Training Loss: 0.5890828371047974, Train F1: 0.6750, Validation F1: 0.5500
# Epoch 184, Training Loss: 0.5890122652053833, Train F1: 0.6750, Validation F1: 0.5500
# Epoch 185, Training Loss: 0.5889405012130737, Train F1: 0.6750, Validation F1: 0.5500
# Epoch 186, Training Loss: 0.588867723941803, Train F1: 0.6750, Validation F1: 0.5500
# Epoch 187, Training Loss: 0.588794469833374, Train F1: 0.6750, Validation F1: 0.5500
# Epoch 188, Training Loss: 0.5887209177017212, Train F1: 0.6750, Validation F1: 0.5500
# Epoch 189, Training Loss: 0.58866947889328, Train F1: 0.6750, Validation F1: 0.5500
# Epoch 190, Training Loss: 0.5885873436927795, Train F1: 0.6750, Validation F1: 0.5500
# Epoch 191, Training Loss: 0.5885133147239685, Train F1: 0.6750, Validation F1: 0.5500
# Epoch 192, Training Loss: 0.588449239730835, Train F1: 0.6750, Validation F1: 0.5500
# Epoch 193, Training Loss: 0.5883904695510864, Train F1: 0.6750, Validation F1: 0.5500
# Epoch 194, Training Loss: 0.5883223414421082, Train F1: 0.6750, Validation F1: 0.5500
# Epoch 195, Training Loss: 0.5882447361946106, Train F1: 0.6750, Validation F1: 0.5500
# Epoch 196, Training Loss: 0.588161289691925, Train F1: 0.6750, Validation F1: 0.5500
# Epoch 197, Training Loss: 0.5880857706069946, Train F1: 0.6750, Validation F1: 0.5500
# Epoch 198, Training Loss: 0.5880175232887268, Train F1: 0.6750, Validation F1: 0.5500
# Epoch 199, Training Loss: 0.5879489183425903, Train F1: 0.6750, Validation F1: 0.5500
# Epoch 200, Training Loss: 0.5878849029541016, Train F1: 0.6750, Validation F1: 0.5500

# %% [markdown]
# ## 3.3 Topological changes to improve training

# %% [markdown]
# ### Q3.3.a - Plot the Ricci Curvature for each edge.
#
# • Plot a barplot of the the Ricci curvature per edge, where the x-axis are the edges and y-axis
# is the ricci curvature.

# %%
# SOLUTION Q3.3.a
# ####################################################
# MODIFY THE CODE BELOW 
# ####################################################  


# Load data
G1_train = read_json_data(G1_TRAIN_DATA_PATH, has_label=True) #returns a list of (X,A,y) - features, Adj Matrix, per Graph label
G1_eval = read_json_data(G1_EVAL_DATA_PATH, has_label=True) #returns a list of (X,A,y) - features, Adj Matrix, per Graph label

G2_train = read_json_data(G2_TRAIN_DATA_PATH, has_label=True) #returns a list of (X,A,y) - features, Adj Matrix, per Graph label
G2_eval = read_json_data(G2_EVAL_DATA_PATH, has_label=True) #returns a list of (X,A,y) - features, Adj Matrix, per Graph label


# Plot curvature against edges
from graph_ricci_curvature import GraphRicciCurvature 

def plot_ricci_per_edge(A):
    """
    Plots the Ricci curvature for each edge in the graph defined by adjacency matrix A.
    """
    # Convert PyTorch adjacency matrix to NumPy array
    A_np = A.numpy()

    # Create a NetworkX graph from the adjacency matrix
    G = nx.from_numpy_array(A_np)

    # Instantiate OllivierRicci object for the graph
    ricci_calculator = GraphRicciCurvature(G)

    # Compute the Ricci curvature
    curvatures = ricci_calculator.compute_ricci_curvatures()

    # Gather edge-level Ricci curvature values
    edges = list(curvatures.keys())
    ricci_values = list(curvatures.values())

    # Plot the Ricci curvature per edge
    plt.figure(figsize=(12, 6))
    plt.bar(range(len(edges)), ricci_values, tick_label=[f"{u}-{v}" for u, v in edges])
    plt.xlabel('Edges')
    plt.ylabel('Ricci Curvature')
    plt.title('Ricci Curvature per Edge')
    plt.xticks(rotation=90)
    plt.show()

# Example usage with G1_train adjacency matrix
plot_ricci_per_edge(G1_train[1])
plot_ricci_per_edge(G2_train[1])


# ####################################################
# END OF MODIFICATION
# ####################################################

# %% [markdown]
# ### Q3.3.b Investigate the extreme case topologies.
#
# • How would you modify a topology so that the graph structure is ignored, making the GNN
# behave like an MLP?
#
# • What would an ideal graph structure be for optimal training and testing if labels were
# available (both during training and testing)?
#
# • What are you observations? Analyze the scores and what does it mean about the dataset?
#
# • Provide relevant plots and results.

# %%
# SOLUTION Q3.3.b
# ####################################################
# MODIFY THE CODE BELOW 
# ####################################################  

def augment_graph_gold_labels(G):
    """Augment graph to return A that would be 'perfect'"""
    X,A,y = G

    # Set all connections with the same label to 1 others to 0
    for i in range(len(y)):
        for j in range(len(y)):
            if y[i] == y[j]:
                A[i, j] = 1
            else:
                A[i, j] = 0

    return X,A,y

def augment_graph_no_effect(G):
    """Modify graph to return A that has no 'effect'"""
    X,A,y = G

    # Set A to an indentity matrix
    A = torch.eye(A.size(0))

    return X, A, y

    
def improved_training(
        G_train,
        G_eval,
        model_params,
        num_epochs=200,
        lr=0.0005,
        verbose=True,
        return_embeddings = True,
        change_topology_params = {},
    ):
    """
    How can you improve the topologies to train better.
    """
    if change_topology_params["augmentation_strategy"] == "no_effect":
        augmentation_function = augment_graph_no_effect
    elif change_topology_params["augmentation_strategy"] == "gold":
        augmentation_function = augment_graph_gold_labels
    else:
        raise NotImplementedError("This augmentation setting is not implemented.")

    G_train = augmentation_function(G_train)
    G_eval = augmentation_function(G_eval)

    if change_topology_params["normalise"]:
        G_train = G_train[0],symmetric_normalize(G_train[1]),G_train[2]
        G_eval = G_eval[0],symmetric_normalize(G_eval[1]),G_eval[2]

    # Initialising the model
    model = LayeredGCN(**model_params)
    print(model)

    losses, train_f1, val_f1, last_embeddings = train_model(
        model,
        G_train,
        G_eval,
        num_epochs=num_epochs,
        lr=lr,
        verbose=verbose,
        return_embeddings = True
    )
    return losses, train_f1, val_f1, last_embeddings

# ####################################################
# END OF MODIFICATION
# ####################################################

# %% [markdown]
# ### Code to run improvement
# Note: run it a few times to see what performance can be reached on the eval dataset.

# %%
# Load data

set_seed(3)
G1_train = read_json_data(G1_TRAIN_DATA_PATH, has_label=True) #returns a list of (X,A,y) - features, Adj Matrix, per Graph label
G1_eval = read_json_data(G1_EVAL_DATA_PATH, has_label=True) #returns a list of (X,A,y) - features, Adj Matrix, per Graph label

G2_train = read_json_data(G2_TRAIN_DATA_PATH, has_label=True) #returns a list of (X,A,y) - features, Adj Matrix, per Graph label
G2_eval = read_json_data(G2_EVAL_DATA_PATH, has_label=True) #returns a list of (X,A,y) - features, Adj Matrix, per Graph label

model_params = {    
    "input_dim":10, 
    "hidden_dim":8,
    "num_layers":3,
}

change_topology_params = {
    "augmentation_strategy":"no_effect",
    "normalise" : False,
}

G1_results_final=[]
G2_results_final=[]

for i in range(10):
    losses, train_f1, val_f1, last_embeddings_G1 = improved_training(
        G1_train,
        G1_eval,
        model_params=model_params,
        num_epochs=250,
        lr=0.0005,
        verbose=True,
        return_embeddings = True,
        change_topology_params = change_topology_params #change as needed
    )

    print(f"Iteration {i}: G2 Results: f1={val_f1[-1]}")
    G2_results_final.append([losses, train_f1, val_f1, last_embeddings_G1]) 

    losses, train_f1, val_f1, last_embeddings_G2 = improved_training(
        G2_train,
        G2_eval,
        model_params=model_params,
        num_epochs=250,
        lr=0.0005,
        verbose=True,
        return_embeddings = True,
        change_topology_params = change_topology_params #change as needed
    )

    print(f"Iteration {i}: G1 Results: f1={val_f1[-1]}")
    G1_results_final.append([losses, train_f1, val_f1, last_embeddings_G2])
# Out:
# LayeredGCN(
#   (layers): ModuleList(
#     (0-2): 3 x GCNLayer()
#   )
#   (output_layer): GCNLayer()
# )
# Epoch 1, Training Loss: 0.6856775879859924, Train F1: 0.5375, Validation F1: 0.5000
# Epoch 2, Training Loss: 0.6855083107948303, Train F1: 0.5375, Validation F1: 0.5000
# Epoch 3, Training Loss: 0.685338020324707, Train F1: 0.5375, Validation F1: 0.5000
# Epoch 4, Training Loss: 0.6851665377616882, Train F1: 0.5375, Validation F1: 0.5000
# Epoch 5, Training Loss: 0.684994101524353, Train F1: 0.5375, Validation F1: 0.5000
# Epoch 6, Training Loss: 0.6848207712173462, Train F1: 0.5375, Validation F1: 0.5000
# Epoch 7, Training Loss: 0.6846463084220886, Train F1: 0.5375, Validation F1: 0.5000
# Epoch 8, Training Loss: 0.6844707727432251, Train F1: 0.5375, Validation F1: 0.5000
# Epoch 9, Training Loss: 0.6842926740646362, Train F1: 0.5375, Validation F1: 0.5000
# Epoch 10, Training Loss: 0.6841126680374146, Train F1: 0.5375, Validation F1: 0.5000
# Epoch 11, Training Loss: 0.6839306950569153, Train F1: 0.5375, Validation F1: 0.5000
# Epoch 12, Training Loss: 0.6837440729141235, Train F1: 0.5375, Validation F1: 0.5000
# Epoch 13, Training Loss: 0.6835559606552124, Train F1: 0.5375, Validation F1: 0.5000
# Epoch 14, Training Loss: 0.6833643913269043, Train F1: 0.5375, Validation F1: 0.5000
# Epoch 15, Training Loss: 0.6831698417663574, Train F1: 0.5375, Validation F1: 0.5000
# Epoch 16, Training Loss: 0.6829726099967957, Train F1: 0.5375, Validation F1: 0.5000
# Epoch 17, Training Loss: 0.6827735900878906, Train F1: 0.5375, Validation F1: 0.5000
# Epoch 18, Training Loss: 0.6825729608535767, Train F1: 0.5375, Validation F1: 0.5000
# Epoch 19, Training Loss: 0.6823700666427612, Train F1: 0.5375, Validation F1: 0.5000
# Epoch 20, Training Loss: 0.6821650266647339, Train F1: 0.5375, Validation F1: 0.5000
# Epoch 21, Training Loss: 0.681958019733429, Train F1: 0.5375, Validation F1: 0.5000
# Epoch 22, Training Loss: 0.6817461252212524, Train F1: 0.5375, Validation F1: 0.5000
# Epoch 23, Training Loss: 0.6815322041511536, Train F1: 0.5375, Validation F1: 0.5000
# Epoch 24, Training Loss: 0.6813163161277771, Train F1: 0.5375, Validation F1: 0.5000
# Epoch 25, Training Loss: 0.681096076965332, Train F1: 0.5375, Validation F1: 0.5000
# Epoch 26, Training Loss: 0.6808735132217407, Train F1: 0.5375, Validation F1: 0.5000
# Epoch 27, Training Loss: 0.6806485056877136, Train F1: 0.5375, Validation F1: 0.5000
# Epoch 28, Training Loss: 0.6804215908050537, Train F1: 0.5375, Validation F1: 0.5000
# Epoch 29, Training Loss: 0.6801925897598267, Train F1: 0.5375, Validation F1: 0.5000
# Epoch 30, Training Loss: 0.6799612641334534, Train F1: 0.5375, Validation F1: 0.5000
# Epoch 31, Training Loss: 0.6797279715538025, Train F1: 0.5375, Validation F1: 0.5000
# Epoch 32, Training Loss: 0.6794928312301636, Train F1: 0.5375, Validation F1: 0.5000
# Epoch 33, Training Loss: 0.6792556643486023, Train F1: 0.5375, Validation F1: 0.5000
# Epoch 34, Training Loss: 0.6790158152580261, Train F1: 0.5375, Validation F1: 0.5000
# Epoch 35, Training Loss: 0.6787738800048828, Train F1: 0.5375, Validation F1: 0.5000
# Epoch 36, Training Loss: 0.6785296201705933, Train F1: 0.5375, Validation F1: 0.5000
# Epoch 37, Training Loss: 0.6782827973365784, Train F1: 0.5375, Validation F1: 0.5000
# Epoch 38, Training Loss: 0.6780332326889038, Train F1: 0.5375, Validation F1: 0.5000
# Epoch 39, Training Loss: 0.6777811646461487, Train F1: 0.5375, Validation F1: 0.5000
# Epoch 40, Training Loss: 0.6775267124176025, Train F1: 0.5375, Validation F1: 0.5000
# Epoch 41, Training Loss: 0.677269697189331, Train F1: 0.5375, Validation F1: 0.5000
# Epoch 42, Training Loss: 0.677010178565979, Train F1: 0.5375, Validation F1: 0.5000
# Epoch 43, Training Loss: 0.6767482757568359, Train F1: 0.5375, Validation F1: 0.5000
# Epoch 44, Training Loss: 0.6764837503433228, Train F1: 0.5375, Validation F1: 0.5000
# Epoch 45, Training Loss: 0.6762170195579529, Train F1: 0.5375, Validation F1: 0.5000
# Epoch 46, Training Loss: 0.6759480237960815, Train F1: 0.5375, Validation F1: 0.5000
# Epoch 47, Training Loss: 0.6756764650344849, Train F1: 0.5375, Validation F1: 0.5000
# Epoch 48, Training Loss: 0.6754022836685181, Train F1: 0.5375, Validation F1: 0.5000
# Epoch 49, Training Loss: 0.6751253604888916, Train F1: 0.5375, Validation F1: 0.5000
# Epoch 50, Training Loss: 0.674845814704895, Train F1: 0.5375, Validation F1: 0.5000
# Epoch 51, Training Loss: 0.6745632290840149, Train F1: 0.5375, Validation F1: 0.5000
# Epoch 52, Training Loss: 0.6742777824401855, Train F1: 0.5375, Validation F1: 0.5000
# Epoch 53, Training Loss: 0.6739894151687622, Train F1: 0.5375, Validation F1: 0.5000
# Epoch 54, Training Loss: 0.673698365688324, Train F1: 0.5375, Validation F1: 0.5000
# Epoch 55, Training Loss: 0.6734044551849365, Train F1: 0.5375, Validation F1: 0.5000
# Epoch 56, Training Loss: 0.6731079816818237, Train F1: 0.5375, Validation F1: 0.5000
# Epoch 57, Training Loss: 0.6728087067604065, Train F1: 0.5375, Validation F1: 0.5000
# Epoch 58, Training Loss: 0.6725068688392639, Train F1: 0.5375, Validation F1: 0.5000
# Epoch 59, Training Loss: 0.6722022891044617, Train F1: 0.5375, Validation F1: 0.5000
# Epoch 60, Training Loss: 0.6718933582305908, Train F1: 0.5375, Validation F1: 0.5000
# Epoch 61, Training Loss: 0.6715813279151917, Train F1: 0.5375, Validation F1: 0.5000
# Epoch 62, Training Loss: 0.6712659597396851, Train F1: 0.5375, Validation F1: 0.5000
# Epoch 63, Training Loss: 0.6709474921226501, Train F1: 0.5375, Validation F1: 0.5000
# Epoch 64, Training Loss: 0.6706261038780212, Train F1: 0.5375, Validation F1: 0.5000
# Epoch 65, Training Loss: 0.6703014373779297, Train F1: 0.5375, Validation F1: 0.5000
# Epoch 66, Training Loss: 0.6699732542037964, Train F1: 0.5375, Validation F1: 0.5000
# Epoch 67, Training Loss: 0.6696416735649109, Train F1: 0.5375, Validation F1: 0.5000
# Epoch 68, Training Loss: 0.6693071126937866, Train F1: 0.5375, Validation F1: 0.5000
# Epoch 69, Training Loss: 0.6689692735671997, Train F1: 0.5375, Validation F1: 0.5000
# Epoch 70, Training Loss: 0.6686282753944397, Train F1: 0.5375, Validation F1: 0.5000
# Epoch 71, Training Loss: 0.6682840585708618, Train F1: 0.5375, Validation F1: 0.5000
# Epoch 72, Training Loss: 0.6679365634918213, Train F1: 0.5375, Validation F1: 0.5000
# Epoch 73, Training Loss: 0.6675857901573181, Train F1: 0.5375, Validation F1: 0.5000
# Epoch 74, Training Loss: 0.6672313213348389, Train F1: 0.5375, Validation F1: 0.5000
# Epoch 75, Training Loss: 0.6668738126754761, Train F1: 0.5375, Validation F1: 0.5000
# Epoch 76, Training Loss: 0.6665129661560059, Train F1: 0.5375, Validation F1: 0.5000
# Epoch 77, Training Loss: 0.6661486625671387, Train F1: 0.5375, Validation F1: 0.5000
# Epoch 78, Training Loss: 0.6657809019088745, Train F1: 0.5375, Validation F1: 0.5000
# Epoch 79, Training Loss: 0.6654099225997925, Train F1: 0.5375, Validation F1: 0.5000
# Epoch 80, Training Loss: 0.6650354862213135, Train F1: 0.5375, Validation F1: 0.5000
# Epoch 81, Training Loss: 0.6646579504013062, Train F1: 0.5375, Validation F1: 0.5000
# Epoch 82, Training Loss: 0.6642771363258362, Train F1: 0.5375, Validation F1: 0.5000
# Epoch 83, Training Loss: 0.663892924785614, Train F1: 0.5375, Validation F1: 0.5000
# Epoch 84, Training Loss: 0.6635052561759949, Train F1: 0.5375, Validation F1: 0.5000
# Epoch 85, Training Loss: 0.6631141901016235, Train F1: 0.5375, Validation F1: 0.5000
# Epoch 86, Training Loss: 0.6627196073532104, Train F1: 0.5375, Validation F1: 0.5000
# Epoch 87, Training Loss: 0.6623213887214661, Train F1: 0.5375, Validation F1: 0.5000
# Epoch 88, Training Loss: 0.6619197130203247, Train F1: 0.5375, Validation F1: 0.5000
# Epoch 89, Training Loss: 0.6615146398544312, Train F1: 0.5375, Validation F1: 0.5000
# Epoch 90, Training Loss: 0.6611064076423645, Train F1: 0.5375, Validation F1: 0.5000
# Epoch 91, Training Loss: 0.6606947183609009, Train F1: 0.5375, Validation F1: 0.5000
# Epoch 92, Training Loss: 0.660279393196106, Train F1: 0.5375, Validation F1: 0.5000
# Epoch 93, Training Loss: 0.6598604321479797, Train F1: 0.5375, Validation F1: 0.5000
# Epoch 94, Training Loss: 0.6594380140304565, Train F1: 0.5375, Validation F1: 0.5000
# Epoch 95, Training Loss: 0.6590121388435364, Train F1: 0.5375, Validation F1: 0.5000
# Epoch 96, Training Loss: 0.6585826873779297, Train F1: 0.5375, Validation F1: 0.5000
# Epoch 97, Training Loss: 0.6581496000289917, Train F1: 0.5375, Validation F1: 0.5000
# Epoch 98, Training Loss: 0.6577129364013672, Train F1: 0.5375, Validation F1: 0.5000
# Epoch 99, Training Loss: 0.6572729349136353, Train F1: 0.5375, Validation F1: 0.5000
# Epoch 100, Training Loss: 0.6568292379379272, Train F1: 0.5375, Validation F1: 0.5000
# Epoch 101, Training Loss: 0.6563819050788879, Train F1: 0.5375, Validation F1: 0.5000
# Epoch 102, Training Loss: 0.6559308767318726, Train F1: 0.5375, Validation F1: 0.5000
# Epoch 103, Training Loss: 0.655476450920105, Train F1: 0.5375, Validation F1: 0.5000
# Epoch 104, Training Loss: 0.6550198197364807, Train F1: 0.5375, Validation F1: 0.5000
# Epoch 105, Training Loss: 0.6545596122741699, Train F1: 0.5375, Validation F1: 0.5000
# Epoch 106, Training Loss: 0.6540960073471069, Train F1: 0.5375, Validation F1: 0.5000
# Epoch 107, Training Loss: 0.653628945350647, Train F1: 0.5375, Validation F1: 0.5000
# Epoch 108, Training Loss: 0.6531581878662109, Train F1: 0.5375, Validation F1: 0.5000
# Epoch 109, Training Loss: 0.6526839137077332, Train F1: 0.5375, Validation F1: 0.5000
# Epoch 110, Training Loss: 0.6522059440612793, Train F1: 0.5375, Validation F1: 0.5000
# Epoch 111, Training Loss: 0.6517247557640076, Train F1: 0.5375, Validation F1: 0.5000
# Epoch 112, Training Loss: 0.6512399911880493, Train F1: 0.5375, Validation F1: 0.5000
# Epoch 113, Training Loss: 0.650751531124115, Train F1: 0.5375, Validation F1: 0.5000
# Epoch 114, Training Loss: 0.6502596139907837, Train F1: 0.5375, Validation F1: 0.5000
# Epoch 115, Training Loss: 0.6497642993927002, Train F1: 0.5375, Validation F1: 0.5000
# Epoch 116, Training Loss: 0.6492653489112854, Train F1: 0.5375, Validation F1: 0.5000
# Epoch 117, Training Loss: 0.6487623453140259, Train F1: 0.5375, Validation F1: 0.5000
# Epoch 118, Training Loss: 0.6482552289962769, Train F1: 0.5375, Validation F1: 0.5000
# Epoch 119, Training Loss: 0.6477444767951965, Train F1: 0.5375, Validation F1: 0.5000
# Epoch 120, Training Loss: 0.6472300291061401, Train F1: 0.5375, Validation F1: 0.5000
# Epoch 121, Training Loss: 0.6467117667198181, Train F1: 0.5375, Validation F1: 0.5000
# Epoch 122, Training Loss: 0.6461899876594543, Train F1: 0.5375, Validation F1: 0.5000
# Epoch 123, Training Loss: 0.645664393901825, Train F1: 0.5375, Validation F1: 0.5000
# Epoch 124, Training Loss: 0.6451351642608643, Train F1: 0.5375, Validation F1: 0.5000
# Epoch 125, Training Loss: 0.6446021795272827, Train F1: 0.5375, Validation F1: 0.5000
# Epoch 126, Training Loss: 0.6440661549568176, Train F1: 0.5375, Validation F1: 0.5000
# Epoch 127, Training Loss: 0.643526554107666, Train F1: 0.5375, Validation F1: 0.5000
# Epoch 128, Training Loss: 0.6429834365844727, Train F1: 0.5375, Validation F1: 0.5000
# Epoch 129, Training Loss: 0.6424363255500793, Train F1: 0.5375, Validation F1: 0.5000
# Epoch 130, Training Loss: 0.6418856978416443, Train F1: 0.5375, Validation F1: 0.5000
# Epoch 131, Training Loss: 0.6413314938545227, Train F1: 0.5375, Validation F1: 0.5000
# Epoch 132, Training Loss: 0.6407738924026489, Train F1: 0.5375, Validation F1: 0.5000
# Epoch 133, Training Loss: 0.6402126550674438, Train F1: 0.5375, Validation F1: 0.5000
# Epoch 134, Training Loss: 0.6396477818489075, Train F1: 0.5375, Validation F1: 0.5000
# Epoch 135, Training Loss: 0.639079213142395, Train F1: 0.5375, Validation F1: 0.5000
# Epoch 136, Training Loss: 0.638507068157196, Train F1: 0.5375, Validation F1: 0.5000
# Epoch 137, Training Loss: 0.6379313468933105, Train F1: 0.5375, Validation F1: 0.5000
# Epoch 138, Training Loss: 0.637351930141449, Train F1: 0.5375, Validation F1: 0.5000
# Epoch 139, Training Loss: 0.6367690563201904, Train F1: 0.5375, Validation F1: 0.5000
# Epoch 140, Training Loss: 0.6361824870109558, Train F1: 0.5375, Validation F1: 0.5000
# Epoch 141, Training Loss: 0.6355924010276794, Train F1: 0.5375, Validation F1: 0.5000
# Epoch 142, Training Loss: 0.6349986791610718, Train F1: 0.5375, Validation F1: 0.5000
# Epoch 143, Training Loss: 0.6344014406204224, Train F1: 0.5375, Validation F1: 0.5000
# Epoch 144, Training Loss: 0.6338005661964417, Train F1: 0.5375, Validation F1: 0.5000
# Epoch 145, Training Loss: 0.633196234703064, Train F1: 0.5375, Validation F1: 0.5000
# Epoch 146, Training Loss: 0.6325883269309998, Train F1: 0.5375, Validation F1: 0.5000
# Epoch 147, Training Loss: 0.6319769620895386, Train F1: 0.5375, Validation F1: 0.5000
# Epoch 148, Training Loss: 0.6313620805740356, Train F1: 0.5375, Validation F1: 0.5000
# Epoch 149, Training Loss: 0.6307438015937805, Train F1: 0.5375, Validation F1: 0.5000
# Epoch 150, Training Loss: 0.6301220655441284, Train F1: 0.5375, Validation F1: 0.5000
# Epoch 151, Training Loss: 0.629496693611145, Train F1: 0.5375, Validation F1: 0.5000
# Epoch 152, Training Loss: 0.628868043422699, Train F1: 0.5375, Validation F1: 0.5000
# Epoch 153, Training Loss: 0.6282359957695007, Train F1: 0.5375, Validation F1: 0.5000
# Epoch 154, Training Loss: 0.6276005506515503, Train F1: 0.5375, Validation F1: 0.5000
# Epoch 155, Training Loss: 0.6269618272781372, Train F1: 0.5375, Validation F1: 0.5000
# Epoch 156, Training Loss: 0.6263208389282227, Train F1: 0.5375, Validation F1: 0.5000
# Epoch 157, Training Loss: 0.6256800889968872, Train F1: 0.5375, Validation F1: 0.5000
# Epoch 158, Training Loss: 0.6250359416007996, Train F1: 0.5375, Validation F1: 0.5000
# Epoch 159, Training Loss: 0.624388575553894, Train F1: 0.5375, Validation F1: 0.5000
# Epoch 160, Training Loss: 0.6237379908561707, Train F1: 0.5375, Validation F1: 0.5000
# Epoch 161, Training Loss: 0.623084306716919, Train F1: 0.5375, Validation F1: 0.5000
# Epoch 162, Training Loss: 0.6224276423454285, Train F1: 0.5375, Validation F1: 0.5000
# Epoch 163, Training Loss: 0.6217678785324097, Train F1: 0.5375, Validation F1: 0.5000
# Epoch 164, Training Loss: 0.6211053133010864, Train F1: 0.5375, Validation F1: 0.5000
# Epoch 165, Training Loss: 0.6204395294189453, Train F1: 0.5375, Validation F1: 0.5000
# Epoch 166, Training Loss: 0.6197708249092102, Train F1: 0.5375, Validation F1: 0.5000
# Epoch 167, Training Loss: 0.6190992593765259, Train F1: 0.5375, Validation F1: 0.5000
# Epoch 168, Training Loss: 0.6184250116348267, Train F1: 0.5375, Validation F1: 0.5000
# Epoch 169, Training Loss: 0.6177481412887573, Train F1: 0.5375, Validation F1: 0.5000
# Epoch 170, Training Loss: 0.6170685291290283, Train F1: 0.5375, Validation F1: 0.5000
# Epoch 171, Training Loss: 0.6163862943649292, Train F1: 0.5375, Validation F1: 0.5000
# Epoch 172, Training Loss: 0.6157013773918152, Train F1: 0.5375, Validation F1: 0.5000
# Epoch 173, Training Loss: 0.6150141358375549, Train F1: 0.5375, Validation F1: 0.5000
# Epoch 174, Training Loss: 0.6143244504928589, Train F1: 0.5375, Validation F1: 0.5000
# Epoch 175, Training Loss: 0.6136323809623718, Train F1: 0.5375, Validation F1: 0.5000
# Epoch 176, Training Loss: 0.6129379868507385, Train F1: 0.5375, Validation F1: 0.5000
# Epoch 177, Training Loss: 0.6122415065765381, Train F1: 0.5375, Validation F1: 0.5000
# Epoch 178, Training Loss: 0.6115431785583496, Train F1: 0.5375, Validation F1: 0.5000
# Epoch 179, Training Loss: 0.6108425855636597, Train F1: 0.5375, Validation F1: 0.5000
# Epoch 180, Training Loss: 0.6101398468017578, Train F1: 0.5375, Validation F1: 0.5000
# Epoch 181, Training Loss: 0.609434962272644, Train F1: 0.5375, Validation F1: 0.5000
# Epoch 182, Training Loss: 0.6087276339530945, Train F1: 0.5375, Validation F1: 0.5000
# Epoch 183, Training Loss: 0.60801762342453, Train F1: 0.5375, Validation F1: 0.5000
# Epoch 184, Training Loss: 0.6073054075241089, Train F1: 0.5375, Validation F1: 0.5000
# Epoch 185, Training Loss: 0.6065913438796997, Train F1: 0.5375, Validation F1: 0.5000
# Epoch 186, Training Loss: 0.6058753728866577, Train F1: 0.5375, Validation F1: 0.5000
# Epoch 187, Training Loss: 0.6051574945449829, Train F1: 0.5375, Validation F1: 0.5000
# Epoch 188, Training Loss: 0.6044378280639648, Train F1: 0.5375, Validation F1: 0.5000
# Epoch 189, Training Loss: 0.6037164330482483, Train F1: 0.5375, Validation F1: 0.5000
# Epoch 190, Training Loss: 0.602993369102478, Train F1: 0.5375, Validation F1: 0.5000
# Epoch 191, Training Loss: 0.6022697687149048, Train F1: 0.5375, Validation F1: 0.5000
# Epoch 192, Training Loss: 0.6015452146530151, Train F1: 0.5375, Validation F1: 0.5000
# Epoch 193, Training Loss: 0.60081946849823, Train F1: 0.5375, Validation F1: 0.5000
# Epoch 194, Training Loss: 0.6000925302505493, Train F1: 0.5375, Validation F1: 0.5000
# Epoch 195, Training Loss: 0.5993642807006836, Train F1: 0.5375, Validation F1: 0.5000
# Epoch 196, Training Loss: 0.5986336469650269, Train F1: 0.5375, Validation F1: 0.5000
# Epoch 197, Training Loss: 0.5979012846946716, Train F1: 0.8125, Validation F1: 0.6000
# Epoch 198, Training Loss: 0.5971686244010925, Train F1: 0.8125, Validation F1: 0.6000
# Epoch 199, Training Loss: 0.5964348912239075, Train F1: 0.8125, Validation F1: 0.6000
# Epoch 200, Training Loss: 0.5957001447677612, Train F1: 0.8250, Validation F1: 0.6000
# Epoch 201, Training Loss: 0.5949643850326538, Train F1: 0.8250, Validation F1: 0.6000
# Epoch 202, Training Loss: 0.59422767162323, Train F1: 0.8250, Validation F1: 0.6000
# Epoch 203, Training Loss: 0.5934902429580688, Train F1: 0.8250, Validation F1: 0.6000
# Epoch 204, Training Loss: 0.5927541851997375, Train F1: 0.8250, Validation F1: 0.6000
# Epoch 205, Training Loss: 0.5920206904411316, Train F1: 0.8250, Validation F1: 0.6333
# Epoch 206, Training Loss: 0.5912867188453674, Train F1: 0.8250, Validation F1: 0.6333
# Epoch 207, Training Loss: 0.5905520915985107, Train F1: 0.8250, Validation F1: 0.6333
# Epoch 208, Training Loss: 0.5898171663284302, Train F1: 0.8250, Validation F1: 0.6333
# Epoch 209, Training Loss: 0.589081883430481, Train F1: 0.8250, Validation F1: 0.6333
# Epoch 210, Training Loss: 0.5883464217185974, Train F1: 0.8250, Validation F1: 0.6333
# Epoch 211, Training Loss: 0.587611198425293, Train F1: 0.8250, Validation F1: 0.6667
# Epoch 212, Training Loss: 0.5868763327598572, Train F1: 0.8375, Validation F1: 0.6667
# Epoch 213, Training Loss: 0.58614182472229, Train F1: 0.8375, Validation F1: 0.6667
# Epoch 214, Training Loss: 0.5854074954986572, Train F1: 0.8375, Validation F1: 0.6667
# Epoch 215, Training Loss: 0.5846735835075378, Train F1: 0.8375, Validation F1: 0.6667
# Epoch 216, Training Loss: 0.5839405059814453, Train F1: 0.8375, Validation F1: 0.6667
# Epoch 217, Training Loss: 0.5832083225250244, Train F1: 0.8375, Validation F1: 0.6667
# Epoch 218, Training Loss: 0.5824767351150513, Train F1: 0.8375, Validation F1: 0.6667
# Epoch 219, Training Loss: 0.581745982170105, Train F1: 0.8375, Validation F1: 0.6667
# Epoch 220, Training Loss: 0.5810158848762512, Train F1: 0.8375, Validation F1: 0.6667
# Epoch 221, Training Loss: 0.5802869200706482, Train F1: 0.8375, Validation F1: 0.6667
# Epoch 222, Training Loss: 0.5795590281486511, Train F1: 0.8375, Validation F1: 0.6667
# Epoch 223, Training Loss: 0.5788322687149048, Train F1: 0.8375, Validation F1: 0.6667
# Epoch 224, Training Loss: 0.578106701374054, Train F1: 0.8375, Validation F1: 0.6667
# Epoch 225, Training Loss: 0.5773824453353882, Train F1: 0.8375, Validation F1: 0.6667
# Epoch 226, Training Loss: 0.5766595602035522, Train F1: 0.8375, Validation F1: 0.6667
# Epoch 227, Training Loss: 0.57593834400177, Train F1: 0.8375, Validation F1: 0.7000
# Epoch 228, Training Loss: 0.5752185583114624, Train F1: 0.8375, Validation F1: 0.7000
# Epoch 229, Training Loss: 0.5745003819465637, Train F1: 0.8375, Validation F1: 0.7000
# Epoch 230, Training Loss: 0.5737844109535217, Train F1: 0.8500, Validation F1: 0.7000
# Epoch 231, Training Loss: 0.5730703473091125, Train F1: 0.8500, Validation F1: 0.7000
# Epoch 232, Training Loss: 0.5723583102226257, Train F1: 0.8500, Validation F1: 0.7000
# Epoch 233, Training Loss: 0.5716482400894165, Train F1: 0.8500, Validation F1: 0.7000
# Epoch 234, Training Loss: 0.570939838886261, Train F1: 0.8500, Validation F1: 0.7000
# Epoch 235, Training Loss: 0.5702332258224487, Train F1: 0.8500, Validation F1: 0.7000
# Epoch 236, Training Loss: 0.5695301294326782, Train F1: 0.8500, Validation F1: 0.7000
# Epoch 237, Training Loss: 0.5688281059265137, Train F1: 0.8500, Validation F1: 0.7000
# Epoch 238, Training Loss: 0.5681284666061401, Train F1: 0.8500, Validation F1: 0.7000
# Epoch 239, Training Loss: 0.5674316883087158, Train F1: 0.8500, Validation F1: 0.7000
# Epoch 240, Training Loss: 0.566737174987793, Train F1: 0.8500, Validation F1: 0.7000
# Epoch 241, Training Loss: 0.5660451650619507, Train F1: 0.8500, Validation F1: 0.7000
# Epoch 242, Training Loss: 0.5653560757637024, Train F1: 0.8500, Validation F1: 0.7000
# Epoch 243, Training Loss: 0.5646694898605347, Train F1: 0.8500, Validation F1: 0.7000
# Epoch 244, Training Loss: 0.5639855861663818, Train F1: 0.8500, Validation F1: 0.7000
# Epoch 245, Training Loss: 0.5633046627044678, Train F1: 0.8500, Validation F1: 0.7000
# Epoch 246, Training Loss: 0.5626264214515686, Train F1: 0.8500, Validation F1: 0.7000
# Epoch 247, Training Loss: 0.5619512796401978, Train F1: 0.8500, Validation F1: 0.7000
# Epoch 248, Training Loss: 0.5612789988517761, Train F1: 0.8500, Validation F1: 0.7000
# Epoch 249, Training Loss: 0.5606098175048828, Train F1: 0.8500, Validation F1: 0.7000
# Epoch 250, Training Loss: 0.5599438548088074, Train F1: 0.8500, Validation F1: 0.7000
# Iteration 0: G2 Results: f1=0.7
# LayeredGCN(
#   (layers): ModuleList(
#     (0-2): 3 x GCNLayer()
#   )
#   (output_layer): GCNLayer()
# )
# Epoch 1, Training Loss: 0.692531406879425, Train F1: 0.4750, Validation F1: 0.6333
# Epoch 2, Training Loss: 0.6923471689224243, Train F1: 0.4750, Validation F1: 0.6333
# Epoch 3, Training Loss: 0.6921675205230713, Train F1: 0.4750, Validation F1: 0.6333
# Epoch 4, Training Loss: 0.6919889450073242, Train F1: 0.4750, Validation F1: 0.6333
# Epoch 5, Training Loss: 0.691811203956604, Train F1: 0.4750, Validation F1: 0.6333
# Epoch 6, Training Loss: 0.6916378736495972, Train F1: 0.4750, Validation F1: 0.6333
# Epoch 7, Training Loss: 0.6914700269699097, Train F1: 0.4750, Validation F1: 0.6333
# Epoch 8, Training Loss: 0.6913048028945923, Train F1: 0.4750, Validation F1: 0.6333
# Epoch 9, Training Loss: 0.6911444664001465, Train F1: 0.4750, Validation F1: 0.6333
# Epoch 10, Training Loss: 0.6909847855567932, Train F1: 0.4875, Validation F1: 0.6333
# Epoch 11, Training Loss: 0.6908260583877563, Train F1: 0.4875, Validation F1: 0.6333
# Epoch 12, Training Loss: 0.6906694173812866, Train F1: 0.4875, Validation F1: 0.6333
# Epoch 13, Training Loss: 0.6905137896537781, Train F1: 0.4875, Validation F1: 0.6333
# Epoch 14, Training Loss: 0.6903610229492188, Train F1: 0.4875, Validation F1: 0.6333
# Epoch 15, Training Loss: 0.6902111768722534, Train F1: 0.4875, Validation F1: 0.6333
# Epoch 16, Training Loss: 0.6900639533996582, Train F1: 0.4875, Validation F1: 0.6333
# Epoch 17, Training Loss: 0.6899224519729614, Train F1: 0.4875, Validation F1: 0.6333
# Epoch 18, Training Loss: 0.689781904220581, Train F1: 0.4875, Validation F1: 0.6333
# Epoch 19, Training Loss: 0.6896423697471619, Train F1: 0.5000, Validation F1: 0.6333
# Epoch 20, Training Loss: 0.6895037889480591, Train F1: 0.5000, Validation F1: 0.6333
# Epoch 21, Training Loss: 0.6893652677536011, Train F1: 0.5000, Validation F1: 0.6333
# Epoch 22, Training Loss: 0.689228355884552, Train F1: 0.5000, Validation F1: 0.6333
# Epoch 23, Training Loss: 0.6890920996665955, Train F1: 0.5000, Validation F1: 0.6333
# Epoch 24, Training Loss: 0.6889567971229553, Train F1: 0.5000, Validation F1: 0.6333
# Epoch 25, Training Loss: 0.6888219714164734, Train F1: 0.5125, Validation F1: 0.6333
# Epoch 26, Training Loss: 0.6886871457099915, Train F1: 0.5125, Validation F1: 0.6333
# Epoch 27, Training Loss: 0.6885542869567871, Train F1: 0.5125, Validation F1: 0.6333
# Epoch 28, Training Loss: 0.688419759273529, Train F1: 0.5125, Validation F1: 0.6333
# Epoch 29, Training Loss: 0.6882861852645874, Train F1: 0.5125, Validation F1: 0.6333
# Epoch 30, Training Loss: 0.6881548166275024, Train F1: 0.5125, Validation F1: 0.6667
# Epoch 31, Training Loss: 0.6880238056182861, Train F1: 0.5125, Validation F1: 0.6667
# Epoch 32, Training Loss: 0.6878949403762817, Train F1: 0.5125, Validation F1: 0.6667
# Epoch 33, Training Loss: 0.6877654790878296, Train F1: 0.5125, Validation F1: 0.6667
# Epoch 34, Training Loss: 0.6876380443572998, Train F1: 0.5125, Validation F1: 0.6667
# Epoch 35, Training Loss: 0.6875094771385193, Train F1: 0.5125, Validation F1: 0.6667
# Epoch 36, Training Loss: 0.6873800158500671, Train F1: 0.5250, Validation F1: 0.6667
# Epoch 37, Training Loss: 0.6872526407241821, Train F1: 0.5375, Validation F1: 0.6667
# Epoch 38, Training Loss: 0.687127411365509, Train F1: 0.5375, Validation F1: 0.6667
# Epoch 39, Training Loss: 0.6869997978210449, Train F1: 0.5375, Validation F1: 0.6667
# Epoch 40, Training Loss: 0.686870276927948, Train F1: 0.5375, Validation F1: 0.6667
# Epoch 41, Training Loss: 0.6867402791976929, Train F1: 0.5375, Validation F1: 0.6667
# Epoch 42, Training Loss: 0.6866104006767273, Train F1: 0.5375, Validation F1: 0.6667
# Epoch 43, Training Loss: 0.6864800453186035, Train F1: 0.5375, Validation F1: 0.6667
# Epoch 44, Training Loss: 0.6863510608673096, Train F1: 0.5375, Validation F1: 0.6667
# Epoch 45, Training Loss: 0.6862257719039917, Train F1: 0.5250, Validation F1: 0.6667
# Epoch 46, Training Loss: 0.6861023902893066, Train F1: 0.5250, Validation F1: 0.6667
# Epoch 47, Training Loss: 0.6859803795814514, Train F1: 0.5375, Validation F1: 0.6667
# Epoch 48, Training Loss: 0.6858577132225037, Train F1: 0.5375, Validation F1: 0.6667
# Epoch 49, Training Loss: 0.6857329607009888, Train F1: 0.5375, Validation F1: 0.6667
# Epoch 50, Training Loss: 0.6856063604354858, Train F1: 0.5375, Validation F1: 0.6667
# Epoch 51, Training Loss: 0.6854778528213501, Train F1: 0.5375, Validation F1: 0.6667
# Epoch 52, Training Loss: 0.685346782207489, Train F1: 0.5375, Validation F1: 0.6667
# Epoch 53, Training Loss: 0.6852138042449951, Train F1: 0.5500, Validation F1: 0.7000
# Epoch 54, Training Loss: 0.6850779056549072, Train F1: 0.5625, Validation F1: 0.7000
# Epoch 55, Training Loss: 0.6849459409713745, Train F1: 0.5625, Validation F1: 0.7000
# Epoch 56, Training Loss: 0.6848145723342896, Train F1: 0.5625, Validation F1: 0.7333
# Epoch 57, Training Loss: 0.6846852898597717, Train F1: 0.5625, Validation F1: 0.7333
# Epoch 58, Training Loss: 0.6845536231994629, Train F1: 0.5625, Validation F1: 0.7333
# Epoch 59, Training Loss: 0.684419572353363, Train F1: 0.5875, Validation F1: 0.7333
# Epoch 60, Training Loss: 0.6842830777168274, Train F1: 0.5750, Validation F1: 0.7667
# Epoch 61, Training Loss: 0.6841446161270142, Train F1: 0.5750, Validation F1: 0.7667
# Epoch 62, Training Loss: 0.6840067505836487, Train F1: 0.5750, Validation F1: 0.7333
# Epoch 63, Training Loss: 0.6838716268539429, Train F1: 0.5750, Validation F1: 0.7333
# Epoch 64, Training Loss: 0.6837340593338013, Train F1: 0.5750, Validation F1: 0.7000
# Epoch 65, Training Loss: 0.6835908889770508, Train F1: 0.5750, Validation F1: 0.7000
# Epoch 66, Training Loss: 0.6834408044815063, Train F1: 0.5750, Validation F1: 0.7000
# Epoch 67, Training Loss: 0.6832883954048157, Train F1: 0.5750, Validation F1: 0.7000
# Epoch 68, Training Loss: 0.6831276416778564, Train F1: 0.5750, Validation F1: 0.7000
# Epoch 69, Training Loss: 0.6829670071601868, Train F1: 0.5750, Validation F1: 0.7000
# Epoch 70, Training Loss: 0.6828068494796753, Train F1: 0.5750, Validation F1: 0.7000
# Epoch 71, Training Loss: 0.6826484203338623, Train F1: 0.5875, Validation F1: 0.7000
# Epoch 72, Training Loss: 0.6824901103973389, Train F1: 0.5875, Validation F1: 0.7000
# Epoch 73, Training Loss: 0.6823273301124573, Train F1: 0.5875, Validation F1: 0.7000
# Epoch 74, Training Loss: 0.6821590662002563, Train F1: 0.5875, Validation F1: 0.7000
# Epoch 75, Training Loss: 0.6819936037063599, Train F1: 0.5750, Validation F1: 0.7000
# Epoch 76, Training Loss: 0.6818262934684753, Train F1: 0.5750, Validation F1: 0.7000
# Epoch 77, Training Loss: 0.6816533803939819, Train F1: 0.5750, Validation F1: 0.7000
# Epoch 78, Training Loss: 0.6814827919006348, Train F1: 0.5750, Validation F1: 0.7000
# Epoch 79, Training Loss: 0.6813063025474548, Train F1: 0.5875, Validation F1: 0.7000
# Epoch 80, Training Loss: 0.681120753288269, Train F1: 0.5875, Validation F1: 0.7000
# Epoch 81, Training Loss: 0.6809318661689758, Train F1: 0.5875, Validation F1: 0.7000
# Epoch 82, Training Loss: 0.6807368397712708, Train F1: 0.5875, Validation F1: 0.7000
# Epoch 83, Training Loss: 0.6805366277694702, Train F1: 0.6000, Validation F1: 0.7000
# Epoch 84, Training Loss: 0.6803317666053772, Train F1: 0.6250, Validation F1: 0.7000
# Epoch 85, Training Loss: 0.6801231503486633, Train F1: 0.6250, Validation F1: 0.7000
# Epoch 86, Training Loss: 0.6799101829528809, Train F1: 0.6250, Validation F1: 0.7000
# Epoch 87, Training Loss: 0.6797038316726685, Train F1: 0.6250, Validation F1: 0.7000
# Epoch 88, Training Loss: 0.6795070767402649, Train F1: 0.6250, Validation F1: 0.7000
# Epoch 89, Training Loss: 0.6793133020401001, Train F1: 0.6125, Validation F1: 0.7000
# Epoch 90, Training Loss: 0.6791176795959473, Train F1: 0.6125, Validation F1: 0.7000
# Epoch 91, Training Loss: 0.678920328617096, Train F1: 0.6125, Validation F1: 0.7333
# Epoch 92, Training Loss: 0.6787163019180298, Train F1: 0.6125, Validation F1: 0.7333
# Epoch 93, Training Loss: 0.6785145401954651, Train F1: 0.6125, Validation F1: 0.7333
# Epoch 94, Training Loss: 0.6783178448677063, Train F1: 0.6125, Validation F1: 0.7333
# Epoch 95, Training Loss: 0.6781262159347534, Train F1: 0.6000, Validation F1: 0.7333
# Epoch 96, Training Loss: 0.6779375672340393, Train F1: 0.6000, Validation F1: 0.7333
# Epoch 97, Training Loss: 0.6777573823928833, Train F1: 0.6000, Validation F1: 0.7333
# Epoch 98, Training Loss: 0.6775785088539124, Train F1: 0.6000, Validation F1: 0.7333
# Epoch 99, Training Loss: 0.6774007678031921, Train F1: 0.5875, Validation F1: 0.7333
# Epoch 100, Training Loss: 0.6772217154502869, Train F1: 0.5875, Validation F1: 0.7333
# Epoch 101, Training Loss: 0.6770440340042114, Train F1: 0.6000, Validation F1: 0.7333
# Epoch 102, Training Loss: 0.6768690347671509, Train F1: 0.6125, Validation F1: 0.7333
# Epoch 103, Training Loss: 0.6767004132270813, Train F1: 0.6125, Validation F1: 0.7333
# Epoch 104, Training Loss: 0.6765318512916565, Train F1: 0.6125, Validation F1: 0.7333
# Epoch 105, Training Loss: 0.6763643026351929, Train F1: 0.6125, Validation F1: 0.7333
# Epoch 106, Training Loss: 0.6761970520019531, Train F1: 0.6125, Validation F1: 0.7333
# Epoch 107, Training Loss: 0.6760320067405701, Train F1: 0.6125, Validation F1: 0.7333
# Epoch 108, Training Loss: 0.6758705377578735, Train F1: 0.6125, Validation F1: 0.7333
# Epoch 109, Training Loss: 0.6757128834724426, Train F1: 0.6125, Validation F1: 0.7333
# Epoch 110, Training Loss: 0.6755544543266296, Train F1: 0.6125, Validation F1: 0.7333
# Epoch 111, Training Loss: 0.6753956079483032, Train F1: 0.6250, Validation F1: 0.7333
# Epoch 112, Training Loss: 0.6752364039421082, Train F1: 0.6375, Validation F1: 0.7333
# Epoch 113, Training Loss: 0.6750777363777161, Train F1: 0.6375, Validation F1: 0.7333
# Epoch 114, Training Loss: 0.6749202013015747, Train F1: 0.6375, Validation F1: 0.7333
# Epoch 115, Training Loss: 0.6747649312019348, Train F1: 0.6375, Validation F1: 0.7333
# Epoch 116, Training Loss: 0.674611508846283, Train F1: 0.6375, Validation F1: 0.7333
# Epoch 117, Training Loss: 0.6744559407234192, Train F1: 0.6375, Validation F1: 0.7333
# Epoch 118, Training Loss: 0.6742992401123047, Train F1: 0.6375, Validation F1: 0.7333
# Epoch 119, Training Loss: 0.674142599105835, Train F1: 0.6375, Validation F1: 0.7333
# Epoch 120, Training Loss: 0.673984944820404, Train F1: 0.6375, Validation F1: 0.7333
# Epoch 121, Training Loss: 0.6738263964653015, Train F1: 0.6375, Validation F1: 0.7333
# Epoch 122, Training Loss: 0.6736682653427124, Train F1: 0.6375, Validation F1: 0.7333
# Epoch 123, Training Loss: 0.6735103130340576, Train F1: 0.6375, Validation F1: 0.7333
# Epoch 124, Training Loss: 0.6733536720275879, Train F1: 0.6250, Validation F1: 0.7333
# Epoch 125, Training Loss: 0.673197329044342, Train F1: 0.6250, Validation F1: 0.7333
# Epoch 126, Training Loss: 0.6730495691299438, Train F1: 0.6250, Validation F1: 0.7333
# Epoch 127, Training Loss: 0.6729060411453247, Train F1: 0.6250, Validation F1: 0.7333
# Epoch 128, Training Loss: 0.6727617979049683, Train F1: 0.6250, Validation F1: 0.7333
# Epoch 129, Training Loss: 0.6726142168045044, Train F1: 0.6250, Validation F1: 0.7333
# Epoch 130, Training Loss: 0.6724638938903809, Train F1: 0.6250, Validation F1: 0.7333
# Epoch 131, Training Loss: 0.6723126769065857, Train F1: 0.6250, Validation F1: 0.7333
# Epoch 132, Training Loss: 0.6721622943878174, Train F1: 0.6250, Validation F1: 0.7333
# Epoch 133, Training Loss: 0.6720149517059326, Train F1: 0.6250, Validation F1: 0.7333
# Epoch 134, Training Loss: 0.6718659996986389, Train F1: 0.6250, Validation F1: 0.7333
# Epoch 135, Training Loss: 0.6717150211334229, Train F1: 0.6250, Validation F1: 0.7333
# Epoch 136, Training Loss: 0.6715668439865112, Train F1: 0.6250, Validation F1: 0.7333
# Epoch 137, Training Loss: 0.6714221239089966, Train F1: 0.6250, Validation F1: 0.7333
# Epoch 138, Training Loss: 0.6712851524353027, Train F1: 0.6250, Validation F1: 0.7333
# Epoch 139, Training Loss: 0.6711479425430298, Train F1: 0.6250, Validation F1: 0.7333
# Epoch 140, Training Loss: 0.671011745929718, Train F1: 0.6250, Validation F1: 0.7333
# Epoch 141, Training Loss: 0.6708722114562988, Train F1: 0.6250, Validation F1: 0.7333
# Epoch 142, Training Loss: 0.6707347631454468, Train F1: 0.6250, Validation F1: 0.7333
# Epoch 143, Training Loss: 0.6705955266952515, Train F1: 0.6250, Validation F1: 0.7333
# Epoch 144, Training Loss: 0.67045658826828, Train F1: 0.6250, Validation F1: 0.7333
# Epoch 145, Training Loss: 0.6703171133995056, Train F1: 0.6250, Validation F1: 0.7333
# Epoch 146, Training Loss: 0.6701816916465759, Train F1: 0.6250, Validation F1: 0.7333
# Epoch 147, Training Loss: 0.6700491905212402, Train F1: 0.6250, Validation F1: 0.7333
# Epoch 148, Training Loss: 0.6699155569076538, Train F1: 0.6250, Validation F1: 0.7333
# Epoch 149, Training Loss: 0.6697791218757629, Train F1: 0.6250, Validation F1: 0.7333
# Epoch 150, Training Loss: 0.6696416735649109, Train F1: 0.6250, Validation F1: 0.7333
# Epoch 151, Training Loss: 0.6695030331611633, Train F1: 0.6250, Validation F1: 0.7333
# Epoch 152, Training Loss: 0.6693663001060486, Train F1: 0.6250, Validation F1: 0.7333
# Epoch 153, Training Loss: 0.6692278385162354, Train F1: 0.6250, Validation F1: 0.7333
# Epoch 154, Training Loss: 0.6690893173217773, Train F1: 0.6250, Validation F1: 0.7333
# Epoch 155, Training Loss: 0.6689490079879761, Train F1: 0.6250, Validation F1: 0.7333
# Epoch 156, Training Loss: 0.6688060164451599, Train F1: 0.6250, Validation F1: 0.7333
# Epoch 157, Training Loss: 0.6686657071113586, Train F1: 0.6250, Validation F1: 0.7333
# Epoch 158, Training Loss: 0.6685258150100708, Train F1: 0.6250, Validation F1: 0.7333
# Epoch 159, Training Loss: 0.6683858036994934, Train F1: 0.6250, Validation F1: 0.7333
# Epoch 160, Training Loss: 0.6682443022727966, Train F1: 0.6250, Validation F1: 0.7333
# Epoch 161, Training Loss: 0.6681032776832581, Train F1: 0.6250, Validation F1: 0.7333
# Epoch 162, Training Loss: 0.6679622530937195, Train F1: 0.6250, Validation F1: 0.7333
# Epoch 163, Training Loss: 0.6678207516670227, Train F1: 0.6250, Validation F1: 0.7333
# Epoch 164, Training Loss: 0.667677640914917, Train F1: 0.6250, Validation F1: 0.7333
# Epoch 165, Training Loss: 0.6675335168838501, Train F1: 0.6250, Validation F1: 0.7333
# Epoch 166, Training Loss: 0.6673908233642578, Train F1: 0.6250, Validation F1: 0.7333
# Epoch 167, Training Loss: 0.6672495007514954, Train F1: 0.6250, Validation F1: 0.7333
# Epoch 168, Training Loss: 0.6671091318130493, Train F1: 0.6250, Validation F1: 0.7333
# Epoch 169, Training Loss: 0.6669696569442749, Train F1: 0.6250, Validation F1: 0.7333
# Epoch 170, Training Loss: 0.6668313145637512, Train F1: 0.6250, Validation F1: 0.7333
# Epoch 171, Training Loss: 0.6666939854621887, Train F1: 0.6250, Validation F1: 0.7333
# Epoch 172, Training Loss: 0.6665562391281128, Train F1: 0.6250, Validation F1: 0.7333
# Epoch 173, Training Loss: 0.6664164662361145, Train F1: 0.6125, Validation F1: 0.7333
# Epoch 174, Training Loss: 0.6662763357162476, Train F1: 0.6125, Validation F1: 0.7333
# Epoch 175, Training Loss: 0.6661357283592224, Train F1: 0.6125, Validation F1: 0.7333
# Epoch 176, Training Loss: 0.6659950017929077, Train F1: 0.6125, Validation F1: 0.7333
# Epoch 177, Training Loss: 0.6658539772033691, Train F1: 0.6250, Validation F1: 0.7333
# Epoch 178, Training Loss: 0.6657124757766724, Train F1: 0.6250, Validation F1: 0.7333
# Epoch 179, Training Loss: 0.6655710935592651, Train F1: 0.6250, Validation F1: 0.7333
# Epoch 180, Training Loss: 0.6654272079467773, Train F1: 0.6250, Validation F1: 0.7333
# Epoch 181, Training Loss: 0.6652823686599731, Train F1: 0.6250, Validation F1: 0.7000
# Epoch 182, Training Loss: 0.6651372909545898, Train F1: 0.6250, Validation F1: 0.7000
# Epoch 183, Training Loss: 0.6649921536445618, Train F1: 0.6250, Validation F1: 0.7000
# Epoch 184, Training Loss: 0.66484534740448, Train F1: 0.6250, Validation F1: 0.7000
# Epoch 185, Training Loss: 0.6646974682807922, Train F1: 0.6250, Validation F1: 0.7000
# Epoch 186, Training Loss: 0.6645503044128418, Train F1: 0.6250, Validation F1: 0.7000
# Epoch 187, Training Loss: 0.6644008755683899, Train F1: 0.6250, Validation F1: 0.7000
# Epoch 188, Training Loss: 0.6642512679100037, Train F1: 0.6250, Validation F1: 0.7000
# Epoch 189, Training Loss: 0.6641027331352234, Train F1: 0.6250, Validation F1: 0.7000
# Epoch 190, Training Loss: 0.6639528274536133, Train F1: 0.6250, Validation F1: 0.7000
# Epoch 191, Training Loss: 0.6638032793998718, Train F1: 0.6250, Validation F1: 0.7000
# Epoch 192, Training Loss: 0.6636544466018677, Train F1: 0.6250, Validation F1: 0.7000
# Epoch 193, Training Loss: 0.6635051369667053, Train F1: 0.6250, Validation F1: 0.7000
# Epoch 194, Training Loss: 0.66335529088974, Train F1: 0.6250, Validation F1: 0.7000
# Epoch 195, Training Loss: 0.6632039546966553, Train F1: 0.6250, Validation F1: 0.7000
# Epoch 196, Training Loss: 0.663053572177887, Train F1: 0.6250, Validation F1: 0.7000
# Epoch 197, Training Loss: 0.6629039645195007, Train F1: 0.6250, Validation F1: 0.7000
# Epoch 198, Training Loss: 0.6627534627914429, Train F1: 0.6250, Validation F1: 0.7000
# Epoch 199, Training Loss: 0.662604033946991, Train F1: 0.6250, Validation F1: 0.7000
# Epoch 200, Training Loss: 0.6624544262886047, Train F1: 0.6250, Validation F1: 0.7000
# Epoch 201, Training Loss: 0.6623059511184692, Train F1: 0.6250, Validation F1: 0.7000
# Epoch 202, Training Loss: 0.6621585488319397, Train F1: 0.6250, Validation F1: 0.7000
# Epoch 203, Training Loss: 0.6620133519172668, Train F1: 0.6250, Validation F1: 0.7000
# Epoch 204, Training Loss: 0.6618664264678955, Train F1: 0.6250, Validation F1: 0.7333
# Epoch 205, Training Loss: 0.6617184281349182, Train F1: 0.6250, Validation F1: 0.7333
# Epoch 206, Training Loss: 0.6615692973136902, Train F1: 0.6250, Validation F1: 0.7333
# Epoch 207, Training Loss: 0.6614185571670532, Train F1: 0.6250, Validation F1: 0.7333
# Epoch 208, Training Loss: 0.6612654328346252, Train F1: 0.6250, Validation F1: 0.7333
# Epoch 209, Training Loss: 0.6611135601997375, Train F1: 0.6250, Validation F1: 0.7333
# Epoch 210, Training Loss: 0.6609624028205872, Train F1: 0.6250, Validation F1: 0.7333
# Epoch 211, Training Loss: 0.6608114242553711, Train F1: 0.6250, Validation F1: 0.7333
# Epoch 212, Training Loss: 0.6606592535972595, Train F1: 0.6250, Validation F1: 0.7333
# Epoch 213, Training Loss: 0.6605085134506226, Train F1: 0.6250, Validation F1: 0.7333
# Epoch 214, Training Loss: 0.660358190536499, Train F1: 0.6250, Validation F1: 0.7333
# Epoch 215, Training Loss: 0.6602067947387695, Train F1: 0.6250, Validation F1: 0.7333
# Epoch 216, Training Loss: 0.6600550413131714, Train F1: 0.6250, Validation F1: 0.7333
# Epoch 217, Training Loss: 0.6599038243293762, Train F1: 0.6250, Validation F1: 0.7333
# Epoch 218, Training Loss: 0.6597527861595154, Train F1: 0.6250, Validation F1: 0.7333
# Epoch 219, Training Loss: 0.6596014499664307, Train F1: 0.6250, Validation F1: 0.7333
# Epoch 220, Training Loss: 0.6594491600990295, Train F1: 0.6250, Validation F1: 0.7333
# Epoch 221, Training Loss: 0.6592955589294434, Train F1: 0.6250, Validation F1: 0.7333
# Epoch 222, Training Loss: 0.6591430902481079, Train F1: 0.6250, Validation F1: 0.7333
# Epoch 223, Training Loss: 0.6589905023574829, Train F1: 0.6250, Validation F1: 0.7333
# Epoch 224, Training Loss: 0.6588355898857117, Train F1: 0.6250, Validation F1: 0.7333
# Epoch 225, Training Loss: 0.6586828231811523, Train F1: 0.6250, Validation F1: 0.7333
# Epoch 226, Training Loss: 0.6585277318954468, Train F1: 0.6375, Validation F1: 0.7333
# Epoch 227, Training Loss: 0.6583718061447144, Train F1: 0.6250, Validation F1: 0.7333
# Epoch 228, Training Loss: 0.6582177877426147, Train F1: 0.6250, Validation F1: 0.7333
# Epoch 229, Training Loss: 0.6580626368522644, Train F1: 0.6250, Validation F1: 0.7333
# Epoch 230, Training Loss: 0.6579053401947021, Train F1: 0.6375, Validation F1: 0.7333
# Epoch 231, Training Loss: 0.6577461957931519, Train F1: 0.6500, Validation F1: 0.7333
# Epoch 232, Training Loss: 0.6575878262519836, Train F1: 0.6500, Validation F1: 0.7333
# Epoch 233, Training Loss: 0.6574293971061707, Train F1: 0.6500, Validation F1: 0.7333
# Epoch 234, Training Loss: 0.6572696566581726, Train F1: 0.6500, Validation F1: 0.7333
# Epoch 235, Training Loss: 0.6571089029312134, Train F1: 0.6500, Validation F1: 0.7333
# Epoch 236, Training Loss: 0.6569474935531616, Train F1: 0.6500, Validation F1: 0.7333
# Epoch 237, Training Loss: 0.6567857265472412, Train F1: 0.6625, Validation F1: 0.7333
# Epoch 238, Training Loss: 0.656623363494873, Train F1: 0.6625, Validation F1: 0.7333
# Epoch 239, Training Loss: 0.6564596891403198, Train F1: 0.6625, Validation F1: 0.7333
# Epoch 240, Training Loss: 0.6562958359718323, Train F1: 0.6625, Validation F1: 0.7333
# Epoch 241, Training Loss: 0.6561303734779358, Train F1: 0.6625, Validation F1: 0.7333
# Epoch 242, Training Loss: 0.655964195728302, Train F1: 0.6625, Validation F1: 0.7333
# Epoch 243, Training Loss: 0.6557966470718384, Train F1: 0.6625, Validation F1: 0.7333
# Epoch 244, Training Loss: 0.6556277275085449, Train F1: 0.6625, Validation F1: 0.7333
# Epoch 245, Training Loss: 0.655457615852356, Train F1: 0.6625, Validation F1: 0.7333
# Epoch 246, Training Loss: 0.6552865505218506, Train F1: 0.6625, Validation F1: 0.7333
# Epoch 247, Training Loss: 0.6551159024238586, Train F1: 0.6625, Validation F1: 0.7667
# Epoch 248, Training Loss: 0.6549423933029175, Train F1: 0.6625, Validation F1: 0.7667
# Epoch 249, Training Loss: 0.6547706723213196, Train F1: 0.6625, Validation F1: 0.7667
# Epoch 250, Training Loss: 0.6546000242233276, Train F1: 0.6625, Validation F1: 0.7667
# Iteration 0: G1 Results: f1=0.7666666666666667
# LayeredGCN(
#   (layers): ModuleList(
#     (0-2): 3 x GCNLayer()
#   )
#   (output_layer): GCNLayer()
# )
# Epoch 1, Training Loss: 0.6919777989387512, Train F1: 0.6250, Validation F1: 0.6333
# Epoch 2, Training Loss: 0.6918195486068726, Train F1: 0.6250, Validation F1: 0.6333
# Epoch 3, Training Loss: 0.6916572451591492, Train F1: 0.6500, Validation F1: 0.6333
# Epoch 4, Training Loss: 0.6914827227592468, Train F1: 0.6500, Validation F1: 0.6333
# Epoch 5, Training Loss: 0.6912978291511536, Train F1: 0.6875, Validation F1: 0.6333
# Epoch 6, Training Loss: 0.691110372543335, Train F1: 0.7000, Validation F1: 0.6333
# Epoch 7, Training Loss: 0.690918505191803, Train F1: 0.7000, Validation F1: 0.6333
# Epoch 8, Training Loss: 0.6907298564910889, Train F1: 0.7250, Validation F1: 0.6000
# Epoch 9, Training Loss: 0.6905395984649658, Train F1: 0.7375, Validation F1: 0.6000
# Epoch 10, Training Loss: 0.6903494000434875, Train F1: 0.7125, Validation F1: 0.6000
# Epoch 11, Training Loss: 0.6901594400405884, Train F1: 0.7125, Validation F1: 0.6000
# Epoch 12, Training Loss: 0.6899694800376892, Train F1: 0.7375, Validation F1: 0.6000
# Epoch 13, Training Loss: 0.6897757053375244, Train F1: 0.7375, Validation F1: 0.6000
# Epoch 14, Training Loss: 0.6895756721496582, Train F1: 0.7375, Validation F1: 0.6333
# Epoch 15, Training Loss: 0.6893676519393921, Train F1: 0.7375, Validation F1: 0.6333
# Epoch 16, Training Loss: 0.689155101776123, Train F1: 0.7500, Validation F1: 0.6333
# Epoch 17, Training Loss: 0.688939094543457, Train F1: 0.7625, Validation F1: 0.6333
# Epoch 18, Training Loss: 0.6887208223342896, Train F1: 0.7625, Validation F1: 0.6333
# Epoch 19, Training Loss: 0.688501238822937, Train F1: 0.7750, Validation F1: 0.6333
# Epoch 20, Training Loss: 0.6882815361022949, Train F1: 0.7875, Validation F1: 0.6333
# Epoch 21, Training Loss: 0.6880606412887573, Train F1: 0.8000, Validation F1: 0.6333
# Epoch 22, Training Loss: 0.6878379583358765, Train F1: 0.8000, Validation F1: 0.6333
# Epoch 23, Training Loss: 0.6876134872436523, Train F1: 0.8000, Validation F1: 0.6667
# Epoch 24, Training Loss: 0.6873868107795715, Train F1: 0.8000, Validation F1: 0.6667
# Epoch 25, Training Loss: 0.6871566772460938, Train F1: 0.8000, Validation F1: 0.6667
# Epoch 26, Training Loss: 0.6869226694107056, Train F1: 0.8125, Validation F1: 0.6667
# Epoch 27, Training Loss: 0.6866868138313293, Train F1: 0.8125, Validation F1: 0.7000
# Epoch 28, Training Loss: 0.6864500045776367, Train F1: 0.8125, Validation F1: 0.7000
# Epoch 29, Training Loss: 0.6862137317657471, Train F1: 0.8125, Validation F1: 0.7000
# Epoch 30, Training Loss: 0.6859759092330933, Train F1: 0.8125, Validation F1: 0.7333
# Epoch 31, Training Loss: 0.6857365369796753, Train F1: 0.8125, Validation F1: 0.7333
# Epoch 32, Training Loss: 0.6854960322380066, Train F1: 0.8125, Validation F1: 0.7333
# Epoch 33, Training Loss: 0.6852544546127319, Train F1: 0.8125, Validation F1: 0.7333
# Epoch 34, Training Loss: 0.6850107908248901, Train F1: 0.8125, Validation F1: 0.7333
# Epoch 35, Training Loss: 0.684766411781311, Train F1: 0.8125, Validation F1: 0.7333
# Epoch 36, Training Loss: 0.6845210194587708, Train F1: 0.8250, Validation F1: 0.7333
# Epoch 37, Training Loss: 0.6842735409736633, Train F1: 0.8250, Validation F1: 0.7333
# Epoch 38, Training Loss: 0.6840254068374634, Train F1: 0.8250, Validation F1: 0.7333
# Epoch 39, Training Loss: 0.6837760210037231, Train F1: 0.8250, Validation F1: 0.7333
# Epoch 40, Training Loss: 0.6835243105888367, Train F1: 0.8250, Validation F1: 0.7333
# Epoch 41, Training Loss: 0.6832723617553711, Train F1: 0.8250, Validation F1: 0.7333
# Epoch 42, Training Loss: 0.6830178499221802, Train F1: 0.8250, Validation F1: 0.7333
# Epoch 43, Training Loss: 0.6827607750892639, Train F1: 0.8250, Validation F1: 0.7333
# Epoch 44, Training Loss: 0.6825010180473328, Train F1: 0.8250, Validation F1: 0.7333
# Epoch 45, Training Loss: 0.6822382211685181, Train F1: 0.8250, Validation F1: 0.7333
# Epoch 46, Training Loss: 0.6819735765457153, Train F1: 0.8250, Validation F1: 0.7333
# Epoch 47, Training Loss: 0.6817065477371216, Train F1: 0.8250, Validation F1: 0.7333
# Epoch 48, Training Loss: 0.6814366579055786, Train F1: 0.8250, Validation F1: 0.7333
# Epoch 49, Training Loss: 0.6811634302139282, Train F1: 0.8250, Validation F1: 0.7333
# Epoch 50, Training Loss: 0.6808871030807495, Train F1: 0.8250, Validation F1: 0.7333
# Epoch 51, Training Loss: 0.6806076169013977, Train F1: 0.8250, Validation F1: 0.7333
# Epoch 52, Training Loss: 0.6803251504898071, Train F1: 0.8250, Validation F1: 0.7333
# Epoch 53, Training Loss: 0.6800403594970703, Train F1: 0.8250, Validation F1: 0.7333
# Epoch 54, Training Loss: 0.6797528862953186, Train F1: 0.8250, Validation F1: 0.7333
# Epoch 55, Training Loss: 0.6794622540473938, Train F1: 0.8250, Validation F1: 0.7333
# Epoch 56, Training Loss: 0.679168701171875, Train F1: 0.8250, Validation F1: 0.7333
# Epoch 57, Training Loss: 0.6788730025291443, Train F1: 0.8250, Validation F1: 0.7333
# Epoch 58, Training Loss: 0.6785763502120972, Train F1: 0.8250, Validation F1: 0.7333
# ...
# Epoch 65, Training Loss: 0.6878403425216675, Train F1: 0.5000, Validation F1: 0.3667
# Epoch 66, Training Loss: 0.6875826120376587, Train F1: 0.5000, Validation F1: 0.3667
# Epoch 67, Training Loss: 0.6873326301574707, Train F1: 0.5000, Validation F1: 0.3333
# Epoch 68, Training Loss: 0.6870831251144409, Train F1: 0.5125, Validation F1: 0.3333
# Epoch 69, Training Loss: 0.6868279576301575, Train F1: 0.5125, Validation F1: 0.3333
# Epoch 70, Training Loss: 0.6865698099136353, Train F1: 0.5250, Validation F1: 0.3333
# Epoch 71, Training Loss: 0.6863180994987488, Train F1: 0.5250, Validation F1: 0.3667
# Epoch 72, Training Loss: 0.6860607862472534, Train F1: 0.5250, Validation F1: 0.3667
# Epoch 73, Training Loss: 0.685808002948761, Train F1: 0.5250, Validation F1: 0.4000
# Epoch 74, Training Loss: 0.6855550408363342, Train F1: 0.5250, Validation F1: 0.4000
# Epoch 75, Training Loss: 0.6853082180023193, Train F1: 0.5250, Validation F1: 0.4000
# Epoch 76, Training Loss: 0.6850630044937134, Train F1: 0.5250, Validation F1: 0.4000
# Epoch 77, Training Loss: 0.6848137974739075, Train F1: 0.5250, Validation F1: 0.4000
# Epoch 78, Training Loss: 0.6845593452453613, Train F1: 0.5250, Validation F1: 0.4000
# Epoch 79, Training Loss: 0.6843053102493286, Train F1: 0.5375, Validation F1: 0.4000
# Epoch 80, Training Loss: 0.6840496063232422, Train F1: 0.5375, Validation F1: 0.4000
# Epoch 81, Training Loss: 0.6837912797927856, Train F1: 0.5375, Validation F1: 0.4000
# Epoch 82, Training Loss: 0.6835368275642395, Train F1: 0.5375, Validation F1: 0.4000
# Epoch 83, Training Loss: 0.6832824945449829, Train F1: 0.5375, Validation F1: 0.4000
# Epoch 84, Training Loss: 0.6830271482467651, Train F1: 0.5375, Validation F1: 0.4000
# Epoch 85, Training Loss: 0.6827681660652161, Train F1: 0.5500, Validation F1: 0.4000
# Epoch 86, Training Loss: 0.6825038194656372, Train F1: 0.5500, Validation F1: 0.4000
# Epoch 87, Training Loss: 0.6822388172149658, Train F1: 0.5500, Validation F1: 0.4000
# Epoch 88, Training Loss: 0.6819800138473511, Train F1: 0.5500, Validation F1: 0.4000
# Epoch 89, Training Loss: 0.6817194223403931, Train F1: 0.5625, Validation F1: 0.4333
# Epoch 90, Training Loss: 0.6814568638801575, Train F1: 0.5625, Validation F1: 0.4333
# Epoch 91, Training Loss: 0.6811946630477905, Train F1: 0.5625, Validation F1: 0.4333
# Epoch 92, Training Loss: 0.6809349060058594, Train F1: 0.5625, Validation F1: 0.4333
# Epoch 93, Training Loss: 0.6806615591049194, Train F1: 0.5625, Validation F1: 0.4333
# Epoch 94, Training Loss: 0.6803900003433228, Train F1: 0.5625, Validation F1: 0.4333
# Epoch 95, Training Loss: 0.6801172494888306, Train F1: 0.5500, Validation F1: 0.4333
# Epoch 96, Training Loss: 0.6798431277275085, Train F1: 0.5625, Validation F1: 0.4333
# Epoch 97, Training Loss: 0.6795629262924194, Train F1: 0.5625, Validation F1: 0.4333
# Epoch 98, Training Loss: 0.6792842149734497, Train F1: 0.5625, Validation F1: 0.4333
# Epoch 99, Training Loss: 0.6790078282356262, Train F1: 0.5625, Validation F1: 0.4333
# Epoch 100, Training Loss: 0.6787447929382324, Train F1: 0.5625, Validation F1: 0.4333
# Epoch 101, Training Loss: 0.6784958243370056, Train F1: 0.5750, Validation F1: 0.4667
# Epoch 102, Training Loss: 0.678249716758728, Train F1: 0.5750, Validation F1: 0.4667
# Epoch 103, Training Loss: 0.6780052185058594, Train F1: 0.5750, Validation F1: 0.4667
# Epoch 104, Training Loss: 0.6777604818344116, Train F1: 0.5750, Validation F1: 0.4667
# Epoch 105, Training Loss: 0.6775134801864624, Train F1: 0.5750, Validation F1: 0.5000
# Epoch 106, Training Loss: 0.6772698760032654, Train F1: 0.5750, Validation F1: 0.5000
# Epoch 107, Training Loss: 0.677033543586731, Train F1: 0.5750, Validation F1: 0.5000
# Epoch 108, Training Loss: 0.6768025159835815, Train F1: 0.5750, Validation F1: 0.5000
# Epoch 109, Training Loss: 0.6765838265419006, Train F1: 0.5750, Validation F1: 0.5000
# Epoch 110, Training Loss: 0.6763704419136047, Train F1: 0.5875, Validation F1: 0.5000
# Epoch 111, Training Loss: 0.6761647462844849, Train F1: 0.5875, Validation F1: 0.5000
# Epoch 112, Training Loss: 0.6759625673294067, Train F1: 0.6000, Validation F1: 0.5000
# Epoch 113, Training Loss: 0.6757617592811584, Train F1: 0.6125, Validation F1: 0.5000
# Epoch 114, Training Loss: 0.6755595207214355, Train F1: 0.6125, Validation F1: 0.5000
# Epoch 115, Training Loss: 0.6753508448600769, Train F1: 0.6125, Validation F1: 0.5000
# Epoch 116, Training Loss: 0.6751397252082825, Train F1: 0.6250, Validation F1: 0.5000
# Epoch 117, Training Loss: 0.6749181747436523, Train F1: 0.6250, Validation F1: 0.5000
# Epoch 118, Training Loss: 0.6746856570243835, Train F1: 0.6250, Validation F1: 0.5000
# Epoch 119, Training Loss: 0.6744495630264282, Train F1: 0.6250, Validation F1: 0.5000
# Epoch 120, Training Loss: 0.6742181181907654, Train F1: 0.6375, Validation F1: 0.5000
# Epoch 121, Training Loss: 0.6739969849586487, Train F1: 0.6375, Validation F1: 0.5000
# Epoch 122, Training Loss: 0.6737785935401917, Train F1: 0.6375, Validation F1: 0.5000
# Epoch 123, Training Loss: 0.6735629439353943, Train F1: 0.6375, Validation F1: 0.5000
# Epoch 124, Training Loss: 0.6733464002609253, Train F1: 0.6375, Validation F1: 0.5000
# Epoch 125, Training Loss: 0.6731317639350891, Train F1: 0.6375, Validation F1: 0.5000
# Epoch 126, Training Loss: 0.6729311943054199, Train F1: 0.6375, Validation F1: 0.5000
# Epoch 127, Training Loss: 0.6727275848388672, Train F1: 0.6375, Validation F1: 0.5000
# Epoch 128, Training Loss: 0.672518789768219, Train F1: 0.6500, Validation F1: 0.5333
# Epoch 129, Training Loss: 0.6723092794418335, Train F1: 0.6500, Validation F1: 0.5333
# Epoch 130, Training Loss: 0.6721037030220032, Train F1: 0.6500, Validation F1: 0.5333
# Epoch 131, Training Loss: 0.6719017624855042, Train F1: 0.6500, Validation F1: 0.5333
# Epoch 132, Training Loss: 0.6716998815536499, Train F1: 0.6500, Validation F1: 0.5333
# Epoch 133, Training Loss: 0.6715036630630493, Train F1: 0.6500, Validation F1: 0.5333
# Epoch 134, Training Loss: 0.6713062524795532, Train F1: 0.6500, Validation F1: 0.5333
# Epoch 135, Training Loss: 0.6711124777793884, Train F1: 0.6500, Validation F1: 0.5333
# Epoch 136, Training Loss: 0.6709176898002625, Train F1: 0.6625, Validation F1: 0.5333
# Epoch 137, Training Loss: 0.6707227826118469, Train F1: 0.6625, Validation F1: 0.5333
# Epoch 138, Training Loss: 0.6705362200737, Train F1: 0.6625, Validation F1: 0.5333
# Epoch 139, Training Loss: 0.6703518629074097, Train F1: 0.6625, Validation F1: 0.5333
# Epoch 140, Training Loss: 0.6701669096946716, Train F1: 0.6625, Validation F1: 0.5333
# Epoch 141, Training Loss: 0.6699889302253723, Train F1: 0.6500, Validation F1: 0.5333
# Epoch 142, Training Loss: 0.669812798500061, Train F1: 0.6500, Validation F1: 0.5333
# Epoch 143, Training Loss: 0.6696412563323975, Train F1: 0.6500, Validation F1: 0.5333
# Epoch 144, Training Loss: 0.6694731116294861, Train F1: 0.6500, Validation F1: 0.5333
# Epoch 145, Training Loss: 0.6693066358566284, Train F1: 0.6500, Validation F1: 0.5333
# Epoch 146, Training Loss: 0.6691423654556274, Train F1: 0.6500, Validation F1: 0.5333
# Epoch 147, Training Loss: 0.6689795851707458, Train F1: 0.6500, Validation F1: 0.5333
# Epoch 148, Training Loss: 0.6688156723976135, Train F1: 0.6500, Validation F1: 0.5333
# Epoch 149, Training Loss: 0.6686493754386902, Train F1: 0.6375, Validation F1: 0.5333
# Epoch 150, Training Loss: 0.6684804558753967, Train F1: 0.6375, Validation F1: 0.5333
# Epoch 151, Training Loss: 0.6683099269866943, Train F1: 0.6375, Validation F1: 0.5333
# Epoch 152, Training Loss: 0.6681367754936218, Train F1: 0.6375, Validation F1: 0.5333
# Epoch 153, Training Loss: 0.6679680943489075, Train F1: 0.6375, Validation F1: 0.5333
# Epoch 154, Training Loss: 0.667799174785614, Train F1: 0.6375, Validation F1: 0.5333
# Epoch 155, Training Loss: 0.6676310896873474, Train F1: 0.6375, Validation F1: 0.5333
# Epoch 156, Training Loss: 0.667472243309021, Train F1: 0.6375, Validation F1: 0.5333
# Epoch 157, Training Loss: 0.6673117876052856, Train F1: 0.6375, Validation F1: 0.5333
# Epoch 158, Training Loss: 0.6671498417854309, Train F1: 0.6375, Validation F1: 0.5333
# Epoch 159, Training Loss: 0.6669873595237732, Train F1: 0.6375, Validation F1: 0.5333
# Epoch 160, Training Loss: 0.6668245792388916, Train F1: 0.6375, Validation F1: 0.5333
# Epoch 161, Training Loss: 0.6666663885116577, Train F1: 0.6375, Validation F1: 0.5333
# Epoch 162, Training Loss: 0.6665074825286865, Train F1: 0.6375, Validation F1: 0.5333
# Epoch 163, Training Loss: 0.6663450002670288, Train F1: 0.6375, Validation F1: 0.5333
# Epoch 164, Training Loss: 0.6661800742149353, Train F1: 0.6375, Validation F1: 0.5333
# Epoch 165, Training Loss: 0.6660155057907104, Train F1: 0.6375, Validation F1: 0.5333
# Epoch 166, Training Loss: 0.6658498644828796, Train F1: 0.6375, Validation F1: 0.5333
# Epoch 167, Training Loss: 0.665682315826416, Train F1: 0.6375, Validation F1: 0.5333
# Epoch 168, Training Loss: 0.6655181050300598, Train F1: 0.6375, Validation F1: 0.5333
# Epoch 169, Training Loss: 0.6653491258621216, Train F1: 0.6375, Validation F1: 0.5333
# Epoch 170, Training Loss: 0.6651811599731445, Train F1: 0.6375, Validation F1: 0.5333
# Epoch 171, Training Loss: 0.6650153398513794, Train F1: 0.6375, Validation F1: 0.5333
# Epoch 172, Training Loss: 0.6648494005203247, Train F1: 0.6375, Validation F1: 0.5333
# Epoch 173, Training Loss: 0.6646844744682312, Train F1: 0.6375, Validation F1: 0.5333
# Epoch 174, Training Loss: 0.6645199060440063, Train F1: 0.6375, Validation F1: 0.5333
# Epoch 175, Training Loss: 0.6643550395965576, Train F1: 0.6375, Validation F1: 0.5333
# Epoch 176, Training Loss: 0.664192795753479, Train F1: 0.6375, Validation F1: 0.5333
# Epoch 177, Training Loss: 0.6640303730964661, Train F1: 0.6375, Validation F1: 0.5333
# Epoch 178, Training Loss: 0.6638613939285278, Train F1: 0.6375, Validation F1: 0.5333
# Epoch 179, Training Loss: 0.6636899709701538, Train F1: 0.6375, Validation F1: 0.5333
# Epoch 180, Training Loss: 0.6635164618492126, Train F1: 0.6375, Validation F1: 0.5333
# Epoch 181, Training Loss: 0.6633437871932983, Train F1: 0.6375, Validation F1: 0.5333
# Epoch 182, Training Loss: 0.6631684303283691, Train F1: 0.6375, Validation F1: 0.5333
# Epoch 183, Training Loss: 0.6629984974861145, Train F1: 0.6375, Validation F1: 0.5333
# Epoch 184, Training Loss: 0.6628304123878479, Train F1: 0.6375, Validation F1: 0.5333
# Epoch 185, Training Loss: 0.6626585125923157, Train F1: 0.6375, Validation F1: 0.5333
# Epoch 186, Training Loss: 0.662488579750061, Train F1: 0.6375, Validation F1: 0.5333
# Epoch 187, Training Loss: 0.6623187065124512, Train F1: 0.6375, Validation F1: 0.5333
# Epoch 188, Training Loss: 0.6621452569961548, Train F1: 0.6375, Validation F1: 0.5333
# Epoch 189, Training Loss: 0.6619773507118225, Train F1: 0.6375, Validation F1: 0.5333
# Epoch 190, Training Loss: 0.6618109941482544, Train F1: 0.6375, Validation F1: 0.5333
# Epoch 191, Training Loss: 0.6616431474685669, Train F1: 0.6375, Validation F1: 0.5333
# Epoch 192, Training Loss: 0.6614763736724854, Train F1: 0.6375, Validation F1: 0.5333
# Epoch 193, Training Loss: 0.6613125205039978, Train F1: 0.6375, Validation F1: 0.5333
# Epoch 194, Training Loss: 0.6611501574516296, Train F1: 0.6375, Validation F1: 0.5333
# Epoch 195, Training Loss: 0.6609891653060913, Train F1: 0.6375, Validation F1: 0.5333
# Epoch 196, Training Loss: 0.660835325717926, Train F1: 0.6375, Validation F1: 0.5333
# Epoch 197, Training Loss: 0.6606807112693787, Train F1: 0.6375, Validation F1: 0.5333
# Epoch 198, Training Loss: 0.6605281233787537, Train F1: 0.6250, Validation F1: 0.5333
# Epoch 199, Training Loss: 0.6603798866271973, Train F1: 0.6125, Validation F1: 0.5333
# Epoch 200, Training Loss: 0.6602305769920349, Train F1: 0.6125, Validation F1: 0.5333
# Epoch 201, Training Loss: 0.6600791215896606, Train F1: 0.6125, Validation F1: 0.5333
# Epoch 202, Training Loss: 0.6599296927452087, Train F1: 0.6125, Validation F1: 0.5333
# Epoch 203, Training Loss: 0.6597836017608643, Train F1: 0.6125, Validation F1: 0.5333
# Epoch 204, Training Loss: 0.6596319079399109, Train F1: 0.6125, Validation F1: 0.5333
# Epoch 205, Training Loss: 0.6594871282577515, Train F1: 0.6125, Validation F1: 0.5333
# Epoch 206, Training Loss: 0.6593495607376099, Train F1: 0.6125, Validation F1: 0.5333
# Epoch 207, Training Loss: 0.6592155694961548, Train F1: 0.6125, Validation F1: 0.5333
# Epoch 208, Training Loss: 0.6590818166732788, Train F1: 0.6125, Validation F1: 0.5333
# Epoch 209, Training Loss: 0.6589480638504028, Train F1: 0.6125, Validation F1: 0.5333
# Epoch 210, Training Loss: 0.6588132977485657, Train F1: 0.6125, Validation F1: 0.5333
# Epoch 211, Training Loss: 0.6586781740188599, Train F1: 0.6125, Validation F1: 0.5333
# Epoch 212, Training Loss: 0.6585437059402466, Train F1: 0.6125, Validation F1: 0.5333
# Epoch 213, Training Loss: 0.658409833908081, Train F1: 0.6125, Validation F1: 0.5333
# Epoch 214, Training Loss: 0.6582775712013245, Train F1: 0.6125, Validation F1: 0.5333
# Epoch 215, Training Loss: 0.6581444144248962, Train F1: 0.6125, Validation F1: 0.5333
# Epoch 216, Training Loss: 0.658009946346283, Train F1: 0.6125, Validation F1: 0.5333
# Epoch 217, Training Loss: 0.6578763127326965, Train F1: 0.6125, Validation F1: 0.5333
# Epoch 218, Training Loss: 0.6577440500259399, Train F1: 0.6125, Validation F1: 0.5333
# Epoch 219, Training Loss: 0.6576145887374878, Train F1: 0.6125, Validation F1: 0.5667
# Epoch 220, Training Loss: 0.6574849486351013, Train F1: 0.6125, Validation F1: 0.5667
# Epoch 221, Training Loss: 0.657356321811676, Train F1: 0.6125, Validation F1: 0.5667
# Epoch 222, Training Loss: 0.6572268605232239, Train F1: 0.6125, Validation F1: 0.5667
# Epoch 223, Training Loss: 0.6570958495140076, Train F1: 0.6125, Validation F1: 0.5667
# Epoch 224, Training Loss: 0.6569675207138062, Train F1: 0.6125, Validation F1: 0.5667
# Epoch 225, Training Loss: 0.6568398475646973, Train F1: 0.6125, Validation F1: 0.5667
# Epoch 226, Training Loss: 0.6567121148109436, Train F1: 0.6125, Validation F1: 0.5667
# Epoch 227, Training Loss: 0.656584620475769, Train F1: 0.6125, Validation F1: 0.5667
# Epoch 228, Training Loss: 0.6564573645591736, Train F1: 0.6125, Validation F1: 0.5667
# Epoch 229, Training Loss: 0.6563299894332886, Train F1: 0.6125, Validation F1: 0.5667
# Epoch 230, Training Loss: 0.656204104423523, Train F1: 0.6125, Validation F1: 0.5667
# Epoch 231, Training Loss: 0.6560781598091125, Train F1: 0.6125, Validation F1: 0.5667
# Epoch 232, Training Loss: 0.6559523940086365, Train F1: 0.6125, Validation F1: 0.5667
# Epoch 233, Training Loss: 0.6558281779289246, Train F1: 0.6125, Validation F1: 0.5667
# Epoch 234, Training Loss: 0.6557046175003052, Train F1: 0.6125, Validation F1: 0.5667
# Epoch 235, Training Loss: 0.6555811166763306, Train F1: 0.6125, Validation F1: 0.5667
# Epoch 236, Training Loss: 0.6554596424102783, Train F1: 0.6125, Validation F1: 0.5667
# Epoch 237, Training Loss: 0.6553381681442261, Train F1: 0.6125, Validation F1: 0.5667
# Epoch 238, Training Loss: 0.6552156209945679, Train F1: 0.6125, Validation F1: 0.5667
# Epoch 239, Training Loss: 0.6550928354263306, Train F1: 0.6125, Validation F1: 0.5667
# Epoch 240, Training Loss: 0.6549730896949768, Train F1: 0.6125, Validation F1: 0.5667
# Epoch 241, Training Loss: 0.6548515558242798, Train F1: 0.6125, Validation F1: 0.5667
# Epoch 242, Training Loss: 0.6547298431396484, Train F1: 0.6125, Validation F1: 0.5667
# Epoch 243, Training Loss: 0.654609739780426, Train F1: 0.6125, Validation F1: 0.5667
# Epoch 244, Training Loss: 0.6544889211654663, Train F1: 0.6125, Validation F1: 0.5667
# Epoch 245, Training Loss: 0.654367208480835, Train F1: 0.6125, Validation F1: 0.5667
# Epoch 246, Training Loss: 0.6542445421218872, Train F1: 0.6125, Validation F1: 0.5667
# Epoch 247, Training Loss: 0.6541248559951782, Train F1: 0.6250, Validation F1: 0.5667
# Epoch 248, Training Loss: 0.6540042161941528, Train F1: 0.6250, Validation F1: 0.5667
# Epoch 249, Training Loss: 0.6538845896720886, Train F1: 0.6250, Validation F1: 0.5667
# Epoch 250, Training Loss: 0.6537649035453796, Train F1: 0.6250, Validation F1: 0.5667
# Iteration 9: G1 Results: f1=0.5666666666666667

# %%
best_epoch_G1 = max(range(len(G1_results_final)), key=lambda i: G1_results_final[i][2])
best_embedding_G1 = G1_results_final[best_epoch_G1][3]

best_epoch_G2 = max(range(len(G2_results_final)), key=lambda i: G2_results_final[i][2])
best_embedding_G2 = G2_results_final[best_epoch_G2][3]

G1_results_performance = [ result[:-1] for result in G1_results_final]
G2_results_performance = [ result[:-1] for result in G1_results_final]

mean_G1_results = np.mean(G1_results_performance, axis=0)
mean_G2_results = np.mean(G2_results_performance, axis=0)

mean_G1_losses = mean_G1_results[0]
mean_G1_val_f1 = mean_G1_results[2]

mean_G2_losses = mean_G2_results[0]
mean_G2_val_f1 = mean_G2_results[2]

plot_training_and_validation(mean_G1_losses, val_f1, title=f"Average Training loss and Validation Accuracy over time using {change_topology_params['augmentation_strategy']} in G1 over 10 runs")

plot_training_and_validation(mean_G2_losses, val_f1, title=f"Average Training loss and Validation Accuracy over time using {change_topology_params['augmentation_strategy']} in G2 over 10 runs")

X,A,y = G1_train
plot_tsne(best_embedding_G1, y, layer_to_plot=-1, subject="Best Node Embeddings in G1")

X,A,y = G2_train
plot_tsne(best_embedding_G2, y, layer_to_plot=-1, subject="Best Node Embeddings in G2")

# %%
set_seed(42)
G1_train = read_json_data(G1_TRAIN_DATA_PATH, has_label=True) #returns a list of (X,A,y) - features, Adj Matrix, per Graph label
G1_eval = read_json_data(G1_EVAL_DATA_PATH, has_label=True) #returns a list of (X,A,y) - features, Adj Matrix, per Graph label

G2_train = read_json_data(G2_TRAIN_DATA_PATH, has_label=True) #returns a list of (X,A,y) - features, Adj Matrix, per Graph label
G2_eval = read_json_data(G2_EVAL_DATA_PATH, has_label=True) #returns a list of (X,A,y) - features, Adj Matrix, per Graph label

model_params = {    
    "input_dim":10, 
    "hidden_dim":8,
    "num_layers":3,
}

change_topology_params = {
    "augmentation_strategy":"gold",
    "normalise" : True,

}

G1_results_final=[]
G2_results_final=[]

for i in range(10):
    losses, train_f1, val_f1, last_embeddings_G1 = improved_training(
        G1_train,
        G1_eval,
        model_params=model_params,
        num_epochs=250,
        lr=0.0005,
        verbose=True,
        return_embeddings = True,
        change_topology_params = change_topology_params #change as needed
    )

    print(f"Iteration {i}: G2 Results: f1={val_f1[-1]}")
    G2_results_final.append([losses, train_f1, val_f1, last_embeddings_G1]) 

    losses, train_f1, val_f1, last_embeddings_G2 = improved_training(
        G2_train,
        G2_eval,
        model_params=model_params,
        num_epochs=250,
        lr=0.0005,
        verbose=True,
        return_embeddings = True,
        change_topology_params = change_topology_params #change as needed
    )

    print(f"Iteration {i}: G1 Results: f1={val_f1[-1]}")
    G1_results_final.append([losses, train_f1, val_f1, last_embeddings_G2])
# Out:
# LayeredGCN(
#   (layers): ModuleList(
#     (0-2): 3 x GCNLayer()
#   )
#   (output_layer): GCNLayer()
# )
# Epoch 1, Training Loss: 0.7758477330207825, Train F1: 0.4625, Validation F1: 0.5000
# Epoch 2, Training Loss: 0.7731992602348328, Train F1: 0.4625, Validation F1: 0.5000
# Epoch 3, Training Loss: 0.7705737948417664, Train F1: 0.4625, Validation F1: 0.5000
# Epoch 4, Training Loss: 0.7679700255393982, Train F1: 0.4625, Validation F1: 0.5000
# Epoch 5, Training Loss: 0.7654721140861511, Train F1: 0.4625, Validation F1: 0.5000
# Epoch 6, Training Loss: 0.7631740570068359, Train F1: 0.4625, Validation F1: 0.5000
# Epoch 7, Training Loss: 0.7608808875083923, Train F1: 0.4625, Validation F1: 0.5000
# Epoch 8, Training Loss: 0.7585967779159546, Train F1: 0.4625, Validation F1: 0.5000
# Epoch 9, Training Loss: 0.7563250660896301, Train F1: 0.4625, Validation F1: 0.5000
# Epoch 10, Training Loss: 0.7540677189826965, Train F1: 0.4625, Validation F1: 0.5000
# Epoch 11, Training Loss: 0.7518256306648254, Train F1: 0.4625, Validation F1: 0.5000
# Epoch 12, Training Loss: 0.749599277973175, Train F1: 0.4625, Validation F1: 0.5000
# Epoch 13, Training Loss: 0.7473889589309692, Train F1: 0.4625, Validation F1: 0.5000
# Epoch 14, Training Loss: 0.745194673538208, Train F1: 0.4625, Validation F1: 0.5000
# Epoch 15, Training Loss: 0.7430161237716675, Train F1: 0.4625, Validation F1: 0.5000
# Epoch 16, Training Loss: 0.7408533096313477, Train F1: 0.4625, Validation F1: 0.5000
# Epoch 17, Training Loss: 0.7387059330940247, Train F1: 0.4625, Validation F1: 0.5000
# Epoch 18, Training Loss: 0.7365728616714478, Train F1: 0.4625, Validation F1: 0.5000
# Epoch 19, Training Loss: 0.7344536781311035, Train F1: 0.4625, Validation F1: 0.5000
# Epoch 20, Training Loss: 0.7323482632637024, Train F1: 0.4625, Validation F1: 0.5000
# Epoch 21, Training Loss: 0.7302559018135071, Train F1: 0.4625, Validation F1: 0.5000
# Epoch 22, Training Loss: 0.7281758189201355, Train F1: 0.4625, Validation F1: 0.5000
# Epoch 23, Training Loss: 0.7261082530021667, Train F1: 0.4625, Validation F1: 0.5000
# Epoch 24, Training Loss: 0.7240525484085083, Train F1: 0.4625, Validation F1: 0.5000
# Epoch 25, Training Loss: 0.7220085263252258, Train F1: 0.4625, Validation F1: 0.5000
# Epoch 26, Training Loss: 0.7199757695198059, Train F1: 0.4625, Validation F1: 0.5000
# Epoch 27, Training Loss: 0.7179538011550903, Train F1: 0.4625, Validation F1: 0.5000
# Epoch 28, Training Loss: 0.7159426808357239, Train F1: 0.4625, Validation F1: 0.5000
# Epoch 29, Training Loss: 0.7139731645584106, Train F1: 0.4625, Validation F1: 0.5000
# Epoch 30, Training Loss: 0.7120134830474854, Train F1: 0.4625, Validation F1: 0.5000
# Epoch 31, Training Loss: 0.7100270986557007, Train F1: 0.4625, Validation F1: 0.5000
# Epoch 32, Training Loss: 0.7080646753311157, Train F1: 0.4625, Validation F1: 0.5000
# Epoch 33, Training Loss: 0.7061317563056946, Train F1: 0.4625, Validation F1: 0.5000
# Epoch 34, Training Loss: 0.7042056322097778, Train F1: 0.4625, Validation F1: 0.5000
# Epoch 35, Training Loss: 0.7022861242294312, Train F1: 0.4625, Validation F1: 0.5000
# Epoch 36, Training Loss: 0.7003734707832336, Train F1: 0.4625, Validation F1: 0.5000
# Epoch 37, Training Loss: 0.6984671950340271, Train F1: 0.4625, Validation F1: 0.5000
# Epoch 38, Training Loss: 0.696567714214325, Train F1: 0.4625, Validation F1: 0.5000
# Epoch 39, Training Loss: 0.6946746110916138, Train F1: 0.4625, Validation F1: 0.5000
# Epoch 40, Training Loss: 0.6927881240844727, Train F1: 0.4625, Validation F1: 0.5000
# Epoch 41, Training Loss: 0.6909078359603882, Train F1: 0.4625, Validation F1: 0.5000
# Epoch 42, Training Loss: 0.6890338063240051, Train F1: 0.4625, Validation F1: 0.5000
# Epoch 43, Training Loss: 0.6871657371520996, Train F1: 0.4625, Validation F1: 0.5000
# Epoch 44, Training Loss: 0.6853437423706055, Train F1: 0.4625, Validation F1: 0.5000
# Epoch 45, Training Loss: 0.6834962368011475, Train F1: 0.4625, Validation F1: 0.5000
# Epoch 46, Training Loss: 0.6816281080245972, Train F1: 0.4625, Validation F1: 0.5000
# Epoch 47, Training Loss: 0.6798017621040344, Train F1: 0.4625, Validation F1: 0.5000
# Epoch 48, Training Loss: 0.6779788136482239, Train F1: 0.4625, Validation F1: 0.5000
# Epoch 49, Training Loss: 0.6761590838432312, Train F1: 0.4625, Validation F1: 0.5000
# Epoch 50, Training Loss: 0.6743427515029907, Train F1: 0.4625, Validation F1: 0.5000
# Epoch 51, Training Loss: 0.6725297570228577, Train F1: 0.4625, Validation F1: 0.5000
# Epoch 52, Training Loss: 0.6707199215888977, Train F1: 0.4625, Validation F1: 0.5000
# Epoch 53, Training Loss: 0.6689130663871765, Train F1: 0.4625, Validation F1: 0.5000
# Epoch 54, Training Loss: 0.6671431064605713, Train F1: 0.4625, Validation F1: 0.5000
# Epoch 55, Training Loss: 0.665339469909668, Train F1: 0.4625, Validation F1: 0.5000
# Epoch 56, Training Loss: 0.6635428667068481, Train F1: 0.4625, Validation F1: 0.5000
# Epoch 57, Training Loss: 0.6617664694786072, Train F1: 0.4625, Validation F1: 0.5000
# Epoch 58, Training Loss: 0.6599910259246826, Train F1: 0.4625, Validation F1: 0.5000
# Epoch 59, Training Loss: 0.6582266092300415, Train F1: 0.4625, Validation F1: 0.5000
# Epoch 60, Training Loss: 0.6564785242080688, Train F1: 0.4625, Validation F1: 0.5000
# Epoch 61, Training Loss: 0.6547313928604126, Train F1: 0.4625, Validation F1: 0.5000
# Epoch 62, Training Loss: 0.6529852151870728, Train F1: 0.4625, Validation F1: 0.5000
# Epoch 63, Training Loss: 0.6512401700019836, Train F1: 0.4625, Validation F1: 0.5000
# Epoch 64, Training Loss: 0.6494957804679871, Train F1: 0.4625, Validation F1: 0.5000
# Epoch 65, Training Loss: 0.6477524042129517, Train F1: 0.4625, Validation F1: 0.5000
# Epoch 66, Training Loss: 0.6460500359535217, Train F1: 0.4625, Validation F1: 0.5000
# Epoch 67, Training Loss: 0.6443133354187012, Train F1: 0.4625, Validation F1: 0.5000
# Epoch 68, Training Loss: 0.6425597071647644, Train F1: 0.4625, Validation F1: 0.5000
# Epoch 69, Training Loss: 0.6408387422561646, Train F1: 0.4625, Validation F1: 0.5000
# Epoch 70, Training Loss: 0.6391164064407349, Train F1: 0.4625, Validation F1: 0.5000
# Epoch 71, Training Loss: 0.6373926401138306, Train F1: 0.4625, Validation F1: 0.5000
# Epoch 72, Training Loss: 0.6356676816940308, Train F1: 0.4625, Validation F1: 0.5000
# Epoch 73, Training Loss: 0.6339411735534668, Train F1: 0.4625, Validation F1: 0.5000
# Epoch 74, Training Loss: 0.6322137117385864, Train F1: 0.4625, Validation F1: 0.5000
# Epoch 75, Training Loss: 0.6304848790168762, Train F1: 0.4625, Validation F1: 0.5000
# Epoch 76, Training Loss: 0.6287687420845032, Train F1: 0.4625, Validation F1: 0.5000
# Epoch 77, Training Loss: 0.6270343065261841, Train F1: 0.4625, Validation F1: 0.5000
# Epoch 78, Training Loss: 0.6253114938735962, Train F1: 0.4625, Validation F1: 0.5000
# Epoch 79, Training Loss: 0.6235913038253784, Train F1: 0.4625, Validation F1: 0.5000
# Epoch 80, Training Loss: 0.621870219707489, Train F1: 0.4625, Validation F1: 0.5000
# Epoch 81, Training Loss: 0.6201507449150085, Train F1: 0.4625, Validation F1: 0.5000
# Epoch 82, Training Loss: 0.6184274554252625, Train F1: 0.4625, Validation F1: 0.5000
# Epoch 83, Training Loss: 0.6167008280754089, Train F1: 0.4625, Validation F1: 0.5000
# Epoch 84, Training Loss: 0.6149708032608032, Train F1: 0.4625, Validation F1: 0.5000
# Epoch 85, Training Loss: 0.6132373809814453, Train F1: 0.4625, Validation F1: 0.5000
# Epoch 86, Training Loss: 0.61150062084198, Train F1: 0.4625, Validation F1: 0.5000
# Epoch 87, Training Loss: 0.6097812652587891, Train F1: 0.4625, Validation F1: 0.5000
# Epoch 88, Training Loss: 0.6080331802368164, Train F1: 0.4625, Validation F1: 0.5000
# Epoch 89, Training Loss: 0.6063041090965271, Train F1: 0.4625, Validation F1: 0.5000
# Epoch 90, Training Loss: 0.6045740842819214, Train F1: 0.4625, Validation F1: 0.5000
# Epoch 91, Training Loss: 0.6028385758399963, Train F1: 0.4625, Validation F1: 0.5000
# Epoch 92, Training Loss: 0.601097583770752, Train F1: 0.4625, Validation F1: 0.5000
# Epoch 93, Training Loss: 0.5993514060974121, Train F1: 0.4625, Validation F1: 0.5000
# Epoch 94, Training Loss: 0.5976001024246216, Train F1: 0.4625, Validation F1: 0.5000
# Epoch 95, Training Loss: 0.5958437323570251, Train F1: 0.4625, Validation F1: 0.5000
# Epoch 96, Training Loss: 0.594082236289978, Train F1: 0.4625, Validation F1: 0.5000
# Epoch 97, Training Loss: 0.5923156142234802, Train F1: 0.4625, Validation F1: 0.5000
# Epoch 98, Training Loss: 0.5905440449714661, Train F1: 0.4625, Validation F1: 0.5000
# Epoch 99, Training Loss: 0.5887938141822815, Train F1: 0.4625, Validation F1: 0.5000
# Epoch 100, Training Loss: 0.5870182514190674, Train F1: 0.4625, Validation F1: 0.5000
# Epoch 101, Training Loss: 0.5852347612380981, Train F1: 0.4625, Validation F1: 0.5000
# Epoch 102, Training Loss: 0.5834642648696899, Train F1: 0.4625, Validation F1: 0.5000
# Epoch 103, Training Loss: 0.5816865563392639, Train F1: 0.4625, Validation F1: 0.5000
# Epoch 104, Training Loss: 0.5799019932746887, Train F1: 0.4625, Validation F1: 0.5000
# Epoch 105, Training Loss: 0.5781106948852539, Train F1: 0.4625, Validation F1: 0.5000
# Epoch 106, Training Loss: 0.5763128399848938, Train F1: 0.4625, Validation F1: 0.5000
# Epoch 107, Training Loss: 0.5745082497596741, Train F1: 0.4625, Validation F1: 0.5000
# Epoch 108, Training Loss: 0.5726974606513977, Train F1: 0.4625, Validation F1: 0.5000
# Epoch 109, Training Loss: 0.5708821415901184, Train F1: 0.4625, Validation F1: 0.5000
# Epoch 110, Training Loss: 0.5690690875053406, Train F1: 0.4625, Validation F1: 0.5000
# Epoch 111, Training Loss: 0.5673614740371704, Train F1: 0.4625, Validation F1: 0.5000
# Epoch 112, Training Loss: 0.5657374858856201, Train F1: 0.4625, Validation F1: 0.5000
# Epoch 113, Training Loss: 0.5641131401062012, Train F1: 0.4625, Validation F1: 0.5000
# Epoch 114, Training Loss: 0.5624731183052063, Train F1: 0.4625, Validation F1: 0.5000
# Epoch 115, Training Loss: 0.5608326196670532, Train F1: 0.4625, Validation F1: 0.5000
# Epoch 116, Training Loss: 0.5591868162155151, Train F1: 0.4625, Validation F1: 0.5000
# Epoch 117, Training Loss: 0.5575383305549622, Train F1: 0.4625, Validation F1: 0.5000
# Epoch 118, Training Loss: 0.5558841824531555, Train F1: 0.4625, Validation F1: 0.5000
# Epoch 119, Training Loss: 0.554222822189331, Train F1: 0.4625, Validation F1: 0.5000
# Epoch 120, Training Loss: 0.5525486469268799, Train F1: 0.4625, Validation F1: 0.5000
# Epoch 121, Training Loss: 0.5508474707603455, Train F1: 0.4625, Validation F1: 0.5000
# Epoch 122, Training Loss: 0.5491309762001038, Train F1: 0.4625, Validation F1: 0.5000
# Epoch 123, Training Loss: 0.547406792640686, Train F1: 0.4625, Validation F1: 0.5000
# Epoch 124, Training Loss: 0.5456712245941162, Train F1: 0.4625, Validation F1: 0.5000
# Epoch 125, Training Loss: 0.543933629989624, Train F1: 0.4625, Validation F1: 0.5000
# Epoch 126, Training Loss: 0.5421813726425171, Train F1: 0.4625, Validation F1: 0.5000
# Epoch 127, Training Loss: 0.5404273271560669, Train F1: 0.4625, Validation F1: 0.5000
# Epoch 128, Training Loss: 0.5386646389961243, Train F1: 0.4625, Validation F1: 0.5000
# Epoch 129, Training Loss: 0.5369786620140076, Train F1: 0.4625, Validation F1: 0.5000
# Epoch 130, Training Loss: 0.5352941751480103, Train F1: 0.4625, Validation F1: 0.5000
# Epoch 131, Training Loss: 0.5335884690284729, Train F1: 0.4625, Validation F1: 0.5000
# Epoch 132, Training Loss: 0.5318771600723267, Train F1: 0.4625, Validation F1: 0.5000
# Epoch 133, Training Loss: 0.5301617383956909, Train F1: 0.4625, Validation F1: 0.5000
# Epoch 134, Training Loss: 0.5284361839294434, Train F1: 0.4625, Validation F1: 0.5000
# Epoch 135, Training Loss: 0.5267011523246765, Train F1: 0.4625, Validation F1: 0.5000
# Epoch 136, Training Loss: 0.5249572992324829, Train F1: 0.4625, Validation F1: 0.5000
# Epoch 137, Training Loss: 0.5232052803039551, Train F1: 0.4625, Validation F1: 0.5000
# Epoch 138, Training Loss: 0.5214628577232361, Train F1: 0.4625, Validation F1: 0.5000
# Epoch 139, Training Loss: 0.5197044610977173, Train F1: 0.4625, Validation F1: 0.5000
# Epoch 140, Training Loss: 0.5179301500320435, Train F1: 0.4625, Validation F1: 0.5000
# Epoch 141, Training Loss: 0.5161651968955994, Train F1: 0.4625, Validation F1: 0.5000
# Epoch 142, Training Loss: 0.5143930912017822, Train F1: 0.4625, Validation F1: 0.5000
# Epoch 143, Training Loss: 0.5126144886016846, Train F1: 0.4625, Validation F1: 0.5000
# Epoch 144, Training Loss: 0.5108298659324646, Train F1: 0.4625, Validation F1: 0.5000
# Epoch 145, Training Loss: 0.5090475082397461, Train F1: 1.0000, Validation F1: 0.5000
# Epoch 146, Training Loss: 0.5072590708732605, Train F1: 1.0000, Validation F1: 0.5000
# Epoch 147, Training Loss: 0.5054649114608765, Train F1: 1.0000, Validation F1: 0.5000
# Epoch 148, Training Loss: 0.5036751627922058, Train F1: 1.0000, Validation F1: 0.5000
# Epoch 149, Training Loss: 0.5018693804740906, Train F1: 1.0000, Validation F1: 0.5000
# Epoch 150, Training Loss: 0.5000678300857544, Train F1: 1.0000, Validation F1: 0.5000
# Epoch 151, Training Loss: 0.4982658922672272, Train F1: 1.0000, Validation F1: 0.5000
# Epoch 152, Training Loss: 0.4964577555656433, Train F1: 1.0000, Validation F1: 0.5000
# Epoch 153, Training Loss: 0.49464935064315796, Train F1: 1.0000, Validation F1: 0.5000
# Epoch 154, Training Loss: 0.4928359091281891, Train F1: 1.0000, Validation F1: 0.5000
# Epoch 155, Training Loss: 0.4910259246826172, Train F1: 1.0000, Validation F1: 0.5000
# Epoch 156, Training Loss: 0.4892374575138092, Train F1: 1.0000, Validation F1: 0.5000
# Epoch 157, Training Loss: 0.48742714524269104, Train F1: 1.0000, Validation F1: 0.5000
# Epoch 158, Training Loss: 0.48561254143714905, Train F1: 1.0000, Validation F1: 0.5000
# Epoch 159, Training Loss: 0.48378539085388184, Train F1: 1.0000, Validation F1: 0.5000
# Epoch 160, Training Loss: 0.4819546341896057, Train F1: 1.0000, Validation F1: 0.5000
# Epoch 161, Training Loss: 0.48014289140701294, Train F1: 1.0000, Validation F1: 0.5000
# Epoch 162, Training Loss: 0.47831812500953674, Train F1: 1.0000, Validation F1: 0.5000
# Epoch 163, Training Loss: 0.4764958322048187, Train F1: 1.0000, Validation F1: 0.5000
# Epoch 164, Training Loss: 0.47467106580734253, Train F1: 1.0000, Validation F1: 0.5000
# Epoch 165, Training Loss: 0.47284460067749023, Train F1: 1.0000, Validation F1: 0.5000
# Epoch 166, Training Loss: 0.4714890122413635, Train F1: 1.0000, Validation F1: 0.5000
# Epoch 167, Training Loss: 0.47050610184669495, Train F1: 1.0000, Validation F1: 0.5000
# Epoch 168, Training Loss: 0.4694724678993225, Train F1: 1.0000, Validation F1: 0.5000
# Epoch 169, Training Loss: 0.46839460730552673, Train F1: 1.0000, Validation F1: 0.5000
# Epoch 170, Training Loss: 0.4672791361808777, Train F1: 1.0000, Validation F1: 0.5000
# Epoch 171, Training Loss: 0.46613168716430664, Train F1: 1.0000, Validation F1: 0.5000
# Epoch 172, Training Loss: 0.4649569094181061, Train F1: 1.0000, Validation F1: 0.5000
# Epoch 173, Training Loss: 0.4637594223022461, Train F1: 1.0000, Validation F1: 0.5000
# Epoch 174, Training Loss: 0.4625433087348938, Train F1: 1.0000, Validation F1: 0.5000
# Epoch 175, Training Loss: 0.46131187677383423, Train F1: 1.0000, Validation F1: 0.5000
# Epoch 176, Training Loss: 0.46006837487220764, Train F1: 1.0000, Validation F1: 0.5000
# Epoch 177, Training Loss: 0.45881524682044983, Train F1: 1.0000, Validation F1: 0.5000
# Epoch 178, Training Loss: 0.4575553834438324, Train F1: 1.0000, Validation F1: 0.5000
# Epoch 179, Training Loss: 0.45629096031188965, Train F1: 1.0000, Validation F1: 0.5000
# Epoch 180, Training Loss: 0.45502346754074097, Train F1: 1.0000, Validation F1: 0.5000
# Epoch 181, Training Loss: 0.45375537872314453, Train F1: 1.0000, Validation F1: 0.5000
# Epoch 182, Training Loss: 0.45248740911483765, Train F1: 1.0000, Validation F1: 0.5000
# Epoch 183, Training Loss: 0.4512217044830322, Train F1: 1.0000, Validation F1: 0.5000
# Epoch 184, Training Loss: 0.4499590992927551, Train F1: 1.0000, Validation F1: 0.5000
# Epoch 185, Training Loss: 0.4488798677921295, Train F1: 1.0000, Validation F1: 0.5000
# Epoch 186, Training Loss: 0.44793620705604553, Train F1: 1.0000, Validation F1: 0.5000
# Epoch 187, Training Loss: 0.4468425214290619, Train F1: 1.0000, Validation F1: 0.5000
# Epoch 188, Training Loss: 0.4456125795841217, Train F1: 1.0000, Validation F1: 0.5000
# Epoch 189, Training Loss: 0.44431471824645996, Train F1: 1.0000, Validation F1: 0.5000
# Epoch 190, Training Loss: 0.44328445196151733, Train F1: 1.0000, Validation F1: 0.5000
# Epoch 191, Training Loss: 0.4422389566898346, Train F1: 1.0000, Validation F1: 0.5000
# Epoch 192, Training Loss: 0.44118109345436096, Train F1: 1.0000, Validation F1: 0.5000
# Epoch 193, Training Loss: 0.44011348485946655, Train F1: 1.0000, Validation F1: 0.5000
# Epoch 194, Training Loss: 0.43904438614845276, Train F1: 1.0000, Validation F1: 0.5000
# Epoch 195, Training Loss: 0.4380035400390625, Train F1: 1.0000, Validation F1: 0.5000
# Epoch 196, Training Loss: 0.4369592070579529, Train F1: 1.0000, Validation F1: 0.5000
# Epoch 197, Training Loss: 0.4361557066440582, Train F1: 1.0000, Validation F1: 0.5000
# Epoch 198, Training Loss: 0.4351138174533844, Train F1: 1.0000, Validation F1: 0.5000
# Epoch 199, Training Loss: 0.43403881788253784, Train F1: 1.0000, Validation F1: 0.5000
# Epoch 200, Training Loss: 0.43312105536460876, Train F1: 1.0000, Validation F1: 0.5000
# Epoch 201, Training Loss: 0.43219074606895447, Train F1: 1.0000, Validation F1: 0.5000
# Epoch 202, Training Loss: 0.43125057220458984, Train F1: 1.0000, Validation F1: 0.5000
# Epoch 203, Training Loss: 0.43030256032943726, Train F1: 1.0000, Validation F1: 0.5000
# Epoch 204, Training Loss: 0.42934831976890564, Train F1: 1.0000, Validation F1: 0.5000
# Epoch 205, Training Loss: 0.42838984727859497, Train F1: 1.0000, Validation F1: 0.5000
# Epoch 206, Training Loss: 0.4274282455444336, Train F1: 1.0000, Validation F1: 0.5000
# Epoch 207, Training Loss: 0.4267190098762512, Train F1: 1.0000, Validation F1: 0.5000
# Epoch 208, Training Loss: 0.4258284568786621, Train F1: 1.0000, Validation F1: 0.5000
# Epoch 209, Training Loss: 0.4247555136680603, Train F1: 1.0000, Validation F1: 0.5000
# Epoch 210, Training Loss: 0.4239102900028229, Train F1: 1.0000, Validation F1: 0.5000
# Epoch 211, Training Loss: 0.4230925440788269, Train F1: 1.0000, Validation F1: 0.5000
# Epoch 212, Training Loss: 0.4222617745399475, Train F1: 1.0000, Validation F1: 0.5000
# Epoch 213, Training Loss: 0.42142000794410706, Train F1: 1.0000, Validation F1: 0.5000
# Epoch 214, Training Loss: 0.4205694794654846, Train F1: 1.0000, Validation F1: 0.5000
# Epoch 215, Training Loss: 0.41971176862716675, Train F1: 1.0000, Validation F1: 0.5000
# Epoch 216, Training Loss: 0.41884881258010864, Train F1: 1.0000, Validation F1: 0.5000
# Epoch 217, Training Loss: 0.41798195242881775, Train F1: 1.0000, Validation F1: 0.5000
# Epoch 218, Training Loss: 0.41711264848709106, Train F1: 1.0000, Validation F1: 0.5000
# Epoch 219, Training Loss: 0.4162420630455017, Train F1: 1.0000, Validation F1: 0.5000
# Epoch 220, Training Loss: 0.4153710901737213, Train F1: 1.0000, Validation F1: 0.5000
# Epoch 221, Training Loss: 0.414500892162323, Train F1: 1.0000, Validation F1: 0.5000
# Epoch 222, Training Loss: 0.4138641953468323, Train F1: 1.0000, Validation F1: 0.5000
# Epoch 223, Training Loss: 0.41300255060195923, Train F1: 1.0000, Validation F1: 0.5000
# Epoch 224, Training Loss: 0.41209760308265686, Train F1: 1.0000, Validation F1: 0.5000
# Epoch 225, Training Loss: 0.41135072708129883, Train F1: 1.0000, Validation F1: 0.5000
# Epoch 226, Training Loss: 0.41059499979019165, Train F1: 1.0000, Validation F1: 0.5000
# Epoch 227, Training Loss: 0.409832239151001, Train F1: 1.0000, Validation F1: 0.5000
# Epoch 228, Training Loss: 0.4090639650821686, Train F1: 1.0000, Validation F1: 0.5000
# Epoch 229, Training Loss: 0.4082914888858795, Train F1: 1.0000, Validation F1: 0.5000
# Epoch 230, Training Loss: 0.40751609206199646, Train F1: 1.0000, Validation F1: 0.5000
# Epoch 231, Training Loss: 0.40673914551734924, Train F1: 1.0000, Validation F1: 0.5000
# Epoch 232, Training Loss: 0.40596097707748413, Train F1: 1.0000, Validation F1: 0.5000
# Epoch 233, Training Loss: 0.40526896715164185, Train F1: 1.0000, Validation F1: 0.5000
# Epoch 234, Training Loss: 0.4044717252254486, Train F1: 1.0000, Validation F1: 0.5000
# Epoch 235, Training Loss: 0.4037807583808899, Train F1: 1.0000, Validation F1: 0.5000
# Epoch 236, Training Loss: 0.4030941426753998, Train F1: 1.0000, Validation F1: 0.5000
# Epoch 237, Training Loss: 0.40240055322647095, Train F1: 1.0000, Validation F1: 0.5000
# Epoch 238, Training Loss: 0.4017011523246765, Train F1: 1.0000, Validation F1: 0.5000
# Epoch 239, Training Loss: 0.4009975492954254, Train F1: 1.0000, Validation F1: 0.5000
# Epoch 240, Training Loss: 0.40029066801071167, Train F1: 1.0000, Validation F1: 0.5000
# Epoch 241, Training Loss: 0.3995817303657532, Train F1: 1.0000, Validation F1: 0.5000
# Epoch 242, Training Loss: 0.39887166023254395, Train F1: 1.0000, Validation F1: 0.5000
# Epoch 243, Training Loss: 0.3981611728668213, Train F1: 1.0000, Validation F1: 0.5000
# Epoch 244, Training Loss: 0.39768800139427185, Train F1: 1.0000, Validation F1: 0.5000
# Epoch 245, Training Loss: 0.3967931270599365, Train F1: 1.0000, Validation F1: 0.5000
# Epoch 246, Training Loss: 0.3961315155029297, Train F1: 1.0000, Validation F1: 0.5000
# Epoch 247, Training Loss: 0.3954674303531647, Train F1: 1.0000, Validation F1: 0.5000
# Epoch 248, Training Loss: 0.39480167627334595, Train F1: 1.0000, Validation F1: 0.5000
# Epoch 249, Training Loss: 0.3941715359687805, Train F1: 1.0000, Validation F1: 0.5000
# Epoch 250, Training Loss: 0.3935329020023346, Train F1: 1.0000, Validation F1: 0.5000
# Iteration 0: G2 Results: f1=0.5
# LayeredGCN(
#   (layers): ModuleList(
#     (0-2): 3 x GCNLayer()
#   )
#   (output_layer): GCNLayer()
# )
# Epoch 1, Training Loss: 0.6635791659355164, Train F1: 0.5125, Validation F1: 0.3667
# Epoch 2, Training Loss: 0.663155198097229, Train F1: 0.5125, Validation F1: 0.3667
# Epoch 3, Training Loss: 0.6629117727279663, Train F1: 0.5125, Validation F1: 0.3667
# Epoch 4, Training Loss: 0.6626260280609131, Train F1: 0.5125, Validation F1: 0.3667
# Epoch 5, Training Loss: 0.6623067855834961, Train F1: 0.5125, Validation F1: 0.3667
# Epoch 6, Training Loss: 0.6619656085968018, Train F1: 0.5125, Validation F1: 0.3667
# Epoch 7, Training Loss: 0.6616619229316711, Train F1: 0.5125, Validation F1: 0.3667
# Epoch 8, Training Loss: 0.661325991153717, Train F1: 0.5125, Validation F1: 0.3667
# Epoch 9, Training Loss: 0.6610568761825562, Train F1: 0.5125, Validation F1: 0.3667
# Epoch 10, Training Loss: 0.66077721118927, Train F1: 0.5125, Validation F1: 0.3667
# Epoch 11, Training Loss: 0.6604781150817871, Train F1: 0.5125, Validation F1: 0.3667
# Epoch 12, Training Loss: 0.6601629853248596, Train F1: 0.5125, Validation F1: 0.3667
# Epoch 13, Training Loss: 0.6598342061042786, Train F1: 0.5125, Validation F1: 0.3667
# Epoch 14, Training Loss: 0.6594935655593872, Train F1: 0.5125, Validation F1: 0.3667
# Epoch 15, Training Loss: 0.659165620803833, Train F1: 0.5125, Validation F1: 0.3667
# Epoch 16, Training Loss: 0.6588472127914429, Train F1: 0.5125, Validation F1: 0.3667
# Epoch 17, Training Loss: 0.6585468053817749, Train F1: 0.5125, Validation F1: 0.3667
# Epoch 18, Training Loss: 0.6582478284835815, Train F1: 0.5125, Validation F1: 0.3667
# Epoch 19, Training Loss: 0.6579347848892212, Train F1: 0.5125, Validation F1: 0.3667
# Epoch 20, Training Loss: 0.6576089262962341, Train F1: 0.5125, Validation F1: 0.3667
# Epoch 21, Training Loss: 0.6572716236114502, Train F1: 0.5125, Validation F1: 0.3667
# Epoch 22, Training Loss: 0.656930148601532, Train F1: 0.5125, Validation F1: 0.3667
# Epoch 23, Training Loss: 0.6566082835197449, Train F1: 0.5125, Validation F1: 0.3667
# Epoch 24, Training Loss: 0.6562799215316772, Train F1: 0.5125, Validation F1: 0.3667
# Epoch 25, Training Loss: 0.6559892892837524, Train F1: 0.5125, Validation F1: 0.3667
# Epoch 26, Training Loss: 0.6556296944618225, Train F1: 0.5125, Validation F1: 0.3667
# Epoch 27, Training Loss: 0.6553059220314026, Train F1: 0.5125, Validation F1: 0.3667
# Epoch 28, Training Loss: 0.6549701690673828, Train F1: 0.5125, Validation F1: 0.3667
# Epoch 29, Training Loss: 0.6546781659126282, Train F1: 0.5125, Validation F1: 0.3667
# Epoch 30, Training Loss: 0.6543070077896118, Train F1: 0.5125, Validation F1: 0.3667
# Epoch 31, Training Loss: 0.6540123224258423, Train F1: 0.5125, Validation F1: 0.3667
# Epoch 32, Training Loss: 0.6537038087844849, Train F1: 0.5125, Validation F1: 0.3667
# Epoch 33, Training Loss: 0.6533811092376709, Train F1: 0.5125, Validation F1: 0.3667
# Epoch 34, Training Loss: 0.6530455350875854, Train F1: 0.5125, Validation F1: 0.3667
# Epoch 35, Training Loss: 0.6526980400085449, Train F1: 0.5125, Validation F1: 0.3667
# Epoch 36, Training Loss: 0.6523395776748657, Train F1: 0.5125, Validation F1: 0.3667
# Epoch 37, Training Loss: 0.6519712209701538, Train F1: 0.5125, Validation F1: 0.3667
# Epoch 38, Training Loss: 0.6515988111495972, Train F1: 0.5125, Validation F1: 0.3667
# Epoch 39, Training Loss: 0.651254415512085, Train F1: 0.5125, Validation F1: 0.3667
# Epoch 40, Training Loss: 0.6509258151054382, Train F1: 0.5125, Validation F1: 0.3667
# Epoch 41, Training Loss: 0.6505910158157349, Train F1: 0.5125, Validation F1: 0.3667
# Epoch 42, Training Loss: 0.6502431631088257, Train F1: 0.5125, Validation F1: 0.3667
# Epoch 43, Training Loss: 0.6498829126358032, Train F1: 0.5125, Validation F1: 0.3667
# Epoch 44, Training Loss: 0.6495119333267212, Train F1: 0.5125, Validation F1: 0.3667
# Epoch 45, Training Loss: 0.6491490006446838, Train F1: 0.5125, Validation F1: 0.3667
# Epoch 46, Training Loss: 0.6487987637519836, Train F1: 0.5125, Validation F1: 0.3667
# Epoch 47, Training Loss: 0.648491382598877, Train F1: 0.5125, Validation F1: 0.3667
# Epoch 48, Training Loss: 0.6481813192367554, Train F1: 0.5125, Validation F1: 0.3667
# Epoch 49, Training Loss: 0.6478694677352905, Train F1: 0.5125, Validation F1: 0.3667
# Epoch 50, Training Loss: 0.6475557088851929, Train F1: 0.5125, Validation F1: 0.3667
# Epoch 51, Training Loss: 0.6472338438034058, Train F1: 0.5125, Validation F1: 0.3667
# Epoch 52, Training Loss: 0.6469049453735352, Train F1: 0.5125, Validation F1: 0.3667
# Epoch 53, Training Loss: 0.646570086479187, Train F1: 0.5125, Validation F1: 0.3667
# Epoch 54, Training Loss: 0.64622962474823, Train F1: 0.5125, Validation F1: 0.3667
# Epoch 55, Training Loss: 0.6458843946456909, Train F1: 0.5125, Validation F1: 0.3667
# Epoch 56, Training Loss: 0.6455351114273071, Train F1: 0.5125, Validation F1: 0.3667
# Epoch 57, Training Loss: 0.6451822519302368, Train F1: 0.5125, Validation F1: 0.3667
# Epoch 58, Training Loss: 0.6448262929916382, Train F1: 0.5125, Validation F1: 0.3667
# Epoch 59, Training Loss: 0.6444975137710571, Train F1: 0.5125, Validation F1: 0.3667
# Epoch 60, Training Loss: 0.6441262364387512, Train F1: 0.5125, Validation F1: 0.3667
# Epoch 61, Training Loss: 0.6437803506851196, Train F1: 0.5125, Validation F1: 1.0000
# Epoch 62, Training Loss: 0.6434594392776489, Train F1: 0.5125, Validation F1: 1.0000
# Epoch 63, Training Loss: 0.643123209476471, Train F1: 0.5125, Validation F1: 1.0000
# Epoch 64, Training Loss: 0.6427696347236633, Train F1: 0.5125, Validation F1: 1.0000
# Epoch 65, Training Loss: 0.6424857378005981, Train F1: 0.5125, Validation F1: 1.0000
# Epoch 66, Training Loss: 0.6421034932136536, Train F1: 0.5125, Validation F1: 1.0000
# Epoch 67, Training Loss: 0.6417359709739685, Train F1: 0.5125, Validation F1: 1.0000
# Epoch 68, Training Loss: 0.6413956880569458, Train F1: 0.5125, Validation F1: 1.0000
# Epoch 69, Training Loss: 0.6410564184188843, Train F1: 1.0000, Validation F1: 1.0000
# Epoch 70, Training Loss: 0.6407182812690735, Train F1: 1.0000, Validation F1: 1.0000
# Epoch 71, Training Loss: 0.6403743028640747, Train F1: 1.0000, Validation F1: 1.0000
# Epoch 72, Training Loss: 0.6400249600410461, Train F1: 1.0000, Validation F1: 1.0000
# Epoch 73, Training Loss: 0.6396705508232117, Train F1: 1.0000, Validation F1: 1.0000
# Epoch 74, Training Loss: 0.6393117308616638, Train F1: 1.0000, Validation F1: 1.0000
# Epoch 75, Training Loss: 0.6389487981796265, Train F1: 1.0000, Validation F1: 1.0000
# Epoch 76, Training Loss: 0.6385820508003235, Train F1: 1.0000, Validation F1: 1.0000
# Epoch 77, Training Loss: 0.638211727142334, Train F1: 1.0000, Validation F1: 1.0000
# Epoch 78, Training Loss: 0.6378738880157471, Train F1: 1.0000, Validation F1: 1.0000
# Epoch 79, Training Loss: 0.6374794840812683, Train F1: 1.0000, Validation F1: 1.0000
# Epoch 80, Training Loss: 0.6371160745620728, Train F1: 1.0000, Validation F1: 1.0000
# Epoch 81, Training Loss: 0.6367480158805847, Train F1: 1.0000, Validation F1: 1.0000
# Epoch 82, Training Loss: 0.6363843679428101, Train F1: 1.0000, Validation F1: 1.0000
# Epoch 83, Training Loss: 0.636016309261322, Train F1: 1.0000, Validation F1: 1.0000
# Epoch 84, Training Loss: 0.6356284022331238, Train F1: 1.0000, Validation F1: 1.0000
# Epoch 85, Training Loss: 0.6352882981300354, Train F1: 1.0000, Validation F1: 1.0000
# Epoch 86, Training Loss: 0.6348854303359985, Train F1: 1.0000, Validation F1: 1.0000
# Epoch 87, Training Loss: 0.6345162391662598, Train F1: 1.0000, Validation F1: 1.0000
# Epoch 88, Training Loss: 0.6341420412063599, Train F1: 1.0000, Validation F1: 1.0000
# Epoch 89, Training Loss: 0.633763313293457, Train F1: 1.0000, Validation F1: 1.0000
# Epoch 90, Training Loss: 0.6333800554275513, Train F1: 1.0000, Validation F1: 1.0000
# Epoch 91, Training Loss: 0.6329983472824097, Train F1: 1.0000, Validation F1: 1.0000
# Epoch 92, Training Loss: 0.632603645324707, Train F1: 1.0000, Validation F1: 1.0000
# Epoch 93, Training Loss: 0.632257342338562, Train F1: 1.0000, Validation F1: 1.0000
# Epoch 94, Training Loss: 0.631839394569397, Train F1: 1.0000, Validation F1: 1.0000
# Epoch 95, Training Loss: 0.6314571499824524, Train F1: 1.0000, Validation F1: 1.0000
# Epoch 96, Training Loss: 0.631061851978302, Train F1: 1.0000, Validation F1: 1.0000
# Epoch 97, Training Loss: 0.6306709051132202, Train F1: 1.0000, Validation F1: 1.0000
# Epoch 98, Training Loss: 0.6302751302719116, Train F1: 1.0000, Validation F1: 1.0000
# Epoch 99, Training Loss: 0.6298748254776001, Train F1: 1.0000, Validation F1: 1.0000
# Epoch 100, Training Loss: 0.6294965147972107, Train F1: 1.0000, Validation F1: 1.0000
# Epoch 101, Training Loss: 0.6290791630744934, Train F1: 1.0000, Validation F1: 1.0000
# Epoch 102, Training Loss: 0.6286824941635132, Train F1: 1.0000, Validation F1: 1.0000
# Epoch 103, Training Loss: 0.6283044219017029, Train F1: 1.0000, Validation F1: 1.0000
# Epoch 104, Training Loss: 0.6279009580612183, Train F1: 1.0000, Validation F1: 1.0000
# Epoch 105, Training Loss: 0.6274741888046265, Train F1: 1.0000, Validation F1: 1.0000
# Epoch 106, Training Loss: 0.6270574331283569, Train F1: 1.0000, Validation F1: 1.0000
# Epoch 107, Training Loss: 0.6266419887542725, Train F1: 1.0000, Validation F1: 1.0000
# Epoch 108, Training Loss: 0.6262220144271851, Train F1: 1.0000, Validation F1: 1.0000
# Epoch 109, Training Loss: 0.6258624792098999, Train F1: 1.0000, Validation F1: 1.0000
# Epoch 110, Training Loss: 0.6253870129585266, Train F1: 1.0000, Validation F1: 1.0000
# Epoch 111, Training Loss: 0.6249704360961914, Train F1: 1.0000, Validation F1: 1.0000
# Epoch 112, Training Loss: 0.6245487332344055, Train F1: 1.0000, Validation F1: 1.0000
# Epoch 113, Training Loss: 0.6241215467453003, Train F1: 1.0000, Validation F1: 1.0000
# Epoch 114, Training Loss: 0.6236898899078369, Train F1: 1.0000, Validation F1: 1.0000
# Epoch 115, Training Loss: 0.6232535243034363, Train F1: 1.0000, Validation F1: 1.0000
# Epoch 116, Training Loss: 0.6228126287460327, Train F1: 1.0000, Validation F1: 1.0000
# Epoch 117, Training Loss: 0.6223675608634949, Train F1: 1.0000, Validation F1: 1.0000
# Epoch 118, Training Loss: 0.6219341158866882, Train F1: 1.0000, Validation F1: 1.0000
# Epoch 119, Training Loss: 0.6215085387229919, Train F1: 1.0000, Validation F1: 1.0000
# Epoch 120, Training Loss: 0.6210421323776245, Train F1: 1.0000, Validation F1: 1.0000
# Epoch 121, Training Loss: 0.6205928325653076, Train F1: 1.0000, Validation F1: 1.0000
# Epoch 122, Training Loss: 0.6201479434967041, Train F1: 1.0000, Validation F1: 1.0000
# Epoch 123, Training Loss: 0.6196978092193604, Train F1: 1.0000, Validation F1: 1.0000
# Epoch 124, Training Loss: 0.6192420721054077, Train F1: 1.0000, Validation F1: 1.0000
# Epoch 125, Training Loss: 0.6189775466918945, Train F1: 1.0000, Validation F1: 1.0000
# Epoch 126, Training Loss: 0.6183684468269348, Train F1: 1.0000, Validation F1: 1.0000
# Epoch 127, Training Loss: 0.6179481744766235, Train F1: 1.0000, Validation F1: 1.0000
# Epoch 128, Training Loss: 0.6175211668014526, Train F1: 1.0000, Validation F1: 1.0000
# Epoch 129, Training Loss: 0.6170868873596191, Train F1: 1.0000, Validation F1: 1.0000
# Epoch 130, Training Loss: 0.6166452169418335, Train F1: 1.0000, Validation F1: 1.0000
# Epoch 131, Training Loss: 0.6162014603614807, Train F1: 1.0000, Validation F1: 1.0000
# Epoch 132, Training Loss: 0.6157426834106445, Train F1: 1.0000, Validation F1: 1.0000
# Epoch 133, Training Loss: 0.6152817010879517, Train F1: 1.0000, Validation F1: 1.0000
# Epoch 134, Training Loss: 0.6148141026496887, Train F1: 1.0000, Validation F1: 1.0000
# Epoch 135, Training Loss: 0.6143399477005005, Train F1: 1.0000, Validation F1: 1.0000
# Epoch 136, Training Loss: 0.6138597726821899, Train F1: 1.0000, Validation F1: 1.0000
# Epoch 137, Training Loss: 0.6133735775947571, Train F1: 1.0000, Validation F1: 1.0000
# Epoch 138, Training Loss: 0.6128817796707153, Train F1: 1.0000, Validation F1: 1.0000
# Epoch 139, Training Loss: 0.6123846769332886, Train F1: 1.0000, Validation F1: 1.0000
# Epoch 140, Training Loss: 0.6118825674057007, Train F1: 1.0000, Validation F1: 1.0000
# Epoch 141, Training Loss: 0.6115085482597351, Train F1: 1.0000, Validation F1: 1.0000
# Epoch 142, Training Loss: 0.6109574437141418, Train F1: 1.0000, Validation F1: 1.0000
# Epoch 143, Training Loss: 0.6104849576950073, Train F1: 1.0000, Validation F1: 1.0000
# Epoch 144, Training Loss: 0.6100291609764099, Train F1: 1.0000, Validation F1: 1.0000
# Epoch 145, Training Loss: 0.609539806842804, Train F1: 1.0000, Validation F1: 1.0000
# Epoch 146, Training Loss: 0.6090197563171387, Train F1: 1.0000, Validation F1: 1.0000
# Epoch 147, Training Loss: 0.6084718704223633, Train F1: 1.0000, Validation F1: 1.0000
# Epoch 148, Training Loss: 0.6079686880111694, Train F1: 1.0000, Validation F1: 1.0000
# Epoch 149, Training Loss: 0.6074590086936951, Train F1: 1.0000, Validation F1: 1.0000
# Epoch 150, Training Loss: 0.6069426536560059, Train F1: 1.0000, Validation F1: 1.0000
# Epoch 151, Training Loss: 0.6065431833267212, Train F1: 1.0000, Validation F1: 1.0000
# Epoch 152, Training Loss: 0.6059788465499878, Train F1: 1.0000, Validation F1: 1.0000
# Epoch 153, Training Loss: 0.6054674983024597, Train F1: 1.0000, Validation F1: 1.0000
# Epoch 154, Training Loss: 0.6050087213516235, Train F1: 1.0000, Validation F1: 1.0000
# Epoch 155, Training Loss: 0.6045387983322144, Train F1: 1.0000, Validation F1: 1.0000
# Epoch 156, Training Loss: 0.6040581464767456, Train F1: 1.0000, Validation F1: 1.0000
# Epoch 157, Training Loss: 0.6035664677619934, Train F1: 1.0000, Validation F1: 1.0000
# Epoch 158, Training Loss: 0.6030642986297607, Train F1: 1.0000, Validation F1: 1.0000
# Epoch 159, Training Loss: 0.602552056312561, Train F1: 1.0000, Validation F1: 1.0000
# Epoch 160, Training Loss: 0.6020298004150391, Train F1: 1.0000, Validation F1: 1.0000
# Epoch 161, Training Loss: 0.601498007774353, Train F1: 1.0000, Validation F1: 1.0000
# Epoch 162, Training Loss: 0.6009572744369507, Train F1: 1.0000, Validation F1: 1.0000
# Epoch 163, Training Loss: 0.600408136844635, Train F1: 1.0000, Validation F1: 1.0000
# Epoch 164, Training Loss: 0.5998512506484985, Train F1: 1.0000, Validation F1: 1.0000
# Epoch 165, Training Loss: 0.599286675453186, Train F1: 1.0000, Validation F1: 1.0000
# Epoch 166, Training Loss: 0.59871506690979, Train F1: 1.0000, Validation F1: 1.0000
# Epoch 167, Training Loss: 0.598136842250824, Train F1: 1.0000, Validation F1: 1.0000
# Epoch 168, Training Loss: 0.5975526571273804, Train F1: 1.0000, Validation F1: 1.0000
# Epoch 169, Training Loss: 0.5969696044921875, Train F1: 1.0000, Validation F1: 1.0000
# Epoch 170, Training Loss: 0.5963782072067261, Train F1: 1.0000, Validation F1: 1.0000
# Epoch 171, Training Loss: 0.5958361029624939, Train F1: 1.0000, Validation F1: 1.0000
# Epoch 172, Training Loss: 0.5952931046485901, Train F1: 1.0000, Validation F1: 1.0000
# Epoch 173, Training Loss: 0.5947397947311401, Train F1: 1.0000, Validation F1: 1.0000
# Epoch 174, Training Loss: 0.5941771268844604, Train F1: 1.0000, Validation F1: 1.0000
# Epoch 175, Training Loss: 0.5936048626899719, Train F1: 1.0000, Validation F1: 1.0000
# Epoch 176, Training Loss: 0.5930687189102173, Train F1: 1.0000, Validation F1: 1.0000
# Epoch 177, Training Loss: 0.5924658179283142, Train F1: 1.0000, Validation F1: 1.0000
# Epoch 178, Training Loss: 0.5918973684310913, Train F1: 1.0000, Validation F1: 1.0000
# Epoch 179, Training Loss: 0.5913306474685669, Train F1: 1.0000, Validation F1: 1.0000
# Epoch 180, Training Loss: 0.5907339453697205, Train F1: 1.0000, Validation F1: 1.0000
# Epoch 181, Training Loss: 0.590164065361023, Train F1: 1.0000, Validation F1: 1.0000
# Epoch 182, Training Loss: 0.5895606875419617, Train F1: 1.0000, Validation F1: 1.0000
# Epoch 183, Training Loss: 0.5889767408370972, Train F1: 1.0000, Validation F1: 1.0000
# Epoch 184, Training Loss: 0.5883821249008179, Train F1: 1.0000, Validation F1: 1.0000
# Epoch 185, Training Loss: 0.5877863764762878, Train F1: 1.0000, Validation F1: 1.0000
# Epoch 186, Training Loss: 0.5873834490776062, Train F1: 1.0000, Validation F1: 1.0000
# Epoch 187, Training Loss: 0.586614727973938, Train F1: 1.0000, Validation F1: 1.0000
# Epoch 188, Training Loss: 0.5860521793365479, Train F1: 1.0000, Validation F1: 1.0000
# Epoch 189, Training Loss: 0.5854787230491638, Train F1: 1.0000, Validation F1: 1.0000
# Epoch 190, Training Loss: 0.584886372089386, Train F1: 1.0000, Validation F1: 1.0000
# Epoch 191, Training Loss: 0.584283709526062, Train F1: 1.0000, Validation F1: 1.0000
# Epoch 192, Training Loss: 0.5836690664291382, Train F1: 1.0000, Validation F1: 1.0000
# Epoch 193, Training Loss: 0.5830423831939697, Train F1: 1.0000, Validation F1: 1.0000
# Epoch 194, Training Loss: 0.5824052095413208, Train F1: 1.0000, Validation F1: 1.0000
# Epoch 195, Training Loss: 0.5818015336990356, Train F1: 1.0000, Validation F1: 1.0000
# Epoch 196, Training Loss: 0.5811394453048706, Train F1: 1.0000, Validation F1: 1.0000
# Epoch 197, Training Loss: 0.5805085897445679, Train F1: 1.0000, Validation F1: 1.0000
# Epoch 198, Training Loss: 0.5798659920692444, Train F1: 1.0000, Validation F1: 1.0000
# Epoch 199, Training Loss: 0.5793217420578003, Train F1: 1.0000, Validation F1: 1.0000
# Epoch 200, Training Loss: 0.5786499381065369, Train F1: 1.0000, Validation F1: 1.0000
# Epoch 201, Training Loss: 0.5780361294746399, Train F1: 1.0000, Validation F1: 1.0000
# Epoch 202, Training Loss: 0.5774197578430176, Train F1: 1.0000, Validation F1: 1.0000
# Epoch 203, Training Loss: 0.5767906904220581, Train F1: 1.0000, Validation F1: 1.0000
# Epoch 204, Training Loss: 0.5761473774909973, Train F1: 1.0000, Validation F1: 1.0000
# Epoch 205, Training Loss: 0.5754902958869934, Train F1: 1.0000, Validation F1: 1.0000
# Epoch 206, Training Loss: 0.5749140977859497, Train F1: 1.0000, Validation F1: 1.0000
# Epoch 207, Training Loss: 0.5741817951202393, Train F1: 1.0000, Validation F1: 1.0000
# Epoch 208, Training Loss: 0.5735281109809875, Train F1: 1.0000, Validation F1: 1.0000
# Epoch 209, Training Loss: 0.5728603005409241, Train F1: 1.0000, Validation F1: 1.0000
# Epoch 210, Training Loss: 0.5721791982650757, Train F1: 1.0000, Validation F1: 1.0000
# Epoch 211, Training Loss: 0.5715358853340149, Train F1: 1.0000, Validation F1: 1.0000
# Epoch 212, Training Loss: 0.5708250403404236, Train F1: 1.0000, Validation F1: 1.0000
# Epoch 213, Training Loss: 0.5702317357063293, Train F1: 1.0000, Validation F1: 1.0000
# Epoch 214, Training Loss: 0.5696147084236145, Train F1: 1.0000, Validation F1: 1.0000
# Epoch 215, Training Loss: 0.5689862966537476, Train F1: 1.0000, Validation F1: 1.0000
# Epoch 216, Training Loss: 0.5683132410049438, Train F1: 1.0000, Validation F1: 1.0000
# Epoch 217, Training Loss: 0.5676291584968567, Train F1: 1.0000, Validation F1: 1.0000
# Epoch 218, Training Loss: 0.5669510960578918, Train F1: 1.0000, Validation F1: 1.0000
# Epoch 219, Training Loss: 0.5662568807601929, Train F1: 1.0000, Validation F1: 1.0000
# Epoch 220, Training Loss: 0.5655473470687866, Train F1: 1.0000, Validation F1: 1.0000
# Epoch 221, Training Loss: 0.5648240447044373, Train F1: 1.0000, Validation F1: 1.0000
# Epoch 222, Training Loss: 0.5641424059867859, Train F1: 1.0000, Validation F1: 1.0000
# Epoch 223, Training Loss: 0.5634867548942566, Train F1: 1.0000, Validation F1: 1.0000
# Epoch 224, Training Loss: 0.5627811551094055, Train F1: 1.0000, Validation F1: 1.0000
# Epoch 225, Training Loss: 0.5621519088745117, Train F1: 1.0000, Validation F1: 1.0000
# Epoch 226, Training Loss: 0.5615004301071167, Train F1: 1.0000, Validation F1: 1.0000
# Epoch 227, Training Loss: 0.5608280897140503, Train F1: 1.0000, Validation F1: 1.0000
# Epoch 228, Training Loss: 0.5601348876953125, Train F1: 1.0000, Validation F1: 1.0000
# Epoch 229, Training Loss: 0.5594224333763123, Train F1: 1.0000, Validation F1: 1.0000
# Epoch 230, Training Loss: 0.5587018728256226, Train F1: 1.0000, Validation F1: 1.0000
# Epoch 231, Training Loss: 0.5579423308372498, Train F1: 1.0000, Validation F1: 1.0000
# Epoch 232, Training Loss: 0.5571774840354919, Train F1: 1.0000, Validation F1: 1.0000
# Epoch 233, Training Loss: 0.5563987493515015, Train F1: 1.0000, Validation F1: 1.0000
# Epoch 234, Training Loss: 0.5556074380874634, Train F1: 1.0000, Validation F1: 1.0000
# Epoch 235, Training Loss: 0.5552362203598022, Train F1: 1.0000, Validation F1: 1.0000
# Epoch 236, Training Loss: 0.5543313026428223, Train F1: 1.0000, Validation F1: 1.0000
# Epoch 237, Training Loss: 0.5534843802452087, Train F1: 1.0000, Validation F1: 1.0000
# Epoch 238, Training Loss: 0.5528485178947449, Train F1: 1.0000, Validation F1: 1.0000
# Epoch 239, Training Loss: 0.552144467830658, Train F1: 1.0000, Validation F1: 1.0000
# Epoch 240, Training Loss: 0.5514411926269531, Train F1: 1.0000, Validation F1: 1.0000
# Epoch 241, Training Loss: 0.5507143139839172, Train F1: 1.0000, Validation F1: 1.0000
# Epoch 242, Training Loss: 0.5499649047851562, Train F1: 1.0000, Validation F1: 1.0000
# Epoch 243, Training Loss: 0.5491946339607239, Train F1: 1.0000, Validation F1: 1.0000
# Epoch 244, Training Loss: 0.5484053492546082, Train F1: 1.0000, Validation F1: 1.0000
# Epoch 245, Training Loss: 0.54768306016922, Train F1: 1.0000, Validation F1: 1.0000
# Epoch 246, Training Loss: 0.5468875169754028, Train F1: 1.0000, Validation F1: 1.0000
# Epoch 247, Training Loss: 0.5461105108261108, Train F1: 1.0000, Validation F1: 1.0000
# Epoch 248, Training Loss: 0.545386016368866, Train F1: 1.0000, Validation F1: 1.0000
# Epoch 249, Training Loss: 0.5446326732635498, Train F1: 1.0000, Validation F1: 1.0000
# Epoch 250, Training Loss: 0.543810248374939, Train F1: 1.0000, Validation F1: 1.0000
# Iteration 0: G1 Results: f1=1.0
# LayeredGCN(
#   (layers): ModuleList(
#     (0-2): 3 x GCNLayer()
#   )
#   (output_layer): GCNLayer()
# )
# Epoch 1, Training Loss: 0.6889809370040894, Train F1: 0.4625, Validation F1: 0.5000
# Epoch 2, Training Loss: 0.6882635354995728, Train F1: 0.4625, Validation F1: 0.5000
# Epoch 3, Training Loss: 0.6875463724136353, Train F1: 0.4625, Validation F1: 0.5000
# Epoch 4, Training Loss: 0.6868292689323425, Train F1: 1.0000, Validation F1: 0.5000
# Epoch 5, Training Loss: 0.6861122846603394, Train F1: 1.0000, Validation F1: 0.5000
# Epoch 6, Training Loss: 0.685395359992981, Train F1: 1.0000, Validation F1: 0.5000
# Epoch 7, Training Loss: 0.6849827766418457, Train F1: 1.0000, Validation F1: 0.5000
# Epoch 8, Training Loss: 0.6846528053283691, Train F1: 1.0000, Validation F1: 1.0000
# Epoch 9, Training Loss: 0.6843193769454956, Train F1: 1.0000, Validation F1: 1.0000
# Epoch 10, Training Loss: 0.6839969754219055, Train F1: 1.0000, Validation F1: 1.0000
# Epoch 11, Training Loss: 0.6837018132209778, Train F1: 1.0000, Validation F1: 1.0000
# Epoch 12, Training Loss: 0.6834040880203247, Train F1: 1.0000, Validation F1: 1.0000
# Epoch 13, Training Loss: 0.6831040382385254, Train F1: 1.0000, Validation F1: 1.0000
# Epoch 14, Training Loss: 0.6828018426895142, Train F1: 1.0000, Validation F1: 1.0000
# Epoch 15, Training Loss: 0.6824971437454224, Train F1: 1.0000, Validation F1: 1.0000
# Epoch 16, Training Loss: 0.6821901798248291, Train F1: 1.0000, Validation F1: 1.0000
# Epoch 17, Training Loss: 0.6818807125091553, Train F1: 1.0000, Validation F1: 1.0000
# Epoch 18, Training Loss: 0.6815690994262695, Train F1: 1.0000, Validation F1: 1.0000
# Epoch 19, Training Loss: 0.6812548041343689, Train F1: 1.0000, Validation F1: 1.0000
# Epoch 20, Training Loss: 0.6809381246566772, Train F1: 1.0000, Validation F1: 1.0000
# Epoch 21, Training Loss: 0.6806188821792603, Train F1: 1.0000, Validation F1: 1.0000
# Epoch 22, Training Loss: 0.6802972555160522, Train F1: 1.0000, Validation F1: 1.0000
# Epoch 23, Training Loss: 0.6799727082252502, Train F1: 1.0000, Validation F1: 1.0000
# Epoch 24, Training Loss: 0.6796457171440125, Train F1: 1.0000, Validation F1: 1.0000
# Epoch 25, Training Loss: 0.6793158650398254, Train F1: 1.0000, Validation F1: 1.0000
# Epoch 26, Training Loss: 0.6789834499359131, Train F1: 1.0000, Validation F1: 1.0000
# Epoch 27, Training Loss: 0.6786481142044067, Train F1: 1.0000, Validation F1: 1.0000
# Epoch 28, Training Loss: 0.6783100366592407, Train F1: 1.0000, Validation F1: 1.0000
# Epoch 29, Training Loss: 0.6779688596725464, Train F1: 1.0000, Validation F1: 1.0000
# Epoch 30, Training Loss: 0.6776248812675476, Train F1: 1.0000, Validation F1: 1.0000
# Epoch 31, Training Loss: 0.6772780418395996, Train F1: 1.0000, Validation F1: 1.0000
# Epoch 32, Training Loss: 0.6769280433654785, Train F1: 1.0000, Validation F1: 1.0000
# Epoch 33, Training Loss: 0.6765750646591187, Train F1: 1.0000, Validation F1: 1.0000
# Epoch 34, Training Loss: 0.6762188673019409, Train F1: 1.0000, Validation F1: 1.0000
# Epoch 35, Training Loss: 0.6758594512939453, Train F1: 1.0000, Validation F1: 1.0000
# Epoch 36, Training Loss: 0.6754969954490662, Train F1: 1.0000, Validation F1: 1.0000
# Epoch 37, Training Loss: 0.6751313209533691, Train F1: 1.0000, Validation F1: 1.0000
# Epoch 38, Training Loss: 0.6747625470161438, Train F1: 1.0000, Validation F1: 1.0000
# Epoch 39, Training Loss: 0.6743901371955872, Train F1: 1.0000, Validation F1: 1.0000
# Epoch 40, Training Loss: 0.6740145683288574, Train F1: 1.0000, Validation F1: 1.0000
# Epoch 41, Training Loss: 0.6736356019973755, Train F1: 1.0000, Validation F1: 1.0000
# Epoch 42, Training Loss: 0.6732532382011414, Train F1: 1.0000, Validation F1: 1.0000
# Epoch 43, Training Loss: 0.6728672385215759, Train F1: 1.0000, Validation F1: 1.0000
# Epoch 44, Training Loss: 0.6724778413772583, Train F1: 1.0000, Validation F1: 1.0000
# Epoch 45, Training Loss: 0.6720849275588989, Train F1: 1.0000, Validation F1: 1.0000
# Epoch 46, Training Loss: 0.6716883778572083, Train F1: 1.0000, Validation F1: 1.0000
# Epoch 47, Training Loss: 0.6712883114814758, Train F1: 1.0000, Validation F1: 1.0000
# Epoch 48, Training Loss: 0.6708845496177673, Train F1: 1.0000, Validation F1: 1.0000
# Epoch 49, Training Loss: 0.670477032661438, Train F1: 1.0000, Validation F1: 1.0000
# Epoch 50, Training Loss: 0.6700658202171326, Train F1: 1.0000, Validation F1: 1.0000
# Epoch 51, Training Loss: 0.6696509718894958, Train F1: 1.0000, Validation F1: 1.0000
# Epoch 52, Training Loss: 0.6692322492599487, Train F1: 1.0000, Validation F1: 1.0000
# Epoch 53, Training Loss: 0.6688095927238464, Train F1: 1.0000, Validation F1: 1.0000
# Epoch 54, Training Loss: 0.6683833599090576, Train F1: 1.0000, Validation F1: 1.0000
# Epoch 55, Training Loss: 0.6679530143737793, Train F1: 1.0000, Validation F1: 1.0000
# Epoch 56, Training Loss: 0.6675187349319458, Train F1: 1.0000, Validation F1: 1.0000
# Epoch 57, Training Loss: 0.6670805215835571, Train F1: 1.0000, Validation F1: 1.0000
# ...
# Epoch 65, Training Loss: 0.591553270816803, Train F1: 1.0000, Validation F1: 1.0000
# Epoch 66, Training Loss: 0.5907469391822815, Train F1: 1.0000, Validation F1: 1.0000
# Epoch 67, Training Loss: 0.5901150703430176, Train F1: 1.0000, Validation F1: 1.0000
# Epoch 68, Training Loss: 0.5895728468894958, Train F1: 1.0000, Validation F1: 1.0000
# Epoch 69, Training Loss: 0.5889865756034851, Train F1: 1.0000, Validation F1: 1.0000
# Epoch 70, Training Loss: 0.5882989168167114, Train F1: 1.0000, Validation F1: 1.0000
# Epoch 71, Training Loss: 0.5875204205513, Train F1: 1.0000, Validation F1: 1.0000
# Epoch 72, Training Loss: 0.5866826772689819, Train F1: 1.0000, Validation F1: 1.0000
# Epoch 73, Training Loss: 0.5859655141830444, Train F1: 1.0000, Validation F1: 1.0000
# Epoch 74, Training Loss: 0.5852824449539185, Train F1: 1.0000, Validation F1: 1.0000
# Epoch 75, Training Loss: 0.5845834612846375, Train F1: 1.0000, Validation F1: 1.0000
# Epoch 76, Training Loss: 0.583869457244873, Train F1: 1.0000, Validation F1: 1.0000
# Epoch 77, Training Loss: 0.5831413865089417, Train F1: 1.0000, Validation F1: 1.0000
# Epoch 78, Training Loss: 0.5824002027511597, Train F1: 1.0000, Validation F1: 1.0000
# Epoch 79, Training Loss: 0.5816617608070374, Train F1: 1.0000, Validation F1: 1.0000
# Epoch 80, Training Loss: 0.5809365510940552, Train F1: 1.0000, Validation F1: 1.0000
# Epoch 81, Training Loss: 0.5801805257797241, Train F1: 1.0000, Validation F1: 1.0000
# Epoch 82, Training Loss: 0.5793958902359009, Train F1: 1.0000, Validation F1: 1.0000
# Epoch 83, Training Loss: 0.5786341428756714, Train F1: 1.0000, Validation F1: 1.0000
# Epoch 84, Training Loss: 0.5779331922531128, Train F1: 1.0000, Validation F1: 1.0000
# Epoch 85, Training Loss: 0.5771489143371582, Train F1: 1.0000, Validation F1: 1.0000
# Epoch 86, Training Loss: 0.5764087438583374, Train F1: 1.0000, Validation F1: 1.0000
# Epoch 87, Training Loss: 0.5756698846817017, Train F1: 1.0000, Validation F1: 1.0000
# Epoch 88, Training Loss: 0.5748965740203857, Train F1: 1.0000, Validation F1: 1.0000
# Epoch 89, Training Loss: 0.5741408467292786, Train F1: 1.0000, Validation F1: 1.0000
# Epoch 90, Training Loss: 0.5734537839889526, Train F1: 1.0000, Validation F1: 1.0000
# Epoch 91, Training Loss: 0.5726758241653442, Train F1: 1.0000, Validation F1: 1.0000
# Epoch 92, Training Loss: 0.5719064474105835, Train F1: 1.0000, Validation F1: 1.0000
# Epoch 93, Training Loss: 0.5711137652397156, Train F1: 1.0000, Validation F1: 1.0000
# Epoch 94, Training Loss: 0.5703678131103516, Train F1: 1.0000, Validation F1: 1.0000
# Epoch 95, Training Loss: 0.569591224193573, Train F1: 1.0000, Validation F1: 1.0000
# Epoch 96, Training Loss: 0.5688289403915405, Train F1: 1.0000, Validation F1: 1.0000
# Epoch 97, Training Loss: 0.5680186152458191, Train F1: 1.0000, Validation F1: 1.0000
# Epoch 98, Training Loss: 0.5672696828842163, Train F1: 1.0000, Validation F1: 1.0000
# Epoch 99, Training Loss: 0.5665069818496704, Train F1: 1.0000, Validation F1: 1.0000
# Epoch 100, Training Loss: 0.565739631652832, Train F1: 1.0000, Validation F1: 1.0000
# Epoch 101, Training Loss: 0.5649601817131042, Train F1: 1.0000, Validation F1: 1.0000
# Epoch 102, Training Loss: 0.5641618371009827, Train F1: 1.0000, Validation F1: 1.0000
# Epoch 103, Training Loss: 0.5633456707000732, Train F1: 1.0000, Validation F1: 1.0000
# Epoch 104, Training Loss: 0.562512993812561, Train F1: 1.0000, Validation F1: 1.0000
# Epoch 105, Training Loss: 0.561693012714386, Train F1: 1.0000, Validation F1: 1.0000
# Epoch 106, Training Loss: 0.5609230995178223, Train F1: 1.0000, Validation F1: 1.0000
# Epoch 107, Training Loss: 0.5601130127906799, Train F1: 1.0000, Validation F1: 1.0000
# Epoch 108, Training Loss: 0.5592999458312988, Train F1: 1.0000, Validation F1: 1.0000
# Epoch 109, Training Loss: 0.5584625005722046, Train F1: 1.0000, Validation F1: 1.0000
# Epoch 110, Training Loss: 0.5577592849731445, Train F1: 1.0000, Validation F1: 1.0000
# Epoch 111, Training Loss: 0.5570862293243408, Train F1: 1.0000, Validation F1: 1.0000
# Epoch 112, Training Loss: 0.5563706159591675, Train F1: 1.0000, Validation F1: 1.0000
# Epoch 113, Training Loss: 0.5556167364120483, Train F1: 1.0000, Validation F1: 1.0000
# Epoch 114, Training Loss: 0.5548411011695862, Train F1: 1.0000, Validation F1: 1.0000
# Epoch 115, Training Loss: 0.5540894269943237, Train F1: 1.0000, Validation F1: 1.0000
# Epoch 116, Training Loss: 0.553327202796936, Train F1: 1.0000, Validation F1: 1.0000
# Epoch 117, Training Loss: 0.552588164806366, Train F1: 1.0000, Validation F1: 1.0000
# Epoch 118, Training Loss: 0.5518323183059692, Train F1: 1.0000, Validation F1: 1.0000
# Epoch 119, Training Loss: 0.5510369539260864, Train F1: 1.0000, Validation F1: 1.0000
# Epoch 120, Training Loss: 0.5502051711082458, Train F1: 1.0000, Validation F1: 1.0000
# Epoch 121, Training Loss: 0.5495156645774841, Train F1: 1.0000, Validation F1: 1.0000
# Epoch 122, Training Loss: 0.548735499382019, Train F1: 1.0000, Validation F1: 1.0000
# Epoch 123, Training Loss: 0.5478693246841431, Train F1: 1.0000, Validation F1: 1.0000
# Epoch 124, Training Loss: 0.5470179319381714, Train F1: 1.0000, Validation F1: 1.0000
# Epoch 125, Training Loss: 0.5462883710861206, Train F1: 1.0000, Validation F1: 1.0000
# Epoch 126, Training Loss: 0.545538067817688, Train F1: 1.0000, Validation F1: 1.0000
# Epoch 127, Training Loss: 0.5447531938552856, Train F1: 1.0000, Validation F1: 1.0000
# Epoch 128, Training Loss: 0.543964684009552, Train F1: 1.0000, Validation F1: 1.0000
# Epoch 129, Training Loss: 0.5431278347969055, Train F1: 1.0000, Validation F1: 1.0000
# Epoch 130, Training Loss: 0.5423001646995544, Train F1: 1.0000, Validation F1: 1.0000
# Epoch 131, Training Loss: 0.5414889454841614, Train F1: 1.0000, Validation F1: 1.0000
# Epoch 132, Training Loss: 0.5406460762023926, Train F1: 1.0000, Validation F1: 1.0000
# Epoch 133, Training Loss: 0.5398604273796082, Train F1: 1.0000, Validation F1: 1.0000
# Epoch 134, Training Loss: 0.5390623211860657, Train F1: 1.0000, Validation F1: 1.0000
# Epoch 135, Training Loss: 0.5382243394851685, Train F1: 1.0000, Validation F1: 1.0000
# Epoch 136, Training Loss: 0.5374237298965454, Train F1: 1.0000, Validation F1: 1.0000
# Epoch 137, Training Loss: 0.5365759134292603, Train F1: 1.0000, Validation F1: 1.0000
# Epoch 138, Training Loss: 0.5358900427818298, Train F1: 1.0000, Validation F1: 1.0000
# Epoch 139, Training Loss: 0.5350798964500427, Train F1: 1.0000, Validation F1: 1.0000
# Epoch 140, Training Loss: 0.534239649772644, Train F1: 1.0000, Validation F1: 1.0000
# Epoch 141, Training Loss: 0.533415675163269, Train F1: 1.0000, Validation F1: 1.0000
# Epoch 142, Training Loss: 0.5325935482978821, Train F1: 1.0000, Validation F1: 1.0000
# Epoch 143, Training Loss: 0.5318135023117065, Train F1: 1.0000, Validation F1: 1.0000
# Epoch 144, Training Loss: 0.5309563875198364, Train F1: 1.0000, Validation F1: 1.0000
# Epoch 145, Training Loss: 0.5302491784095764, Train F1: 1.0000, Validation F1: 1.0000
# Epoch 146, Training Loss: 0.5295206308364868, Train F1: 1.0000, Validation F1: 1.0000
# Epoch 147, Training Loss: 0.5286732912063599, Train F1: 1.0000, Validation F1: 1.0000
# Epoch 148, Training Loss: 0.5278083086013794, Train F1: 1.0000, Validation F1: 1.0000
# Epoch 149, Training Loss: 0.5270336866378784, Train F1: 1.0000, Validation F1: 1.0000
# Epoch 150, Training Loss: 0.5261848568916321, Train F1: 1.0000, Validation F1: 1.0000
# Epoch 151, Training Loss: 0.5253517031669617, Train F1: 1.0000, Validation F1: 1.0000
# Epoch 152, Training Loss: 0.5246239304542542, Train F1: 1.0000, Validation F1: 1.0000
# Epoch 153, Training Loss: 0.5238274931907654, Train F1: 1.0000, Validation F1: 1.0000
# Epoch 154, Training Loss: 0.523047149181366, Train F1: 1.0000, Validation F1: 1.0000
# Epoch 155, Training Loss: 0.5222477912902832, Train F1: 1.0000, Validation F1: 1.0000
# Epoch 156, Training Loss: 0.5213516354560852, Train F1: 1.0000, Validation F1: 1.0000
# Epoch 157, Training Loss: 0.5205000042915344, Train F1: 1.0000, Validation F1: 1.0000
# Epoch 158, Training Loss: 0.5197634100914001, Train F1: 1.0000, Validation F1: 1.0000
# Epoch 159, Training Loss: 0.5189541578292847, Train F1: 1.0000, Validation F1: 1.0000
# Epoch 160, Training Loss: 0.5181723833084106, Train F1: 1.0000, Validation F1: 1.0000
# Epoch 161, Training Loss: 0.5173674821853638, Train F1: 1.0000, Validation F1: 1.0000
# Epoch 162, Training Loss: 0.516490638256073, Train F1: 1.0000, Validation F1: 1.0000
# Epoch 163, Training Loss: 0.5156873464584351, Train F1: 1.0000, Validation F1: 1.0000
# Epoch 164, Training Loss: 0.5148884057998657, Train F1: 1.0000, Validation F1: 1.0000
# Epoch 165, Training Loss: 0.5139530897140503, Train F1: 1.0000, Validation F1: 1.0000
# Epoch 166, Training Loss: 0.5132245421409607, Train F1: 1.0000, Validation F1: 1.0000
# Epoch 167, Training Loss: 0.512332558631897, Train F1: 1.0000, Validation F1: 1.0000
# Epoch 168, Training Loss: 0.5116288661956787, Train F1: 1.0000, Validation F1: 1.0000
# Epoch 169, Training Loss: 0.5108684301376343, Train F1: 1.0000, Validation F1: 1.0000
# Epoch 170, Training Loss: 0.5098800659179688, Train F1: 1.0000, Validation F1: 1.0000
# Epoch 171, Training Loss: 0.5091079473495483, Train F1: 1.0000, Validation F1: 1.0000
# Epoch 172, Training Loss: 0.5083864331245422, Train F1: 1.0000, Validation F1: 1.0000
# Epoch 173, Training Loss: 0.5075405836105347, Train F1: 1.0000, Validation F1: 1.0000
# Epoch 174, Training Loss: 0.5066229701042175, Train F1: 1.0000, Validation F1: 1.0000
# Epoch 175, Training Loss: 0.5059072375297546, Train F1: 1.0000, Validation F1: 1.0000
# Epoch 176, Training Loss: 0.5051735639572144, Train F1: 1.0000, Validation F1: 1.0000
# Epoch 177, Training Loss: 0.5043076276779175, Train F1: 1.0000, Validation F1: 1.0000
# Epoch 178, Training Loss: 0.5033270716667175, Train F1: 1.0000, Validation F1: 1.0000
# Epoch 179, Training Loss: 0.5024183988571167, Train F1: 1.0000, Validation F1: 1.0000
# Epoch 180, Training Loss: 0.5016139149665833, Train F1: 1.0000, Validation F1: 1.0000
# Epoch 181, Training Loss: 0.500714123249054, Train F1: 1.0000, Validation F1: 1.0000
# Epoch 182, Training Loss: 0.49995890259742737, Train F1: 1.0000, Validation F1: 1.0000
# Epoch 183, Training Loss: 0.4991823732852936, Train F1: 1.0000, Validation F1: 1.0000
# Epoch 184, Training Loss: 0.49830690026283264, Train F1: 1.0000, Validation F1: 1.0000
# Epoch 185, Training Loss: 0.49740904569625854, Train F1: 1.0000, Validation F1: 1.0000
# Epoch 186, Training Loss: 0.49661359190940857, Train F1: 1.0000, Validation F1: 1.0000
# Epoch 187, Training Loss: 0.4957018494606018, Train F1: 1.0000, Validation F1: 1.0000
# Epoch 188, Training Loss: 0.4948313236236572, Train F1: 1.0000, Validation F1: 1.0000
# Epoch 189, Training Loss: 0.4940463900566101, Train F1: 1.0000, Validation F1: 1.0000
# Epoch 190, Training Loss: 0.49317535758018494, Train F1: 1.0000, Validation F1: 1.0000
# Epoch 191, Training Loss: 0.492299884557724, Train F1: 1.0000, Validation F1: 1.0000
# Epoch 192, Training Loss: 0.4914471209049225, Train F1: 1.0000, Validation F1: 1.0000
# Epoch 193, Training Loss: 0.4906015396118164, Train F1: 1.0000, Validation F1: 1.0000
# Epoch 194, Training Loss: 0.48974019289016724, Train F1: 1.0000, Validation F1: 1.0000
# Epoch 195, Training Loss: 0.48887571692466736, Train F1: 1.0000, Validation F1: 1.0000
# Epoch 196, Training Loss: 0.48797184228897095, Train F1: 1.0000, Validation F1: 1.0000
# Epoch 197, Training Loss: 0.48713913559913635, Train F1: 1.0000, Validation F1: 1.0000
# Epoch 198, Training Loss: 0.4864114820957184, Train F1: 1.0000, Validation F1: 1.0000
# Epoch 199, Training Loss: 0.48560890555381775, Train F1: 1.0000, Validation F1: 1.0000
# Epoch 200, Training Loss: 0.48468098044395447, Train F1: 1.0000, Validation F1: 1.0000
# Epoch 201, Training Loss: 0.48373880982398987, Train F1: 1.0000, Validation F1: 1.0000
# Epoch 202, Training Loss: 0.4828222692012787, Train F1: 1.0000, Validation F1: 1.0000
# Epoch 203, Training Loss: 0.48225951194763184, Train F1: 1.0000, Validation F1: 1.0000
# Epoch 204, Training Loss: 0.4814671576023102, Train F1: 1.0000, Validation F1: 1.0000
# Epoch 205, Training Loss: 0.4804352819919586, Train F1: 1.0000, Validation F1: 1.0000
# Epoch 206, Training Loss: 0.47948789596557617, Train F1: 1.0000, Validation F1: 1.0000
# Epoch 207, Training Loss: 0.4786408543586731, Train F1: 1.0000, Validation F1: 1.0000
# Epoch 208, Training Loss: 0.4778200089931488, Train F1: 1.0000, Validation F1: 1.0000
# Epoch 209, Training Loss: 0.4769546389579773, Train F1: 1.0000, Validation F1: 1.0000
# Epoch 210, Training Loss: 0.4760311245918274, Train F1: 1.0000, Validation F1: 1.0000
# Epoch 211, Training Loss: 0.47517579793930054, Train F1: 1.0000, Validation F1: 1.0000
# Epoch 212, Training Loss: 0.4743252694606781, Train F1: 1.0000, Validation F1: 1.0000
# Epoch 213, Training Loss: 0.47355562448501587, Train F1: 1.0000, Validation F1: 1.0000
# Epoch 214, Training Loss: 0.4726247191429138, Train F1: 1.0000, Validation F1: 1.0000
# Epoch 215, Training Loss: 0.4717933237552643, Train F1: 1.0000, Validation F1: 1.0000
# Epoch 216, Training Loss: 0.4709482789039612, Train F1: 1.0000, Validation F1: 1.0000
# Epoch 217, Training Loss: 0.4701870083808899, Train F1: 1.0000, Validation F1: 1.0000
# Epoch 218, Training Loss: 0.46933668851852417, Train F1: 1.0000, Validation F1: 1.0000
# Epoch 219, Training Loss: 0.46841755509376526, Train F1: 1.0000, Validation F1: 1.0000
# Epoch 220, Training Loss: 0.4676281809806824, Train F1: 1.0000, Validation F1: 1.0000
# Epoch 221, Training Loss: 0.4666732847690582, Train F1: 1.0000, Validation F1: 1.0000
# Epoch 222, Training Loss: 0.46589866280555725, Train F1: 1.0000, Validation F1: 1.0000
# Epoch 223, Training Loss: 0.4649958610534668, Train F1: 1.0000, Validation F1: 1.0000
# Epoch 224, Training Loss: 0.46423134207725525, Train F1: 1.0000, Validation F1: 1.0000
# Epoch 225, Training Loss: 0.4634103775024414, Train F1: 1.0000, Validation F1: 1.0000
# Epoch 226, Training Loss: 0.4625222086906433, Train F1: 1.0000, Validation F1: 1.0000
# Epoch 227, Training Loss: 0.4616483747959137, Train F1: 1.0000, Validation F1: 1.0000
# Epoch 228, Training Loss: 0.46076035499572754, Train F1: 1.0000, Validation F1: 1.0000
# Epoch 229, Training Loss: 0.4598345160484314, Train F1: 1.0000, Validation F1: 1.0000
# Epoch 230, Training Loss: 0.45907729864120483, Train F1: 1.0000, Validation F1: 1.0000
# Epoch 231, Training Loss: 0.4581957459449768, Train F1: 1.0000, Validation F1: 1.0000
# Epoch 232, Training Loss: 0.4575173258781433, Train F1: 1.0000, Validation F1: 1.0000
# Epoch 233, Training Loss: 0.45657816529273987, Train F1: 1.0000, Validation F1: 1.0000
# Epoch 234, Training Loss: 0.45565924048423767, Train F1: 1.0000, Validation F1: 1.0000
# Epoch 235, Training Loss: 0.4547356963157654, Train F1: 1.0000, Validation F1: 1.0000
# Epoch 236, Training Loss: 0.45392847061157227, Train F1: 1.0000, Validation F1: 1.0000
# Epoch 237, Training Loss: 0.4531435966491699, Train F1: 1.0000, Validation F1: 1.0000
# Epoch 238, Training Loss: 0.45229417085647583, Train F1: 1.0000, Validation F1: 1.0000
# Epoch 239, Training Loss: 0.4514693319797516, Train F1: 1.0000, Validation F1: 1.0000
# Epoch 240, Training Loss: 0.4505334496498108, Train F1: 1.0000, Validation F1: 1.0000
# Epoch 241, Training Loss: 0.4496684670448303, Train F1: 1.0000, Validation F1: 1.0000
# Epoch 242, Training Loss: 0.44889846444129944, Train F1: 1.0000, Validation F1: 1.0000
# Epoch 243, Training Loss: 0.4479677081108093, Train F1: 1.0000, Validation F1: 1.0000
# Epoch 244, Training Loss: 0.447195827960968, Train F1: 1.0000, Validation F1: 1.0000
# Epoch 245, Training Loss: 0.4462382197380066, Train F1: 1.0000, Validation F1: 1.0000
# Epoch 246, Training Loss: 0.4454905390739441, Train F1: 1.0000, Validation F1: 1.0000
# Epoch 247, Training Loss: 0.44455546140670776, Train F1: 1.0000, Validation F1: 1.0000
# Epoch 248, Training Loss: 0.44373711943626404, Train F1: 1.0000, Validation F1: 1.0000
# Epoch 249, Training Loss: 0.443060964345932, Train F1: 1.0000, Validation F1: 1.0000
# Epoch 250, Training Loss: 0.4421312212944031, Train F1: 1.0000, Validation F1: 1.0000
# Iteration 9: G1 Results: f1=1.0

# %%
best_epoch_G1 = max(range(len(G1_results_final)), key=lambda i: G1_results_final[i][2])
best_embedding_G1 = G1_results_final[best_epoch_G1][3]

best_epoch_G2 = max(range(len(G2_results_final)), key=lambda i: G2_results_final[i][2])
best_embedding_G2 = G2_results_final[best_epoch_G2][3]

G1_results_performance = [ result[:-1] for result in G1_results_final]
G2_results_performance = [ result[:-1] for result in G1_results_final]

mean_G1_results = np.mean(G1_results_performance, axis=0)
mean_G2_results = np.mean(G2_results_performance, axis=0)

mean_G1_losses = mean_G1_results[0]
mean_G1_val_f1 = mean_G1_results[2]

mean_G2_losses = mean_G2_results[0]
mean_G2_val_f1 = mean_G2_results[2]

plot_training_and_validation(mean_G1_losses, val_f1, title=f"Average Training loss and Validation Accuracy over time using {change_topology_params['augmentation_strategy']} in G1 over 10 runs")

plot_training_and_validation(mean_G2_losses, val_f1, title=f"Average Training loss and Validation Accuracy over time using {change_topology_params['augmentation_strategy']} in G2 over 10 runs")

X,A,y = G1_train
plot_tsne(best_embedding_G1, y, layer_to_plot=-1, subject="Best Node Embeddings in G1")

X,A,y = G2_train
plot_tsne(best_embedding_G2, y, layer_to_plot=-1, subject="Best Node Embeddings in G2")

# %% [markdown]
# ### Q3.3.C Improving Graph Topology for Better Learning
#
# • Implement two graph modifications.
#
# • Describe your modifications.
#
# • What motivated your implementation?
#
# • If it helped give a hypothesis on why you think that is? If it did not give a hypothesis why
# you think it did not help.
#
# • Provide relevant plots and results

# %%
# SOLUTION Q3.3.c
# ####################################################
# MODIFY THE CODE BELOW 
# #################################################### 

from sklearn.metrics.pairwise import cosine_similarity 

def augment_graph_final(G):
    """Augments the graph."""
    X,A,y = G

    # Set all connections with the same label to 1 others to 0
    for i in range(len(y)):
        for j in range(len(y)):
            if y[i] == y[j]:
                A[i, j] *= 2
            else:
                A[i, j] *= 0.5


    similarity_matrix = cosine_similarity(X)

    # Apply similarity threshold
    similarity_threshold = 0.7
    similarity_matrix = (similarity_matrix >= similarity_threshold).astype(float)

    # Combine with original adjacency matrix using alpha
    alpha = 0.5
    augmented_A = alpha * A + (1 - alpha) * similarity_matrix

    # Normalize adjacency matrix (optional, for GNNs like GCN)
    row_sums = augmented_A.sum(axis=1, keepdims=True)
    augmented_A = augmented_A / np.maximum(row_sums, 1e-10)  # Avoid division by zero

    return X,augmented_A.float(),y
    
def improved_training_final(
        G_train,
        G_eval,
        model_params,
        num_epochs=200,
        lr=0.0005,
        verbose=True,
        return_embeddings = True,
        change_topology_params = {}
    ):
    """
    How can you improve the topologies to train better.
    """

    G_train = augment_graph_final(G_train)
    G_train = G_train[0],symmetric_normalize(G_train[1]),G_train[2]

    G_eval = augment_graph_final(G_eval)
    G_eval = G_eval[0],symmetric_normalize(G_eval[1]),G_eval[2]

    # Initialising the model
    model = LayeredGCN(**model_params)
    print(model)

    losses, train_f1, val_f1, last_embeddings = train_model(
        model,
        G_train,
        G_eval,
        num_epochs=num_epochs,
        lr=lr,
        verbose=verbose,
        return_embeddings = return_embeddings
    )
    return losses, train_f1, val_f1, last_embeddings

# ####################################################
# END OF MODIFICATION
# ####################################################

# %% [markdown]
# ### Code to run improvement

# %%
# Load data
G1_train = read_json_data(G1_TRAIN_DATA_PATH, has_label=True) #returns a list of (X,A,y) - features, Adj Matrix, per Graph label
G1_eval = read_json_data(G1_EVAL_DATA_PATH, has_label=True) #returns a list of (X,A,y) - features, Adj Matrix, per Graph label

G2_train = read_json_data(G2_TRAIN_DATA_PATH, has_label=True) #returns a list of (X,A,y) - features, Adj Matrix, per Graph label
G2_eval = read_json_data(G2_EVAL_DATA_PATH, has_label=True) #returns a list of (X,A,y) - features, Adj Matrix, per Graph label


model_params = {    
    "input_dim":10, 
    "hidden_dim":8,
    "num_layers":3,
}

change_topology_params = {
    "augmentation_strategy":"eval",
}

G1_results_final=[]
G2_results_final=[]

for i in range(10):
    losses, train_f1, val_f1, last_embeddings_G1 = improved_training_final(
        G1_train,
        G1_eval,
        model_params=model_params,
        num_epochs=250,
        lr=0.0005,
        verbose=True,
        return_embeddings = True,
        change_topology_params = change_topology_params #change as needed
    )

    print(f"Iteration {i}: G2 Results: f1={val_f1[-1]}")
    G2_results_final.append([losses, train_f1, val_f1, last_embeddings_G1]) 

    losses, train_f1, val_f1, last_embeddings_G2 = improved_training_final(
        G2_train,
        G2_eval,
        model_params=model_params,
        num_epochs=250,
        lr=0.0005,
        verbose=True,
        return_embeddings = True,
        change_topology_params = change_topology_params #change as needed
    )

    print(f"Iteration {i}: G1 Results: f1={val_f1[-1]}")
    G1_results_final.append([losses, train_f1, val_f1, last_embeddings_G2])
# Out:
# LayeredGCN(
#   (layers): ModuleList(
#     (0-2): 3 x GCNLayer()
#   )
#   (output_layer): GCNLayer()
# )
# Epoch 1, Training Loss: 0.6713289022445679, Train F1: 0.8500, Validation F1: 0.7667
# Epoch 2, Training Loss: 0.6703853607177734, Train F1: 0.8500, Validation F1: 0.7667
# Epoch 3, Training Loss: 0.6694458723068237, Train F1: 0.8500, Validation F1: 0.7667
# Epoch 4, Training Loss: 0.6685103178024292, Train F1: 0.8500, Validation F1: 0.7667
# Epoch 5, Training Loss: 0.66785728931427, Train F1: 0.8500, Validation F1: 0.7667
# Epoch 6, Training Loss: 0.6674990653991699, Train F1: 0.8500, Validation F1: 0.7667
# Epoch 7, Training Loss: 0.6671485900878906, Train F1: 0.8500, Validation F1: 0.7667
# Epoch 8, Training Loss: 0.6668006181716919, Train F1: 0.8500, Validation F1: 0.7667
# Epoch 9, Training Loss: 0.6664546728134155, Train F1: 0.8500, Validation F1: 0.7667
# Epoch 10, Training Loss: 0.6661101579666138, Train F1: 0.8500, Validation F1: 0.7667
# Epoch 11, Training Loss: 0.6657663583755493, Train F1: 0.8500, Validation F1: 0.7667
# Epoch 12, Training Loss: 0.6654233932495117, Train F1: 0.8500, Validation F1: 0.7667
# Epoch 13, Training Loss: 0.6650808453559875, Train F1: 0.8500, Validation F1: 0.7667
# Epoch 14, Training Loss: 0.6647384166717529, Train F1: 0.8500, Validation F1: 0.7667
# Epoch 15, Training Loss: 0.6643961071968079, Train F1: 0.8500, Validation F1: 0.7667
# Epoch 16, Training Loss: 0.6640537977218628, Train F1: 0.8500, Validation F1: 0.7667
# Epoch 17, Training Loss: 0.6637111902236938, Train F1: 0.8500, Validation F1: 0.7667
# Epoch 18, Training Loss: 0.663368284702301, Train F1: 0.8500, Validation F1: 0.7667
# Epoch 19, Training Loss: 0.6630250215530396, Train F1: 0.8500, Validation F1: 0.7667
# Epoch 20, Training Loss: 0.6626813411712646, Train F1: 0.8500, Validation F1: 0.7667
# Epoch 21, Training Loss: 0.6623370051383972, Train F1: 0.8375, Validation F1: 0.7667
# Epoch 22, Training Loss: 0.6619923114776611, Train F1: 0.8375, Validation F1: 0.7667
# Epoch 23, Training Loss: 0.6616469621658325, Train F1: 0.8375, Validation F1: 0.7667
# Epoch 24, Training Loss: 0.6613008975982666, Train F1: 0.8375, Validation F1: 0.7667
# Epoch 25, Training Loss: 0.6609542369842529, Train F1: 0.8375, Validation F1: 0.7667
# Epoch 26, Training Loss: 0.660606861114502, Train F1: 0.8375, Validation F1: 0.7667
# Epoch 27, Training Loss: 0.6602586507797241, Train F1: 0.8375, Validation F1: 0.7667
# Epoch 28, Training Loss: 0.6599098443984985, Train F1: 0.8375, Validation F1: 0.7667
# Epoch 29, Training Loss: 0.6595602035522461, Train F1: 0.8375, Validation F1: 0.7667
# Epoch 30, Training Loss: 0.6592097878456116, Train F1: 0.8375, Validation F1: 0.7667
# Epoch 31, Training Loss: 0.6588584780693054, Train F1: 0.8375, Validation F1: 0.7667
# Epoch 32, Training Loss: 0.6585065126419067, Train F1: 0.8375, Validation F1: 0.7667
# Epoch 33, Training Loss: 0.6581535935401917, Train F1: 0.8375, Validation F1: 0.7667
# Epoch 34, Training Loss: 0.6577998995780945, Train F1: 0.8375, Validation F1: 0.7667
# Epoch 35, Training Loss: 0.6574454307556152, Train F1: 0.8375, Validation F1: 0.7667
# Epoch 36, Training Loss: 0.6570900082588196, Train F1: 0.8375, Validation F1: 0.7667
# Epoch 37, Training Loss: 0.6567337512969971, Train F1: 0.8375, Validation F1: 0.7667
# Epoch 38, Training Loss: 0.6563765406608582, Train F1: 0.8375, Validation F1: 0.7667
# Epoch 39, Training Loss: 0.6560185551643372, Train F1: 0.8375, Validation F1: 0.7667
# Epoch 40, Training Loss: 0.6556596755981445, Train F1: 0.8375, Validation F1: 0.7667
# Epoch 41, Training Loss: 0.6552999019622803, Train F1: 0.8375, Validation F1: 0.7667
# Epoch 42, Training Loss: 0.6549393534660339, Train F1: 0.8375, Validation F1: 0.7667
# Epoch 43, Training Loss: 0.654577910900116, Train F1: 0.8375, Validation F1: 0.7667
# Epoch 44, Training Loss: 0.6542156934738159, Train F1: 0.8375, Validation F1: 0.7667
# Epoch 45, Training Loss: 0.6538524627685547, Train F1: 0.8375, Validation F1: 0.7667
# Epoch 46, Training Loss: 0.6534885168075562, Train F1: 0.8375, Validation F1: 0.7667
# Epoch 47, Training Loss: 0.653123676776886, Train F1: 0.8375, Validation F1: 0.7667
# Epoch 48, Training Loss: 0.6527581214904785, Train F1: 0.8375, Validation F1: 0.7667
# Epoch 49, Training Loss: 0.6523917317390442, Train F1: 0.8375, Validation F1: 0.7667
# Epoch 50, Training Loss: 0.6520243883132935, Train F1: 0.8375, Validation F1: 0.7667
# Epoch 51, Training Loss: 0.6516563296318054, Train F1: 0.8375, Validation F1: 0.7667
# Epoch 52, Training Loss: 0.6512875556945801, Train F1: 0.8375, Validation F1: 0.7667
# Epoch 53, Training Loss: 0.6509178876876831, Train F1: 0.8375, Validation F1: 0.7667
# Epoch 54, Training Loss: 0.6505475640296936, Train F1: 0.8375, Validation F1: 0.7667
# Epoch 55, Training Loss: 0.6501762270927429, Train F1: 0.8375, Validation F1: 0.7667
# Epoch 56, Training Loss: 0.6498042345046997, Train F1: 0.8375, Validation F1: 0.7667
# Epoch 57, Training Loss: 0.649431586265564, Train F1: 0.8375, Validation F1: 0.7667
# Epoch 58, Training Loss: 0.6490581035614014, Train F1: 0.8375, Validation F1: 0.7667
# Epoch 59, Training Loss: 0.6486839056015015, Train F1: 0.8375, Validation F1: 0.7667
# Epoch 60, Training Loss: 0.6483088731765747, Train F1: 0.8375, Validation F1: 0.7667
# Epoch 61, Training Loss: 0.6479332447052002, Train F1: 0.8375, Validation F1: 0.7667
# Epoch 62, Training Loss: 0.6475568413734436, Train F1: 0.8375, Validation F1: 0.7667
# Epoch 63, Training Loss: 0.6471797823905945, Train F1: 0.8375, Validation F1: 0.7667
# Epoch 64, Training Loss: 0.6468019485473633, Train F1: 0.8375, Validation F1: 0.7667
# Epoch 65, Training Loss: 0.6464240550994873, Train F1: 0.8375, Validation F1: 0.7667
# Epoch 66, Training Loss: 0.6460444331169128, Train F1: 0.8375, Validation F1: 0.7667
# Epoch 67, Training Loss: 0.6456647515296936, Train F1: 0.8375, Validation F1: 0.7667
# Epoch 68, Training Loss: 0.6452842950820923, Train F1: 0.8375, Validation F1: 0.7667
# Epoch 69, Training Loss: 0.644903302192688, Train F1: 0.8375, Validation F1: 0.7667
# Epoch 70, Training Loss: 0.6445216536521912, Train F1: 0.8375, Validation F1: 0.7667
# Epoch 71, Training Loss: 0.644139289855957, Train F1: 0.8375, Validation F1: 0.7667
# Epoch 72, Training Loss: 0.6437563300132751, Train F1: 0.8375, Validation F1: 0.7667
# Epoch 73, Training Loss: 0.6433728337287903, Train F1: 0.8375, Validation F1: 0.7667
# Epoch 74, Training Loss: 0.6429886817932129, Train F1: 0.8375, Validation F1: 0.7667
# Epoch 75, Training Loss: 0.6426040530204773, Train F1: 0.8375, Validation F1: 0.7333
# Epoch 76, Training Loss: 0.642219066619873, Train F1: 0.8375, Validation F1: 0.5000
# Epoch 77, Training Loss: 0.6418335437774658, Train F1: 0.8375, Validation F1: 0.5000
# Epoch 78, Training Loss: 0.6414476037025452, Train F1: 0.8375, Validation F1: 0.5000
# Epoch 79, Training Loss: 0.6410609483718872, Train F1: 0.8375, Validation F1: 0.5000
# Epoch 80, Training Loss: 0.6406739354133606, Train F1: 0.8375, Validation F1: 0.5000
# Epoch 81, Training Loss: 0.6402863264083862, Train F1: 0.8375, Validation F1: 0.5000
# Epoch 82, Training Loss: 0.6399051547050476, Train F1: 0.8375, Validation F1: 0.5000
# Epoch 83, Training Loss: 0.6395127177238464, Train F1: 0.8375, Validation F1: 0.5000
# Epoch 84, Training Loss: 0.6391218900680542, Train F1: 0.8375, Validation F1: 0.5000
# Epoch 85, Training Loss: 0.6387338638305664, Train F1: 0.8375, Validation F1: 0.5000
# Epoch 86, Training Loss: 0.6383442282676697, Train F1: 0.8375, Validation F1: 0.5000
# Epoch 87, Training Loss: 0.637954592704773, Train F1: 0.8375, Validation F1: 0.5667
# Epoch 88, Training Loss: 0.6375646591186523, Train F1: 0.8375, Validation F1: 0.7333
# Epoch 89, Training Loss: 0.6371742486953735, Train F1: 0.8375, Validation F1: 0.7667
# Epoch 90, Training Loss: 0.6367833614349365, Train F1: 0.8375, Validation F1: 0.7667
# Epoch 91, Training Loss: 0.6363918781280518, Train F1: 0.8375, Validation F1: 0.7667
# Epoch 92, Training Loss: 0.6360000371932983, Train F1: 0.8375, Validation F1: 0.7667
# Epoch 93, Training Loss: 0.6356077194213867, Train F1: 0.8375, Validation F1: 0.7667
# Epoch 94, Training Loss: 0.6352149248123169, Train F1: 0.8375, Validation F1: 0.7667
# Epoch 95, Training Loss: 0.6348217725753784, Train F1: 0.8375, Validation F1: 0.7667
# Epoch 96, Training Loss: 0.6344281435012817, Train F1: 0.8375, Validation F1: 0.7667
# Epoch 97, Training Loss: 0.6340342164039612, Train F1: 0.8375, Validation F1: 0.7667
# Epoch 98, Training Loss: 0.633639931678772, Train F1: 0.8375, Validation F1: 0.7667
# Epoch 99, Training Loss: 0.6332451701164246, Train F1: 0.8375, Validation F1: 0.7667
# Epoch 100, Training Loss: 0.6328502893447876, Train F1: 0.8375, Validation F1: 0.7667
# Epoch 101, Training Loss: 0.6324551105499268, Train F1: 0.8375, Validation F1: 0.7667
# Epoch 102, Training Loss: 0.6320594549179077, Train F1: 0.8375, Validation F1: 0.7667
# Epoch 103, Training Loss: 0.6316636800765991, Train F1: 0.8375, Validation F1: 0.7667
# Epoch 104, Training Loss: 0.6312685012817383, Train F1: 0.8375, Validation F1: 0.7667
# Epoch 105, Training Loss: 0.6308716535568237, Train F1: 0.8375, Validation F1: 0.7333
# Epoch 106, Training Loss: 0.6304755806922913, Train F1: 0.8375, Validation F1: 0.7667
# Epoch 107, Training Loss: 0.6300797462463379, Train F1: 0.8375, Validation F1: 0.7667
# Epoch 108, Training Loss: 0.6296837329864502, Train F1: 0.8375, Validation F1: 0.7667
# Epoch 109, Training Loss: 0.6292874813079834, Train F1: 0.8375, Validation F1: 0.7667
# Epoch 110, Training Loss: 0.628891110420227, Train F1: 0.8375, Validation F1: 0.7667
# Epoch 111, Training Loss: 0.6284944415092468, Train F1: 0.8375, Validation F1: 0.7667
# Epoch 112, Training Loss: 0.628097653388977, Train F1: 0.8375, Validation F1: 0.7667
# Epoch 113, Training Loss: 0.6277006268501282, Train F1: 0.8375, Validation F1: 0.7667
# Epoch 114, Training Loss: 0.6273034811019897, Train F1: 0.8375, Validation F1: 0.7667
# Epoch 115, Training Loss: 0.6269069910049438, Train F1: 0.8375, Validation F1: 0.7667
# Epoch 116, Training Loss: 0.6265097856521606, Train F1: 0.8375, Validation F1: 0.7667
# Epoch 117, Training Loss: 0.6261134743690491, Train F1: 0.8375, Validation F1: 0.7667
# Epoch 118, Training Loss: 0.6257165670394897, Train F1: 0.8375, Validation F1: 0.7667
# Epoch 119, Training Loss: 0.6253196001052856, Train F1: 0.8375, Validation F1: 0.7667
# Epoch 120, Training Loss: 0.6249227523803711, Train F1: 0.8375, Validation F1: 0.7667
# Epoch 121, Training Loss: 0.6245259046554565, Train F1: 0.8375, Validation F1: 0.7667
# Epoch 122, Training Loss: 0.6241291165351868, Train F1: 0.8375, Validation F1: 0.7667
# Epoch 123, Training Loss: 0.6237322092056274, Train F1: 0.8375, Validation F1: 0.7667
# Epoch 124, Training Loss: 0.6233354210853577, Train F1: 0.8375, Validation F1: 0.7667
# Epoch 125, Training Loss: 0.6229385137557983, Train F1: 0.8375, Validation F1: 0.7667
# Epoch 126, Training Loss: 0.6225417852401733, Train F1: 0.8375, Validation F1: 0.7667
# Epoch 127, Training Loss: 0.6221451759338379, Train F1: 0.8375, Validation F1: 0.7667
# Epoch 128, Training Loss: 0.6217489838600159, Train F1: 0.8375, Validation F1: 0.7667
# Epoch 129, Training Loss: 0.6213529109954834, Train F1: 0.8375, Validation F1: 0.7667
# Epoch 130, Training Loss: 0.6209573745727539, Train F1: 0.8375, Validation F1: 0.7667
# Epoch 131, Training Loss: 0.6205617785453796, Train F1: 0.8375, Validation F1: 0.7667
# Epoch 132, Training Loss: 0.620166540145874, Train F1: 0.8375, Validation F1: 0.7667
# Epoch 133, Training Loss: 0.619771420955658, Train F1: 0.8375, Validation F1: 0.7667
# Epoch 134, Training Loss: 0.619376540184021, Train F1: 0.8375, Validation F1: 0.7667
# Epoch 135, Training Loss: 0.6189818382263184, Train F1: 0.8375, Validation F1: 0.7667
# Epoch 136, Training Loss: 0.6185873746871948, Train F1: 0.8375, Validation F1: 0.7667
# Epoch 137, Training Loss: 0.6181930899620056, Train F1: 0.8375, Validation F1: 0.7667
# Epoch 138, Training Loss: 0.6177992224693298, Train F1: 0.8375, Validation F1: 0.7667
# Epoch 139, Training Loss: 0.6174055933952332, Train F1: 0.8375, Validation F1: 0.7667
# Epoch 140, Training Loss: 0.6170139908790588, Train F1: 0.8375, Validation F1: 0.7667
# Epoch 141, Training Loss: 0.6166201233863831, Train F1: 0.8375, Validation F1: 0.7667
# Epoch 142, Training Loss: 0.6162282228469849, Train F1: 0.8375, Validation F1: 0.7667
# Epoch 143, Training Loss: 0.615836501121521, Train F1: 0.8375, Validation F1: 0.7667
# Epoch 144, Training Loss: 0.6154452562332153, Train F1: 0.8375, Validation F1: 0.7667
# Epoch 145, Training Loss: 0.6150543093681335, Train F1: 0.8375, Validation F1: 0.7667
# Epoch 146, Training Loss: 0.6146637797355652, Train F1: 0.8375, Validation F1: 0.7667
# Epoch 147, Training Loss: 0.6142738461494446, Train F1: 0.8375, Validation F1: 0.7667
# Epoch 148, Training Loss: 0.6138842701911926, Train F1: 0.8375, Validation F1: 0.7667
# Epoch 149, Training Loss: 0.6134951114654541, Train F1: 0.8375, Validation F1: 0.7667
# Epoch 150, Training Loss: 0.6131064295768738, Train F1: 0.8375, Validation F1: 0.7667
# Epoch 151, Training Loss: 0.6127182841300964, Train F1: 0.8375, Validation F1: 0.7667
# Epoch 152, Training Loss: 0.6123318076133728, Train F1: 0.8375, Validation F1: 0.7667
# Epoch 153, Training Loss: 0.6119444966316223, Train F1: 0.8375, Validation F1: 0.7667
# Epoch 154, Training Loss: 0.6115584969520569, Train F1: 0.8375, Validation F1: 0.7667
# Epoch 155, Training Loss: 0.6111732721328735, Train F1: 0.8375, Validation F1: 0.7667
# Epoch 156, Training Loss: 0.6107885241508484, Train F1: 0.8375, Validation F1: 0.7667
# Epoch 157, Training Loss: 0.610404372215271, Train F1: 0.8375, Validation F1: 0.7667
# Epoch 158, Training Loss: 0.6100208163261414, Train F1: 0.8375, Validation F1: 0.7667
# Epoch 159, Training Loss: 0.6096379160881042, Train F1: 0.8375, Validation F1: 0.7667
# Epoch 160, Training Loss: 0.6092557907104492, Train F1: 0.8375, Validation F1: 0.7667
# Epoch 161, Training Loss: 0.6088742613792419, Train F1: 0.8375, Validation F1: 0.7667
# Epoch 162, Training Loss: 0.608493447303772, Train F1: 0.8375, Validation F1: 0.7667
# Epoch 163, Training Loss: 0.6081134080886841, Train F1: 0.8375, Validation F1: 0.7667
# Epoch 164, Training Loss: 0.6077340245246887, Train F1: 0.8375, Validation F1: 0.7667
# Epoch 165, Training Loss: 0.6073582172393799, Train F1: 0.8375, Validation F1: 0.7667
# Epoch 166, Training Loss: 0.6069784760475159, Train F1: 0.8375, Validation F1: 0.7667
# Epoch 167, Training Loss: 0.6066020727157593, Train F1: 0.8375, Validation F1: 0.7667
# Epoch 168, Training Loss: 0.6062265634536743, Train F1: 0.8375, Validation F1: 0.7667
# Epoch 169, Training Loss: 0.6058517098426819, Train F1: 0.8375, Validation F1: 0.7667
# Epoch 170, Training Loss: 0.6054776310920715, Train F1: 0.8375, Validation F1: 0.7667
# Epoch 171, Training Loss: 0.6051048040390015, Train F1: 0.8375, Validation F1: 0.7667
# Epoch 172, Training Loss: 0.6047323346138, Train F1: 0.8375, Validation F1: 0.7667
# Epoch 173, Training Loss: 0.6043609380722046, Train F1: 0.8375, Validation F1: 0.7667
# Epoch 174, Training Loss: 0.6039905548095703, Train F1: 0.8375, Validation F1: 0.7667
# Epoch 175, Training Loss: 0.6036210060119629, Train F1: 0.8375, Validation F1: 0.7667
# Epoch 176, Training Loss: 0.6032525300979614, Train F1: 0.8375, Validation F1: 0.7667
# Epoch 177, Training Loss: 0.6028857231140137, Train F1: 0.8375, Validation F1: 0.7667
# Epoch 178, Training Loss: 0.6025189757347107, Train F1: 0.8375, Validation F1: 0.7667
# Epoch 179, Training Loss: 0.6021540760993958, Train F1: 0.8375, Validation F1: 0.7667
# Epoch 180, Training Loss: 0.6017900109291077, Train F1: 0.8375, Validation F1: 0.7667
# Epoch 181, Training Loss: 0.6014269590377808, Train F1: 0.8375, Validation F1: 0.7667
# Epoch 182, Training Loss: 0.6010650396347046, Train F1: 0.8375, Validation F1: 0.7667
# Epoch 183, Training Loss: 0.6007041335105896, Train F1: 0.8375, Validation F1: 0.7667
# Epoch 184, Training Loss: 0.6003443002700806, Train F1: 0.8375, Validation F1: 0.7667
# Epoch 185, Training Loss: 0.5999854803085327, Train F1: 0.8375, Validation F1: 0.7667
# Epoch 186, Training Loss: 0.5996277332305908, Train F1: 0.8375, Validation F1: 0.7667
# Epoch 187, Training Loss: 0.5992711782455444, Train F1: 0.8375, Validation F1: 0.7667
# Epoch 188, Training Loss: 0.5989157557487488, Train F1: 0.8375, Validation F1: 0.7667
# Epoch 189, Training Loss: 0.5985614657402039, Train F1: 0.8375, Validation F1: 0.7667
# Epoch 190, Training Loss: 0.5982085466384888, Train F1: 0.8375, Validation F1: 0.7667
# Epoch 191, Training Loss: 0.5978584885597229, Train F1: 0.8375, Validation F1: 0.7667
# Epoch 192, Training Loss: 0.5975066423416138, Train F1: 0.8375, Validation F1: 0.7667
# Epoch 193, Training Loss: 0.5971577167510986, Train F1: 0.8375, Validation F1: 0.7667
# Epoch 194, Training Loss: 0.5968101024627686, Train F1: 0.8375, Validation F1: 0.7667
# Epoch 195, Training Loss: 0.596463680267334, Train F1: 0.8375, Validation F1: 0.7667
# Epoch 196, Training Loss: 0.5961185097694397, Train F1: 0.8375, Validation F1: 0.7667
# Epoch 197, Training Loss: 0.5957745313644409, Train F1: 0.8375, Validation F1: 0.7667
# Epoch 198, Training Loss: 0.5954318046569824, Train F1: 0.8375, Validation F1: 0.7667
# Epoch 199, Training Loss: 0.595090389251709, Train F1: 0.8375, Validation F1: 0.7667
# Epoch 200, Training Loss: 0.5947502851486206, Train F1: 0.8375, Validation F1: 0.7667
# Epoch 201, Training Loss: 0.5944117307662964, Train F1: 0.8375, Validation F1: 0.7667
# Epoch 202, Training Loss: 0.5940741300582886, Train F1: 0.8375, Validation F1: 0.7667
# Epoch 203, Training Loss: 0.5937380194664001, Train F1: 0.8375, Validation F1: 0.7667
# Epoch 204, Training Loss: 0.5934035181999207, Train F1: 0.8375, Validation F1: 0.7667
# Epoch 205, Training Loss: 0.5930708050727844, Train F1: 0.8375, Validation F1: 0.7667
# Epoch 206, Training Loss: 0.5927394032478333, Train F1: 0.8375, Validation F1: 0.7667
# Epoch 207, Training Loss: 0.5924094319343567, Train F1: 0.8375, Validation F1: 0.7667
# Epoch 208, Training Loss: 0.5920807719230652, Train F1: 0.8375, Validation F1: 0.7667
# Epoch 209, Training Loss: 0.5917536020278931, Train F1: 0.8375, Validation F1: 0.7667
# Epoch 210, Training Loss: 0.5914276838302612, Train F1: 0.8375, Validation F1: 0.7667
# Epoch 211, Training Loss: 0.5911032557487488, Train F1: 0.8375, Validation F1: 0.7667
# Epoch 212, Training Loss: 0.5907804369926453, Train F1: 0.8375, Validation F1: 0.7667
# Epoch 213, Training Loss: 0.5904589295387268, Train F1: 0.8375, Validation F1: 0.7667
# Epoch 214, Training Loss: 0.5901389122009277, Train F1: 0.8375, Validation F1: 0.7667
# Epoch 215, Training Loss: 0.589820384979248, Train F1: 0.8375, Validation F1: 0.7667
# Epoch 216, Training Loss: 0.5895034074783325, Train F1: 0.8375, Validation F1: 0.7667
# Epoch 217, Training Loss: 0.5891878008842468, Train F1: 0.8375, Validation F1: 0.7667
# Epoch 218, Training Loss: 0.5888738036155701, Train F1: 0.8375, Validation F1: 0.7667
# Epoch 219, Training Loss: 0.588561475276947, Train F1: 0.8375, Validation F1: 0.7667
# Epoch 220, Training Loss: 0.588250994682312, Train F1: 0.8375, Validation F1: 0.7667
# Epoch 221, Training Loss: 0.5879420042037964, Train F1: 0.8375, Validation F1: 0.7667
# Epoch 222, Training Loss: 0.5876347422599792, Train F1: 0.8375, Validation F1: 0.7667
# Epoch 223, Training Loss: 0.5873289704322815, Train F1: 0.8375, Validation F1: 0.7333
# Epoch 224, Training Loss: 0.5870245695114136, Train F1: 0.8375, Validation F1: 0.7333
# Epoch 225, Training Loss: 0.5867217183113098, Train F1: 0.8375, Validation F1: 0.7333
# Epoch 226, Training Loss: 0.5864206552505493, Train F1: 0.8375, Validation F1: 0.7333
# Epoch 227, Training Loss: 0.5861208438873291, Train F1: 0.8375, Validation F1: 0.7333
# Epoch 228, Training Loss: 0.5858228802680969, Train F1: 0.8375, Validation F1: 0.7333
# Epoch 229, Training Loss: 0.5855263471603394, Train F1: 0.8375, Validation F1: 0.7333
# Epoch 230, Training Loss: 0.5852315425872803, Train F1: 0.8375, Validation F1: 0.7333
# Epoch 231, Training Loss: 0.5849381685256958, Train F1: 0.8375, Validation F1: 0.7333
# Epoch 232, Training Loss: 0.5846465229988098, Train F1: 0.8375, Validation F1: 0.7333
# Epoch 233, Training Loss: 0.584356427192688, Train F1: 0.8375, Validation F1: 0.7333
# Epoch 234, Training Loss: 0.5840680003166199, Train F1: 0.8375, Validation F1: 0.7333
# Epoch 235, Training Loss: 0.5837836265563965, Train F1: 0.8375, Validation F1: 0.7333
# Epoch 236, Training Loss: 0.5834965705871582, Train F1: 0.8375, Validation F1: 0.7333
# Epoch 237, Training Loss: 0.5832135081291199, Train F1: 0.8375, Validation F1: 0.7333
# Epoch 238, Training Loss: 0.5829319953918457, Train F1: 0.8375, Validation F1: 0.7333
# Epoch 239, Training Loss: 0.5826521515846252, Train F1: 0.8375, Validation F1: 0.7333
# Epoch 240, Training Loss: 0.5823739171028137, Train F1: 0.8375, Validation F1: 0.7333
# Epoch 241, Training Loss: 0.5820971727371216, Train F1: 0.8375, Validation F1: 0.7333
# Epoch 242, Training Loss: 0.5818221569061279, Train F1: 0.8375, Validation F1: 0.7333
# Epoch 243, Training Loss: 0.581548810005188, Train F1: 0.8375, Validation F1: 0.7333
# Epoch 244, Training Loss: 0.5812769532203674, Train F1: 0.8375, Validation F1: 0.7333
# Epoch 245, Training Loss: 0.5810068845748901, Train F1: 0.8375, Validation F1: 0.7333
# Epoch 246, Training Loss: 0.580738365650177, Train F1: 0.8375, Validation F1: 0.7333
# Epoch 247, Training Loss: 0.5804715156555176, Train F1: 0.8375, Validation F1: 0.7333
# Epoch 248, Training Loss: 0.5802063345909119, Train F1: 0.8375, Validation F1: 0.7333
# Epoch 249, Training Loss: 0.5799427032470703, Train F1: 0.8375, Validation F1: 0.7333
# Epoch 250, Training Loss: 0.5796808004379272, Train F1: 0.8375, Validation F1: 0.7333
# Iteration 0: G2 Results: f1=0.7333333333333333
# LayeredGCN(
#   (layers): ModuleList(
#     (0-2): 3 x GCNLayer()
#   )
#   (output_layer): GCNLayer()
# )
# Epoch 1, Training Loss: 0.7118452191352844, Train F1: 0.5125, Validation F1: 0.3667
# Epoch 2, Training Loss: 0.7113344669342041, Train F1: 0.5125, Validation F1: 0.3667
# Epoch 3, Training Loss: 0.7108334898948669, Train F1: 0.5125, Validation F1: 0.3667
# Epoch 4, Training Loss: 0.7103529572486877, Train F1: 0.5125, Validation F1: 0.3667
# Epoch 5, Training Loss: 0.7098860144615173, Train F1: 0.5125, Validation F1: 0.3667
# Epoch 6, Training Loss: 0.7094295024871826, Train F1: 0.5125, Validation F1: 0.3667
# Epoch 7, Training Loss: 0.7089830636978149, Train F1: 0.5125, Validation F1: 0.3667
# Epoch 8, Training Loss: 0.7085494995117188, Train F1: 0.5125, Validation F1: 0.3667
# Epoch 9, Training Loss: 0.7081245183944702, Train F1: 0.5125, Validation F1: 0.3667
# Epoch 10, Training Loss: 0.7077100276947021, Train F1: 0.5125, Validation F1: 0.3667
# Epoch 11, Training Loss: 0.7073146104812622, Train F1: 0.5125, Validation F1: 0.3667
# Epoch 12, Training Loss: 0.7069332003593445, Train F1: 0.5125, Validation F1: 0.3667
# Epoch 13, Training Loss: 0.7065645456314087, Train F1: 0.5125, Validation F1: 0.3667
# Epoch 14, Training Loss: 0.7062129378318787, Train F1: 0.5125, Validation F1: 0.3667
# Epoch 15, Training Loss: 0.7058790326118469, Train F1: 0.5125, Validation F1: 0.3667
# Epoch 16, Training Loss: 0.7055625915527344, Train F1: 0.5125, Validation F1: 0.3667
# Epoch 17, Training Loss: 0.7052547931671143, Train F1: 0.5125, Validation F1: 0.3667
# Epoch 18, Training Loss: 0.704957127571106, Train F1: 0.5125, Validation F1: 0.3667
# Epoch 19, Training Loss: 0.704667329788208, Train F1: 0.5125, Validation F1: 0.3667
# Epoch 20, Training Loss: 0.7043872475624084, Train F1: 0.5125, Validation F1: 0.3667
# Epoch 21, Training Loss: 0.7041142582893372, Train F1: 0.5125, Validation F1: 0.3667
# Epoch 22, Training Loss: 0.7038469314575195, Train F1: 0.5125, Validation F1: 0.3667
# Epoch 23, Training Loss: 0.7035855650901794, Train F1: 0.5125, Validation F1: 0.3667
# Epoch 24, Training Loss: 0.7033303380012512, Train F1: 0.5125, Validation F1: 0.3667
# Epoch 25, Training Loss: 0.7030807137489319, Train F1: 0.5125, Validation F1: 0.3667
# Epoch 26, Training Loss: 0.7028375864028931, Train F1: 0.5125, Validation F1: 0.3667
# Epoch 27, Training Loss: 0.7026007771492004, Train F1: 0.5125, Validation F1: 0.3667
# Epoch 28, Training Loss: 0.702369213104248, Train F1: 0.5125, Validation F1: 0.3667
# Epoch 29, Training Loss: 0.7021433711051941, Train F1: 0.5125, Validation F1: 0.3667
# Epoch 30, Training Loss: 0.701921820640564, Train F1: 0.5125, Validation F1: 0.3667
# Epoch 31, Training Loss: 0.7017050981521606, Train F1: 0.5125, Validation F1: 0.3667
# Epoch 32, Training Loss: 0.701492965221405, Train F1: 0.5125, Validation F1: 0.3667
# Epoch 33, Training Loss: 0.701285719871521, Train F1: 0.5125, Validation F1: 0.3667
# Epoch 34, Training Loss: 0.7010825276374817, Train F1: 0.5125, Validation F1: 0.3667
# Epoch 35, Training Loss: 0.7008826732635498, Train F1: 0.5125, Validation F1: 0.3667
# Epoch 36, Training Loss: 0.7006860971450806, Train F1: 0.5125, Validation F1: 0.3667
# Epoch 37, Training Loss: 0.7004926800727844, Train F1: 0.5125, Validation F1: 0.3667
# Epoch 38, Training Loss: 0.700302243232727, Train F1: 0.5125, Validation F1: 0.3667
# Epoch 39, Training Loss: 0.7001148462295532, Train F1: 0.5125, Validation F1: 0.3667
# Epoch 40, Training Loss: 0.6999306678771973, Train F1: 0.5125, Validation F1: 0.3667
# Epoch 41, Training Loss: 0.6997496485710144, Train F1: 0.5125, Validation F1: 0.3667
# Epoch 42, Training Loss: 0.6995733380317688, Train F1: 0.5125, Validation F1: 0.3667
# Epoch 43, Training Loss: 0.6994008421897888, Train F1: 0.5125, Validation F1: 0.3667
# Epoch 44, Training Loss: 0.6992315649986267, Train F1: 0.5125, Validation F1: 0.3667
# Epoch 45, Training Loss: 0.699065089225769, Train F1: 0.5125, Validation F1: 0.3667
# Epoch 46, Training Loss: 0.6989011168479919, Train F1: 0.5125, Validation F1: 0.3667
# Epoch 47, Training Loss: 0.6987396478652954, Train F1: 0.5125, Validation F1: 0.3667
# Epoch 48, Training Loss: 0.6985808610916138, Train F1: 0.5125, Validation F1: 0.3667
# Epoch 49, Training Loss: 0.6984250545501709, Train F1: 0.5125, Validation F1: 0.3667
# Epoch 50, Training Loss: 0.6982718110084534, Train F1: 0.5125, Validation F1: 0.3667
# Epoch 51, Training Loss: 0.6981214284896851, Train F1: 0.5125, Validation F1: 0.3667
# Epoch 52, Training Loss: 0.6979734301567078, Train F1: 0.5125, Validation F1: 0.3667
# Epoch 53, Training Loss: 0.6978276968002319, Train F1: 0.5125, Validation F1: 0.3667
# Epoch 54, Training Loss: 0.6976839900016785, Train F1: 0.5125, Validation F1: 0.3667
# Epoch 55, Training Loss: 0.6975423097610474, Train F1: 0.5125, Validation F1: 0.3667
# Epoch 56, Training Loss: 0.6974025964736938, Train F1: 0.5125, Validation F1: 0.3667
# Epoch 57, Training Loss: 0.6972647905349731, Train F1: 0.5125, Validation F1: 0.3667
# Epoch 58, Training Loss: 0.6971288919448853, Train F1: 0.5125, Validation F1: 0.3667
# Epoch 59, Training Loss: 0.6969947814941406, Train F1: 0.5125, Validation F1: 0.3667
# Epoch 60, Training Loss: 0.6968623399734497, Train F1: 0.5125, Validation F1: 0.3667
# Epoch 61, Training Loss: 0.696731448173523, Train F1: 0.5125, Validation F1: 0.3667
# Epoch 62, Training Loss: 0.6966022253036499, Train F1: 0.5125, Validation F1: 0.3667
# Epoch 63, Training Loss: 0.6964744925498962, Train F1: 0.5125, Validation F1: 0.3667
# Epoch 64, Training Loss: 0.6963483095169067, Train F1: 0.5125, Validation F1: 0.3667
# Epoch 65, Training Loss: 0.6962236762046814, Train F1: 0.5125, Validation F1: 0.3667
# Epoch 66, Training Loss: 0.6961005330085754, Train F1: 0.5125, Validation F1: 0.3667
# Epoch 67, Training Loss: 0.6959787607192993, Train F1: 0.5125, Validation F1: 0.3667
# Epoch 68, Training Loss: 0.6958585381507874, Train F1: 0.5125, Validation F1: 0.3667
# Epoch 69, Training Loss: 0.6957395672798157, Train F1: 0.5125, Validation F1: 0.3667
# Epoch 70, Training Loss: 0.6956218481063843, Train F1: 0.5125, Validation F1: 0.3667
# Epoch 71, Training Loss: 0.6955054998397827, Train F1: 0.5125, Validation F1: 0.3667
# Epoch 72, Training Loss: 0.6953903436660767, Train F1: 0.5125, Validation F1: 0.3667
# Epoch 73, Training Loss: 0.6952763795852661, Train F1: 0.5125, Validation F1: 0.3667
# Epoch 74, Training Loss: 0.6951634883880615, Train F1: 0.5125, Validation F1: 0.3667
# Epoch 75, Training Loss: 0.6950520873069763, Train F1: 0.5125, Validation F1: 0.3667
# Epoch 76, Training Loss: 0.6949419975280762, Train F1: 0.5125, Validation F1: 0.3667
# Epoch 77, Training Loss: 0.694832980632782, Train F1: 0.5125, Validation F1: 0.3667
# Epoch 78, Training Loss: 0.6947249174118042, Train F1: 0.5125, Validation F1: 0.3667
# Epoch 79, Training Loss: 0.6946179866790771, Train F1: 0.5125, Validation F1: 0.3667
# Epoch 80, Training Loss: 0.6945120096206665, Train F1: 0.5125, Validation F1: 0.3667
# Epoch 81, Training Loss: 0.6944074630737305, Train F1: 0.5125, Validation F1: 0.3667
# Epoch 82, Training Loss: 0.6943039894104004, Train F1: 0.5125, Validation F1: 0.3667
# Epoch 83, Training Loss: 0.6942013502120972, Train F1: 0.5125, Validation F1: 0.3667
# Epoch 84, Training Loss: 0.6940997242927551, Train F1: 0.5125, Validation F1: 0.3667
# Epoch 85, Training Loss: 0.6939993500709534, Train F1: 0.5125, Validation F1: 0.3667
# Epoch 86, Training Loss: 0.6939007639884949, Train F1: 0.5125, Validation F1: 0.3667
# Epoch 87, Training Loss: 0.6938031315803528, Train F1: 0.5125, Validation F1: 0.3667
# Epoch 88, Training Loss: 0.6937077045440674, Train F1: 0.5125, Validation F1: 0.3667
# Epoch 89, Training Loss: 0.6936144232749939, Train F1: 0.5125, Validation F1: 0.3667
# Epoch 90, Training Loss: 0.6935221552848816, Train F1: 0.5125, Validation F1: 0.3667
# Epoch 91, Training Loss: 0.69343101978302, Train F1: 0.5125, Validation F1: 0.3667
# Epoch 92, Training Loss: 0.6933408975601196, Train F1: 0.5125, Validation F1: 0.3667
# Epoch 93, Training Loss: 0.6932516098022461, Train F1: 0.5125, Validation F1: 0.3667
# Epoch 94, Training Loss: 0.6931632161140442, Train F1: 0.5125, Validation F1: 0.3667
# Epoch 95, Training Loss: 0.6930754780769348, Train F1: 0.5125, Validation F1: 0.3667
# Epoch 96, Training Loss: 0.6929882764816284, Train F1: 0.5125, Validation F1: 0.3667
# Epoch 97, Training Loss: 0.692902147769928, Train F1: 0.5125, Validation F1: 0.3667
# Epoch 98, Training Loss: 0.6928168535232544, Train F1: 0.5125, Validation F1: 0.3667
# Epoch 99, Training Loss: 0.6927323937416077, Train F1: 0.5125, Validation F1: 0.3667
# Epoch 100, Training Loss: 0.6926487684249878, Train F1: 0.5125, Validation F1: 0.3667
# Epoch 101, Training Loss: 0.6925655603408813, Train F1: 0.5125, Validation F1: 0.3667
# Epoch 102, Training Loss: 0.6924830079078674, Train F1: 0.5125, Validation F1: 0.3667
# Epoch 103, Training Loss: 0.6924010515213013, Train F1: 0.5125, Validation F1: 0.3667
# Epoch 104, Training Loss: 0.692319393157959, Train F1: 0.5125, Validation F1: 0.3667
# Epoch 105, Training Loss: 0.6922391057014465, Train F1: 0.5125, Validation F1: 0.3667
# Epoch 106, Training Loss: 0.6921597123146057, Train F1: 0.5125, Validation F1: 0.3667
# Epoch 107, Training Loss: 0.69208163022995, Train F1: 0.5125, Validation F1: 0.3667
# Epoch 108, Training Loss: 0.692004382610321, Train F1: 0.5125, Validation F1: 0.3667
# Epoch 109, Training Loss: 0.6919275522232056, Train F1: 0.5125, Validation F1: 0.3667
# Epoch 110, Training Loss: 0.6918511390686035, Train F1: 0.5125, Validation F1: 0.3667
# Epoch 111, Training Loss: 0.6917752027511597, Train F1: 0.5125, Validation F1: 0.3667
# Epoch 112, Training Loss: 0.6916995048522949, Train F1: 0.5125, Validation F1: 0.3667
# Epoch 113, Training Loss: 0.691624104976654, Train F1: 0.5125, Validation F1: 0.3667
# Epoch 114, Training Loss: 0.6915491223335266, Train F1: 0.5125, Validation F1: 0.3667
# Epoch 115, Training Loss: 0.6914743781089783, Train F1: 0.5125, Validation F1: 0.3667
# Epoch 116, Training Loss: 0.691400408744812, Train F1: 0.5125, Validation F1: 0.3667
# Epoch 117, Training Loss: 0.6913267970085144, Train F1: 0.5125, Validation F1: 0.3667
# Epoch 118, Training Loss: 0.6912537813186646, Train F1: 0.5125, Validation F1: 0.3667
# Epoch 119, Training Loss: 0.6911816000938416, Train F1: 0.5125, Validation F1: 0.3667
# Epoch 120, Training Loss: 0.6911097764968872, Train F1: 0.5125, Validation F1: 0.3667
# Epoch 121, Training Loss: 0.6910387277603149, Train F1: 0.5125, Validation F1: 0.3667
# Epoch 122, Training Loss: 0.69096839427948, Train F1: 0.5125, Validation F1: 0.3667
# Epoch 123, Training Loss: 0.6908985376358032, Train F1: 0.5125, Validation F1: 0.3667
# Epoch 124, Training Loss: 0.6908291578292847, Train F1: 0.5125, Validation F1: 0.3667
# Epoch 125, Training Loss: 0.6907602548599243, Train F1: 0.5125, Validation F1: 0.3667
# Epoch 126, Training Loss: 0.6906923055648804, Train F1: 0.5125, Validation F1: 0.3667
# Epoch 127, Training Loss: 0.6906250715255737, Train F1: 0.5125, Validation F1: 0.3667
# Epoch 128, Training Loss: 0.6905585527420044, Train F1: 0.5125, Validation F1: 0.3667
# Epoch 129, Training Loss: 0.6904921531677246, Train F1: 0.5125, Validation F1: 0.3667
# Epoch 130, Training Loss: 0.6904264688491821, Train F1: 0.5125, Validation F1: 0.3667
# Epoch 131, Training Loss: 0.6903607249259949, Train F1: 0.5125, Validation F1: 0.3667
# Epoch 132, Training Loss: 0.6902958154678345, Train F1: 0.5125, Validation F1: 0.3667
# Epoch 133, Training Loss: 0.6902326345443726, Train F1: 0.5125, Validation F1: 0.3667
# Epoch 134, Training Loss: 0.6901695132255554, Train F1: 0.5125, Validation F1: 0.3667
# Epoch 135, Training Loss: 0.6901063919067383, Train F1: 0.5125, Validation F1: 0.3667
# Epoch 136, Training Loss: 0.6900433897972107, Train F1: 0.5125, Validation F1: 0.3667
# Epoch 137, Training Loss: 0.6899803876876831, Train F1: 0.5125, Validation F1: 0.3667
# Epoch 138, Training Loss: 0.6899175047874451, Train F1: 0.5125, Validation F1: 0.3667
# Epoch 139, Training Loss: 0.6898552775382996, Train F1: 0.5125, Validation F1: 0.3667
# Epoch 140, Training Loss: 0.6897934675216675, Train F1: 0.5125, Validation F1: 0.3667
# Epoch 141, Training Loss: 0.6897318959236145, Train F1: 0.5125, Validation F1: 0.3667
# Epoch 142, Training Loss: 0.6896701455116272, Train F1: 0.5125, Validation F1: 0.3667
# Epoch 143, Training Loss: 0.6896082758903503, Train F1: 0.5125, Validation F1: 0.3667
# Epoch 144, Training Loss: 0.6895462274551392, Train F1: 0.5125, Validation F1: 0.3667
# Epoch 145, Training Loss: 0.6894840598106384, Train F1: 0.5125, Validation F1: 0.3667
# Epoch 146, Training Loss: 0.6894218325614929, Train F1: 0.5125, Validation F1: 0.3667
# Epoch 147, Training Loss: 0.6893593668937683, Train F1: 0.5125, Validation F1: 0.3667
# Epoch 148, Training Loss: 0.6892971992492676, Train F1: 0.5125, Validation F1: 0.3667
# Epoch 149, Training Loss: 0.6892348527908325, Train F1: 0.5125, Validation F1: 0.3667
# Epoch 150, Training Loss: 0.6891722679138184, Train F1: 0.5125, Validation F1: 0.3667
# Epoch 151, Training Loss: 0.6891095638275146, Train F1: 0.5125, Validation F1: 0.3667
# Epoch 152, Training Loss: 0.6890466213226318, Train F1: 0.5125, Validation F1: 0.3667
# Epoch 153, Training Loss: 0.6889833807945251, Train F1: 0.5125, Validation F1: 0.3667
# Epoch 154, Training Loss: 0.6889199018478394, Train F1: 0.5125, Validation F1: 0.3667
# Epoch 155, Training Loss: 0.6888562440872192, Train F1: 0.5125, Validation F1: 0.3667
# Epoch 156, Training Loss: 0.6887922286987305, Train F1: 0.5125, Validation F1: 0.3667
# Epoch 157, Training Loss: 0.688727855682373, Train F1: 0.5125, Validation F1: 0.3667
# Epoch 158, Training Loss: 0.6886631846427917, Train F1: 0.5125, Validation F1: 0.3667
# Epoch 159, Training Loss: 0.6885982155799866, Train F1: 0.5125, Validation F1: 0.3667
# Epoch 160, Training Loss: 0.6885328888893127, Train F1: 0.5125, Validation F1: 0.3667
# Epoch 161, Training Loss: 0.6884672045707703, Train F1: 0.5125, Validation F1: 0.3667
# Epoch 162, Training Loss: 0.6884013414382935, Train F1: 0.5125, Validation F1: 0.3667
# Epoch 163, Training Loss: 0.6883350610733032, Train F1: 0.5125, Validation F1: 0.3667
# Epoch 164, Training Loss: 0.6882684826850891, Train F1: 0.5125, Validation F1: 0.3667
# Epoch 165, Training Loss: 0.6882014274597168, Train F1: 0.5125, Validation F1: 0.3667
# Epoch 166, Training Loss: 0.6881340742111206, Train F1: 0.5125, Validation F1: 0.3667
# Epoch 167, Training Loss: 0.6880663633346558, Train F1: 0.5125, Validation F1: 0.3667
# Epoch 168, Training Loss: 0.6879981756210327, Train F1: 0.5125, Validation F1: 0.3667
# Epoch 169, Training Loss: 0.6879295110702515, Train F1: 0.5125, Validation F1: 0.3667
# Epoch 170, Training Loss: 0.6878606081008911, Train F1: 0.5125, Validation F1: 0.3667
# Epoch 171, Training Loss: 0.6877910494804382, Train F1: 0.5125, Validation F1: 0.3667
# Epoch 172, Training Loss: 0.6877211928367615, Train F1: 0.5125, Validation F1: 0.3667
# Epoch 173, Training Loss: 0.6876508593559265, Train F1: 0.5125, Validation F1: 0.3667
# Epoch 174, Training Loss: 0.6875801682472229, Train F1: 0.5125, Validation F1: 0.3667
# Epoch 175, Training Loss: 0.6875088810920715, Train F1: 0.5125, Validation F1: 0.3667
# Epoch 176, Training Loss: 0.6874371767044067, Train F1: 0.5125, Validation F1: 0.3667
# Epoch 177, Training Loss: 0.687364935874939, Train F1: 0.5125, Validation F1: 0.3667
# Epoch 178, Training Loss: 0.687292218208313, Train F1: 0.5125, Validation F1: 0.3667
# Epoch 179, Training Loss: 0.6872189044952393, Train F1: 0.5125, Validation F1: 0.3667
# Epoch 180, Training Loss: 0.6871451735496521, Train F1: 0.5125, Validation F1: 0.3667
# Epoch 181, Training Loss: 0.6870709657669067, Train F1: 0.5125, Validation F1: 0.3667
# Epoch 182, Training Loss: 0.6869962811470032, Train F1: 0.5125, Validation F1: 0.3667
# Epoch 183, Training Loss: 0.6869210004806519, Train F1: 0.5125, Validation F1: 0.3667
# Epoch 184, Training Loss: 0.6868451237678528, Train F1: 0.5125, Validation F1: 0.3667
# Epoch 185, Training Loss: 0.6867688298225403, Train F1: 0.5125, Validation F1: 0.3667
# Epoch 186, Training Loss: 0.6866918802261353, Train F1: 0.5125, Validation F1: 0.3667
# Epoch 187, Training Loss: 0.686614453792572, Train F1: 0.5125, Validation F1: 0.3667
# Epoch 188, Training Loss: 0.686536431312561, Train F1: 0.5125, Validation F1: 0.3667
# Epoch 189, Training Loss: 0.6864577531814575, Train F1: 0.5125, Validation F1: 0.3667
# Epoch 190, Training Loss: 0.6863785982131958, Train F1: 0.5125, Validation F1: 0.3667
# Epoch 191, Training Loss: 0.6862987875938416, Train F1: 0.5125, Validation F1: 0.3667
# Epoch 192, Training Loss: 0.6862184405326843, Train F1: 0.5125, Validation F1: 0.3667
# Epoch 193, Training Loss: 0.6861374974250793, Train F1: 0.5125, Validation F1: 0.3667
# Epoch 194, Training Loss: 0.6860558986663818, Train F1: 0.5125, Validation F1: 0.3667
# Epoch 195, Training Loss: 0.6859737634658813, Train F1: 0.5125, Validation F1: 0.3667
# Epoch 196, Training Loss: 0.6858909726142883, Train F1: 0.5125, Validation F1: 0.3667
# Epoch 197, Training Loss: 0.6858075857162476, Train F1: 0.5125, Validation F1: 0.3667
# Epoch 198, Training Loss: 0.6857234239578247, Train F1: 0.5125, Validation F1: 0.3667
# Epoch 199, Training Loss: 0.6856387257575989, Train F1: 0.5125, Validation F1: 0.3667
# Epoch 200, Training Loss: 0.6855534315109253, Train F1: 0.5125, Validation F1: 0.3667
# Epoch 201, Training Loss: 0.6854674816131592, Train F1: 0.5125, Validation F1: 0.3667
# Epoch 202, Training Loss: 0.6853808164596558, Train F1: 0.5125, Validation F1: 0.3667
# Epoch 203, Training Loss: 0.6852934956550598, Train F1: 0.5125, Validation F1: 0.3667
# Epoch 204, Training Loss: 0.6852055191993713, Train F1: 0.5125, Validation F1: 0.3667
# Epoch 205, Training Loss: 0.6851167678833008, Train F1: 0.5125, Validation F1: 0.3667
# Epoch 206, Training Loss: 0.6850274801254272, Train F1: 0.5125, Validation F1: 0.3667
# Epoch 207, Training Loss: 0.6849373579025269, Train F1: 0.5125, Validation F1: 0.3667
# Epoch 208, Training Loss: 0.6848467588424683, Train F1: 0.5125, Validation F1: 0.3667
# Epoch 209, Training Loss: 0.6847552061080933, Train F1: 0.5125, Validation F1: 0.3667
# Epoch 210, Training Loss: 0.6846631765365601, Train F1: 0.5125, Validation F1: 0.3667
# Epoch 211, Training Loss: 0.6845702528953552, Train F1: 0.5125, Validation F1: 0.3667
# Epoch 212, Training Loss: 0.6844767332077026, Train F1: 0.5125, Validation F1: 0.3667
# Epoch 213, Training Loss: 0.684382438659668, Train F1: 0.5125, Validation F1: 0.3667
# Epoch 214, Training Loss: 0.6842874884605408, Train F1: 0.5125, Validation F1: 0.3667
# Epoch 215, Training Loss: 0.6841917037963867, Train F1: 0.5125, Validation F1: 0.3667
# Epoch 216, Training Loss: 0.6840952634811401, Train F1: 0.5125, Validation F1: 0.3667
# Epoch 217, Training Loss: 0.6839979887008667, Train F1: 0.5125, Validation F1: 0.3667
# Epoch 218, Training Loss: 0.683899998664856, Train F1: 0.5125, Validation F1: 0.3667
# Epoch 219, Training Loss: 0.6838012933731079, Train F1: 0.5125, Validation F1: 0.3667
# Epoch 220, Training Loss: 0.6837018132209778, Train F1: 0.5125, Validation F1: 0.3667
# Epoch 221, Training Loss: 0.6836014986038208, Train F1: 0.5125, Validation F1: 0.3667
# Epoch 222, Training Loss: 0.6835004091262817, Train F1: 0.5125, Validation F1: 0.3667
# Epoch 223, Training Loss: 0.6833986043930054, Train F1: 0.5125, Validation F1: 0.3667
# Epoch 224, Training Loss: 0.6832959651947021, Train F1: 0.5125, Validation F1: 0.3667
# Epoch 225, Training Loss: 0.6831925511360168, Train F1: 0.5125, Validation F1: 0.3667
# Epoch 226, Training Loss: 0.6830883622169495, Train F1: 0.5125, Validation F1: 0.3667
# Epoch 227, Training Loss: 0.6829832792282104, Train F1: 0.5125, Validation F1: 0.3667
# Epoch 228, Training Loss: 0.6828776001930237, Train F1: 0.5125, Validation F1: 0.3667
# Epoch 229, Training Loss: 0.682770848274231, Train F1: 0.5125, Validation F1: 0.3667
# Epoch 230, Training Loss: 0.6826635003089905, Train F1: 0.5125, Validation F1: 0.3667
# Epoch 231, Training Loss: 0.6825553178787231, Train F1: 0.5125, Validation F1: 0.3667
# Epoch 232, Training Loss: 0.6824461221694946, Train F1: 0.5125, Validation F1: 0.3667
# Epoch 233, Training Loss: 0.6823362112045288, Train F1: 0.5125, Validation F1: 0.3667
# Epoch 234, Training Loss: 0.6822254657745361, Train F1: 0.5125, Validation F1: 0.3667
# Epoch 235, Training Loss: 0.6821139454841614, Train F1: 0.5125, Validation F1: 0.3667
# Epoch 236, Training Loss: 0.6820015907287598, Train F1: 0.5125, Validation F1: 0.3667
# Epoch 237, Training Loss: 0.6818884611129761, Train F1: 0.5125, Validation F1: 0.3667
# Epoch 238, Training Loss: 0.6817743182182312, Train F1: 0.5125, Validation F1: 0.3667
# Epoch 239, Training Loss: 0.6816593408584595, Train F1: 0.5125, Validation F1: 0.3667
# Epoch 240, Training Loss: 0.6815435886383057, Train F1: 0.5125, Validation F1: 0.3667
# Epoch 241, Training Loss: 0.6814268827438354, Train F1: 0.5125, Validation F1: 0.3667
# Epoch 242, Training Loss: 0.6813094019889832, Train F1: 0.5125, Validation F1: 0.3667
# Epoch 243, Training Loss: 0.6811908483505249, Train F1: 0.5125, Validation F1: 0.3667
# Epoch 244, Training Loss: 0.6810715794563293, Train F1: 0.5125, Validation F1: 0.3667
# Epoch 245, Training Loss: 0.6809513568878174, Train F1: 0.5250, Validation F1: 0.3667
# Epoch 246, Training Loss: 0.6808302402496338, Train F1: 0.5125, Validation F1: 0.3667
# Epoch 247, Training Loss: 0.6807082891464233, Train F1: 0.5000, Validation F1: 0.3667
# Epoch 248, Training Loss: 0.6805853843688965, Train F1: 0.4875, Validation F1: 0.3667
# Epoch 249, Training Loss: 0.6804615259170532, Train F1: 0.4875, Validation F1: 0.3667
# Epoch 250, Training Loss: 0.6803367733955383, Train F1: 0.5000, Validation F1: 0.3667
# Iteration 0: G1 Results: f1=0.36666666666666664
# LayeredGCN(
#   (layers): ModuleList(
#     (0-2): 3 x GCNLayer()
#   )
#   (output_layer): GCNLayer()
# )
# Epoch 1, Training Loss: 0.6931472420692444, Train F1: 0.5375, Validation F1: 0.5000
# Epoch 2, Training Loss: 0.6931284666061401, Train F1: 0.5375, Validation F1: 0.5000
# Epoch 3, Training Loss: 0.6931098103523254, Train F1: 0.5375, Validation F1: 0.5000
# Epoch 4, Training Loss: 0.6930912137031555, Train F1: 0.5375, Validation F1: 0.5000
# Epoch 5, Training Loss: 0.6930726766586304, Train F1: 0.5375, Validation F1: 0.5000
# Epoch 6, Training Loss: 0.6930543184280396, Train F1: 0.5375, Validation F1: 0.5000
# Epoch 7, Training Loss: 0.6930359601974487, Train F1: 0.5375, Validation F1: 0.5000
# Epoch 8, Training Loss: 0.6930176019668579, Train F1: 0.5375, Validation F1: 0.5000
# Epoch 9, Training Loss: 0.6929993033409119, Train F1: 0.5375, Validation F1: 0.5000
# Epoch 10, Training Loss: 0.6929811239242554, Train F1: 0.5375, Validation F1: 0.5000
# Epoch 11, Training Loss: 0.6929630041122437, Train F1: 0.5375, Validation F1: 0.5000
# Epoch 12, Training Loss: 0.6929450035095215, Train F1: 0.5375, Validation F1: 0.5000
# Epoch 13, Training Loss: 0.6929270029067993, Train F1: 0.5375, Validation F1: 0.5000
# Epoch 14, Training Loss: 0.6929091215133667, Train F1: 0.5375, Validation F1: 0.5000
# Epoch 15, Training Loss: 0.6928913593292236, Train F1: 0.5375, Validation F1: 0.5000
# Epoch 16, Training Loss: 0.6928736567497253, Train F1: 0.5375, Validation F1: 0.5000
# Epoch 17, Training Loss: 0.692855954170227, Train F1: 0.5375, Validation F1: 0.5000
# Epoch 18, Training Loss: 0.6928384304046631, Train F1: 0.5375, Validation F1: 0.5000
# Epoch 19, Training Loss: 0.6928208470344543, Train F1: 0.5375, Validation F1: 0.5000
# Epoch 20, Training Loss: 0.6928034424781799, Train F1: 0.5375, Validation F1: 0.5000
# Epoch 21, Training Loss: 0.6927861571311951, Train F1: 0.5375, Validation F1: 0.5000
# Epoch 22, Training Loss: 0.692768931388855, Train F1: 0.5375, Validation F1: 0.5000
# Epoch 23, Training Loss: 0.6927517056465149, Train F1: 0.5375, Validation F1: 0.5000
# Epoch 24, Training Loss: 0.6927345991134644, Train F1: 0.5375, Validation F1: 0.5000
# Epoch 25, Training Loss: 0.6927176117897034, Train F1: 0.5375, Validation F1: 0.5000
# Epoch 26, Training Loss: 0.6927005648612976, Train F1: 0.5375, Validation F1: 0.5000
# Epoch 27, Training Loss: 0.6926838159561157, Train F1: 0.5375, Validation F1: 0.5000
# Epoch 28, Training Loss: 0.6926670074462891, Train F1: 0.5375, Validation F1: 0.5000
# Epoch 29, Training Loss: 0.6926504373550415, Train F1: 0.5375, Validation F1: 0.5000
# Epoch 30, Training Loss: 0.6926337480545044, Train F1: 0.5375, Validation F1: 0.5000
# Epoch 31, Training Loss: 0.6926172971725464, Train F1: 0.5375, Validation F1: 0.5000
# Epoch 32, Training Loss: 0.6926008462905884, Train F1: 0.5375, Validation F1: 0.5000
# Epoch 33, Training Loss: 0.6925844550132751, Train F1: 0.5375, Validation F1: 0.5000
# Epoch 34, Training Loss: 0.692568302154541, Train F1: 0.5375, Validation F1: 0.5000
# Epoch 35, Training Loss: 0.6925520300865173, Train F1: 0.5375, Validation F1: 0.5000
# Epoch 36, Training Loss: 0.6925359964370728, Train F1: 0.5375, Validation F1: 0.5000
# Epoch 37, Training Loss: 0.6925199627876282, Train F1: 0.5375, Validation F1: 0.5000
# Epoch 38, Training Loss: 0.6925040483474731, Train F1: 0.5375, Validation F1: 0.5000
# Epoch 39, Training Loss: 0.6924881339073181, Train F1: 0.5375, Validation F1: 0.5000
# Epoch 40, Training Loss: 0.6924723982810974, Train F1: 0.5375, Validation F1: 0.5000
# Epoch 41, Training Loss: 0.6924567222595215, Train F1: 0.5375, Validation F1: 0.5000
# Epoch 42, Training Loss: 0.6924411654472351, Train F1: 0.5375, Validation F1: 0.5000
# Epoch 43, Training Loss: 0.6924257278442383, Train F1: 0.5375, Validation F1: 0.5000
# Epoch 44, Training Loss: 0.6924102902412415, Train F1: 0.5375, Validation F1: 0.5000
# Epoch 45, Training Loss: 0.6923949122428894, Train F1: 0.5375, Validation F1: 0.5000
# Epoch 46, Training Loss: 0.6923796534538269, Train F1: 0.5375, Validation F1: 0.5000
# Epoch 47, Training Loss: 0.6923643946647644, Train F1: 0.5375, Validation F1: 0.5000
# Epoch 48, Training Loss: 0.6923494338989258, Train F1: 0.5375, Validation F1: 0.5000
# Epoch 49, Training Loss: 0.6923343539237976, Train F1: 0.5375, Validation F1: 0.5000
# Epoch 50, Training Loss: 0.6923195123672485, Train F1: 0.5375, Validation F1: 0.5000
# Epoch 51, Training Loss: 0.6923046708106995, Train F1: 0.5375, Validation F1: 0.5000
# Epoch 52, Training Loss: 0.6922898888587952, Train F1: 0.5375, Validation F1: 0.5000
# Epoch 53, Training Loss: 0.6922752261161804, Train F1: 0.5375, Validation F1: 0.5000
# Epoch 54, Training Loss: 0.6922606229782104, Train F1: 0.5375, Validation F1: 0.5000
# Epoch 55, Training Loss: 0.6922460794448853, Train F1: 0.5375, Validation F1: 0.5000
# Epoch 56, Training Loss: 0.6922317743301392, Train F1: 0.5375, Validation F1: 0.5000
# Epoch 57, Training Loss: 0.6922174096107483, Train F1: 0.5375, Validation F1: 0.5000
# ...
# Epoch 65, Training Loss: 0.6877096891403198, Train F1: 0.4875, Validation F1: 0.6333
# Epoch 66, Training Loss: 0.6875240206718445, Train F1: 0.4875, Validation F1: 0.6333
# Epoch 67, Training Loss: 0.6872970461845398, Train F1: 0.4875, Validation F1: 0.6333
# Epoch 68, Training Loss: 0.6869810223579407, Train F1: 0.4875, Validation F1: 0.6333
# Epoch 69, Training Loss: 0.6867082715034485, Train F1: 0.4875, Validation F1: 0.6333
# Epoch 70, Training Loss: 0.6864839792251587, Train F1: 0.4875, Validation F1: 0.6333
# Epoch 71, Training Loss: 0.6862479448318481, Train F1: 0.4875, Validation F1: 0.6333
# Epoch 72, Training Loss: 0.6860013604164124, Train F1: 0.4875, Validation F1: 0.6333
# Epoch 73, Training Loss: 0.6857450604438782, Train F1: 0.4875, Validation F1: 0.6333
# Epoch 74, Training Loss: 0.6854802370071411, Train F1: 0.4875, Validation F1: 0.6333
# Epoch 75, Training Loss: 0.685208261013031, Train F1: 0.4875, Validation F1: 0.6333
# Epoch 76, Training Loss: 0.6849302053451538, Train F1: 0.4875, Validation F1: 0.6333
# Epoch 77, Training Loss: 0.684646487236023, Train F1: 0.4875, Validation F1: 0.6333
# Epoch 78, Training Loss: 0.6844280958175659, Train F1: 0.4875, Validation F1: 0.6333
# Epoch 79, Training Loss: 0.6841781139373779, Train F1: 0.4875, Validation F1: 0.6333
# Epoch 80, Training Loss: 0.6838661432266235, Train F1: 0.4875, Validation F1: 0.6333
# Epoch 81, Training Loss: 0.6836259365081787, Train F1: 0.4875, Validation F1: 0.6333
# Epoch 82, Training Loss: 0.6833803057670593, Train F1: 0.4875, Validation F1: 0.6333
# Epoch 83, Training Loss: 0.6831256151199341, Train F1: 0.4875, Validation F1: 0.6333
# Epoch 84, Training Loss: 0.6828626394271851, Train F1: 0.4875, Validation F1: 0.6333
# Epoch 85, Training Loss: 0.6825917959213257, Train F1: 0.4875, Validation F1: 0.6333
# Epoch 86, Training Loss: 0.6823140978813171, Train F1: 0.4875, Validation F1: 0.6333
# Epoch 87, Training Loss: 0.6820826530456543, Train F1: 0.4875, Validation F1: 0.6333
# Epoch 88, Training Loss: 0.6818021535873413, Train F1: 0.4875, Validation F1: 0.6333
# Epoch 89, Training Loss: 0.6815305948257446, Train F1: 0.4875, Validation F1: 0.6333
# Epoch 90, Training Loss: 0.6812684535980225, Train F1: 0.4875, Validation F1: 0.6333
# Epoch 91, Training Loss: 0.6809905767440796, Train F1: 0.4875, Validation F1: 0.6333
# Epoch 92, Training Loss: 0.6806986927986145, Train F1: 0.4875, Validation F1: 0.6333
# Epoch 93, Training Loss: 0.6804050207138062, Train F1: 0.4875, Validation F1: 0.6333
# Epoch 94, Training Loss: 0.6801288723945618, Train F1: 0.4875, Validation F1: 0.6333
# Epoch 95, Training Loss: 0.6798304319381714, Train F1: 0.4875, Validation F1: 0.6333
# Epoch 96, Training Loss: 0.6795477867126465, Train F1: 0.4875, Validation F1: 0.6333
# Epoch 97, Training Loss: 0.6792618632316589, Train F1: 0.4875, Validation F1: 0.6333
# Epoch 98, Training Loss: 0.6789649724960327, Train F1: 0.4875, Validation F1: 0.6333
# Epoch 99, Training Loss: 0.6786705851554871, Train F1: 0.4875, Validation F1: 0.6333
# Epoch 100, Training Loss: 0.6783859133720398, Train F1: 0.4875, Validation F1: 0.6333
# Epoch 101, Training Loss: 0.678085446357727, Train F1: 0.4875, Validation F1: 0.6333
# Epoch 102, Training Loss: 0.6777973175048828, Train F1: 0.4875, Validation F1: 0.6333
# Epoch 103, Training Loss: 0.6775038242340088, Train F1: 0.4875, Validation F1: 0.6333
# Epoch 104, Training Loss: 0.6772114038467407, Train F1: 0.4875, Validation F1: 0.6333
# Epoch 105, Training Loss: 0.6769235730171204, Train F1: 0.4875, Validation F1: 0.6333
# Epoch 106, Training Loss: 0.6766326427459717, Train F1: 0.4875, Validation F1: 0.6333
# Epoch 107, Training Loss: 0.6763461828231812, Train F1: 0.4875, Validation F1: 0.6333
# Epoch 108, Training Loss: 0.6760603189468384, Train F1: 0.4875, Validation F1: 0.6333
# Epoch 109, Training Loss: 0.6757721304893494, Train F1: 0.4875, Validation F1: 0.6333
# Epoch 110, Training Loss: 0.6754864454269409, Train F1: 0.4875, Validation F1: 0.6333
# Epoch 111, Training Loss: 0.6751973628997803, Train F1: 0.4875, Validation F1: 0.6333
# Epoch 112, Training Loss: 0.6749088764190674, Train F1: 0.4875, Validation F1: 0.6333
# Epoch 113, Training Loss: 0.6746221780776978, Train F1: 0.4875, Validation F1: 0.6333
# Epoch 114, Training Loss: 0.6743355989456177, Train F1: 0.4875, Validation F1: 0.6333
# Epoch 115, Training Loss: 0.6740536093711853, Train F1: 0.4875, Validation F1: 0.6333
# Epoch 116, Training Loss: 0.6737692952156067, Train F1: 0.4875, Validation F1: 0.6333
# Epoch 117, Training Loss: 0.6734875440597534, Train F1: 0.4875, Validation F1: 0.6333
# Epoch 118, Training Loss: 0.6732065677642822, Train F1: 0.4875, Validation F1: 0.6333
# Epoch 119, Training Loss: 0.6729258298873901, Train F1: 0.4875, Validation F1: 0.6333
# Epoch 120, Training Loss: 0.6726483702659607, Train F1: 0.4875, Validation F1: 0.6333
# Epoch 121, Training Loss: 0.6723674535751343, Train F1: 0.4875, Validation F1: 0.6333
# Epoch 122, Training Loss: 0.672091007232666, Train F1: 0.4875, Validation F1: 0.6333
# Epoch 123, Training Loss: 0.6718127131462097, Train F1: 0.4875, Validation F1: 0.6333
# Epoch 124, Training Loss: 0.6715361475944519, Train F1: 0.4875, Validation F1: 0.6333
# Epoch 125, Training Loss: 0.6712621450424194, Train F1: 0.4875, Validation F1: 0.6333
# Epoch 126, Training Loss: 0.6709863543510437, Train F1: 0.4875, Validation F1: 0.6333
# Epoch 127, Training Loss: 0.6707136631011963, Train F1: 0.4875, Validation F1: 0.6333
# Epoch 128, Training Loss: 0.6704405546188354, Train F1: 0.4875, Validation F1: 0.6333
# Epoch 129, Training Loss: 0.6701700091362, Train F1: 0.4875, Validation F1: 0.6333
# Epoch 130, Training Loss: 0.6698996424674988, Train F1: 0.4875, Validation F1: 0.6333
# Epoch 131, Training Loss: 0.6696299314498901, Train F1: 0.4875, Validation F1: 0.6333
# Epoch 132, Training Loss: 0.66936194896698, Train F1: 0.4875, Validation F1: 0.6333
# Epoch 133, Training Loss: 0.6690946817398071, Train F1: 0.4875, Validation F1: 0.6333
# Epoch 134, Training Loss: 0.6688281297683716, Train F1: 0.4875, Validation F1: 0.6333
# Epoch 135, Training Loss: 0.6685624718666077, Train F1: 0.4875, Validation F1: 0.6333
# Epoch 136, Training Loss: 0.6682981848716736, Train F1: 0.4875, Validation F1: 0.6333
# Epoch 137, Training Loss: 0.6680341958999634, Train F1: 0.4875, Validation F1: 0.6333
# Epoch 138, Training Loss: 0.6677718758583069, Train F1: 0.4875, Validation F1: 0.6333
# Epoch 139, Training Loss: 0.6675106287002563, Train F1: 0.4875, Validation F1: 0.6333
# Epoch 140, Training Loss: 0.6672492623329163, Train F1: 0.4875, Validation F1: 0.6333
# Epoch 141, Training Loss: 0.6669912338256836, Train F1: 0.4875, Validation F1: 0.6333
# Epoch 142, Training Loss: 0.666730523109436, Train F1: 0.4875, Validation F1: 0.6333
# Epoch 143, Training Loss: 0.6664727330207825, Train F1: 0.4875, Validation F1: 0.6333
# Epoch 144, Training Loss: 0.6662161946296692, Train F1: 0.4875, Validation F1: 0.6333
# Epoch 145, Training Loss: 0.6659594774246216, Train F1: 0.4875, Validation F1: 0.6333
# Epoch 146, Training Loss: 0.665705680847168, Train F1: 0.4875, Validation F1: 0.6333
# Epoch 147, Training Loss: 0.6654454469680786, Train F1: 0.4875, Validation F1: 0.6333
# Epoch 148, Training Loss: 0.6651739478111267, Train F1: 0.4875, Validation F1: 0.6333
# Epoch 149, Training Loss: 0.6648862361907959, Train F1: 0.4875, Validation F1: 0.6333
# Epoch 150, Training Loss: 0.6645931601524353, Train F1: 0.4875, Validation F1: 0.6333
# Epoch 151, Training Loss: 0.6643139719963074, Train F1: 0.4875, Validation F1: 0.6333
# Epoch 152, Training Loss: 0.6640250086784363, Train F1: 0.4875, Validation F1: 0.6333
# Epoch 153, Training Loss: 0.6637508273124695, Train F1: 0.4875, Validation F1: 0.6333
# Epoch 154, Training Loss: 0.6634854674339294, Train F1: 0.4875, Validation F1: 0.6333
# Epoch 155, Training Loss: 0.6632190942764282, Train F1: 0.4875, Validation F1: 0.6333
# Epoch 156, Training Loss: 0.6629592180252075, Train F1: 0.4875, Validation F1: 0.6333
# Epoch 157, Training Loss: 0.6627009510993958, Train F1: 0.4875, Validation F1: 0.6333
# Epoch 158, Training Loss: 0.6624425053596497, Train F1: 0.4875, Validation F1: 0.6333
# Epoch 159, Training Loss: 0.6621960997581482, Train F1: 0.4875, Validation F1: 0.6333
# Epoch 160, Training Loss: 0.661935567855835, Train F1: 0.4875, Validation F1: 0.6333
# Epoch 161, Training Loss: 0.6616894602775574, Train F1: 0.4875, Validation F1: 0.6333
# Epoch 162, Training Loss: 0.6614488959312439, Train F1: 0.4875, Validation F1: 0.6333
# Epoch 163, Training Loss: 0.6612087488174438, Train F1: 0.4875, Validation F1: 0.6333
# Epoch 164, Training Loss: 0.6609752774238586, Train F1: 0.4875, Validation F1: 0.6333
# Epoch 165, Training Loss: 0.6607478260993958, Train F1: 0.4875, Validation F1: 0.6333
# Epoch 166, Training Loss: 0.6605289578437805, Train F1: 0.4875, Validation F1: 0.6333
# Epoch 167, Training Loss: 0.6603027582168579, Train F1: 0.4875, Validation F1: 0.6333
# Epoch 168, Training Loss: 0.6601082682609558, Train F1: 0.4875, Validation F1: 0.6333
# Epoch 169, Training Loss: 0.6598755121231079, Train F1: 0.4875, Validation F1: 0.6333
# Epoch 170, Training Loss: 0.659671425819397, Train F1: 0.4875, Validation F1: 0.6333
# Epoch 171, Training Loss: 0.6594774723052979, Train F1: 0.4875, Validation F1: 0.6333
# Epoch 172, Training Loss: 0.6592609882354736, Train F1: 0.8375, Validation F1: 0.6333
# Epoch 173, Training Loss: 0.6590690612792969, Train F1: 0.8375, Validation F1: 0.6333
# Epoch 174, Training Loss: 0.6588683128356934, Train F1: 0.8375, Validation F1: 0.6333
# Epoch 175, Training Loss: 0.6586707830429077, Train F1: 0.8375, Validation F1: 0.6333
# Epoch 176, Training Loss: 0.6584782600402832, Train F1: 0.8375, Validation F1: 0.6333
# Epoch 177, Training Loss: 0.6582782864570618, Train F1: 0.8375, Validation F1: 0.6333
# Epoch 178, Training Loss: 0.6580842137336731, Train F1: 0.8375, Validation F1: 0.6333
# Epoch 179, Training Loss: 0.6578922271728516, Train F1: 0.8375, Validation F1: 0.6333
# Epoch 180, Training Loss: 0.6576971411705017, Train F1: 0.8375, Validation F1: 0.6333
# Epoch 181, Training Loss: 0.6575007438659668, Train F1: 0.8375, Validation F1: 0.6333
# Epoch 182, Training Loss: 0.6573089361190796, Train F1: 0.8375, Validation F1: 0.6333
# Epoch 183, Training Loss: 0.6571213603019714, Train F1: 0.8375, Validation F1: 0.6333
# Epoch 184, Training Loss: 0.6569262742996216, Train F1: 0.8375, Validation F1: 0.6333
# Epoch 185, Training Loss: 0.6567412614822388, Train F1: 0.7500, Validation F1: 0.6333
# Epoch 186, Training Loss: 0.6565640568733215, Train F1: 0.7000, Validation F1: 0.6333
# Epoch 187, Training Loss: 0.6563904881477356, Train F1: 0.6875, Validation F1: 0.6333
# Epoch 188, Training Loss: 0.6562108397483826, Train F1: 0.6875, Validation F1: 0.6333
# Epoch 189, Training Loss: 0.6560226082801819, Train F1: 0.6875, Validation F1: 0.6333
# Epoch 190, Training Loss: 0.6558541059494019, Train F1: 0.6875, Validation F1: 0.6333
# Epoch 191, Training Loss: 0.655665397644043, Train F1: 0.6875, Validation F1: 0.6333
# Epoch 192, Training Loss: 0.6554912328720093, Train F1: 0.6875, Validation F1: 0.6333
# Epoch 193, Training Loss: 0.6553037762641907, Train F1: 0.6875, Validation F1: 0.6333
# Epoch 194, Training Loss: 0.6551566123962402, Train F1: 0.6875, Validation F1: 0.6333
# Epoch 195, Training Loss: 0.65495765209198, Train F1: 0.6875, Validation F1: 0.6333
# Epoch 196, Training Loss: 0.6548079252243042, Train F1: 0.6875, Validation F1: 0.6333
# Epoch 197, Training Loss: 0.654623806476593, Train F1: 0.6875, Validation F1: 0.6333
# Epoch 198, Training Loss: 0.6544250845909119, Train F1: 0.6875, Validation F1: 0.6333
# Epoch 199, Training Loss: 0.6542609333992004, Train F1: 0.6875, Validation F1: 0.5667
# Epoch 200, Training Loss: 0.6540883779525757, Train F1: 0.6875, Validation F1: 0.5667
# Epoch 201, Training Loss: 0.6539251804351807, Train F1: 0.6875, Validation F1: 0.5667
# Epoch 202, Training Loss: 0.6537421941757202, Train F1: 0.6875, Validation F1: 0.5667
# Epoch 203, Training Loss: 0.6535784006118774, Train F1: 0.6875, Validation F1: 0.5333
# Epoch 204, Training Loss: 0.6533901691436768, Train F1: 0.6875, Validation F1: 0.5333
# Epoch 205, Training Loss: 0.6532403230667114, Train F1: 0.6875, Validation F1: 0.5333
# Epoch 206, Training Loss: 0.6530681848526001, Train F1: 0.6875, Validation F1: 0.5333
# Epoch 207, Training Loss: 0.6528815031051636, Train F1: 0.6875, Validation F1: 0.5333
# Epoch 208, Training Loss: 0.6527151465415955, Train F1: 0.6875, Validation F1: 0.5667
# Epoch 209, Training Loss: 0.6525552272796631, Train F1: 0.6875, Validation F1: 0.7667
# Epoch 210, Training Loss: 0.6523867845535278, Train F1: 0.6875, Validation F1: 0.8667
# Epoch 211, Training Loss: 0.6522048711776733, Train F1: 0.6875, Validation F1: 0.8333
# Epoch 212, Training Loss: 0.652035653591156, Train F1: 0.6875, Validation F1: 0.8000
# Epoch 213, Training Loss: 0.6518825888633728, Train F1: 0.6875, Validation F1: 0.8000
# Epoch 214, Training Loss: 0.6517084836959839, Train F1: 0.6875, Validation F1: 0.8000
# Epoch 215, Training Loss: 0.6515475511550903, Train F1: 0.6875, Validation F1: 0.8000
# Epoch 216, Training Loss: 0.6513686180114746, Train F1: 0.6875, Validation F1: 0.8000
# Epoch 217, Training Loss: 0.6512140035629272, Train F1: 0.6875, Validation F1: 0.8000
# Epoch 218, Training Loss: 0.6510478258132935, Train F1: 0.6875, Validation F1: 0.8000
# Epoch 219, Training Loss: 0.6508713960647583, Train F1: 0.6875, Validation F1: 0.8000
# Epoch 220, Training Loss: 0.6507102251052856, Train F1: 0.6875, Validation F1: 0.8000
# Epoch 221, Training Loss: 0.650551438331604, Train F1: 0.6875, Validation F1: 0.8000
# Epoch 222, Training Loss: 0.6503801345825195, Train F1: 0.6875, Validation F1: 0.8000
# Epoch 223, Training Loss: 0.6502276659011841, Train F1: 0.6875, Validation F1: 0.8000
# Epoch 224, Training Loss: 0.6500517129898071, Train F1: 0.6875, Validation F1: 0.8000
# Epoch 225, Training Loss: 0.6498931646347046, Train F1: 0.6875, Validation F1: 0.8000
# Epoch 226, Training Loss: 0.6497252583503723, Train F1: 0.6875, Validation F1: 0.8000
# Epoch 227, Training Loss: 0.6495604515075684, Train F1: 0.6875, Validation F1: 0.8000
# Epoch 228, Training Loss: 0.6493979692459106, Train F1: 0.6875, Validation F1: 0.8000
# Epoch 229, Training Loss: 0.6492388248443604, Train F1: 0.6875, Validation F1: 0.8000
# Epoch 230, Training Loss: 0.6490786671638489, Train F1: 0.6875, Validation F1: 0.8000
# Epoch 231, Training Loss: 0.6489140391349792, Train F1: 0.6875, Validation F1: 0.8000
# Epoch 232, Training Loss: 0.648757815361023, Train F1: 0.6875, Validation F1: 0.8000
# Epoch 233, Training Loss: 0.6485904455184937, Train F1: 0.6875, Validation F1: 0.8000
# Epoch 234, Training Loss: 0.6484283804893494, Train F1: 0.6875, Validation F1: 0.8000
# Epoch 235, Training Loss: 0.6482778191566467, Train F1: 0.6875, Validation F1: 0.8000
# Epoch 236, Training Loss: 0.648114025592804, Train F1: 0.6875, Validation F1: 0.8000
# Epoch 237, Training Loss: 0.6479480862617493, Train F1: 0.6875, Validation F1: 0.8000
# Epoch 238, Training Loss: 0.6478023529052734, Train F1: 0.6875, Validation F1: 0.8000
# Epoch 239, Training Loss: 0.6476309299468994, Train F1: 0.6875, Validation F1: 0.8000
# Epoch 240, Training Loss: 0.6474725008010864, Train F1: 0.6875, Validation F1: 0.8000
# Epoch 241, Training Loss: 0.6473133563995361, Train F1: 0.6875, Validation F1: 0.8000
# Epoch 242, Training Loss: 0.6471495032310486, Train F1: 0.6875, Validation F1: 0.8000
# Epoch 243, Training Loss: 0.6469906568527222, Train F1: 0.6875, Validation F1: 0.8000
# Epoch 244, Training Loss: 0.6468352675437927, Train F1: 0.6875, Validation F1: 0.8000
# Epoch 245, Training Loss: 0.6466782093048096, Train F1: 0.6875, Validation F1: 0.8000
# Epoch 246, Training Loss: 0.6465140581130981, Train F1: 0.6875, Validation F1: 0.8000
# Epoch 247, Training Loss: 0.6463661193847656, Train F1: 0.6875, Validation F1: 0.8000
# Epoch 248, Training Loss: 0.6462043523788452, Train F1: 0.6875, Validation F1: 0.8000
# Epoch 249, Training Loss: 0.6460407972335815, Train F1: 0.6875, Validation F1: 0.8000
# Epoch 250, Training Loss: 0.6458947658538818, Train F1: 0.6875, Validation F1: 0.8000
# Iteration 9: G1 Results: f1=0.8

# %%
best_epoch_G1 = max(range(len(G1_results_final)), key=lambda i: G1_results_final[i][2])
best_embedding_G1 = G1_results_final[best_epoch_G1][3]

best_epoch_G2 = max(range(len(G2_results_final)), key=lambda i: G2_results_final[i][2])
best_embedding_G2 = G2_results_final[best_epoch_G2][3]

G1_results_performance = [ result[:-1] for result in G1_results_final]
G2_results_performance = [ result[:-1] for result in G1_results_final]

mean_G1_results = np.mean(G1_results_performance, axis=0)
mean_G2_results = np.mean(G2_results_performance, axis=0)

mean_G1_losses = mean_G1_results[0]
mean_G1_val_f1 = mean_G1_results[2]

mean_G2_losses = mean_G2_results[0]
mean_G2_val_f1 = mean_G2_results[2]

plot_training_and_validation(mean_G1_losses, val_f1, title=f"Average Training loss and Validation Accuracy over time using {change_topology_params['augmentation_strategy']} in G1 over 10 runs")

plot_training_and_validation(mean_G2_losses, val_f1, title=f"Average Training loss and Validation Accuracy over time using {change_topology_params['augmentation_strategy']} in G2 over 10 runs")

X,A,y = G1_train
plot_tsne(best_embedding_G1, y, layer_to_plot=-1, subject="Best Node Embeddings in G1")

X,A,y = G2_train
plot_tsne(best_embedding_G2, y, layer_to_plot=-1, subject="Best Node Embeddings in G2")
