# %% [markdown]
# # Question 2: Node Classification in a Heterogeneous Graph
#
# In this question, you will explore node classifcation using GNNs in a heterogeneous graph with two types of nodes containing different number of features.

# %% [markdown]
# ## Setting a Seed for Reproducibility
#
# To ensure that our results are reproducible, we will set a fixed seed for the random number generator. This step is crucial for educational and testing purposes, as it allows the same random numbers to be generated each time the notebook is run.

# %%
import numpy as np
import torch
import torch.nn as nn
import torch.nn.functional as F
import random
from scipy.stats import norm
import matplotlib.pyplot as plt
import json
import torch.optim as optim
import copy
from torch.nn.functional import binary_cross_entropy
from sklearn.metrics import precision_recall_fscore_support
from torch.optim import lr_scheduler
import networkx as nx
import seaborn as sns
import pandas as pd

SEED = 2
TRAIN_PATH = "data/q2_train.json"
VAL_PATH = "data/q2_val.json"

def set_seed(seed=42):
    random.seed(seed)
    np.random.seed(seed)
    torch.manual_seed(seed)
    if torch.cuda.is_available():
        torch.cuda.manual_seed_all(seed)

    torch.backends.cudnn.deterministic = True
    torch.backends.cudnn.benchmark = False
    

set_seed(SEED)

# %% [markdown]
# ## Question 2.1 Dataset
#
# The heterogeneous graph $G=(V,E)$ consists of a set of nodes $V$ with two types of nodes:
# - **Type 1 nodes**: Feature dimension of $d_1 = 20$
# - **Type 2 nodes**: Feature dimension of $d_2 = 30$
#
# Each node belongs to one of two classes:
#   - **Class 0**: $y_i = 0$
#   - **Class 1**: $y_i = 1$
#
# In total, there are $N=N_1 + N_2$ nodes in the graph.
#
# In the following cell, we load the data from the given **JSON** file.

# %%
def load_data_from_json(json_path):
    """
    Loads a JSON describing a heterogeneous graph

    Returns:
      A : torch.FloatTensor, shape (N, N)
          Adjacency matrix for all nodes (0...N-1).
      X1 : torch.FloatTensor, shape (N1, d1)
      X2 : torch.FloatTensor, shape (N2, d2)
      y : torch.LongTensor, shape (N,)
          Labels for each node (0 or 1 for binary).
      mapping : dict
          mapping[i] = {
             "node_type": str ("type1" or "type2"),
             "feat_index": int index into the relevant feature array
          }
        This tells us how adjacency row i corresponds to a row in either type1_features or type2_features.
    """
    with open(json_path, "r") as f:
        data = json.load(f)

    nodes_info = data["nodes"]
    # Sort so adjacency row i matches global_index = i
    nodes_info.sort(key=lambda x: x["global_index"])

    N = len(nodes_info)
    A = torch.zeros((N, N), dtype=torch.float)

    # We'll store raw lists for type1 and type2, then convert to tensors
    type1_list = []
    type2_list = []
    # We'll also store the mapping from adjacency index -> (type, index_in_that_type)
    mapping = {}
    # We'll store labels in a list
    labels_list = []

    # Step 1: first pass to build adjacency
    #         (we'll also note how many type1 vs type2)
    for i, node in enumerate(nodes_info):
        for nbr_idx in node["connected_nodes"]:
            A[i, nbr_idx] = 1.0
            A[nbr_idx, i] = 1.0  # undirected

    # Step 2: second pass, fill feature arrays, mapping
    type1_count = 0
    type2_count = 0

    for i, node in enumerate(nodes_info):
        node_type = node["node_type"]
        feats = node["features"]
        label = node["label"] if node["label"] is not None else 0
        labels_list.append(label)

        if node_type == "type1":
            type1_list.append(feats)
            mapping[i] = {"node_type": "type1", "feat_index": type1_count}
            type1_count += 1
        else:
            type2_list.append(feats)
            mapping[i] = {"node_type": "type2", "feat_index": type2_count}
            type2_count += 1

    # Convert type1 and type2 lists into float tensors
    X1 = torch.tensor(type1_list, dtype=torch.float) if len(type1_list) else torch.empty((0,0))
    X2 = torch.tensor(type2_list, dtype=torch.float) if len(type2_list) else torch.empty((0,0))

    # Convert labels
    y = torch.tensor(labels_list, dtype=torch.long)  # shape (N,)

    return A, X1, X2, y, mapping

# %% [markdown]
# In the following cell, we load the **train** and **validation** datasets.

# %%
A_train, X1_train, X2_train, y_train, mapping_train = load_data_from_json(TRAIN_PATH)
A_val,   X1_val,   X2_val,   y_val,   mapping_val   = load_data_from_json(VAL_PATH)

# %% [markdown]
# ## Question 2.1 Interpretation of the Dataset
#
# Before diving into the modeling phase, it's crucial to explore and understand the data. Immplement the following functions to assist in this analysis:
#
#
# ### Question 2.1.c `plot_graph`
# - Implement the `plot_graph` function which visualizes the graph structure.
# - Color nodes by class labels and display their types.

# %%
# ####################################################
# MODIFY THE CODE BELOW 
# ####################################################

def plot_graph(A, y, mapping):
    """
    Visualize the graph structure with:
      - node colors based on their labels
      - node types written over the nodes
    """
    G = nx.from_numpy_array(A.numpy())

    # Assign labels and types to nodes
    labels = y.numpy()
    types = [mapping[i]["node_type"] for i in range(len(mapping))]

    # Draw the graph with node colors based on labels and node types as labels
    pos = nx.spring_layout(G)
    node_colors = ['red' if label == 1 else 'blue' for label in labels]
    node_labels = {i: types[i] for i in range(len(types))}

    plt.figure(figsize=(12, 8))
    nx.draw(G, pos, with_labels=True, labels=node_labels, node_color=node_colors, node_size=500, font_size=8, font_color="white", edge_color="gray")
    plt.title("Heterogeneous Graph Visualization")
    plt.show()


# ####################################################
# END OF MODIFICATION
# ####################################################

# %% [markdown]
# ### Question 2.1.d `plot_node_feature_distributions`
# Implement the `plot_node_feature_distributions` function.
#
# - This function should plot the distribution of the node features.
# - Do not consider the distribution of a specific feature $x_i$; instead, consider the mean of the feature vector $\mathbf{x}$ for each node.
# - All distributions should appear on the **same figure**, so you can compare the feature distributions of $t_1$ and $t_2$ nodes as well as $c_1$ and $c_2$ nodes in Question 2.1.e
# - Check Figure 1 in the Coursework Description PDF for reference on how your plot should look.
#
#
# **NOTE:** The questions above are named as Question 2.1.c and Question 2.1.d by purpose to be consistent with the Coursework Description PDF, the other subquestions of Question 2 need to be answered in your report.

# %%
# ####################################################
# MODIFY THE CODE BELOW 
# ####################################################

import seaborn as sns

def plot_node_feature_distributions(X1, X2, y, mapping):
    """
    Plots the distributions (as normal PDFs) of the *average* feature values
    for four groups of nodes on the *same* figure:
      * type1, class=1
      * type1, class=2
      * type2, class=1
      * type2, class=2
    """
    # Calculate the mean feature values for each node
    type1_class0_means = [X1[mapping[i]['feat_index']].mean().item() for i in range(len(y)) if mapping[i]['node_type'] == 'type1' and y[i] == 0]
    type1_class1_means = [X1[mapping[i]['feat_index']].mean().item() for i in range(len(y)) if mapping[i]['node_type'] == 'type1' and y[i] == 1]
    type2_class0_means = [X2[mapping[i]['feat_index']].mean().item() for i in range(len(y)) if mapping[i]['node_type'] == 'type2' and y[i] == 0]
    type2_class1_means = [X2[mapping[i]['feat_index']].mean().item() for i in range(len(y)) if mapping[i]['node_type'] == 'type2' and y[i] == 1]

    # Plot the distributions
    plt.figure(figsize=(12, 8))

    sns.kdeplot(type1_class0_means, label='Type1, Class0', color='blue')
    sns.kdeplot(type1_class1_means, label='Type1, Class1', color='red')
    sns.kdeplot(type2_class0_means, label='Type2, Class0', color='green')
    sns.kdeplot(type2_class1_means, label='Type2, Class1', color='purple')

    plt.title('Distribution of Average Feature Values')
    plt.xlabel('Average Feature Value')
    plt.ylabel('Density')
    plt.legend()
    plt.show()

# ####################################################
# END OF MODIFICATION
# ####################################################

# %% [markdown]
# Call your functions...

# %%
# ####################################################
# MODIFY THE CODE BELOW 
# ####################################################
A_train, X1_train, X2_train, y_train, mapping_train = load_data_from_json(TRAIN_PATH)
A_val, X1_val, X2_val, y_val, mapping_val = load_data_from_json(VAL_PATH)

# Create a NetworkX graph from the adjacency matrix

plot_graph(A_train, y_train, mapping_train)

# ####################################################
# END OF MODIFICATION
# ####################################################

# %%
def plot_node_type_class_distribution(y, mapping):
    """
    Plots a heatmap showing the distribution of node types and class labels.
    """
    # Extract node types and class labels
    node_types = [mapping[i]["node_type"] for i in range(len(mapping))]
    class_labels = y.numpy()

    # Create a DataFrame for the heatmap
    data = pd.DataFrame({'Node Type': node_types, 'Class Label': class_labels})

    # Create a pivot table to count occurrences
    pivot_table = data.pivot_table(index='Node Type', columns='Class Label', aggfunc='size', fill_value=0)

    # Plot the heatmap
    plt.figure(figsize=(8, 6))
    sns.heatmap(pivot_table, annot=True, cmap="viridis", fmt="d")
    plt.title('Node Type and Class Label Distribution')
    plt.xlabel('Class Label')
    plt.ylabel('Node Type')
    plt.show()

# Call the function with training data
plot_node_type_class_distribution(y_train, mapping_train)

# %%
# ####################################################
# MODIFY THE CODE BELOW 
# ####################################################

plot_node_feature_distributions(X1_train, X2_train, y_train, mapping_train)

# ####################################################
# END OF MODIFICATION
# ####################################################

# %% [markdown]
# ## Question 2.2 Naive Solution
#
# Nothing to implement in Question 2.2 :)
#
# In the naive solution, we handle the challenge of heterogeneous node feature dimensions by zero-padding all node feature vectors to match the maximum dimension. This ensures uniformity in the input dimensions for the Graph Convolutional Network (GCN).
#
# ### Zero Padding
# Let the feature dimension of a node $i$ be $d_i$. To create uniform dimensions:
#
# $$
# \mathbf{x}_i^{\text{padded}} = \begin{bmatrix}
# \mathbf{x}_i \\
# \mathbf{0}
# \end{bmatrix},
# $$
#
# where $ \mathbf{x}_i \in \mathbb{R}^{d_i} $ is the original feature vector, and the padding $ \mathbf{0} $ is of size $ d_{\text{max}} - d_i $. Here, $ d_{\text{max}} = \max\{d_i \mid i \in \text{nodes}\} $.

# %%
def pad_features(A, type1_features, type2_features, mapping):
    """
    Given:
      A : (N, N) adjacency
      type1_features : (num_type1, d1)
      type2_features : (num_type2, d2)
      mapping : a dict so that mapping[i] = {"node_type": "type1" or "type2",
                                             "feat_index": index in that type's feature array}

    Produces:
      X : torch.FloatTensor, shape (N, d_max)
        Where d_max = max(d1, d2).
        For each node i, we copy either type1_features or type2_features 
        into row i, zero-padding if needed.
      d_max : the dimension used for the padding.
    """
    device = A.device
    N = A.shape[0]

    # Determine the dimensions of type1 & type2
    d1 = type1_features.shape[1] if type1_features.ndim == 2 and type1_features.shape[0] > 0 else 0
    d2 = type2_features.shape[1] if type2_features.ndim == 2 and type2_features.shape[0] > 0 else 0

    d_max = max(d1, d2)

    # Create a (N, d_max) zero tensor
    X = torch.zeros((N, d_max), dtype=torch.float, device=device)

    # Fill each row
    for i in range(N):
        node_type = mapping[i]["node_type"]
        feat_index = mapping[i]["feat_index"]
        if node_type == "type1":
            # If we have any type1 features at all
            if d1 > 0:
                X[i, :d1] = type1_features[feat_index].to(device)
        else:
            # type2
            if d2 > 0:
                X[i, :d2] = type2_features[feat_index].to(device)

    return X, d_max

# %% [markdown]
# ### Graph Convolutional Network (GCN)
#
# We are going to use a 2-layer GCN for the **binary node classification** task on the heterogeneous graph. Below, you can see the mathematical representation to generate predictions from GCN.
#
# The feature update rule for the next layer $ H_{k+1} $ in a graph convolutional network is given by the equation
#
# $$
# H_{k+1} = \sigma(\tilde{D}^{-1/2} \tilde{A} \tilde{D}^{-1/2} H_k \Omega_k + \Beta_k)
# $$
#
# where  $\tilde{D}$ is the degree matrix with added self-loops, $\tilde{A}$ is the adjacency matrix with self-loops, $H_k$ are the features from the previous layer, $ \Omega_k $ is the weight matrix at layer $ k $, $\Beta_k$ is the bias vector at layer $k$, and $\sigma $ denotes the activation function.

# %% [markdown]
# $\tilde{D}^{-1/2} \tilde{A} \tilde{D}^{-1/2}$ is the normalized adjacency matrix with self-loops. Below, you need to implement this normalization function.

# %%
def symmetric_normalize(A_tilde):
    """
    Performs symmetric normalization of A_tilde (Adj. matrix with self loops):
      A_norm = D^{-1/2} * A_tilde * D^{-1/2}
    Where D_{ii} = sum of row i in A_tilde.

    A_tilde (N, N): Adj. matrix with self loops
    Returns:
      A_norm : (N, N)
    """

    eps = 1e-5
    d = A_tilde.sum(dim=1) + eps
    D_inv = torch.diag(torch.pow(d, -0.5))
    return D_inv @ A_tilde @ D_inv

# %%
A_train_self_loops = A_train + torch.eye(A_train.size(0))
A_val_self_loops = A_val + torch.eye(A_val.size(0))

A_train_normalized = symmetric_normalize(A_train_self_loops)
A_val_normalized = symmetric_normalize(A_val_self_loops)

# %% [markdown]
# In the following cell, we define a simple 2-layer GCN model to use with our padded node features.

# %%
class GCNLayer(nn.Module):
    """
    A single layer of a Graph Convolutional Network (GCN).
    """
    def __init__(self, input_dim, output_dim, use_nonlinearity=True):
        super(GCNLayer, self).__init__()
        self.use_nonlinearity = use_nonlinearity
        self.Omega = nn.Parameter(torch.randn(input_dim, output_dim) * torch.sqrt(torch.tensor(2.0) / (input_dim + output_dim)))
        self.beta = nn.Parameter(torch.zeros(output_dim))

    def forward(self, H_k, A_normalized):
        agg = torch.matmul(A_normalized, H_k) # local agg
        H_k_next = torch.matmul(agg, self.Omega) + self.beta
        return F.relu(H_k_next) if self.use_nonlinearity else H_k_next

class GraphNeuralNetwork(nn.Module):
    """
    A simple Graph Neural Network model using two layers of Graph Convolutional Network (GCN)
    for binary classification. The sigmoid activation is applied in the output layer only if
    use_nonlinearity is set to True.
    """
    def __init__(self, input_dim, hidden_dim):
        super(GraphNeuralNetwork, self).__init__()

        # Define GCN layers
        self.gcn1 = GCNLayer(input_dim, hidden_dim, True)
        self.gcn2 = GCNLayer(hidden_dim, 1, False)

    def forward(self, A, X, **kwargs):
        # Pass through GCN layers
        H1 = self.gcn1(X, A)
        H2 = self.gcn2(H1, A)  # Output shape: (num_nodes, 1)

        output = torch.sigmoid(H2)  # Sigmoid activation per node
        if torch.isnan(output).any():
            output = torch.where(torch.isnan(output), torch.zeros_like(output), output)

        if kwargs.get("return_embeddings", None):
            return output, H1, H2
        else:
            return output

# %% [markdown]
# Please do not modify the following `train_model` and `evaluate_model` functions.

# %%
def get_lr(optimizer):
    for param_group in optimizer.param_groups:
        return param_group['lr']

def train_model(
    model,
    y_train,
    val_model_inputs,
    y_val,
    num_epochs=100,
    lr=0.01,
    validate_every=10,
    patience=10,
    **train_model_inputs
):
    """
    Train the model, validate every 'validate_every' epochs, and pick the 
    checkpoint with best validation accuracy.

    Parameters:
    -----------
    model : torch.nn.Module
        The PyTorch model to train.
    y_train : torch.Tensor
        Training labels (shape: (N,)).
    val_model_inputs : dict
        Dictionary of keyword arguments for the model's forward pass 
        for the validation set.
    y_val : torch.Tensor
        Validation labels (shape: (N_val,)).
    num_epochs : int
        Number of training epochs.
    lr : float
        Learning rate for the optimizer.
    validate_every : int
        Validate (and possibly checkpoint) every 'validate_every' epochs.
    **train_model_inputs :
        Keyword arguments for the model's forward pass for the training set.

    Returns:
    --------
    best_loss_history : list
        The training loss history across epochs.
    best_model_state_dict : dict
        The state dictionary of the model achieving the best validation accuracy.
    """

    model.train()
    optimizer = optim.AdamW(model.parameters(), lr=lr)
    scheduler = lr_scheduler.ReduceLROnPlateau(optimizer, mode="max", patience=patience)
    loss_history = []

    best_val_f1 = 0.0
    best_model_state_dict = None

    for epoch in range(num_epochs):
        model.train()

        optimizer.zero_grad()


        # Forward pass on training data
        out = model(**train_model_inputs)  # shape: (N, 1)
        out = out.squeeze(-1)  # shape: (N,)
        y_float = y_train.float()  # for BCE

        # Compute training loss
        loss = binary_cross_entropy(out, y_float)
        loss.backward()

        torch.nn.utils.clip_grad_norm_(model.parameters(), max_norm=1.0)

        optimizer.step()

        # Record training loss
        loss_value = loss.item()
        loss_history.append(loss_value)

        # Validation step
        if (epoch + 1) % validate_every == 0 or (epoch + 1) == num_epochs:
            val_prec, val_rec, val_f1, _ = evaluate_model(model, y_val, **val_model_inputs)
            scheduler.step(val_f1)
            
            lr = get_lr(optimizer)

            print(
                f"Epoch {epoch+1}/{num_epochs} - "
                f"Train Loss: {loss_value:.4f} - "
                f"Val Precision: {val_prec:.4f} - "
                f"Val Recall: {val_rec:.4f} - "
                f"Val F1: {val_f1:.4f} - "
                f"LR: {lr}"
            )
    
            # Check if this is the best f1 score so far
            if val_f1 > best_val_f1:
                best_val_f1 = val_f1
                best_model_state_dict = copy.deepcopy(model.state_dict())


            if lr < 1e-5:
                break

    
    # If we have a best model, load it
    if best_model_state_dict is not None:
        model.load_state_dict(best_model_state_dict)

    return loss_history, best_model_state_dict


@torch.no_grad()
def evaluate_model(model, y, **kwargs):
    """
    Runs forward pass, calculates binary predictions (threshold=0.5),
    and returns the accuracy score.
    """
    model.eval()
    out = model(**kwargs)  # shape: (N, 1)
    out = out.squeeze(-1)  # shape: (N,)
    preds = (out >= 0.5).long()

    y_true = y.cpu().numpy()
    y_pred = preds.cpu().numpy()

    return precision_recall_fscore_support(y_true, y_pred, average="micro")

# %% [markdown]
# Helper function to plot the history of loss during the training.

# %%
def plot_loss(loss_history, title):
    plt.figure()
    plt.plot(loss_history, label="loss")
    plt.xlabel("Epoch")
    plt.ylabel("Loss")
    plt.title(title)
    plt.legend()
    plt.show()

# %%
def plot_results(val_precs, val_recs, val_f1s, title_prefix='', figsize=(15,5)):
    """
    Plots three bar charts comparing precision, recall, and F1 scores 
    for multiple models on a single figure, each sorted by its own metric.
    The best model is always on the right for each plot.
    
    Args:
        val_precs (dict): Dictionary of model -> precision score
        val_recs (dict): Dictionary of model -> recall score
        val_f1s (dict): Dictionary of model -> F1 score
        title_prefix (str): Optional prefix for subplot titles
        figsize (tuple): Size of the overall figure
    """
    
    # Prepare the figure
    fig, axes = plt.subplots(nrows=1, ncols=3, figsize=figsize)
    
    # --- Sort and plot Precision ---
    # Sort by precision (ascending), so best is on the right
    sorted_precs = sorted(val_precs.items(), key=lambda x: x[1])
    prec_models = [x[0] for x in sorted_precs]  # model names
    prec_scores = [x[1] for x in sorted_precs]  # scores
    min_prec = min(prec_scores)
    
    axes[0].bar(prec_models, prec_scores, color='skyblue')
    # Start the y-axis a bit lower than the min value
    axes[0].set_ylim([
        min_prec - 0.05*(1 if min_prec == 0 else min_prec), 
        max(1.0, max(prec_scores))  # in case some scores > 1.0
    ])
    axes[0].set_title(f'{title_prefix}Precision', fontsize=12)
    axes[0].set_ylabel('Score')
    axes[0].set_xticks(range(len(prec_models)))
    axes[0].set_xticklabels(prec_models, rotation=45, ha='right')
    
    # --- Sort and plot Recall ---
    sorted_recs = sorted(val_recs.items(), key=lambda x: x[1])
    rec_models = [x[0] for x in sorted_recs]
    rec_scores = [x[1] for x in sorted_recs]
    min_recs = min(rec_scores)
    
    axes[1].bar(rec_models, rec_scores, color='salmon')
    axes[1].set_ylim([
        min_recs - 0.05*(1 if min_recs == 0 else min_recs),
        max(1.0, max(rec_scores))
    ])
    axes[1].set_title(f'{title_prefix}Recall', fontsize=12)
    axes[1].set_xticks(range(len(rec_models)))
    axes[1].set_xticklabels(rec_models, rotation=45, ha='right')
    
    # --- Sort and plot F1 ---
    sorted_f1s = sorted(val_f1s.items(), key=lambda x: x[1])
    f1_models = [x[0] for x in sorted_f1s]
    f1_scores = [x[1] for x in sorted_f1s]
    min_f1 = min(f1_scores)
    
    axes[2].bar(f1_models, f1_scores, color='limegreen')
    axes[2].set_ylim([
        min_f1 - 0.05*(1 if min_f1 == 0 else min_f1),
        max(1.0, max(f1_scores))
    ])
    axes[2].set_title(f'{title_prefix}F1', fontsize=12)
    axes[2].set_xticks(range(len(f1_models)))
    axes[2].set_xticklabels(f1_models, rotation=45, ha='right')
    
    plt.tight_layout()
    plt.show()

# %%
val_precs, val_recs, val_f1s = {}, {}, {}

# %% [markdown]
# Running the naive approach

# %%
set_seed(SEED)

# Naively pad
X_train, d_max_train = pad_features(A_train, X1_train, X2_train, mapping_train)
X_val,   d_max_val   = pad_features(A_val,   X1_val,   X2_val,   mapping_val)

print("Train adjacency:", A_train.shape)
print("Train features after padding:", X_train.shape, "with d_max =", d_max_train)
print("Val adjacency:", A_val.shape)
print("Val features after padding:", X_val.shape, "with d_max =", d_max_val)

# Convert labels to float if using BCE with sigmoid
y_train = y_train.float()  # shape (N,)
y_val   = y_val.float()

# Build the GCN model
input_dim = X_train.shape[1]  # the padded dimension
hidden_dim = 2
naive_gnn_model = GraphNeuralNetwork(input_dim, hidden_dim)

# Train
loss_history, _ = train_model(naive_gnn_model, y_train, val_model_inputs={"A":A_val_normalized.clone(), "X":X_val.clone()}, y_val=y_val.clone(), A=A_train_normalized, X=X_train, num_epochs=10000, lr=0.01, patience=50)

# Test on validation data
val_prec, val_rec, val_f1, _ = evaluate_model(naive_gnn_model, y_val, A=A_val_normalized, X=X_val)
print(f"[VAL] Prec={val_prec:.4f}, Rec={val_rec:.4f}, F1={val_f1:.4f}")

val_precs["Naive GCN"] = val_prec
val_recs["Naive GCN"] = val_rec
val_f1s["Naive GCN"] = val_f1

# Plot loss
plot_loss(loss_history, title="GCN Naive Approach Training Loss")
# Out:
# Train adjacency: torch.Size([500, 500])
# Train features after padding: torch.Size([500, 30]) with d_max = 30
# Val adjacency: torch.Size([200, 200])
# Val features after padding: torch.Size([200, 30]) with d_max = 30
# Epoch 10/10000 - Train Loss: 0.6924 - Val Precision: 0.5000 - Val Recall: 0.5000 - Val F1: 0.5000 - LR: 0.01
# Epoch 20/10000 - Train Loss: 0.6906 - Val Precision: 0.5400 - Val Recall: 0.5400 - Val F1: 0.5400 - LR: 0.01
# Epoch 30/10000 - Train Loss: 0.6893 - Val Precision: 0.4900 - Val Recall: 0.4900 - Val F1: 0.4900 - LR: 0.01
# Epoch 40/10000 - Train Loss: 0.6878 - Val Precision: 0.4900 - Val Recall: 0.4900 - Val F1: 0.4900 - LR: 0.01
# Epoch 50/10000 - Train Loss: 0.6867 - Val Precision: 0.4900 - Val Recall: 0.4900 - Val F1: 0.4900 - LR: 0.01
# Epoch 60/10000 - Train Loss: 0.6859 - Val Precision: 0.4900 - Val Recall: 0.4900 - Val F1: 0.4900 - LR: 0.01
# Epoch 70/10000 - Train Loss: 0.6854 - Val Precision: 0.4900 - Val Recall: 0.4900 - Val F1: 0.4900 - LR: 0.01
# Epoch 80/10000 - Train Loss: 0.6851 - Val Precision: 0.4900 - Val Recall: 0.4900 - Val F1: 0.4900 - LR: 0.01
# Epoch 90/10000 - Train Loss: 0.6847 - Val Precision: 0.4900 - Val Recall: 0.4900 - Val F1: 0.4900 - LR: 0.01
# Epoch 100/10000 - Train Loss: 0.6842 - Val Precision: 0.4900 - Val Recall: 0.4900 - Val F1: 0.4900 - LR: 0.01
# Epoch 110/10000 - Train Loss: 0.6837 - Val Precision: 0.4900 - Val Recall: 0.4900 - Val F1: 0.4900 - LR: 0.01
# Epoch 120/10000 - Train Loss: 0.6832 - Val Precision: 0.4900 - Val Recall: 0.4900 - Val F1: 0.4900 - LR: 0.01
# Epoch 130/10000 - Train Loss: 0.6826 - Val Precision: 0.4900 - Val Recall: 0.4900 - Val F1: 0.4900 - LR: 0.01
# Epoch 140/10000 - Train Loss: 0.6819 - Val Precision: 0.4900 - Val Recall: 0.4900 - Val F1: 0.4900 - LR: 0.01
# Epoch 150/10000 - Train Loss: 0.6810 - Val Precision: 0.4900 - Val Recall: 0.4900 - Val F1: 0.4900 - LR: 0.01
# Epoch 160/10000 - Train Loss: 0.6800 - Val Precision: 0.4900 - Val Recall: 0.4900 - Val F1: 0.4900 - LR: 0.01
# Epoch 170/10000 - Train Loss: 0.6788 - Val Precision: 0.4900 - Val Recall: 0.4900 - Val F1: 0.4900 - LR: 0.01
# Epoch 180/10000 - Train Loss: 0.6774 - Val Precision: 0.4900 - Val Recall: 0.4900 - Val F1: 0.4900 - LR: 0.01
# Epoch 190/10000 - Train Loss: 0.6757 - Val Precision: 0.4900 - Val Recall: 0.4900 - Val F1: 0.4900 - LR: 0.01
# Epoch 200/10000 - Train Loss: 0.6736 - Val Precision: 0.4900 - Val Recall: 0.4900 - Val F1: 0.4900 - LR: 0.01
# Epoch 210/10000 - Train Loss: 0.6712 - Val Precision: 0.4900 - Val Recall: 0.4900 - Val F1: 0.4900 - LR: 0.01
# Epoch 220/10000 - Train Loss: 0.6684 - Val Precision: 0.4950 - Val Recall: 0.4950 - Val F1: 0.4950 - LR: 0.01
# Epoch 230/10000 - Train Loss: 0.6651 - Val Precision: 0.5050 - Val Recall: 0.5050 - Val F1: 0.5050 - LR: 0.01
# Epoch 240/10000 - Train Loss: 0.6614 - Val Precision: 0.5050 - Val Recall: 0.5050 - Val F1: 0.5050 - LR: 0.01
# Epoch 250/10000 - Train Loss: 0.6578 - Val Precision: 0.5200 - Val Recall: 0.5200 - Val F1: 0.5200 - LR: 0.01
# Epoch 260/10000 - Train Loss: 0.6547 - Val Precision: 0.5100 - Val Recall: 0.5100 - Val F1: 0.5100 - LR: 0.01
# Epoch 270/10000 - Train Loss: 0.6512 - Val Precision: 0.5150 - Val Recall: 0.5150 - Val F1: 0.5150 - LR: 0.01
# Epoch 280/10000 - Train Loss: 0.6475 - Val Precision: 0.5300 - Val Recall: 0.5300 - Val F1: 0.5300 - LR: 0.01
# Epoch 290/10000 - Train Loss: 0.6435 - Val Precision: 0.5350 - Val Recall: 0.5350 - Val F1: 0.5350 - LR: 0.01
# Epoch 300/10000 - Train Loss: 0.6394 - Val Precision: 0.5450 - Val Recall: 0.5450 - Val F1: 0.5450 - LR: 0.01
# Epoch 310/10000 - Train Loss: 0.6350 - Val Precision: 0.5700 - Val Recall: 0.5700 - Val F1: 0.5700 - LR: 0.01
# Epoch 320/10000 - Train Loss: 0.6308 - Val Precision: 0.6250 - Val Recall: 0.6250 - Val F1: 0.6250 - LR: 0.01
# Epoch 330/10000 - Train Loss: 0.6263 - Val Precision: 0.6100 - Val Recall: 0.6100 - Val F1: 0.6100 - LR: 0.01
- Val Precision: 0.8700 - Val Recall: 0.8700 - Val F1: 0.8700 - LR: 0.001
# Epoch 2580/10000 - Train Loss: 0.2812 - Val Precision: 0.8700 - Val Recall: 0.8700 - Val F1: 0.8700 - LR: 0.001
# Epoch 2590/10000 - Train Loss: 0.2811 - Val Precision: 0.8700 - Val Recall: 0.8700 - Val F1: 0.8700 - LR: 0.001
# Epoch 2600/10000 - Train Loss: 0.2810 - Val Precision: 0.8700 - Val Recall: 0.8700 - Val F1: 0.8700 - LR: 0.001
# Epoch 2610/10000 - Train Loss: 0.2810 - Val Precision: 0.8700 - Val Recall: 0.8700 - Val F1: 0.8700 - LR: 0.001
# Epoch 2620/10000 - Train Loss: 0.2809 - Val Precision: 0.8700 - Val Recall: 0.8700 - Val F1: 0.8700 - LR: 0.001
# Epoch 2630/10000 - Train Loss: 0.2809 - Val Precision: 0.8700 - Val Recall: 0.8700 - Val F1: 0.8700 - LR: 0.001
# Epoch 2640/10000 - Train Loss: 0.2808 - Val Precision: 0.8700 - Val Recall: 0.8700 - Val F1: 0.8700 - LR: 0.001
# Epoch 2650/10000 - Train Loss: 0.2808 - Val Precision: 0.8700 - Val Recall: 0.8700 - Val F1: 0.8700 - LR: 0.001
# Epoch 2660/10000 - Train Loss: 0.2807 - Val Precision: 0.8700 - Val Recall: 0.8700 - Val F1: 0.8700 - LR: 0.001
# Epoch 2670/10000 - Train Loss: 0.2806 - Val Precision: 0.8700 - Val Recall: 0.8700 - Val F1: 0.8700 - LR: 0.001
# Epoch 2680/10000 - Train Loss: 0.2806 - Val Precision: 0.8700 - Val Recall: 0.8700 - Val F1: 0.8700 - LR: 0.001
# Epoch 2690/10000 - Train Loss: 0.2805 - Val Precision: 0.8700 - Val Recall: 0.8700 - Val F1: 0.8700 - LR: 0.001
# Epoch 2700/10000 - Train Loss: 0.2805 - Val Precision: 0.8700 - Val Recall: 0.8700 - Val F1: 0.8700 - LR: 0.001
# Epoch 2710/10000 - Train Loss: 0.2804 - Val Precision: 0.8700 - Val Recall: 0.8700 - Val F1: 0.8700 - LR: 0.001
# Epoch 2720/10000 - Train Loss: 0.2803 - Val Precision: 0.8700 - Val Recall: 0.8700 - Val F1: 0.8700 - LR: 0.001
# Epoch 2730/10000 - Train Loss: 0.2803 - Val Precision: 0.8700 - Val Recall: 0.8700 - Val F1: 0.8700 - LR: 0.001
# Epoch 2740/10000 - Train Loss: 0.2802 - Val Precision: 0.8700 - Val Recall: 0.8700 - Val F1: 0.8700 - LR: 0.001
# Epoch 2750/10000 - Train Loss: 0.2801 - Val Precision: 0.8700 - Val Recall: 0.8700 - Val F1: 0.8700 - LR: 0.001
# Epoch 2760/10000 - Train Loss: 0.2801 - Val Precision: 0.8700 - Val Recall: 0.8700 - Val F1: 0.8700 - LR: 0.001
# Epoch 2770/10000 - Train Loss: 0.2800 - Val Precision: 0.8700 - Val Recall: 0.8700 - Val F1: 0.8700 - LR: 0.001
# Epoch 2780/10000 - Train Loss: 0.2800 - Val Precision: 0.8700 - Val Recall: 0.8700 - Val F1: 0.8700 - LR: 0.001
# Epoch 2790/10000 - Train Loss: 0.2799 - Val Precision: 0.8700 - Val Recall: 0.8700 - Val F1: 0.8700 - LR: 0.001
# Epoch 2800/10000 - Train Loss: 0.2798 - Val Precision: 0.8700 - Val Recall: 0.8700 - Val F1: 0.8700 - LR: 0.001
# Epoch 2810/10000 - Train Loss: 0.2798 - Val Precision: 0.8700 - Val Recall: 0.8700 - Val F1: 0.8700 - LR: 0.001
# Epoch 2820/10000 - Train Loss: 0.2797 - Val Precision: 0.8700 - Val Recall: 0.8700 - Val F1: 0.8700 - LR: 0.001
# Epoch 2830/10000 - Train Loss: 0.2796 - Val Precision: 0.8700 - Val Recall: 0.8700 - Val F1: 0.8700 - LR: 0.001
# Epoch 2840/10000 - Train Loss: 0.2796 - Val Precision: 0.8700 - Val Recall: 0.8700 - Val F1: 0.8700 - LR: 0.001
# Epoch 2850/10000 - Train Loss: 0.2795 - Val Precision: 0.8700 - Val Recall: 0.8700 - Val F1: 0.8700 - LR: 0.001
# Epoch 2860/10000 - Train Loss: 0.2794 - Val Precision: 0.8700 - Val Recall: 0.8700 - Val F1: 0.8700 - LR: 0.001
# Epoch 2870/10000 - Train Loss: 0.2794 - Val Precision: 0.8700 - Val Recall: 0.8700 - Val F1: 0.8700 - LR: 0.001
# Epoch 2880/10000 - Train Loss: 0.2793 - Val Precision: 0.8700 - Val Recall: 0.8700 - Val F1: 0.8700 - LR: 0.001
# Epoch 2890/10000 - Train Loss: 0.2792 - Val Precision: 0.8700 - Val Recall: 0.8700 - Val F1: 0.8700 - LR: 0.001
# Epoch 2900/10000 - Train Loss: 0.2792 - Val Precision: 0.8700 - Val Recall: 0.8700 - Val F1: 0.8700 - LR: 0.001
# Epoch 2910/10000 - Train Loss: 0.2791 - Val Precision: 0.8700 - Val Recall: 0.8700 - Val F1: 0.8700 - LR: 0.001
# Epoch 2920/10000 - Train Loss: 0.2790 - Val Precision: 0.8700 - Val Recall: 0.8700 - Val F1: 0.8700 - LR: 0.001
# Epoch 2930/10000 - Train Loss: 0.2790 - Val Precision: 0.8700 - Val Recall: 0.8700 - Val F1: 0.8700 - LR: 0.0001
# Epoch 2940/10000 - Train Loss: 0.2790 - Val Precision: 0.8700 - Val Recall: 0.8700 - Val F1: 0.8700 - LR: 0.0001
# Epoch 2950/10000 - Train Loss: 0.2790 - Val Precision: 0.8700 - Val Recall: 0.8700 - Val F1: 0.8700 - LR: 0.0001
# Epoch 2960/10000 - Train Loss: 0.2789 - Val Precision: 0.8700 - Val Recall: 0.8700 - Val F1: 0.8700 - LR: 0.0001
# Epoch 2970/10000 - Train Loss: 0.2789 - Val Precision: 0.8700 - Val Recall: 0.8700 - Val F1: 0.8700 - LR: 0.0001
# Epoch 2980/10000 - Train Loss: 0.2789 - Val Precision: 0.8700 - Val Recall: 0.8700 - Val F1: 0.8700 - LR: 0.0001
# Epoch 2990/10000 - Train Loss: 0.2789 - Val Precision: 0.8700 - Val Recall: 0.8700 - Val F1: 0.8700 - LR: 0.0001
# Epoch 3000/10000 - Train Loss: 0.2789 - Val Precision: 0.8700 - Val Recall: 0.8700 - Val F1: 0.8700 - LR: 0.0001
# Epoch 3010/10000 - Train Loss: 0.2789 - Val Precision: 0.8700 - Val Recall: 0.8700 - Val F1: 0.8700 - LR: 0.0001
# Epoch 3020/10000 - Train Loss: 0.2789 - Val Precision: 0.8700 - Val Recall: 0.8700 - Val F1: 0.8700 - LR: 0.0001
# Epoch 3030/10000 - Train Loss: 0.2789 - Val Precision: 0.8700 - Val Recall: 0.8700 - Val F1: 0.8700 - LR: 0.0001
# Epoch 3040/10000 - Train Loss: 0.2789 - Val Precision: 0.8700 - Val Recall: 0.8700 - Val F1: 0.8700 - LR: 0.0001
# Epoch 3050/10000 - Train Loss: 0.2789 - Val Precision: 0.8700 - Val Recall: 0.8700 - Val F1: 0.8700 - LR: 0.0001
# Epoch 3060/10000 - Train Loss: 0.2789 - Val Precision: 0.8700 - Val Recall: 0.8700 - Val F1: 0.8700 - LR: 0.0001
# Epoch 3070/10000 - Train Loss: 0.2789 - Val Precision: 0.8700 - Val Recall: 0.8700 - Val F1: 0.8700 - LR: 0.0001
# Epoch 3080/10000 - Train Loss: 0.2789 - Val Precision: 0.8700 - Val Recall: 0.8700 - Val F1: 0.8700 - LR: 0.0001
# Epoch 3090/10000 - Train Loss: 0.2789 - Val Precision: 0.8700 - Val Recall: 0.8700 - Val F1: 0.8700 - LR: 0.0001
# Epoch 3100/10000 - Train Loss: 0.2788 - Val Precision: 0.8700 - Val Recall: 0.8700 - Val F1: 0.8700 - LR: 0.0001
# Epoch 3110/10000 - Train Loss: 0.2788 - Val Precision: 0.8700 - Val Recall: 0.8700 - Val F1: 0.8700 - LR: 0.0001
# Epoch 3120/10000 - Train Loss: 0.2788 - Val Precision: 0.8700 - Val Recall: 0.8700 - Val F1: 0.8700 - LR: 0.0001
# Epoch 3130/10000 - Train Loss: 0.2788 - Val Precision: 0.8700 - Val Recall: 0.8700 - Val F1: 0.8700 - LR: 0.0001
# Epoch 3140/10000 - Train Loss: 0.2788 - Val Precision: 0.8700 - Val Recall: 0.8700 - Val F1: 0.8700 - LR: 0.0001
# Epoch 3150/10000 - Train Loss: 0.2788 - Val Precision: 0.8700 - Val Recall: 0.8700 - Val F1: 0.8700 - LR: 0.0001
# Epoch 3160/10000 - Train Loss: 0.2788 - Val Precision: 0.8700 - Val Recall: 0.8700 - Val F1: 0.8700 - LR: 0.0001
# Epoch 3170/10000 - Train Loss: 0.2788 - Val Precision: 0.8700 - Val Recall: 0.8700 - Val F1: 0.8700 - LR: 0.0001
# Epoch 3180/10000 - Train Loss: 0.2788 - Val Precision: 0.8700 - Val Recall: 0.8700 - Val F1: 0.8700 - LR: 0.0001
# Epoch 3190/10000 - Train Loss: 0.2788 - Val Precision: 0.8700 - Val Recall: 0.8700 - Val F1: 0.8700 - LR: 0.0001
# Epoch 3200/10000 - Train Loss: 0.2788 - Val Precision: 0.8700 - Val Recall: 0.8700 - Val F1: 0.8700 - LR: 0.0001
# Epoch 3210/10000 - Train Loss: 0.2788 - Val Precision: 0.8700 - Val Recall: 0.8700 - Val F1: 0.8700 - LR: 0.0001
# Epoch 3220/10000 - Train Loss: 0.2788 - Val Precision: 0.8700 - Val Recall: 0.8700 - Val F1: 0.8700 - LR: 0.0001
# Epoch 3230/10000 - Train Loss: 0.2787 - Val Precision: 0.8700 - Val Recall: 0.8700 - Val F1: 0.8700 - LR: 0.0001
# Epoch 3240/10000 - Train Loss: 0.2787 - Val Precision: 0.8700 - Val Recall: 0.8700 - Val F1: 0.8700 - LR: 0.0001
# Epoch 3250/10000 - Train Loss: 0.2787 - Val Precision: 0.8700 - Val Recall: 0.8700 - Val F1: 0.8700 - LR: 0.0001
# Epoch 3260/10000 - Train Loss: 0.2787 - Val Precision: 0.8700 - Val Recall: 0.8700 - Val F1: 0.8700 - LR: 0.0001
# Epoch 3270/10000 - Train Loss: 0.2787 - Val Precision: 0.8700 - Val Recall: 0.8700 - Val F1: 0.8700 - LR: 0.0001
# Epoch 3280/10000 - Train Loss: 0.2787 - Val Precision: 0.8700 - Val Recall: 0.8700 - Val F1: 0.8700 - LR: 0.0001
# Epoch 3290/10000 - Train Loss: 0.2787 - Val Precision: 0.8700 - Val Recall: 0.8700 - Val F1: 0.8700 - LR: 0.0001
# Epoch 3300/10000 - Train Loss: 0.2787 - Val Precision: 0.8700 - Val Recall: 0.8700 - Val F1: 0.8700 - LR: 0.0001
# Epoch 3310/10000 - Train Loss: 0.2787 - Val Precision: 0.8700 - Val Recall: 0.8700 - Val F1: 0.8700 - LR: 0.0001
# Epoch 3320/10000 - Train Loss: 0.2787 - Val Precision: 0.8700 - Val Recall: 0.8700 - Val F1: 0.8700 - LR: 0.0001
# Epoch 3330/10000 - Train Loss: 0.2787 - Val Precision: 0.8700 - Val Recall: 0.8700 - Val F1: 0.8700 - LR: 0.0001
# Epoch 3340/10000 - Train Loss: 0.2787 - Val Precision: 0.8700 - Val Recall: 0.8700 - Val F1: 0.8700 - LR: 0.0001
# Epoch 3350/10000 - Train Loss: 0.2786 - Val Precision: 0.8700 - Val Recall: 0.8700 - Val F1: 0.8700 - LR: 0.0001
# Epoch 3360/10000 - Train Loss: 0.2786 - Val Precision: 0.8700 - Val Recall: 0.8700 - Val F1: 0.8700 - LR: 0.0001
# Epoch 3370/10000 - Train Loss: 0.2786 - Val Precision: 0.8700 - Val Recall: 0.8700 - Val F1: 0.8700 - LR: 0.0001
# Epoch 3380/10000 - Train Loss: 0.2786 - Val Precision: 0.8700 - Val Recall: 0.8700 - Val F1: 0.8700 - LR: 0.0001
# Epoch 3390/10000 - Train Loss: 0.2786 - Val Precision: 0.8700 - Val Recall: 0.8700 - Val F1: 0.8700 - LR: 0.0001
# Epoch 3400/10000 - Train Loss: 0.2786 - Val Precision: 0.8700 - Val Recall: 0.8700 - Val F1: 0.8700 - LR: 0.0001
# Epoch 3410/10000 - Train Loss: 0.2786 - Val Precision: 0.8700 - Val Recall: 0.8700 - Val F1: 0.8700 - LR: 0.0001
# Epoch 3420/10000 - Train Loss: 0.2786 - Val Precision: 0.8700 - Val Recall: 0.8700 - Val F1: 0.8700 - LR: 0.0001
# Epoch 3430/10000 - Train Loss: 0.2786 - Val Precision: 0.8700 - Val Recall: 0.8700 - Val F1: 0.8700 - LR: 0.0001
# Epoch 3440/10000 - Train Loss: 0.2786 - Val Precision: 0.8700 - Val Recall: 0.8700 - Val F1: 0.8700 - LR: 1e-05
# Epoch 3450/10000 - Train Loss: 0.2786 - Val Precision: 0.8700 - Val Recall: 0.8700 - Val F1: 0.8700 - LR: 1e-05
# Epoch 3460/10000 - Train Loss: 0.2786 - Val Precision: 0.8700 - Val Recall: 0.8700 - Val F1: 0.8700 - LR: 1e-05
# Epoch 3470/10000 - Train Loss: 0.2786 - Val Precision: 0.8700 - Val Recall: 0.8700 - Val F1: 0.8700 - LR: 1e-05
# Epoch 3480/10000 - Train Loss: 0.2786 - Val Precision: 0.8700 - Val Recall: 0.8700 - Val F1: 0.8700 - LR: 1e-05
# Epoch 3490/10000 - Train Loss: 0.2786 - Val Precision: 0.8700 - Val Recall: 0.8700 - Val F1: 0.8700 - LR: 1e-05
# Epoch 3500/10000 - Train Loss: 0.2786 - Val Precision: 0.8700 - Val Recall: 0.8700 - Val F1: 0.8700 - LR: 1e-05
# Epoch 3510/10000 - Train Loss: 0.2786 - Val Precision: 0.8700 - Val Recall: 0.8700 - Val F1: 0.8700 - LR: 1e-05
# Epoch 3520/10000 - Train Loss: 0.2786 - Val Precision: 0.8700 - Val Recall: 0.8700 - Val F1: 0.8700 - LR: 1e-05
# Epoch 3530/10000 - Train Loss: 0.2786 - Val Precision: 0.8700 - Val Recall: 0.8700 - Val F1: 0.8700 - LR: 1e-05
# Epoch 3540/10000 - Train Loss: 0.2786 - Val Precision: 0.8700 - Val Recall: 0.8700 - Val F1: 0.8700 - LR: 1e-05
# Epoch 3550/10000 - Train Loss: 0.2786 - Val Precision: 0.8700 - Val Recall: 0.8700 - Val F1: 0.8700 - LR: 1e-05
# Epoch 3560/10000 - Train Loss: 0.2786 - Val Precision: 0.8700 - Val Recall: 0.8700 - Val F1: 0.8700 - LR: 1e-05
# Epoch 3570/10000 - Train Loss: 0.2786 - Val Precision: 0.8700 - Val Recall: 0.8700 - Val F1: 0.8700 - LR: 1e-05
# Epoch 3580/10000 - Train Loss: 0.2786 - Val Precision: 0.8700 - Val Recall: 0.8700 - Val F1: 0.8700 - LR: 1e-05
# Epoch 3590/10000 - Train Loss: 0.2786 - Val Precision: 0.8700 - Val Recall: 0.8700 - Val F1: 0.8700 - LR: 1e-05
# Epoch 3600/10000 - Train Loss: 0.2786 - Val Precision: 0.8700 - Val Recall: 0.8700 - Val F1: 0.8700 - LR: 1e-05
# Epoch 3610/10000 - Train Loss: 0.2786 - Val Precision: 0.8700 - Val Recall: 0.8700 - Val F1: 0.8700 - LR: 1e-05
# Epoch 3620/10000 - Train Loss: 0.2786 - Val Precision: 0.8700 - Val Recall: 0.8700 - Val F1: 0.8700 - LR: 1e-05
# Epoch 3630/10000 - Train Loss: 0.2786 - Val Precision: 0.8700 - Val Recall: 0.8700 - Val F1: 0.8700 - LR: 1e-05
# Epoch 3640/10000 - Train Loss: 0.2786 - Val Precision: 0.8700 - Val Recall: 0.8700 - Val F1: 0.8700 - LR: 1e-05
# Epoch 3650/10000 - Train Loss: 0.2786 - Val Precision: 0.8700 - Val Recall: 0.8700 - Val F1: 0.8700 - LR: 1e-05
# Epoch 3660/10000 - Train Loss: 0.2786 - Val Precision: 0.8700 - Val Recall: 0.8700 - Val F1: 0.8700 - LR: 1e-05
# Epoch 3670/10000 - Train Loss: 0.2786 - Val Precision: 0.8700 - Val Recall: 0.8700 - Val F1: 0.8700 - LR: 1e-05
# Epoch 3680/10000 - Train Loss: 0.2786 - Val Precision: 0.8700 - Val Recall: 0.8700 - Val F1: 0.8700 - LR: 1e-05
# Epoch 3690/10000 - Train Loss: 0.2786 - Val Precision: 0.8700 - Val Recall: 0.8700 - Val F1: 0.8700 - LR: 1e-05
# Epoch 3700/10000 - Train Loss: 0.2786 - Val Precision: 0.8700 - Val Recall: 0.8700 - Val F1: 0.8700 - LR: 1e-05
# Epoch 3710/10000 - Train Loss: 0.2786 - Val Precision: 0.8700 - Val Recall: 0.8700 - Val F1: 0.8700 - LR: 1e-05
# Epoch 3720/10000 - Train Loss: 0.2785 - Val Precision: 0.8700 - Val Recall: 0.8700 - Val F1: 0.8700 - LR: 1e-05
# Epoch 3730/10000 - Train Loss: 0.2785 - Val Precision: 0.8700 - Val Recall: 0.8700 - Val F1: 0.8700 - LR: 1e-05
# Epoch 3740/10000 - Train Loss: 0.2785 - Val Precision: 0.8700 - Val Recall: 0.8700 - Val F1: 0.8700 - LR: 1e-05
# Epoch 3750/10000 - Train Loss: 0.2785 - Val Precision: 0.8700 - Val Recall: 0.8700 - Val F1: 0.8700 - LR: 1e-05
# Epoch 3760/10000 - Train Loss: 0.2785 - Val Precision: 0.8700 - Val Recall: 0.8700 - Val F1: 0.8700 - LR: 1e-05
# Epoch 3770/10000 - Train Loss: 0.2785 - Val Precision: 0.8700 - Val Recall: 0.8700 - Val F1: 0.8700 - LR: 1e-05
# Epoch 3780/10000 - Train Loss: 0.2785 - Val Precision: 0.8700 - Val Recall: 0.8700 - Val F1: 0.8700 - LR: 1e-05
# Epoch 3790/10000 - Train Loss: 0.2785 - Val Precision: 0.8700 - Val Recall: 0.8700 - Val F1: 0.8700 - LR: 1e-05
# Epoch 3800/10000 - Train Loss: 0.2785 - Val Precision: 0.8700 - Val Recall: 0.8700 - Val F1: 0.8700 - LR: 1e-05
# Epoch 3810/10000 - Train Loss: 0.2785 - Val Precision: 0.8700 - Val Recall: 0.8700 - Val F1: 0.8700 - LR: 1e-05
# Epoch 3820/10000 - Train Loss: 0.2785 - Val Precision: 0.8700 - Val Recall: 0.8700 - Val F1: 0.8700 - LR: 1e-05
# Epoch 3830/10000 - Train Loss: 0.2785 - Val Precision: 0.8700 - Val Recall: 0.8700 - Val F1: 0.8700 - LR: 1e-05
# Epoch 3840/10000 - Train Loss: 0.2785 - Val Precision: 0.8700 - Val Recall: 0.8700 - Val F1: 0.8700 - LR: 1e-05
# Epoch 3850/10000 - Train Loss: 0.2785 - Val Precision: 0.8700 - Val Recall: 0.8700 - Val F1: 0.8700 - LR: 1e-05
# Epoch 3860/10000 - Train Loss: 0.2785 - Val Precision: 0.8700 - Val Recall: 0.8700 - Val F1: 0.8700 - LR: 1e-05
# Epoch 3870/10000 - Train Loss: 0.2785 - Val Precision: 0.8700 - Val Recall: 0.8700 - Val F1: 0.8700 - LR: 1e-05
# Epoch 3880/10000 - Train Loss: 0.2785 - Val Precision: 0.8700 - Val Recall: 0.8700 - Val F1: 0.8700 - LR: 1e-05
# Epoch 3890/10000 - Train Loss: 0.2785 - Val Precision: 0.8700 - Val Recall: 0.8700 - Val F1: 0.8700 - LR: 1e-05
# Epoch 3900/10000 - Train Loss: 0.2785 - Val Precision: 0.8700 - Val Recall: 0.8700 - Val F1: 0.8700 - LR: 1e-05
# Epoch 3910/10000 - Train Loss: 0.2785 - Val Precision: 0.8700 - Val Recall: 0.8700 - Val F1: 0.8700 - LR: 1e-05
# Epoch 3920/10000 - Train Loss: 0.2785 - Val Precision: 0.8700 - Val Recall: 0.8700 - Val F1: 0.8700 - LR: 1e-05
# Epoch 3930/10000 - Train Loss: 0.2785 - Val Precision: 0.8700 - Val Recall: 0.8700 - Val F1: 0.8700 - LR: 1e-05
# Epoch 3940/10000 - Train Loss: 0.2785 - Val Precision: 0.8700 - Val Recall: 0.8700 - Val F1: 0.8700 - LR: 1e-05
# Epoch 3950/10000 - Train Loss: 0.2785 - Val Precision: 0.8700 - Val Recall: 0.8700 - Val F1: 0.8700 - LR: 1.0000000000000002e-06
# [VAL] Prec=0.8800, Rec=0.8800, F1=0.8800

# %% [markdown]
# Naive Average Performance

# %%
results = []

for i in range(10):
    set_seed(i)
    # Build the GCN model
    input_dim = X_train.shape[1]  # the padded dimension
    hidden_dim = 2
    naive_gnn_model = GraphNeuralNetwork(input_dim, hidden_dim)

    # Train
    loss_history, _ = train_model(naive_gnn_model, y_train, val_model_inputs={"A":A_val_normalized.clone(), "X":X_val.clone()}, y_val=y_val.clone(), A=A_train_normalized, X=X_train, num_epochs=10000, lr=0.01, patience=50)

    # Test on validation data
    val_prec, val_rec, val_f1, _ = evaluate_model(naive_gnn_model, y_val, A=A_val_normalized, X=X_val)
    print(f"[VAL] Prec={val_prec:.4f}, Rec={val_rec:.4f}, F1={val_f1:.4f}")

    val_precs["Naive GCN"] = val_prec
    val_recs["Naive GCN"] = val_rec
    val_f1s["Naive GCN"] = val_f1

    results.append([val_prec, val_rec, val_f1])

mean = np.mean(results, axis=0)
# Print average results
print(f"Average Precision: {mean[0]:.4f}, Recall: {mean[1]:.4f}, F1: {mean[2]:.4f}")
# Out:
# Epoch 10/10000 - Train Loss: 0.6869 - Val Precision: 0.4900 - Val Recall: 0.4900 - Val F1: 0.4900 - LR: 0.01
# Epoch 20/10000 - Train Loss: 0.6863 - Val Precision: 0.4900 - Val Recall: 0.4900 - Val F1: 0.4900 - LR: 0.01
# Epoch 30/10000 - Train Loss: 0.6855 - Val Precision: 0.4900 - Val Recall: 0.4900 - Val F1: 0.4900 - LR: 0.01
# Epoch 40/10000 - Train Loss: 0.6845 - Val Precision: 0.4900 - Val Recall: 0.4900 - Val F1: 0.4900 - LR: 0.01
# Epoch 50/10000 - Train Loss: 0.6833 - Val Precision: 0.4900 - Val Recall: 0.4900 - Val F1: 0.4900 - LR: 0.01
# Epoch 60/10000 - Train Loss: 0.6817 - Val Precision: 0.4900 - Val Recall: 0.4900 - Val F1: 0.4900 - LR: 0.01
# Epoch 70/10000 - Train Loss: 0.6797 - Val Precision: 0.4900 - Val Recall: 0.4900 - Val F1: 0.4900 - LR: 0.01
# Epoch 80/10000 - Train Loss: 0.6773 - Val Precision: 0.4900 - Val Recall: 0.4900 - Val F1: 0.4900 - LR: 0.01
# Epoch 90/10000 - Train Loss: 0.6743 - Val Precision: 0.4900 - Val Recall: 0.4900 - Val F1: 0.4900 - LR: 0.01
# Epoch 100/10000 - Train Loss: 0.6716 - Val Precision: 0.4900 - Val Recall: 0.4900 - Val F1: 0.4900 - LR: 0.01
# Epoch 110/10000 - Train Loss: 0.6686 - Val Precision: 0.4950 - Val Recall: 0.4950 - Val F1: 0.4950 - LR: 0.01
# Epoch 120/10000 - Train Loss: 0.6654 - Val Precision: 0.5050 - Val Recall: 0.5050 - Val F1: 0.5050 - LR: 0.01
# Epoch 130/10000 - Train Loss: 0.6620 - Val Precision: 0.4950 - Val Recall: 0.4950 - Val F1: 0.4950 - LR: 0.01
# Epoch 140/10000 - Train Loss: 0.6582 - Val Precision: 0.5100 - Val Recall: 0.5100 - Val F1: 0.5100 - LR: 0.01
# Epoch 150/10000 - Train Loss: 0.6544 - Val Precision: 0.5300 - Val Recall: 0.5300 - Val F1: 0.5300 - LR: 0.01
# Epoch 160/10000 - Train Loss: 0.6502 - Val Precision: 0.5200 - Val Recall: 0.5200 - Val F1: 0.5200 - LR: 0.01
# Epoch 170/10000 - Train Loss: 0.6462 - Val Precision: 0.5300 - Val Recall: 0.5300 - Val F1: 0.5300 - LR: 0.01
# Epoch 180/10000 - Train Loss: 0.6420 - Val Precision: 0.6400 - Val Recall: 0.6400 - Val F1: 0.6400 - LR: 0.01
# Epoch 190/10000 - Train Loss: 0.6375 - Val Precision: 0.5650 - Val Recall: 0.5650 - Val F1: 0.5650 - LR: 0.01
# Epoch 200/10000 - Train Loss: 0.6332 - Val Precision: 0.6700 - Val Recall: 0.6700 - Val F1: 0.6700 - LR: 0.01
# Epoch 210/10000 - Train Loss: 0.6286 - Val Precision: 0.6050 - Val Recall: 0.6050 - Val F1: 0.6050 - LR: 0.01
# Epoch 220/10000 - Train Loss: 0.6243 - Val Precision: 0.6950 - Val Recall: 0.6950 - Val F1: 0.6950 - LR: 0.01
# Epoch 230/10000 - Train Loss: 0.6194 - Val Precision: 0.6800 - Val Recall: 0.6800 - Val F1: 0.6800 - LR: 0.01
# Epoch 240/10000 - Train Loss: 0.6146 - Val Precision: 0.6900 - Val Recall: 0.6900 - Val F1: 0.6900 - LR: 0.01
# Epoch 250/10000 - Train Loss: 0.6102 - Val Precision: 0.7000 - Val Recall: 0.7000 - Val F1: 0.7000 - LR: 0.01
# Epoch 260/10000 - Train Loss: 0.6054 - Val Precision: 0.7200 - Val Recall: 0.7200 - Val F1: 0.7200 - LR: 0.01
# Epoch 270/10000 - Train Loss: 0.6008 - Val Precision: 0.7200 - Val Recall: 0.7200 - Val F1: 0.7200 - LR:
10000 - Train Loss: 0.6931 - Val Precision: 0.5000 - Val Recall: 0.5000 - Val F1: 0.5000 - LR: 1.0000000000000002e-06
# [VAL] Prec=0.5000, Rec=0.5000, F1=0.5000
# Average Precision: 0.6405, Recall: 0.6405, F1: 0.6405

# %% [markdown]
# ## Question 2.3 Node-Type Aware GCN
#
# In this task, **design and implement** a node-type aware 2-layer GCN model that explicitly accounts for two distinct node types and performs binary node classification. Your design should adhere to the following requirements:
#
# - Consider two types of nodes without using padding.
# - Limit your model to **two layers**, as in the naive solution.
# - You may either use the provided `GCNLayer` and `GraphNeuralNetwork` classes or implement your own classes. However, the final model architecture must be implemented within the `HeteroGCN` class.
# - While you are allowed to introduce additional learnable parameters, your approach must **explicitly** account for different node types rather than merely increasing the number of learnable parameters.
# - Determine the optimal hyperparameters for your model, such as hidden dimensions, learning rate, scheduler patience, etc. These hyperparameters do not need to match those of the naive model, as each design has its own optimal configuration.
# - Your model must achieve superior **validation F1 score** compared to the naive approach.
# - You may use different versions of adjacency matrices in your implementation:
#   - Unmodified adjacency matrices, i.e., `A_train`.
#   - Self-looped adjacency matrices, i.e., `A_train_self_loops`.
#   - Normalized adjacency matrices, i.e., `A_train_normalized`.
#
# Please see the Coursework Description PDF Question 2.3 for more details

# %%
# ####################################################
# MODIFY THE CODE BELOW 
# ####################################################

class HeteroGCN(nn.Module):
    def __init__(self, input_dim1, input_dim2, hidden_dim, output_dim):
        super(HeteroGCN, self).__init__()
        self.gcn1_type1 = GCNLayer(input_dim1, hidden_dim, True)
        self.gcn1_type2 = GCNLayer(input_dim2, hidden_dim, True)
        self.gcn2 = GCNLayer(hidden_dim, output_dim, False)
        self.linear = nn.Linear(output_dim, 1)

    def forward(self, A, X1, X2):
        # Initialize hidden representations
        H1_type1 = torch.zeros(X1.shape[0], self.gcn1_type1.Omega.shape[1])
        H1_type2 = torch.zeros(X2.shape[0], self.gcn1_type2.Omega.shape[1])

        # Apply first GCN layer separately for type1 and type2 nodes
        H1_type1 = self.gcn1_type1(X1, A[:X1.shape[0], :X1.shape[0]])
        H1_type2 = self.gcn1_type2(X2, A[X1.shape[0]:, X1.shape[0]:])   

        # Stack hidden representations
        H1 = torch.cat((H1_type1, H1_type2), dim=0)

        # Apply second GCN layer
        H2 = self.gcn2(H1, A)

        # Output layer with sigmoid activation
        output = torch.sigmoid(self.linear(H2))
        
        return output

# ####################################################
# END OF MODIFICATION
# ####################################################

# %%
set_seed(SEED)

# Convert labels to float if using BCE with sigmoid
y_train = y_train.float()  # shape (N,)
y_val   = y_val.float()

# ####################################################
# MODIFY THE CODE BELOW 
# ####################################################
# Build the HeteroGCN model
input_dim1 = X1_train.shape[1]
input_dim2 = X2_train.shape[1]

hidden_dim = 2
output_dim = 1

hetero_gcn = HeteroGCN(input_dim1, input_dim2, hidden_dim, output_dim)

def sort_A_by_type(A, mapping):
    """
    Sorts the adjacency matrix A such that all type1 nodes come before type2 nodes.
    """
    type1_indices = [i for i in range(len(mapping)) if mapping[i]["node_type"] == "type1"]
    type2_indices = [i for i in range(len(mapping)) if mapping[i]["node_type"] == "type2"]
    sorted_indices = type1_indices + type2_indices

    A_sorted = A[sorted_indices, :][:, sorted_indices]
    return A_sorted
    
A_train_normalized_sorted = sort_A_by_type(A_train_normalized, mapping_train)
A_val_normalized_sorted = sort_A_by_type(A_val_normalized, mapping_val)

# Train
loss_history, _ = train_model(
    hetero_gcn, 
    y_train, 
    val_model_inputs={
        "A":A_val_normalized_sorted.clone(),
        "X1":X1_val.clone(), 
        "X2":X2_val.clone()}, 
    y_val=y_val.clone(), 
    A=A_train_normalized_sorted,
    X1=X1_train, 
    X2=X2_train,
    num_epochs=10000, 
    lr=0.01, 
    patience=50)


# ####################################################
# END OF MODIFICATION
# ####################################################

# Test on validation data
val_prec, val_rec, val_f1, _ = evaluate_model(hetero_gcn, y_val, A=A_val_normalized_sorted, X1=X1_val, X2=X2_val,)
print(f"[VAL] Prec={val_prec:.4f}, Rec={val_rec:.4f}, F1={val_f1:.4f}")

val_precs["Hetero GCN"] = val_prec
val_recs["Hetero GCN"] = val_rec
val_f1s["Hetero GCN"] = val_f1

# Plot loss
plot_loss(loss_history, title="Hetero GNN Approach Training Loss")
# Out:
# Epoch 10/10000 - Train Loss: 0.7370 - Val Precision: 0.5000 - Val Recall: 0.5000 - Val F1: 0.5000 - LR: 0.01
# Epoch 20/10000 - Train Loss: 0.7254 - Val Precision: 0.5100 - Val Recall: 0.5100 - Val F1: 0.5100 - LR: 0.01
# Epoch 30/10000 - Train Loss: 0.7166 - Val Precision: 0.5250 - Val Recall: 0.5250 - Val F1: 0.5250 - LR: 0.01
# Epoch 40/10000 - Train Loss: 0.7112 - Val Precision: 0.5000 - Val Recall: 0.5000 - Val F1: 0.5000 - LR: 0.01
# Epoch 50/10000 - Train Loss: 0.7060 - Val Precision: 0.5150 - Val Recall: 0.5150 - Val F1: 0.5150 - LR: 0.01
# Epoch 60/10000 - Train Loss: 0.7018 - Val Precision: 0.5400 - Val Recall: 0.5400 - Val F1: 0.5400 - LR: 0.01
# Epoch 70/10000 - Train Loss: 0.6981 - Val Precision: 0.5000 - Val Recall: 0.5000 - Val F1: 0.5000 - LR: 0.01
# Epoch 80/10000 - Train Loss: 0.6950 - Val Precision: 0.5000 - Val Recall: 0.5000 - Val F1: 0.5000 - LR: 0.01
# Epoch 90/10000 - Train Loss: 0.6933 - Val Precision: 0.5000 - Val Recall: 0.5000 - Val F1: 0.5000 - LR: 0.01
# Epoch 100/10000 - Train Loss: 0.6932 - Val Precision: 0.5000 - Val Recall: 0.5000 - Val F1: 0.5000 - LR: 0.01
# Epoch 110/10000 - Train Loss: 0.6932 - Val Precision: 0.5000 - Val Recall: 0.5000 - Val F1: 0.5000 - LR: 0.01
# Epoch 120/10000 - Train Loss: 0.6932 - Val Precision: 0.5000 - Val Recall: 0.5000 - Val F1: 0.5000 - LR: 0.01
# Epoch 130/10000 - Train Loss: 0.6931 - Val Precision: 0.5000 - Val Recall: 0.5000 - Val F1: 0.5000 - LR: 0.01
# Epoch 140/10000 - Train Loss: 0.6932 - Val Precision: 0.5000 - Val Recall: 0.5000 - Val F1: 0.5000 - LR: 0.01
# Epoch 150/10000 - Train Loss: 0.6931 - Val Precision: 0.5000 - Val Recall: 0.5000 - Val F1: 0.5000 - LR: 0.01
# Epoch 160/10000 - Train Loss: 0.6931 - Val Precision: 0.5000 - Val Recall: 0.5000 - Val F1: 0.5000 - LR: 0.01
# Epoch 170/10000 - Train Loss: 0.6931 - Val Precision: 0.5000 - Val Recall: 0.5000 - Val F1: 0.5000 - LR: 0.01
# Epoch 180/10000 - Train Loss: 0.6931 - Val Precision: 0.5000 - Val Recall: 0.5000 - Val F1: 0.5000 - LR: 0.01
# Epoch 190/10000 - Train Loss: 0.6931 - Val Precision: 0.5000 - Val Recall: 0.5000 - Val F1: 0.5000 - LR: 0.01
# Epoch 200/10000 - Train Loss: 0.6931 - Val Precision: 0.5000 - Val Recall: 0.5000 - Val F1: 0.5000 - LR: 0.01
# Epoch 210/10000 - Train Loss: 0.6931 - Val Precision: 0.5000 - Val Recall: 0.5000 - Val F1: 0.5000 - LR: 0.01
# Epoch 220/10000 - Train Loss: 0.6931 - Val Precision: 0.5000 - Val Recall: 0.5000 - Val F1: 0.5000 - LR: 0.01
# Epoch 230/10000 - Train Loss: 0.6931 - Val Precision: 0.5000 - Val Recall: 0.5000 - Val F1: 0.5000 - LR: 0.01
# Epoch 240/10000 - Train Loss: 0.6931 - Val Precision: 0.5000 - Val Recall: 0.5000 - Val F1: 0.5000 - LR: 0.01
# Epoch 250/10000 - Train Loss: 0.6931 - Val Precision: 0.5000 - Val Recall: 0.5000 - Val F1: 0.5000 - LR: 0.01
# Epoch 260/10000 - Train Loss: 0.6931 - Val Precision: 0.5000 - Val Recall: 0.5000 - Val F1: 0.5000 - LR: 0.01
# Epoch 270/10000 - Train Loss: 0.6931 - Val Precision: 0.5000 - Val Recall: 0.5000 - Val F1: 0.5000 - LR: 0.01
# Epoch 280/10000 - Train Loss: 0.6931 - Val Precision: 0.5000 - Val Recall: 0.5000 - Val F1: 0.5000 - LR: 0.01
# Epoch 290/10000 - Train Loss: 0.6931 - Val Precision: 0.5000 - Val Recall: 0.5000 - Val F1: 0.5000 - LR: 0.01
# Epoch 300/10000 - Train Loss: 0.6931 - Val Precision: 0.5000 - Val Recall: 0.5000 - Val F1: 0.5000 - LR: 0.01
# Epoch 310/10000 - Train Loss: 0.6931 - Val Precision: 0.5000 - Val Recall: 0.5000 - Val F1: 0.5000 - LR: 0.01
# Epoch 320/10000 - Train Loss: 0.6931 - Val Precision: 0.5000 - Val Recall: 0.5000 - Val F1: 0.5000 - LR: 0.01
# Epoch 330/10000 - Train Loss: 0.6931 - Val Precision: 0.5000 - Val Recall: 0.5000 - Val F1: 0.5000 - LR: 0.01
# Epoch 340/10000 - Train Loss: 0.6931 - Val Precision: 0.5000 - Val Recall: 0.5000 - Val F1: 0.5000 - LR: 0.01
# Epoch 350/10000 - Train Loss: 0.6931 - Val Precision: 0.5000 - Val Recall: 0.5000 - Val F1: 0.5000 - LR: 0.01
# Epoch 360/10000 - Train Loss: 0.6931 - Val Precision: 0.5000 - Val Recall: 0.5000 - Val F1: 0.5000 - LR: 0.01
# Epoch 370/10000 - Train Loss: 0.6931 - Val Precision: 0.5000 - Val Recall: 0.5000 - Val F1: 0.5000 - LR: 0.01
# Epoch 380/10000 - Train Loss: 0.6931 - Val Precision: 0.5000 - Val Recall: 0.5000 - Val F1: 0.5000 - LR: 0.01
# Epoch 390/10000 - Train Loss: 0.6931 - Val Precision: 0.5000 - Val Recall: 0.5000 - Val F1: 0.5000 - LR: 0.01
# Epoch 400/10000 - Train Loss: 0.6931 - Val Precision: 0.5000 - Val Recall: 0.5000 - Val F1: 0.5000 - LR: 0.01
# Epoch 410/10000 - Train Loss: 0.6931 - Val Precision: 0.5000 - Val Recall: 0.5000 - Val F1: 0.5000 - LR: 0.01
# Epoch 420/10000 - Train Loss: 0.6931 - Val Precision: 0.5000 - Val Recall: 0.5000 - Val F1: 0.5000 - LR: 0.01
# Epoch 430/10000 - Train Loss: 0.6931 - Val Precision: 0.5000 - Val Recall: 0.5000 - Val F1: 0.5000 - LR: 0.01
# Epoch 440/10000 - Train Loss: 0.6931 - Val Precision: 0.5000 - Val Recall: 0.5000 - Val F1: 0.5000 - LR: 0.01
# Epoch 450/10000 - Train Loss: 0.6931 - Val Precision: 0.5000 - Val Recall: 0.5000 - Val F1: 0.5000 - LR: 0.01
# Epoch 460/10000 - Train Loss: 0.6931 - Val Precision: 0.5000 - Val Recall: 0.5000 - Val F1: 0.5000 - LR: 0.01
# Epoch 470/10000 - Train Loss: 0.6931 - Val Precision: 0.5000 - Val Recall: 0.5000 - Val F1: 0.5000 - LR: 0.01
# Epoch 480/10000 - Train Loss: 0.6931 - Val Precision: 0.5000 - Val Recall: 0.5000 - Val F1: 0.5000 - LR: 0.01
# Epoch 490/10000 - Train Loss: 0.6931 - Val Precision: 0.5000 - Val Recall: 0.5000 - Val F1: 0.5000 - LR: 0.01
# Epoch 500/10000 - Train Loss: 0.6931 - Val Precision: 0.5000 - Val Recall: 0.5000 - Val F1: 0.5000 - LR: 0.01
# Epoch 510/10000 - Train Loss: 0.6931 - Val Precision: 0.5000 - Val Recall: 0.5000 - Val F1: 0.5000 - LR: 0.01
# Epoch 520/10000 - Train Loss: 0.6931 - Val Precision: 0.5000 - Val Recall: 0.5000 - Val F1: 0.5000 - LR: 0.01
# Epoch 530/10000 - Train Loss: 0.6931 - Val Precision: 0.5000 - Val Recall: 0.5000 - Val F1: 0.5000 - LR: 0.01
# Epoch 540/10000 - Train Loss: 0.6931 - Val Precision: 0.5000 - Val Recall: 0.5000 - Val F1: 0.5000 - LR: 0.01
# Epoch 550/10000 - Train Loss: 0.6931 - Val Precision: 0.5000 - Val Recall: 0.5000 - Val F1: 0.5000 - LR: 0.01
# Epoch 560/10000 - Train Loss: 0.6931 - Val Precision: 0.5000 - Val Recall: 0.5000 - Val F1: 0.5000 - LR: 0.01
# Epoch 570/10000 - Train Loss: 0.6931 - Val Precision: 0.5000 - Val Recall: 0.5000 - Val F1: 0.5000 - LR: 0.001
# Epoch 580/10000 - Train Loss: 0.6931 - Val Precision: 0.5000 - Val Recall: 0.5000 - Val F1: 0.5000 - LR: 0.001
# Epoch 590/10000 - Train Loss: 0.6931 - Val Precision: 0.5000 - Val Recall: 0.5000 - Val F1: 0.5000 - LR: 0.001
# Epoch 600/10000 - Train Loss: 0.6931 - Val Precision: 0.5000 - Val Recall: 0.5000 - Val F1: 0.5000 - LR: 0.001
# Epoch 610/10000 - Train Loss: 0.6931 - Val Precision: 0.5000 - Val Recall: 0.5000 - Val F1: 0.5000 - LR: 0.001
# Epoch 620/10000 - Train Loss: 0.6931 - Val Precision: 0.5000 - Val Recall: 0.5000 - Val F1: 0.5000 - LR: 0.001
# Epoch 630/10000 - Train Loss: 0.6931 - Val Precision: 0.5000 - Val Recall: 0.5000 - Val F1: 0.5000 - LR: 0.001
# Epoch 640/10000 - Train Loss: 0.6931 - Val Precision: 0.5000 - Val Recall: 0.5000 - Val F1: 0.5000 - LR: 0.001
# Epoch 650/10000 - Train Loss: 0.6931 - Val Precision: 0.5000 - Val Recall: 0.5000 - Val F1: 0.5000 - LR: 0.001
# Epoch 660/10000 - Train Loss: 0.6931 - Val Precision: 0.5000 - Val Recall: 0.5000 - Val F1: 0.5000 - LR: 0.001
# Epoch 670/10000 - Train Loss: 0.6931 - Val Precision: 0.5000 - Val Recall: 0.5000 - Val F1: 0.5000 - LR: 0.001
# Epoch 680/10000 - Train Loss: 0.6931 - Val Precision: 0.5000 - Val Recall: 0.5000 - Val F1: 0.5000 - LR: 0.001
# Epoch 690/10000 - Train Loss: 0.6931 - Val Precision: 0.5000 - Val Recall: 0.5000 - Val F1: 0.5000 - LR: 0.001
# Epoch 700/10000 - Train Loss: 0.6931 - Val Precision: 0.5000 - Val Recall: 0.5000 - Val F1: 0.5000 - LR: 0.001
# Epoch 710/10000 - Train Loss: 0.6931 - Val Precision: 0.5000 - Val Recall: 0.5000 - Val F1: 0.5000 - LR: 0.001
# Epoch 720/10000 - Train Loss: 0.6931 - Val Precision: 0.5000 - Val Recall: 0.5000 - Val F1: 0.5000 - LR: 0.001
# Epoch 730/10000 - Train Loss: 0.6931 - Val Precision: 0.5000 - Val Recall: 0.5000 - Val F1: 0.5000 - LR: 0.001
# Epoch 740/10000 - Train Loss: 0.6931 - Val Precision: 0.5000 - Val Recall: 0.5000 - Val F1: 0.5000 - LR: 0.001
# Epoch 750/10000 - Train Loss: 0.6931 - Val Precision: 0.5000 - Val Recall: 0.5000 - Val F1: 0.5000 - LR: 0.001
# Epoch 760/10000 - Train Loss: 0.6931 - Val Precision: 0.5000 - Val Recall: 0.5000 - Val F1: 0.5000 - LR: 0.001
# Epoch 770/10000 - Train Loss: 0.6931 - Val Precision: 0.5000 - Val Recall: 0.5000 - Val F1: 0.5000 - LR: 0.001
# Epoch 780/10000 - Train Loss: 0.6931 - Val Precision: 0.5000 - Val Recall: 0.5000 - Val F1: 0.5000 - LR: 0.001
# Epoch 790/10000 - Train Loss: 0.6931 - Val Precision: 0.5000 - Val Recall: 0.5000 - Val F1: 0.5000 - LR: 0.001
# Epoch 800/10000 - Train Loss: 0.6931 - Val Precision: 0.5000 - Val Recall: 0.5000 - Val F1: 0.5000 - LR: 0.001
# Epoch 810/10000 - Train Loss: 0.6931 - Val Precision: 0.5000 - Val Recall: 0.5000 - Val F1: 0.5000 - LR: 0.001
# Epoch 820/10000 - Train Loss: 0.6931 - Val Precision: 0.5000 - Val Recall: 0.5000 - Val F1: 0.5000 - LR: 0.001
# Epoch 830/10000 - Train Loss: 0.6931 - Val Precision: 0.5000 - Val Recall: 0.5000 - Val F1: 0.5000 - LR: 0.001
# Epoch 840/10000 - Train Loss: 0.6931 - Val Precision: 0.5000 - Val Recall: 0.5000 - Val F1: 0.5000 - LR: 0.001
# Epoch 850/10000 - Train Loss: 0.6931 - Val Precision: 0.5000 - Val Recall: 0.5000 - Val F1: 0.5000 - LR: 0.001
# Epoch 860/10000 - Train Loss: 0.6931 - Val Precision: 0.5000 - Val Recall: 0.5000 - Val F1: 0.5000 - LR: 0.001
# Epoch 870/10000 - Train Loss: 0.6931 - Val Precision: 0.5000 - Val Recall: 0.5000 - Val F1: 0.5000 - LR: 0.001
# Epoch 880/10000 - Train Loss: 0.6931 - Val Precision: 0.5000 - Val Recall: 0.5000 - Val F1: 0.5000 - LR: 0.001
# Epoch 890/10000 - Train Loss: 0.6931 - Val Precision: 0.5000 - Val Recall: 0.5000 - Val F1: 0.5000 - LR: 0.001
# Epoch 900/10000 - Train Loss: 0.6931 - Val Precision: 0.5000 - Val Recall: 0.5000 - Val F1: 0.5000 - LR: 0.001
# Epoch 910/10000 - Train Loss: 0.6931 - Val Precision: 0.5000 - Val Recall: 0.5000 - Val F1: 0.5000 - LR: 0.001
# Epoch 920/10000 - Train Loss: 0.6931 - Val Precision: 0.5000 - Val Recall: 0.5000 - Val F1: 0.5000 - LR: 0.001
# Epoch 930/10000 - Train Loss: 0.6931 - Val Precision: 0.5000 - Val Recall: 0.5000 - Val F1: 0.5000 - LR: 0.001
# Epoch 940/10000 - Train Loss: 0.6931 - Val Precision: 0.5000 - Val Recall: 0.5000 - Val F1: 0.5000 - LR: 0.001
# Epoch 950/10000 - Train Loss: 0.6931 - Val Precision: 0.5000 - Val Recall: 0.5000 - Val F1: 0.5000 - LR: 0.001
# Epoch 960/10000 - Train Loss: 0.6931 - Val Precision: 0.5000 - Val Recall: 0.5000 - Val F1: 0.5000 - LR: 0.001
# Epoch 970/10000 - Train Loss: 0.6931 - Val Precision: 0.5000 - Val Recall: 0.5000 - Val F1: 0.5000 - LR: 0.001
# Epoch 980/10000 - Train Loss: 0.6931 - Val Precision: 0.5000 - Val Recall: 0.5000 - Val F1: 0.5000 - LR: 0.001
# Epoch 990/10000 - Train Loss: 0.6931 - Val Precision: 0.5000 - Val Recall: 0.5000 - Val F1: 0.5000 - LR: 0.001
# Epoch 1000/10000 - Train Loss: 0.6931 - Val Precision: 0.5000 - Val Recall: 0.5000 - Val F1: 0.5000 - LR: 0.001
# Epoch 1010/10000 - Train Loss: 0.6931 - Val Precision: 0.5000 - Val Recall: 0.5000 - Val F1: 0.5000 - LR: 0.001
# Epoch 1020/10000 - Train Loss: 0.6931 - Val Precision: 0.5000 - Val Recall: 0.5000 - Val F1: 0.5000 - LR: 0.001
# Epoch 1030/10000 - Train Loss: 0.6931 - Val Precision: 0.5000 - Val Recall: 0.5000 - Val F1: 0.5000 - LR: 0.001
# Epoch 1040/10000 - Train Loss: 0.6931 - Val Precision: 0.5000 - Val Recall: 0.5000 - Val F1: 0.5000 - LR: 0.001
# Epoch 1050/10000 - Train Loss: 0.6931 - Val Precision: 0.5000 - Val Recall: 0.5000 - Val F1: 0.5000 - LR: 0.001
# Epoch 1060/10000 - Train Loss: 0.6931 - Val Precision: 0.5000 - Val Recall: 0.5000 - Val F1: 0.5000 - LR: 0.001
# Epoch 1070/10000 - Train Loss: 0.6931 - Val Precision: 0.5000 - Val Recall: 0.5000 - Val F1: 0.5000 - LR: 0.001
# Epoch 1080/10000 - Train Loss: 0.6931 - Val Precision: 0.5000 - Val Recall: 0.5000 - Val F1: 0.5000 - LR: 0.0001
# Epoch 1090/10000 - Train Loss: 0.6931 - Val Precision: 0.5000 - Val Recall: 0.5000 - Val F1: 0.5000 - LR: 0.0001
# Epoch 1100/10000 - Train Loss: 0.6931 - Val Precision: 0.5000 - Val Recall: 0.5000 - Val F1: 0.5000 - LR: 0.0001
# Epoch 1110/10000 - Train Loss: 0.6931 - Val Precision: 0.5000 - Val Recall: 0.5000 - Val F1: 0.5000 - LR: 0.0001
# Epoch 1120/10000 - Train Loss: 0.6931 - Val Precision: 0.5000 - Val Recall: 0.5000 - Val F1: 0.5000 - LR: 0.0001
# Epoch 1130/10000 - Train Loss: 0.6931 - Val Precision: 0.5000 - Val Recall: 0.5000 - Val F1: 0.5000 - LR: 0.0001
# Epoch 1140/10000 - Train Loss: 0.6931 - Val Precision: 0.5000 - Val Recall: 0.5000 - Val F1: 0.5000 - LR: 0.0001
# Epoch 1150/10000 - Train Loss: 0.6931 - Val Precision: 0.5000 - Val Recall: 0.5000 - Val F1: 0.5000 - LR: 0.0001
# Epoch 1160/10000 - Train Loss: 0.6931 - Val Precision: 0.5000 - Val Recall: 0.5000 - Val F1: 0.5000 - LR: 0.0001
# Epoch 1170/10000 - Train Loss: 0.6931 - Val Precision: 0.5000 - Val Recall: 0.5000 - Val F1: 0.5000 - LR: 0.0001
# Epoch 1180/10000 - Train Loss: 0.6931 - Val Precision: 0.5000 - Val Recall: 0.5000 - Val F1: 0.5000 - LR: 0.0001
# Epoch 1190/10000 - Train Loss: 0.6931 - Val Precision: 0.5000 - Val Recall: 0.5000 - Val F1: 0.5000 - LR: 0.0001
# Epoch 1200/10000 - Train Loss: 0.6931 - Val Precision: 0.5000 - Val Recall: 0.5000 - Val F1: 0.5000 - LR: 0.0001
# Epoch 1210/10000 - Train Loss: 0.6931 - Val Precision: 0.5000 - Val Recall: 0.5000 - Val F1: 0.5000 - LR: 0.0001
# Epoch 1220/10000 - Train Loss: 0.6931 - Val Precision: 0.5000 - Val Recall: 0.5000 - Val F1: 0.5000 - LR: 0.0001
# Epoch 1230/10000 - Train Loss: 0.6931 - Val Precision: 0.5000 - Val Recall: 0.5000 - Val F1: 0.5000 - LR: 0.0001
# Epoch 1240/10000 - Train Loss: 0.6931 - Val Precision: 0.5000 - Val Recall: 0.5000 - Val F1: 0.5000 - LR: 0.0001
# Epoch 1250/10000 - Train Loss: 0.6931 - Val Precision: 0.5000 - Val Recall: 0.5000 - Val F1: 0.5000 - LR: 0.0001
# Epoch 1260/10000 - Train Loss: 0.6931 - Val Precision: 0.5000 - Val Recall: 0.5000 - Val F1: 0.5000 - LR: 0.0001
# Epoch 1270/10000 - Train Loss: 0.6931 - Val Precision: 0.5000 - Val Recall: 0.5000 - Val F1: 0.5000 - LR: 0.0001
# Epoch 1280/10000 - Train Loss: 0.6931 - Val Precision: 0.5000 - Val Recall: 0.5000 - Val F1: 0.5000 - LR: 0.0001
# Epoch 1290/10000 - Train Loss: 0.6931 - Val Precision: 0.5000 - Val Recall: 0.5000 - Val F1: 0.5000 - LR: 0.0001
# Epoch 1300/10000 - Train Loss: 0.6931 - Val Precision: 0.5000 - Val Recall: 0.5000 - Val F1: 0.5000 - LR: 0.0001
# Epoch 1310/10000 - Train Loss: 0.6931 - Val Precision: 0.5000 - Val Recall: 0.5000 - Val F1: 0.5000 - LR: 0.0001
# Epoch 1320/10000 - Train Loss: 0.6931 - Val Precision: 0.5000 - Val Recall: 0.5000 - Val F1: 0.5000 - LR: 0.0001
# Epoch 1330/10000 - Train Loss: 0.6931 - Val Precision: 0.5000 - Val Recall: 0.5000 - Val F1: 0.5000 - LR: 0.0001
# Epoch 1340/10000 - Train Loss: 0.6931 - Val Precision: 0.5000 - Val Recall: 0.5000 - Val F1: 0.5000 - LR: 0.0001
# Epoch 1350/10000 - Train Loss: 0.6931 - Val Precision: 0.5000 - Val Recall: 0.5000 - Val F1: 0.5000 - LR: 0.0001
# Epoch 1360/10000 - Train Loss: 0.6931 - Val Precision: 0.5000 - Val Recall: 0.5000 - Val F1: 0.5000 - LR: 0.0001
# Epoch 1370/10000 - Train Loss: 0.6931 - Val Precision: 0.5000 - Val Recall: 0.5000 - Val F1: 0.5000 - LR: 0.0001
# Epoch 1380/10000 - Train Loss: 0.6931 - Val Precision: 0.5000 - Val Recall: 0.5000 - Val F1: 0.5000 - LR: 0.0001
# Epoch 1390/10000 - Train Loss: 0.6931 - Val Precision: 0.5000 - Val Recall: 0.5000 - Val F1: 0.5000 - LR: 0.0001
# Epoch 1400/10000 - Train Loss: 0.6931 - Val Precision: 0.5000 - Val Recall: 0.5000 - Val F1: 0.5000 - LR: 0.0001
# Epoch 1410/10000 - Train Loss: 0.6931 - Val Precision: 0.5000 - Val Recall: 0.5000 - Val F1: 0.5000 - LR: 0.0001
# Epoch 1420/10000 - Train Loss: 0.6931 - Val Precision: 0.5000 - Val Recall: 0.5000 - Val F1: 0.5000 - LR: 0.0001
# Epoch 1430/10000 - Train Loss: 0.6931 - Val Precision: 0.5000 - Val Recall: 0.5000 - Val F1: 0.5000 - LR: 0.0001
# Epoch 1440/10000 - Train Loss: 0.6931 - Val Precision: 0.5000 - Val Recall: 0.5000 - Val F1: 0.5000 - LR: 0.0001
# Epoch 1450/10000 - Train Loss: 0.6931 - Val Precision: 0.5000 - Val Recall: 0.5000 - Val F1: 0.5000 - LR: 0.0001
# Epoch 1460/10000 - Train Loss: 0.6931 - Val Precision: 0.5000 - Val Recall: 0.5000 - Val F1: 0.5000 - LR: 0.0001
# Epoch 1470/10000 - Train Loss: 0.6931 - Val Precision: 0.5000 - Val Recall: 0.5000 - Val F1: 0.5000 - LR: 0.0001
# Epoch 1480/10000 - Train Loss: 0.6931 - Val Precision: 0.5000 - Val Recall: 0.5000 - Val F1: 0.5000 - LR: 0.0001
# Epoch 1490/10000 - Train Loss: 0.6931 - Val Precision: 0.5000 - Val Recall: 0.5000 - Val F1: 0.5000 - LR: 0.0001
# Epoch 1500/10000 - Train Loss: 0.6931 - Val Precision: 0.5000 - Val Recall: 0.5000 - Val F1: 0.5000 - LR: 0.0001
# Epoch 1510/10000 - Train Loss: 0.6931 - Val Precision: 0.5000 - Val Recall: 0.5000 - Val F1: 0.5000 - LR: 0.0001
# Epoch 1520/10000 - Train Loss: 0.6931 - Val Precision: 0.5000 - Val Recall: 0.5000 - Val F1: 0.5000 - LR: 0.0001
# Epoch 1530/10000 - Train Loss: 0.6931 - Val Precision: 0.5000 - Val Recall: 0.5000 - Val F1: 0.5000 - LR: 0.0001
# Epoch 1540/10000 - Train Loss: 0.6931 - Val Precision: 0.5000 - Val Recall: 0.5000 - Val F1: 0.5000 - LR: 0.0001
# Epoch 1550/10000 - Train Loss: 0.6931 - Val Precision: 0.5000 - Val Recall: 0.5000 - Val F1: 0.5000 - LR: 0.0001
# Epoch 1560/10000 - Train Loss: 0.6931 - Val Precision: 0.5000 - Val Recall: 0.5000 - Val F1: 0.5000 - LR: 0.0001
# Epoch 1570/10000 - Train Loss: 0.6931 - Val Precision: 0.5000 - Val Recall: 0.5000 - Val F1: 0.5000 - LR: 0.0001
# Epoch 1580/10000 - Train Loss: 0.6931 - Val Precision: 0.5000 - Val Recall: 0.5000 - Val F1: 0.5000 - LR: 0.0001
# Epoch 1590/10000 - Train Loss: 0.6931 - Val Precision: 0.5000 - Val Recall: 0.5000 - Val F1: 0.5000 - LR: 1e-05
# Epoch 1600/10000 - Train Loss: 0.6931 - Val Precision: 0.5000 - Val Recall: 0.5000 - Val F1: 0.5000 - LR: 1e-05
# Epoch 1610/10000 - Train Loss: 0.6931 - Val Precision: 0.5000 - Val Recall: 0.5000 - Val F1: 0.5000 - LR: 1e-05
# Epoch 1620/10000 - Train Loss: 0.6931 - Val Precision: 0.5000 - Val Recall: 0.5000 - Val F1: 0.5000 - LR: 1e-05
# Epoch 1630/10000 - Train Loss: 0.6931 - Val Precision: 0.5000 - Val Recall: 0.5000 - Val F1: 0.5000 - LR: 1e-05
# Epoch 1640/10000 - Train Loss: 0.6931 - Val Precision: 0.5000 - Val Recall: 0.5000 - Val F1: 0.5000 - LR: 1e-05
# Epoch 1650/10000 - Train Loss: 0.6931 - Val Precision: 0.5000 - Val Recall: 0.5000 - Val F1: 0.5000 - LR: 1e-05
# Epoch 1660/10000 - Train Loss: 0.6931 - Val Precision: 0.5000 - Val Recall: 0.5000 - Val F1: 0.5000 - LR: 1e-05
# Epoch 1670/10000 - Train Loss: 0.6931 - Val Precision: 0.5000 - Val Recall: 0.5000 - Val F1: 0.5000 - LR: 1e-05
# Epoch 1680/10000 - Train Loss: 0.6931 - Val Precision: 0.5000 - Val Recall: 0.5000 - Val F1: 0.5000 - LR: 1e-05
# Epoch 1690/10000 - Train Loss: 0.6931 - Val Precision: 0.5000 - Val Recall: 0.5000 - Val F1: 0.5000 - LR: 1e-05
# Epoch 1700/10000 - Train Loss: 0.6931 - Val Precision: 0.5000 - Val Recall: 0.5000 - Val F1: 0.5000 - LR: 1e-05
# Epoch 1710/10000 - Train Loss: 0.6931 - Val Precision: 0.5000 - Val Recall: 0.5000 - Val F1: 0.5000 - LR: 1e-05
# Epoch 1720/10000 - Train Loss: 0.6931 - Val Precision: 0.5000 - Val Recall: 0.5000 - Val F1: 0.5000 - LR: 1e-05
# Epoch 1730/10000 - Train Loss: 0.6931 - Val Precision: 0.5000 - Val Recall: 0.5000 - Val F1: 0.5000 - LR: 1e-05
# Epoch 1740/10000 - Train Loss: 0.6931 - Val Precision: 0.5000 - Val Recall: 0.5000 - Val F1: 0.5000 - LR: 1e-05
# Epoch 1750/10000 - Train Loss: 0.6931 - Val Precision: 0.5000 - Val Recall: 0.5000 - Val F1: 0.5000 - LR: 1e-05
# Epoch 1760/10000 - Train Loss: 0.6931 - Val Precision: 0.5000 - Val Recall: 0.5000 - Val F1: 0.5000 - LR: 1e-05
# Epoch 1770/10000 - Train Loss: 0.6931 - Val Precision: 0.5000 - Val Recall: 0.5000 - Val F1: 0.5000 - LR: 1e-05
# Epoch 1780/10000 - Train Loss: 0.6931 - Val Precision: 0.5000 - Val Recall: 0.5000 - Val F1: 0.5000 - LR: 1e-05
# Epoch 1790/10000 - Train Loss: 0.6931 - Val Precision: 0.5000 - Val Recall: 0.5000 - Val F1: 0.5000 - LR: 1e-05
# Epoch 1800/10000 - Train Loss: 0.6931 - Val Precision: 0.5000 - Val Recall: 0.5000 - Val F1: 0.5000 - LR: 1e-05
# Epoch 1810/10000 - Train Loss: 0.6931 - Val Precision: 0.5000 - Val Recall: 0.5000 - Val F1: 0.5000 - LR: 1e-05
# Epoch 1820/10000 - Train Loss: 0.6931 - Val Precision: 0.5000 - Val Recall: 0.5000 - Val F1: 0.5000 - LR: 1e-05
# Epoch 1830/10000 - Train Loss: 0.6931 - Val Precision: 0.5000 - Val Recall: 0.5000 - Val F1: 0.5000 - LR: 1e-05
# Epoch 1840/10000 - Train Loss: 0.6931 - Val Precision: 0.5000 - Val Recall: 0.5000 - Val F1: 0.5000 - LR: 1e-05
# Epoch 1850/10000 - Train Loss: 0.6931 - Val Precision: 0.5000 - Val Recall: 0.5000 - Val F1: 0.5000 - LR: 1e-05
# Epoch 1860/10000 - Train Loss: 0.6931 - Val Precision: 0.5000 - Val Recall: 0.5000 - Val F1: 0.5000 - LR: 1e-05
# Epoch 1870/10000 - Train Loss: 0.6931 - Val Precision: 0.5000 - Val Recall: 0.5000 - Val F1: 0.5000 - LR: 1e-05
# Epoch 1880/10000 - Train Loss: 0.6931 - Val Precision: 0.5000 - Val Recall: 0.5000 - Val F1: 0.5000 - LR: 1e-05
# Epoch 1890/10000 - Train Loss: 0.6931 - Val Precision: 0.5000 - Val Recall: 0.5000 - Val F1: 0.5000 - LR: 1e-05
# Epoch 1900/10000 - Train Loss: 0.6931 - Val Precision: 0.5000 - Val Recall: 0.5000 - Val F1: 0.5000 - LR: 1e-05
# Epoch 1910/10000 - Train Loss: 0.6931 - Val Precision: 0.5000 - Val Recall: 0.5000 - Val F1: 0.5000 - LR: 1e-05
# Epoch 1920/10000 - Train Loss: 0.6931 - Val Precision: 0.5000 - Val Recall: 0.5000 - Val F1: 0.5000 - LR: 1e-05
# Epoch 1930/10000 - Train Loss: 0.6931 - Val Precision: 0.5000 - Val Recall: 0.5000 - Val F1: 0.5000 - LR: 1e-05
# Epoch 1940/10000 - Train Loss: 0.6931 - Val Precision: 0.5000 - Val Recall: 0.5000 - Val F1: 0.5000 - LR: 1e-05
# Epoch 1950/10000 - Train Loss: 0.6931 - Val Precision: 0.5000 - Val Recall: 0.5000 - Val F1: 0.5000 - LR: 1e-05
# Epoch 1960/10000 - Train Loss: 0.6931 - Val Precision: 0.5000 - Val Recall: 0.5000 - Val F1: 0.5000 - LR: 1e-05
# Epoch 1970/10000 - Train Loss: 0.6931 - Val Precision: 0.5000 - Val Recall: 0.5000 - Val F1: 0.5000 - LR: 1e-05
# Epoch 1980/10000 - Train Loss: 0.6931 - Val Precision: 0.5000 - Val Recall: 0.5000 - Val F1: 0.5000 - LR: 1e-05
# Epoch 1990/10000 - Train Loss: 0.6931 - Val Precision: 0.5000 - Val Recall: 0.5000 - Val F1: 0.5000 - LR: 1e-05
# Epoch 2000/10000 - Train Loss: 0.6931 - Val Precision: 0.5000 - Val Recall: 0.5000 - Val F1: 0.5000 - LR: 1e-05
# Epoch 2010/10000 - Train Loss: 0.6931 - Val Precision: 0.5000 - Val Recall: 0.5000 - Val F1: 0.5000 - LR: 1e-05
# Epoch 2020/10000 - Train Loss: 0.6931 - Val Precision: 0.5000 - Val Recall: 0.5000 - Val F1: 0.5000 - LR: 1e-05
# Epoch 2030/10000 - Train Loss: 0.6931 - Val Precision: 0.5000 - Val Recall: 0.5000 - Val F1: 0.5000 - LR: 1e-05
# Epoch 2040/10000 - Train Loss: 0.6931 - Val Precision: 0.5000 - Val Recall: 0.5000 - Val F1: 0.5000 - LR: 1e-05
# Epoch 2050/10000 - Train Loss: 0.6931 - Val Precision: 0.5000 - Val Recall: 0.5000 - Val F1: 0.5000 - LR: 1e-05
# Epoch 2060/10000 - Train Loss: 0.6931 - Val Precision: 0.5000 - Val Recall: 0.5000 - Val F1: 0.5000 - LR: 1e-05
# Epoch 2070/10000 - Train Loss: 0.6931 - Val Precision: 0.5000 - Val Recall: 0.5000 - Val F1: 0.5000 - LR: 1e-05
# Epoch 2080/10000 - Train Loss: 0.6931 - Val Precision: 0.5000 - Val Recall: 0.5000 - Val F1: 0.5000 - LR: 1e-05
# Epoch 2090/10000 - Train Loss: 0.6931 - Val Precision: 0.5000 - Val Recall: 0.5000 - Val F1: 0.5000 - LR: 1e-05
# Epoch 2100/10000 - Train Loss: 0.6931 - Val Precision: 0.5000 - Val Recall: 0.5000 - Val F1: 0.5000 - LR: 1.0000000000000002e-06
# [VAL] Prec=0.5400, Rec=0.5400, F1=0.5400

# %% [markdown]
# HeteroGCN Tuning Hyperparameters

# %%
def get_result(X1_train, X2_train, A_train, A_val, mapping_train, mapping_val, num_epochs, hidden_dim, learning_rate, output_dim):
    input_dim1 = X1_train.shape[1]
    input_dim2 = X2_train.shape[1]

    hetero_gcn = HeteroGCN(input_dim1, input_dim2, hidden_dim, output_dim)

    def sort_A_by_type(A, mapping):
        """
        Sorts the adjacency matrix A such that all type1 nodes come before type2 nodes.
        """
        type1_indices = [i for i in range(len(mapping)) if mapping[i]["node_type"] == "type1"]
        type2_indices = [i for i in range(len(mapping)) if mapping[i]["node_type"] == "type2"]
        sorted_indices = type1_indices + type2_indices

        A_sorted = A[sorted_indices, :][:, sorted_indices]
        return A_sorted
        
    A_train_normalized_sorted = sort_A_by_type(A_train, mapping_train)
    A_val_normalized_sorted = sort_A_by_type(A_val, mapping_val)

    # Train
    loss_history, _ = train_model(
        hetero_gcn, 
        y_train, 
        val_model_inputs={
            "A":A_val_normalized_sorted.clone(),
            "X1":X1_val.clone(), 
            "X2":X2_val.clone()}, 
        y_val=y_val.clone(), 
        A=A_train_normalized_sorted,
        X1=X1_train, 
        X2=X2_train,
        num_epochs=num_epochs, 
        lr=learning_rate, 
        patience=50)
    
    

    # Test on validation data
    val_prec, val_rec, val_f1, _ = evaluate_model(hetero_gcn, y_val, A=A_val_normalized_sorted, X1=X1_val, X2=X2_val,)
    print(f"[VAL] Prec={val_prec:.4f}, Rec={val_rec:.4f}, F1={val_f1:.4f}")

    return {"learning_rate": learning_rate, "hidden_dim": hidden_dim, "prec": val_prec, "rec": val_rec, "f1": val_f1}

# %%
hidden_dims = [2, 4, 16, 64, 128, 512]
learning_rates = [0.01, 0.001, 0.0005]

results = []

output_dim = 1
num_epochs = 10000

for hidden_dim in hidden_dims:
    for learning_rate in learning_rates:
        result = get_result(X1_train, X2_train, A_train_normalized, A_val_normalized, mapping_train, mapping_val, num_epochs, hidden_dim, learning_rate, output_dim)
        results.append(result)
# Out:
# Epoch 10/10000 - Train Loss: 0.6896 - Val Precision: 0.4900 - Val Recall: 0.4900 - Val F1: 0.4900 - LR: 0.01
# Epoch 20/10000 - Train Loss: 0.6888 - Val Precision: 0.4900 - Val Recall: 0.4900 - Val F1: 0.4900 - LR: 0.01
# Epoch 30/10000 - Train Loss: 0.6881 - Val Precision: 0.4900 - Val Recall: 0.4900 - Val F1: 0.4900 - LR: 0.01
# Epoch 40/10000 - Train Loss: 0.6868 - Val Precision: 0.4900 - Val Recall: 0.4900 - Val F1: 0.4900 - LR: 0.01
# Epoch 50/10000 - Train Loss: 0.6866 - Val Precision: 0.4900 - Val Recall: 0.4900 - Val F1: 0.4900 - LR: 0.01
# Epoch 60/10000 - Train Loss: 0.6864 - Val Precision: 0.4900 - Val Recall: 0.4900 - Val F1: 0.4900 - LR: 0.01
# Epoch 70/10000 - Train Loss: 0.6862 - Val Precision: 0.4900 - Val Recall: 0.4900 - Val F1: 0.4900 - LR: 0.01
# Epoch 80/10000 - Train Loss: 0.6861 - Val Precision: 0.4900 - Val Recall: 0.4900 - Val F1: 0.4900 - LR: 0.01
# Epoch 90/10000 - Train Loss: 0.6860 - Val Precision: 0.4900 - Val Recall: 0.4900 - Val F1: 0.4900 - LR: 0.01
# Epoch 100/10000 - Train Loss: 0.6858 - Val Precision: 0.4900 - Val Recall: 0.4900 - Val F1: 0.4900 - LR: 0.01
# Epoch 110/10000 - Train Loss: 0.6857 - Val Precision: 0.4900 - Val Recall: 0.4900 - Val F1: 0.4900 - LR: 0.01
# Epoch 120/10000 - Train Loss: 0.6855 - Val Precision: 0.4900 - Val Recall: 0.4900 - Val F1: 0.4900 - LR: 0.01
# Epoch 130/10000 - Train Loss: 0.6853 - Val Precision: 0.4900 - Val Recall: 0.4900 - Val F1: 0.4900 - LR: 0.01
# Epoch 140/10000 - Train Loss: 0.6850 - Val Precision: 0.4900 - Val Recall: 0.4900 - Val F1: 0.4900 - LR: 0.01
# Epoch 150/10000 - Train Loss: 0.6847 - Val Precision: 0.4900 - Val Recall: 0.4900 - Val F1: 0.4900 - LR: 0.01
# Epoch 160/10000 - Train Loss: 0.6844 - Val Precision: 0.4900 - Val Recall: 0.4900 - Val F1: 0.4900 - LR: 0.01
# Epoch 170/10000 - Train Loss: 0.6840 - Val Precision: 0.4900 - Val Recall: 0.4900 - Val F1: 0.4900 - LR: 0.01
# Epoch 180/10000 - Train Loss: 0.6836 - Val Precision: 0.4900 - Val Recall: 0.4900 - Val F1: 0.4900 - LR: 0.01
# Epoch 190/10000 - Train Loss: 0.6831 - Val Precision: 0.4900 - Val Recall: 0.4900 - Val F1: 0.4900 - LR: 0.01
# Epoch 200/10000 - Train Loss: 0.6824 - Val Precision: 0.4900 - Val Recall: 0.4900 - Val F1: 0.4900 - LR: 0.01
# Epoch 210/10000 - Train Loss: 0.6816 - Val Precision: 0.4900 - Val Recall: 0.4900 - Val F1: 0.4900 - LR: 0.01
# Epoch 220/10000 - Train Loss: 0.6806 - Val Precision: 0.4900 - Val Recall: 0.4900 - Val F1: 0.4900 - LR: 0.01
# Epoch 230/10000 - Train Loss: 0.6793 - Val Precision: 0.4900 - Val Recall: 0.4900 - Val F1: 0.4900 - LR: 0.01
# Epoch 240/10000 - Train Loss: 0.6777 - Val Precision: 0.4900 - Val Recall: 0.4900 - Val F1: 0.4900 - LR: 0.01
# Epoch 250/10000 - Train Loss: 0.6756 - Val Precision: 0.4900 - Val Recall: 0.4900 - Val F1: 0.4900 - LR: 0.01
# Epoch
- Val Precision: 0.4950 - Val Recall: 0.4950 - Val F1: 0.4950 - LR: 5e-05
# Epoch 970/10000 - Train Loss: 0.6511 - Val Precision: 0.4950 - Val Recall: 0.4950 - Val F1: 0.4950 - LR: 5e-05
# Epoch 980/10000 - Train Loss: 0.6508 - Val Precision: 0.4950 - Val Recall: 0.4950 - Val F1: 0.4950 - LR: 5e-05
# Epoch 990/10000 - Train Loss: 0.6505 - Val Precision: 0.4950 - Val Recall: 0.4950 - Val F1: 0.4950 - LR: 5e-05
# Epoch 1000/10000 - Train Loss: 0.6502 - Val Precision: 0.4950 - Val Recall: 0.4950 - Val F1: 0.4950 - LR: 5e-05
# Epoch 1010/10000 - Train Loss: 0.6500 - Val Precision: 0.4950 - Val Recall: 0.4950 - Val F1: 0.4950 - LR: 5e-05
# Epoch 1020/10000 - Train Loss: 0.6497 - Val Precision: 0.4950 - Val Recall: 0.4950 - Val F1: 0.4950 - LR: 5e-05
# Epoch 1030/10000 - Train Loss: 0.6494 - Val Precision: 0.4950 - Val Recall: 0.4950 - Val F1: 0.4950 - LR: 5e-06
# [VAL] Prec=0.5000, Rec=0.5000, F1=0.5000

# %%
# Convert results into a DataFrame
df = pd.DataFrame(results)

# Plot Train F1-Scores
heatmap_data = df.pivot(index="learning_rate", columns="hidden_dim", values="f1")

plt.figure(figsize=(8, 6))
sns.heatmap(heatmap_data, annot=True, cmap="viridis", fmt=".3f")

plt.xlabel("Hidden Dimension Size")
plt.ylabel("Learning Rate")
plt.title("Validation F1-Score Heatmap")

plt.show()

# %% [markdown]
# ## Question 2.4 Exploring Attention
# In this question, you will explore the attention-based aggregation mechanism in GNNs. Attention-based aggregation is explained in [Lecture 3.5](https://www.youtube.com/watch?v=zRmzVkidkqA&list=PLug43ldmRSo14Y_vt7S6vanPGh-JpHR7T&index=14).
#
# - Implement an attention-based aggregation mechanism for binary node classification using GCNs.
# - Limit your model to **two layers**, as in Question 2.2 and Question 2.3
# - Base your implementation on the naive padding approach introduced in Question 2.2
# - **Do not** implement a node-type aware special design as in Question 2.3
# - Your implementation must achieve a better **validation F1 score** compared to the naive GCN in Question 2.2
# - Determine the optimal hyperparameters for your model, such as hidden dimensions, learning rate, scheduler patience, etc. These hyperparameters do not need to match those of the previous models, as each design has its own optimal configuration. Explain your hyperparameter tuning process **in detail** in your report.

# %%
# ####################################################
# MODIFY THE CODE BELOW 
# ####################################################

class GraphAttentionNetwork(nn.Module):
    pass

# ####################################################
# END OF MODIFICATION
# ####################################################

# %%
set_seed(SEED)

# Naively pad
X_train, d_max_train = pad_features(A_train, X1_train, X2_train, mapping_train)
X_val,   d_max_val   = pad_features(A_val,   X1_val,   X2_val,   mapping_val)

print("Train adjacency:", A_train.shape)
print("Train features after padding:", X_train.shape, "with d_max =", d_max_train)
print("Val adjacency:", A_val.shape)
print("Val features after padding:", X_val.shape, "with d_max =", d_max_val)

# Convert labels to float if using BCE with sigmoid
y_train = y_train.float()  # shape (N,)
y_val   = y_val.float()


# ####################################################
# MODIFY THE CODE BELOW 
# ####################################################

# Build the model
attn_gnn = GraphAttentionNetwork(...)

# Train
loss_history, _ = train_model(attn_gnn, y_train, val_model_inputs={...}, y_val=y_val, ...)

# ####################################################
# END OF MODIFICATION
# ####################################################

# Test on validation data
val_prec, val_rec, val_f1, _ = evaluate_model(attn_gnn, y_val, ...)
print(f"[VAL] Prec={val_prec:.4f}, Rec={val_rec:.4f}, F1={val_f1:.4f}")

val_precs["Naive GAT"] = val_prec
val_recs["Naive GAT"] = val_rec
val_f1s["Naive GAT"] = val_f1

# Plot loss
plot_loss(loss_history, title="GAT Naive Approach Training Loss")
# Out:
#   Cell In[21], line 25
#     loss_history, _ = train_model(attn_gnn, y_train, val_model_inputs={...}, y_val=y_val, ...)
#                                                                                              ^
# SyntaxError: positional argument follows keyword argument

# %% [markdown]
# ## Question 2.5 Discussion
#
# In your report, include the bar plot comparing the **precision, recall, and F1 scores** of the three models, generated using the following function call. Explain your results in your report.

# %%
plot_results(val_precs, val_recs, val_f1s)
