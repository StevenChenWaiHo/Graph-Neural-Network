# %% [markdown]
# # Question 3: Investigating Topology in Node-Based Classification Using GNNs
#
# In this section, we will explore the impact of graph topology on node-based classification using GNNs. The experiments will focus on analyzing different topological measures, visualizing their distributions, and evaluating GCN performance on 2 graphs with different topologies.

# %%
import json
import torch
import os
import random
import torch.nn as nn
import torch.optim as optim
import torch.nn.functional as F
import networkx as nx
import numpy as np
from sklearn.metrics import precision_score, recall_score, f1_score
import matplotlib.pyplot as plt
from graph_ricci_curvature import GraphRicciCurvature

# %% [markdown]
# ## Helper function and code for loading data

# %%
G1_TRAIN_FILE_NAME = "q3_G1_train.json"
G1_EVAL_FILE_NAME = "q3_G1_eval.json"

G1_TRAIN_DATA_PATH = os.path.join("data",G1_TRAIN_FILE_NAME)
G1_EVAL_DATA_PATH = os.path.join("data",G1_EVAL_FILE_NAME)

G2_TRAIN_FILE_NAME = "q3_G2_train.json"
G2_EVAL_FILE_NAME = "q3_G2_eval.json"

G2_TRAIN_DATA_PATH = os.path.join("data",G2_TRAIN_FILE_NAME)
G2_EVAL_DATA_PATH = os.path.join("data",G2_EVAL_FILE_NAME)

# %%
# Functions to load the data
def create_Adj_matrix(N, edge_index):
    """Creates the adjacency matrix"""
    A = torch.zeros((N, N), dtype=torch.float)
    for idx, jdx in edge_index:
        A[idx, jdx] = 1
        A[jdx, idx] = 1
    return A

def read_json_data(file_path, has_label=True):
    with open(file_path, 'r') as f:
        data = json.load(f)
    
    if not type(data) == list:
        item = data
        X = torch.tensor(item['features'], dtype=torch.float)
        N = len(X)
        A = create_Adj_matrix(N, item['edge_index'])
        if has_label:
            y = torch.tensor(item['label'], dtype=torch.long)
        else:
            y = None
        return (X,A,y)

    graph_data = []
    for item in data:
        X = torch.tensor(item['features'], dtype=torch.float)
        N = len(X)
        A = create_Adj_matrix(N, item['edge_index'])
        if has_label:
            y = torch.tensor(item['label'], dtype=torch.long)
        else:
            y = None
        
        graph_data.append((X,A,y))
    
    return graph_data

# %% [markdown]
# ## Question 3.1 - Analyzing the Graphs

# %% [markdown]
# ### Q3.1.b Visualizing and Comparing Topological and Geometric Measures of Two Graphs
#
# Implement the following three functions to visualize and compare structural properties of two given graphs:
#
# - `plot_node_degree_distribution_two_graphs`
# - `plot_betweenness_centrality_distribution_two_graphs`
# - `plot_ollivier_ricci_curvature_distribution_two_graphs`

# %%
def compute_node_degree(A):
    """
    Given an adjacency matrix A of shape (N, N),
    return the degree (row sum) for each of the N nodes.
    """
    degrees = A.sum(dim=1)  # sum across columns
    return degrees

# ####################################################
# MODIFY THE CODE BELOW 
# ####################################################  


def plot_node_degree_distribution_two_graphs(A1, A2):
    """
    Plots the node degree distributions of two graphs
    with adjacency matrices A1 and A2 (each of shape (N, N))
    in a single figure.
    
    """
    # Compute node degrees
    degrees_G1 = compute_node_degree(A1).numpy()
    degrees_G2 = compute_node_degree(A2).numpy()

    # Plot the distributions
    plt.figure(figsize=(12, 6))
    plt.hist(degrees_G1, bins=30, alpha=0.5, label='Graph 1')
    plt.hist(degrees_G2, bins=30, alpha=0.5, label='Graph 2')
    plt.xlabel('Node Degree')
    plt.ylabel('Frequency')
    plt.title('Node Degree Distribution')
    plt.legend()
    plt.show()

# %%
# ####################################################
# MODIFY THE CODE BELOW 
# ####################################################  

def plot_betweenness_distribution_two_graphs(A1, A2):
    """
    Plots the betweenness centrality distributions of two graphs
    defined by adjacency matrices A1 and A2 (each of shape (N, N)) 
    in a single figure.
    """
    # Convert PyTorch adjacency -> NumPy -> NetworkX Graph
    A1_np = A1.numpy()
    A2_np = A2.numpy()

    G1 = nx.from_numpy_array(A1_np)
    G2 = nx.from_numpy_array(A2_np)

    # Compute betweenness centrality for each graph
    betweenness_G1 = nx.betweenness_centrality(G1)
    betweenness_G2 = nx.betweenness_centrality(G2)

    # Extract betweenness centrality values
    betweenness_values_G1 = list(betweenness_G1.values())
    betweenness_values_G2 = list(betweenness_G2.values())

    # Plot the distributions
    plt.figure(figsize=(12, 6))
    plt.hist(betweenness_values_G1, bins=30, alpha=0.5, label='Graph 1')
    plt.hist(betweenness_values_G2, bins=30, alpha=0.5, label='Graph 2')
    plt.xlabel('Betweenness Centrality')
    plt.ylabel('Frequency')
    plt.title('Betweenness Centrality Distribution')
    plt.legend()
    plt.show()

# %%
# ####################################################
# MODIFY THE CODE BELOW 
# ####################################################  

def plot_ricci_curvature_distribution_two_graphs(A1, A2):
    """
    Plots the Ollivier-Ricci curvature distributions for two graphs
    defined by adjacency matrices A1 and A2 (PyTorch tensors).
    
    Parameters
    ----------
    A1, A2 : torch.Tensor
        Adjacency matrices for two undirected graphs (NxN).
    """
    # 1) Convert PyTorch adjacency -> NumPy -> NetworkX Graph
    A1_np = A1.numpy()
    A2_np = A2.numpy()

    G1 = nx.from_numpy_array(A1_np)
    G2 = nx.from_numpy_array(A2_np)

    # 2) Instantiate OllivierRicci object for each graph
    ricci_calculator_G1 = GraphRicciCurvature(G1)
    ricci_calculator_G2 = GraphRicciCurvature(G2)

    # 3) Compute the Ricci curvature
    curvatures1 = ricci_calculator_G1.compute_ricci_curvatures()
    curvatures2 = ricci_calculator_G2.compute_ricci_curvatures()

    # After computation, the Ricci curvature for each edge is stored in G[u][v]["ricciCurvature"]

    # 4) Gather edge-level Ricci curvature values
    ricci_values_G1 = []
    for (u, v), val in curvatures1.items():
        ricci_values_G1.append(val)

    ricci_values_G2 = []
    for (u, v), val in curvatures2.items():
        ricci_values_G2.append(val)

    # Continue with plotting ...

    # Plot the distributions
    plt.figure(figsize=(12, 6))
    plt.hist(ricci_values_G1, bins=30, alpha=0.5, label='Graph 1')
    plt.hist(ricci_values_G2, bins=30, alpha=0.5, label='Graph 2')
    plt.xlabel('Ollivier-Ricci Curvature')
    plt.ylabel('Frequency')
    plt.title('Ollivier-Ricci Curvature Distribution')
    plt.legend()
    plt.show()

# %%
G1_train = read_json_data(G1_TRAIN_DATA_PATH, has_label=True) #returns a list of (X,A,y) - features, Adj Matrix, per Graph label
G2_train = read_json_data(G2_TRAIN_DATA_PATH, has_label=True) #returns a list of (X,A,y) - features, Adj Matrix, per Graph label

# %%
plot_node_degree_distribution_two_graphs(G1_train[1], G2_train[1])

# %%
plot_betweenness_distribution_two_graphs(G1_train[1], G2_train[1])

# %%
plot_ricci_curvature_distribution_two_graphs(G1_train[1], G2_train[1])

# %% [markdown]
# ### Q3.1.c Visualizing the Graphs
#
# Implement the `plot_graph` function to generate visual representations of both graphs. Ensure that the plots are clear and well-formatted.

# %%
def plot_graph(A):
    """
    Plots a graph defined by adjacency matrix A.
    Parameters
    ----------
    A : torch.Tensor
        Adjacency matrix of shape (N, N).
    """
    # Convert PyTorch adjacency matrix to NumPy array
    A_np = A.numpy()

    # Create a NetworkX graph from the adjacency matrix
    G = nx.from_numpy_array(A_np)

    # Draw the graph
    plt.figure(figsize=(8, 8))
    pos = nx.spring_layout(G)  # positions for all nodes
    nx.draw(G, pos, with_labels=True, node_color='skyblue', edge_color='gray', node_size=500, font_size=10)
    plt.title('Graph Visualization')
    plt.show()

# %%
plot_graph(G1_train[1])

# %%
plot_graph(G2_train[1])

# %% [markdown]
# ### Q3.1.d Visualizing Node Feature Distributions
#
# - Implement the function `plot_node_feature_dist_by_class_two_graphs` to visualize the average node feature distribution per class for two given graphs.
#
# - Do not consider the distribution of a specific feature $ x_i $, consider the mean of the feature vector $ \mathbf{x} $ for each node.
#
# - The function should generate a plot similar to Figure 3 in the Coursework Desciription PDF.

# %%
def plot_node_feature_dist_by_class_two_graphs(Xa, ya, Xb, yb):
    """
    Plots the distribution of the average node features by class for two graphs.

    """

    Xa = Xa.cpu().numpy()
    Xb = Xb.cpu().numpy()
    ya = ya.cpu().numpy()
    yb = yb.cpu().numpy()

     # Calculate the average feature
    average_A = np.mean(Xa, axis=1)
    average_B = np.mean(Xb, axis=1)

    class_0_A = average_A[ya == 0]
    class_1_A = average_A[ya == 1]
    class_0_B = average_B[yb == 0]
    class_1_B = average_B[yb == 1]

    # Plot the distributions for graph A and B as overlapping bar graphs
    fig, axes = plt.subplots(1, 2, figsize=(10, 6))

    axes[0].hist(class_0_A, alpha=0.5, bins=25, label="Class 0", color="blue")
    axes[0].hist(class_1_A, alpha=0.5, bins=25, label="Class 1", color="orange")

    axes[1].hist(class_0_B, alpha=0.5, bins=25, label="Class 0", color="blue")
    axes[1].hist(class_1_B, alpha=0.5, bins=25, label="Class 1", color="orange")

    # Set Titles and Labels
    axes[0].set_title("Average Feature Distribution of Graph 1")
    axes[0].set_xlabel("Mean Feature Value")
    axes[0].set_ylabel("Count")
    axes[0].legend()

    axes[1].set_title("Average Feature Distribution of Graph 2")
    axes[1].set_xlabel("Mean Feature Value")
    axes[1].set_ylabel("Count")
    axes[1].legend()

    plt.tight_layout()
    plt.show()

# %%
X1, A1, y1 = G1_train
X2, A2, y2 = G2_train
plot_node_feature_dist_by_class_two_graphs(X1, y1, X2, y2)

# %% [markdown]
# ## Question 3.2 -  Evaluating GCN Performance on Different Graph Structures

# %% [markdown]
# ### Helper functions for normalising the A matrix.

# %%
# Helper function to normalise the A matrix
def symmetric_normalize(A_tilde):
    """
    Performs symmetric normalization of A_tilde (Adj. matrix with self loops):
      A_norm = D^{-1/2} * A_tilde * D^{-1/2}
    Where D_{ii} = sum of row i in A_tilde.

    A_tilde (N, N): Adj. matrix with self loops
    Returns:
      A_norm : (N, N)
    """

    eps = 1e-5
    d = A_tilde.sum(dim=1) + eps
    D_inv = torch.diag(torch.pow(d, -0.5))
    return D_inv @ A_tilde @ D_inv


def patch_A_matrix(A):
    """Patches the A matrix"""
    A = A + torch.eye(A.size(0))
    A = symmetric_normalize(A)
    return A

def patch_A_for_dataset(dataset):
    """Patches the A matrix for a dataset (list)"""
    dataset = [ (X, patch_A_matrix(A), y) for X,A,y in dataset]
    return dataset

# %% [markdown]
# ### Helper function for plotting training runs.

# %%
# Helper function for plotting:

def plot_training_and_validation(training_losses, validation_losses, aggregation="mean", graph1_label="Training Accuracy", graph2_label="Validation Accuracy", x_label="Epoch",title=None):
    """
    Plots the validation accuracy and training loss over epochs.
    Args:
        validation_losses: List of validation accuracies (or losses)
        training_losses: List of training accuracies (or losses)
        aggregation: Aggregation method used (default: "mean")
    """
    plt.figure(figsize=(10, 6))
    
    # Create figure with two y-axes
    fig, ax1 = plt.subplots(figsize=(10, 6))
    ax2 = ax1.twinx()
    
    # Plot training loss on the first y-axis
    epochs = range(1, len(training_losses) + 1)
    line1 = ax1.plot(epochs, training_losses, 'r-', label=f'{graph1_label}')
    ax1.set_xlabel(f"x_label")
    ax1.set_ylabel(f'{graph1_label}', color='r')
    ax1.tick_params(axis='y', labelcolor='r')
    
    # Plot validation accuracy on the second y-axis
    line2 = ax2.plot(epochs, validation_losses, 'b-', label=f'{graph2_label}')
    ax2.set_ylabel(f'{graph2_label}', color='b')
    ax2.tick_params(axis='y', labelcolor='b')
    
    # Add title and grid
    if not title:
        title = f'Training Accuracy and Validation Accuracy Over Time\nAggregation: {aggregation}'
    plt.title(title)

    ax1.grid(True)
    
    # Add legend
    lines = line1 + line2
    labels = [l.get_label() for l in lines]
    ax1.legend(lines, labels, loc='upper right')
    
    plt.tight_layout()
    plt.show()

# %% [markdown]
# ### Provided GCN Code

# %%
#Provided GCN Implementation
class GCNLayer(nn.Module):
    """
    A single layer of a Graph Convolutional Network (GCN).
    """
    def __init__(self, input_dim, output_dim, use_nonlinearity=True):
        super(GCNLayer, self).__init__()
        self.use_nonlinearity = use_nonlinearity
        self.Omega = nn.Parameter(torch.randn(input_dim, output_dim) * torch.sqrt(torch.tensor(2.0) / (input_dim + output_dim)))
        self.beta = nn.Parameter(torch.zeros(output_dim))

    def forward(self, H_k, A_normalized):
        agg = torch.matmul(A_normalized, H_k) # local agg
        H_k_next = torch.matmul(agg, self.Omega) + self.beta
        return F.relu(H_k_next) if self.use_nonlinearity else H_k_next

class GraphNeuralNetwork(nn.Module):
    """
    A simple Graph Neural Network model using two layers of Graph Convolutional Network (GCN)
    for binary classification. The sigmoid activation is applied in the output layer only if
    use_nonlinearity is set to True.
    """
    def __init__(self, input_dim, hidden_dim):
        super(GraphNeuralNetwork, self).__init__()

        # Define GCN layers
        self.gcn1 = GCNLayer(input_dim, hidden_dim, True)
        self.gcn2 = GCNLayer(hidden_dim, 1, False)

    def forward(self, A, X, **kwargs):
        # Pass through GCN layers
        H1 = self.gcn1(X, A)
        H2 = self.gcn2(H1, A)  # Output shape: (num_nodes, 1)

        output = torch.sigmoid(H2)  # Sigmoid activation per node
        if torch.isnan(output).any():
            output = torch.where(torch.isnan(output), torch.zeros_like(output), output)

        if kwargs.get("return_embeddings", None):
            return output, (H1, H2)
        else:
            return output

# %% [markdown]
# ### Helper functions for training GCN on a graph

# %%
import torch
import torch.optim as optim
import torch.nn as nn
from torch.nn.functional import binary_cross_entropy
from sklearn.metrics import accuracy_score, classification_report,precision_recall_fscore_support

def train_model(
    model,
    G_train,
    G_val,
    num_epochs=10,
    lr=0.0001,
    verbose=True,
    **kwargs,
):
    """
    Train the model, validate every 'validate_every' epochs, and pick the 
    checkpoint with best validation accuracy.

    Parameters:
    -----------
    model : torch.nn.Module
        The PyTorch model to train.
    G_train  = (X_train,A_train,y_train) : input
        the Graph 1
    Y_train = (X_val,A_val,y_val)
        the Graph 2
    num_epochs : int
        Number of training epochs.
    lr : float
        Learning rate for the optimizer.
    verbose: bool
        whether to display the loss, f1 and val_f1


    Returns:
    --------
    loss_history : list
        The training loss history across epochs.
    f1_train_history : list
        train F1s during training
    f1_val_history : list
        val F1s during training
    """
    X_train, A_train, y_train = G_train
    X_val, A_val, y_val = G_val

    model.train()
    optimizer = optim.AdamW(model.parameters(), lr=lr)
    loss_history = []
    train_f1_history = []
    validation_f1_history = []

    for epoch in range(num_epochs):
        # A single Epoch training.
        # TRAINING
        model.train()
        optimizer.zero_grad()
        if kwargs.get("return_embeddings", None):
            out, embeddings= model(A_train, X_train, **kwargs)
        else:
            out = model(A_train, X_train, **kwargs)
        out = out.squeeze(-1)  # shape: (N,) if needed
        y_float = y_train.float()  # for BCE

        # Compute training loss
        loss = binary_cross_entropy(out, y_float)
        loss.backward()

        # torch.nn.utils.clip_grad_norm_(model.parameters(), max_norm=1.0)
        optimizer.step()

        # Record training loss
        loss_value = loss.item()
        
        # EVALUATION
        loss_history.append(loss_value)
        train_prec, train_rec, train_f1, _ = evaluate_model(model, X_train, A_train, y_train)
        val_prec, val_rec, val_f1, _ = evaluate_model(model,  X_val, A_val, y_val)

        train_f1_history.append(train_f1)
        validation_f1_history.append(val_f1)                     
        # Evaluating the model
        if verbose:
            print(f"Epoch {epoch+1}, Training Loss: {loss_value}, Train F1: {train_f1:.4f}, Validation F1: {val_f1:.4f}")
            
    if kwargs.get("return_embeddings", None):
        return loss_history, train_f1_history, validation_f1_history, embeddings
    else:
        return loss_history, train_f1_history, validation_f1_history


@torch.no_grad()
def evaluate_model(model, X,A,y, **kwargs):
    """
    Runs forward pass, calculates binary predictions (threshold=0.5),
    and returns the accuracy score.
    """
    model.eval()
    if kwargs.get("return_embeddings", None):
        out,_ = model(A,X,**kwargs)  # shape: (N, 1)
    else:
        out = model(A,X,**kwargs)  # shape: (N, 1)
    out = out.squeeze(-1)  # shape: (N,)
    preds = (out >= 0.5).long()

    y_true = y.cpu().numpy()
    y_pred = preds.cpu().numpy()

    return precision_recall_fscore_support(y_true, y_pred, average="micro")

# %% [markdown]
# ### Q3.2.a - Implementation of Layered GCN
#
#
# • Implement a GCN where layers can be passed as input parameter and that can return all
# embedding layers. (If you will not be able to do so, to get results implement one class per
# layer).
#
# • Train the GCN on G1 and G2 independently. Plot your results. (Note: you don’t need to
# get a high performance at this stage, just make sure it trains).

# %%
# SOLUTION Q3.2.a
# ####################################################
# MODIFY THE CODE BELOW 
# ####################################################  
class LayeredGCN(nn.Module):
    """
    A simple Graph Neural Network model using two layers of Graph Convolutional Network (GCN)
    for binary classification. The sigmoid activation is applied in the output layer only if
    use_nonlinearity is set to True.
    """
    def __init__(self, input_dim, hidden_dim, num_layers=2, output_dim=2):
        super(LayeredGCN, self).__init__()
        self.num_layers = num_layers
        self.layers = nn.ModuleList()
        
        # Input layer
        self.layers.append(GCNLayer(input_dim, hidden_dim, True))
        
        # Hidden layers
        for _ in range(num_layers - 2):
            self.layers.append(GCNLayer(hidden_dim, hidden_dim, True))
        
        # Final layer
        self.layers.append(GCNLayer(hidden_dim, output_dim, True))

        self.output_layer = GCNLayer(output_dim, 1, False)

    def forward(self, A, X, **kwargs):

        # Forward pass through each layer
        graph_embedding = []
        H = X
        for layer in self.layers:
            H = layer(H, A)
            graph_embedding.append(H)

        H = self.output_layer(H, A)

        # Sigmoid activation
        graph_output = torch.sigmoid(H)

        if kwargs.get("return_embeddings", None):
            return graph_output, graph_embedding
        else:
            return graph_output

# ####################################################
# END OF MODIFICATION
# ####################################################

# %% [markdown]
# ### Code to run the training and evaluation of the model with different number of layers.
#
# Adapt it as needed.

# %%
SEED = 42

def set_seed(seed=42):
    random.seed(seed)
    np.random.seed(seed)
    torch.manual_seed(seed)
    if torch.cuda.is_available():
        torch.cuda.manual_seed_all(seed)

    torch.backends.cudnn.deterministic = True
    torch.backends.cudnn.benchmark = False
    
set_seed(SEED)

# Load data
G1_train = read_json_data(G1_TRAIN_DATA_PATH, has_label=True) #returns a list of (X,A,y) - features, Adj Matrix, per Graph label
G1_eval = read_json_data(G1_EVAL_DATA_PATH, has_label=True) #returns a list of (X,A,y) - features, Adj Matrix, per Graph label

G2_train = read_json_data(G2_TRAIN_DATA_PATH, has_label=True) #returns a list of (X,A,y) - features, Adj Matrix, per Graph label
G2_eval = read_json_data(G2_EVAL_DATA_PATH, has_label=True) #returns a list of (X,A,y) - features, Adj Matrix, per Graph label


# Patch A
G1_train = (G1_train[0], patch_A_matrix(G1_train[1]), G1_train[2])
G1_eval = (G1_eval[0], patch_A_matrix(G1_eval[1]), G1_eval[2])

G2_train = (G2_train[0], patch_A_matrix(G2_train[1]), G2_train[2])
G2_eval = (G2_eval[0], patch_A_matrix(G2_eval[1]), G2_eval[2])

# Initialising the model
input_dim = 10
hidden_dim = 8
num_layers = 4
model = LayeredGCN(input_dim, hidden_dim, num_layers=num_layers)
print(model)

losses, train_f1, val_f1 = train_model(
    model,
    G1_train,
    G1_eval,
    num_epochs=200,
    lr=0.0005,
    verbose=True,
)
plot_training_and_validation(losses, val_f1, graph1_label="Training Loss", graph2_label="Validation F1-score", title="Training Loss and Validation F1 Over Time for Graph 1", x_label="Epoch")


model = LayeredGCN(input_dim, hidden_dim, num_layers=num_layers)
print(model)

losses, train_f2, val_f2 = train_model(
    model,
    G2_train,
    G2_eval,
    num_epochs=200,
    lr=0.0005,
    verbose=True,
)
plot_training_and_validation(losses, val_f2, graph1_label="Training Loss", graph2_label="Validation F1-score", title="Training Loss and Validation F1 Over Time for Graph 2", x_label="Epoch")
# Out:
# LayeredGCN(
#   (layers): ModuleList(
#     (0-3): 4 x GCNLayer()
#   )
#   (output_layer): GCNLayer()
# )
# Epoch 1, Training Loss: 0.6889723539352417, Train F1: 0.5375, Validation F1: 0.5000
# Epoch 2, Training Loss: 0.6887275576591492, Train F1: 0.5375, Validation F1: 0.5000
# Epoch 3, Training Loss: 0.6884824633598328, Train F1: 0.5375, Validation F1: 0.5000
# Epoch 4, Training Loss: 0.6882367730140686, Train F1: 0.5375, Validation F1: 0.5000
# Epoch 5, Training Loss: 0.6879923343658447, Train F1: 0.5375, Validation F1: 0.5000
# Epoch 6, Training Loss: 0.6877485513687134, Train F1: 0.5375, Validation F1: 0.5000
# Epoch 7, Training Loss: 0.6875083446502686, Train F1: 0.5375, Validation F1: 0.5000
# Epoch 8, Training Loss: 0.6872689723968506, Train F1: 0.5375, Validation F1: 0.5000
# Epoch 9, Training Loss: 0.6870294809341431, Train F1: 0.5375, Validation F1: 0.5000
# Epoch 10, Training Loss: 0.6867897510528564, Train F1: 0.5375, Validation F1: 0.5000
# Epoch 11, Training Loss: 0.686551034450531, Train F1: 0.5375, Validation F1: 0.5000
# Epoch 12, Training Loss: 0.6863108277320862, Train F1: 0.5375, Validation F1: 0.5000
# Epoch 13, Training Loss: 0.6860705018043518, Train F1: 0.5375, Validation F1: 0.5000
# Epoch 14, Training Loss: 0.6858289837837219, Train F1: 0.5375, Validation F1: 0.5000
# Epoch 15, Training Loss: 0.6855853796005249, Train F1: 0.5375, Validation F1: 0.5000
# Epoch 16, Training Loss: 0.6853400468826294, Train F1: 0.5375, Validation F1: 0.5000
# Epoch 17, Training Loss: 0.685092568397522, Train F1: 0.5375, Validation F1: 0.5000
# Epoch 18, Training Loss: 0.6848427057266235, Train F1: 0.5375, Validation F1: 0.5000
# Epoch 19, Training Loss: 0.6845913529396057, Train F1: 0.5375, Validation F1: 0.5000
# Epoch 20, Training Loss: 0.6843388676643372, Train F1: 0.5375, Validation F1: 0.5000
# Epoch 21, Training Loss: 0.684085488319397, Train F1: 0.5375, Validation F1: 0.5000
# Epoch 22, Training Loss: 0.6838303208351135, Train F1: 0.5375, Validation F1: 0.5000
# Epoch 23, Training Loss: 0.6835728287696838, Train F1: 0.5375, Validation F1: 0.5000
# Epoch 24, Training Loss: 0.6833131909370422, Train F1: 0.5375, Validation F1: 0.5000
# Epoch 25, Training Loss: 0.6830517053604126, Train F1: 0.5375, Validation F1: 0.5000
# Epoch 26, Training Loss: 0.682788074016571, Train F1: 0.5375, Validation F1: 0.5000
# Epoch 27, Training Loss: 0.6825233697891235, Train F1: 0.5375, Validation F1: 0.5000
# Epoch 28, Training Loss: 0.6822565197944641, Train F1: 0.5375, Validation F1: 0.5000
# Epoch 29, Training Loss: 0.681986927986145, Train F1: 0.5375, Validation F1: 0.5000
# Epoch 30, Training Loss: 0.681714653968811, Train F1: 0.5375, Validation F1: 0.5000
# Epoch 31, Training Loss: 0.6814390420913696, Train F1: 0.5375, Validation F1: 0.5000
# Epoch 32, Training Loss: 0.6811603903770447, Train F1: 0.5375, Validation F1: 0.5000
# Epoch 33, Training Loss: 0.6808789968490601, Train F1: 0.5375, Validation F1: 0.5000
# Epoch 34, Training Loss: 0.6805943250656128, Train F1: 0.5375, Validation F1: 0.5000
# Epoch 35, Training Loss: 0.6803062558174133, Train F1: 0.5375, Validation F1: 0.5000
# Epoch 36, Training Loss: 0.6800144910812378, Train F1: 0.5375, Validation F1: 0.5000
# Epoch 37, Training Loss: 0.6797195672988892, Train F1: 0.5375, Validation F1: 0.5000
# Epoch 38, Training Loss: 0.6794204115867615, Train F1: 0.5375, Validation F1: 0.5000
# Epoch 39, Training Loss: 0.6791169047355652, Train F1: 0.5375, Validation F1: 0.5000
# Epoch 40, Training Loss: 0.6788092255592346, Train F1: 0.5375, Validation F1: 0.5000
# Epoch 41, Training Loss: 0.6784964203834534, Train F1: 0.5375, Validation F1: 0.5000
# Epoch 42, Training Loss: 0.6781781315803528, Train F1: 0.5375, Validation F1: 0.5000
# Epoch 43, Training Loss: 0.6778534650802612, Train F1: 0.5375, Validation F1: 0.5000
# Epoch 44, Training Loss: 0.6775237321853638, Train F1: 0.5375, Validation F1: 0.5000
# Epoch 45, Training Loss: 0.6771878004074097, Train F1: 0.5375, Validation F1: 0.5000
# Epoch 46, Training Loss: 0.6768465042114258, Train F1: 0.5375, Validation F1: 0.5000
# Epoch 47, Training Loss: 0.6765012741088867, Train F1: 0.5375, Validation F1: 0.5000
# Epoch 48, Training Loss: 0.6761511564254761, Train F1: 0.5375, Validation F1: 0.5000
# Epoch 49, Training Loss: 0.6757966876029968, Train F1: 0.5375, Validation F1: 0.5000
# Epoch 50, Training Loss: 0.6754368543624878, Train F1: 0.5375, Validation F1: 0.5000
# Epoch 51, Training Loss: 0.6750710606575012, Train F1: 0.5375, Validation F1: 0.5000
# Epoch 52, Training Loss: 0.6746994853019714, Train F1: 0.5375, Validation F1: 0.5000
# Epoch 53, Training Loss: 0.674322247505188, Train F1: 0.5375, Validation F1: 0.5000
# Epoch 54, Training Loss: 0.673940122127533, Train F1: 0.5375, Validation F1: 0.5000
# Epoch 55, Training Loss: 0.6735522150993347, Train F1: 0.5375, Validation F1: 0.5000
# Epoch 56, Training Loss: 0.673158586025238, Train F1: 0.5375, Validation F1: 0.5000
# Epoch 57, Training Loss: 0.672758162021637, Train F1: 0.5375, Validation F1: 0.5000
# Epoch 58, Training Loss: 0.6723495125770569, Train F1: 0.5375, Validation F1: 0.5000
# Epoch 59, Training Loss: 0.6719352602958679, Train F1: 0.5375, Validation F1: 0.5000
# Epoch 60, Training Loss: 0.6715148091316223, Train F1: 0.5375, Validation F1: 0.5000
# Epoch 61, Training Loss: 0.6710874438285828, Train F1: 0.5375, Validation F1: 0.5000
# Epoch 62, Training Loss: 0.6706538200378418, Train F1: 0.5375, Validation F1: 0.5000
# Epoch 63, Training Loss: 0.6702144742012024, Train F1: 0.5375, Validation F1: 0.5000
# Epoch 64, Training Loss: 0.6697695255279541, Train F1: 0.5375, Validation F1: 0.5000
# Epoch 65, Training Loss: 0.6693188548088074, Train F1: 0.5375, Validation F1: 0.5000
# Epoch 66, Training Loss: 0.6688609719276428, Train F1: 0.5375, Validation F1: 0.5000
# Epoch 67, Training Loss: 0.6683958768844604, Train F1: 0.5375, Validation F1: 0.5000
# Epoch 68, Training Loss: 0.6679223775863647, Train F1: 0.5375, Validation F1: 0.5000
# Epoch 69, Training Loss: 0.6674408316612244, Train F1: 0.5375, Validation F1: 0.5000
# Epoch 70, Training Loss: 0.6669515371322632, Train F1: 0.5375, Validation F1: 0.5000
# Epoch 71, Training Loss: 0.6664553284645081, Train F1: 0.5375, Validation F1: 0.5000
# Epoch 72, Training Loss: 0.6659528017044067, Train F1: 0.5375, Validation F1: 0.5000
# Epoch 73, Training Loss: 0.6654438972473145, Train F1: 0.5375, Validation F1: 0.5000
# Epoch 74, Training Loss: 0.6649256348609924, Train F1: 0.5375, Validation F1: 0.5000
# Epoch 75, Training Loss: 0.6643990278244019, Train F1: 0.5375, Validation F1: 0.5000
# Epoch 76, Training Loss: 0.6638657450675964, Train F1: 0.5375, Validation F1: 0.5000
# Epoch 77, Training Loss: 0.6633272767066956, Train F1: 0.5375, Validation F1: 0.5000
# Epoch 78, Training Loss: 0.6627829074859619, Train F1: 0.5375, Validation F1: 0.5000
# Epoch 79, Training Loss: 0.6622298955917358, Train F1: 0.5375, Validation F1: 0.5000
# Epoch 80, Training Loss: 0.6616686582565308, Train F1: 0.5375, Validation F1: 0.5000
# Epoch 81, Training Loss: 0.661101222038269, Train F1: 0.5375, Validation F1: 0.5000
# Epoch 82, Training Loss: 0.6605223417282104, Train F1: 0.5375, Validation F1: 0.5000
# Epoch 83, Training Loss: 0.6599340438842773, Train F1: 0.5375, Validation F1: 0.5000
# Epoch 84, Training Loss: 0.659338116645813, Train F1: 0.5375, Validation F1: 0.5000
# Epoch 85, Training Loss: 0.6587330102920532, Train F1: 0.5375, Validation F1: 0.5000
# Epoch 86, Training Loss: 0.6581194996833801, Train F1: 0.5375, Validation F1: 0.5000
# Epoch 87, Training Loss: 0.6574971079826355, Train F1: 0.5375, Validation F1: 0.5000
# Epoch 88, Training Loss: 0.6568702459335327, Train F1: 0.5375, Validation F1: 0.5000
# Epoch 89, Training Loss: 0.6562336683273315, Train F1: 0.5375, Validation F1: 0.5000
# Epoch 90, Training Loss: 0.6555871367454529, Train F1: 0.5375, Validation F1: 0.5000
# Epoch 91, Training Loss: 0.6549350023269653, Train F1: 0.5375, Validation F1: 0.5000
# Epoch 92, Training Loss: 0.6542743444442749, Train F1: 0.5375, Validation F1: 0.5000
# Epoch 93, Training Loss: 0.6536045074462891, Train F1: 0.5375, Validation F1: 0.5000
# Epoch 94, Training Loss: 0.6529269814491272, Train F1: 0.5375, Validation F1: 0.5000
# Epoch 95, Training Loss: 0.6522409319877625, Train F1: 0.5375, Validation F1: 0.5000
# Epoch 96, Training Loss: 0.651546061038971, Train F1: 0.5375, Validation F1: 0.5000
# Epoch 97, Training Loss: 0.6508426666259766, Train F1: 0.5375, Validation F1: 0.5000
# Epoch 98, Training Loss: 0.6501327753067017, Train F1: 0.5375, Validation F1: 0.5000
# Epoch 99, Training Loss: 0.6494156122207642, Train F1: 0.5375, Validation F1: 0.5000
# Epoch 100, Training Loss: 0.6486889123916626, Train F1: 0.5375, Validation F1: 0.5000
# Epoch 101, Training Loss: 0.6479513645172119, Train F1: 0.5375, Validation F1: 0.5000
# Epoch 102, Training Loss: 0.6472004652023315, Train F1: 0.5375, Validation F1: 0.5000
# Epoch 103, Training Loss: 0.6464429497718811, Train F1: 0.5375, Validation F1: 0.5000
# Epoch 104, Training Loss: 0.6456753611564636, Train F1: 0.5375, Validation F1: 0.5000
# Epoch 105, Training Loss: 0.6449007391929626, Train F1: 0.5375, Validation F1: 0.5000
# Epoch 106, Training Loss: 0.644119381904602, Train F1: 0.5375, Validation F1: 0.5000
# Epoch 107, Training Loss: 0.6433299779891968, Train F1: 0.5375, Validation F1: 0.5000
# Epoch 108, Training Loss: 0.6425309181213379, Train F1: 0.5375, Validation F1: 0.5000
# Epoch 109, Training Loss: 0.6417206525802612, Train F1: 0.5375, Validation F1: 0.5000
# Epoch 110, Training Loss: 0.6409011483192444, Train F1: 0.5375, Validation F1: 0.5000
# Epoch 111, Training Loss: 0.6400737166404724, Train F1: 0.5375, Validation F1: 0.5000
# Epoch 112, Training Loss: 0.6392375826835632, Train F1: 0.5375, Validation F1: 0.5000
# Epoch 113, Training Loss: 0.6383923292160034, Train F1: 0.5375, Validation F1: 0.5000
# Epoch 114, Training Loss: 0.6375365853309631, Train F1: 0.5375, Validation F1: 0.5000
# Epoch 115, Training Loss: 0.636670708656311, Train F1: 0.5375, Validation F1: 0.5000
# Epoch 116, Training Loss: 0.6357977986335754, Train F1: 0.5375, Validation F1: 0.5000
# Epoch 117, Training Loss: 0.6349164247512817, Train F1: 0.5375, Validation F1: 0.5000
# Epoch 118, Training Loss: 0.6340267658233643, Train F1: 0.5375, Validation F1: 0.5000
# Epoch 119, Training Loss: 0.6331281661987305, Train F1: 0.5375, Validation F1: 0.5000
# Epoch 120, Training Loss: 0.6322201490402222, Train F1: 0.5375, Validation F1: 0.5000
# Epoch 121, Training Loss: 0.6313012838363647, Train F1: 0.5375, Validation F1: 0.5000
# Epoch 122, Training Loss: 0.6303733587265015, Train F1: 0.5375, Validation F1: 0.5000
# Epoch 123, Training Loss: 0.6294364929199219, Train F1: 0.5375, Validation F1: 0.5000
# Epoch 124, Training Loss: 0.6284910440444946, Train F1: 0.5375, Validation F1: 0.5000
# Epoch 125, Training Loss: 0.627536416053772, Train F1: 0.5375, Validation F1: 0.5000
# Epoch 126, Training Loss: 0.6265736222267151, Train F1: 0.5375, Validation F1: 0.5000
# Epoch 127, Training Loss: 0.625602126121521, Train F1: 0.5375, Validation F1: 0.5000
# Epoch 128, Training Loss: 0.6246225237846375, Train F1: 0.5375, Validation F1: 0.5000
# Epoch 129, Training Loss: 0.6236359477043152, Train F1: 0.5375, Validation F1: 0.5000
# Epoch 130, Training Loss: 0.6226422190666199, Train F1: 0.5375, Validation F1: 0.5000
# Epoch 131, Training Loss: 0.6216424107551575, Train F1: 0.5375, Validation F1: 0.5000
# Epoch 132, Training Loss: 0.6206343770027161, Train F1: 0.5375, Validation F1: 0.5000
# Epoch 133, Training Loss: 0.6196187138557434, Train F1: 0.5375, Validation F1: 0.5000
# Epoch 134, Training Loss: 0.6185957193374634, Train F1: 0.5375, Validation F1: 0.5000
# Epoch 135, Training Loss: 0.6175650954246521, Train F1: 0.5375, Validation F1: 0.5000
# Epoch 136, Training Loss: 0.6165269017219543, Train F1: 0.5375, Validation F1: 0.5000
# Epoch 137, Training Loss: 0.6154819130897522, Train F1: 0.5375, Validation F1: 0.5000
# Epoch 138, Training Loss: 0.6144306063652039, Train F1: 0.5375, Validation F1: 0.5000
# Epoch 139, Training Loss: 0.6133729815483093, Train F1: 0.5375, Validation F1: 0.5000
# Epoch 140, Training Loss: 0.6123088598251343, Train F1: 0.5375, Validation F1: 0.5000
# Epoch 141, Training Loss: 0.6112388372421265, Train F1: 0.5375, Validation F1: 0.5000
# Epoch 142, Training Loss: 0.6101626753807068, Train F1: 0.5375, Validation F1: 0.5000
# Epoch 143, Training Loss: 0.6090800762176514, Train F1: 0.5375, Validation F1: 0.5000
# Epoch 144, Training Loss: 0.6079913973808289, Train F1: 0.5375, Validation F1: 0.5000
# Epoch 145, Training Loss: 0.6068965196609497, Train F1: 0.5375, Validation F1: 0.5000
# Epoch 146, Training Loss: 0.6057963371276855, Train F1: 0.5375, Validation F1: 0.5000
# Epoch 147, Training Loss: 0.6046900153160095, Train F1: 0.5375, Validation F1: 0.5000
# Epoch 148, Training Loss: 0.6035780906677246, Train F1: 0.5625, Validation F1: 0.5000
# Epoch 149, Training Loss: 0.6024605631828308, Train F1: 0.5625, Validation F1: 0.5000
# Epoch 150, Training Loss: 0.6013386249542236, Train F1: 0.5875, Validation F1: 0.5333
# Epoch 151, Training Loss: 0.6002103090286255, Train F1: 0.6125, Validation F1: 0.6000
# Epoch 152, Training Loss: 0.5990762114524841, Train F1: 0.6500, Validation F1: 0.6000
# Epoch 153, Training Loss: 0.5979434251785278, Train F1: 0.7000, Validation F1: 0.6000
# Epoch 154, Training Loss: 0.596809983253479, Train F1: 0.7375, Validation F1: 0.6000
# Epoch 155, Training Loss: 0.5956787467002869, Train F1: 0.7625, Validation F1: 0.5667
# Epoch 156, Training Loss: 0.5945501327514648, Train F1: 0.7500, Validation F1: 0.6000
# Epoch 157, Training Loss: 0.5934253931045532, Train F1: 0.7625, Validation F1: 0.6333
# Epoch 158, Training Loss: 0.5923029184341431, Train F1: 0.7750, Validation F1: 0.6667
# Epoch 159, Training Loss: 0.5911905169487, Train F1: 0.7750, Validation F1: 0.7333
# Epoch 160, Training Loss: 0.590080976486206, Train F1: 0.7750, Validation F1: 0.7333
# Epoch 161, Training Loss: 0.5889694094657898, Train F1: 0.7750, Validation F1: 0.7333
# Epoch 162, Training Loss: 0.5878607034683228, Train F1: 0.7750, Validation F1: 0.7000
# Epoch 163, Training Loss: 0.5867539644241333, Train F1: 0.7750, Validation F1: 0.7000
# Epoch 164, Training Loss: 0.5856459736824036, Train F1: 0.7875, Validation F1: 0.7000
# Epoch 165, Training Loss: 0.5845372676849365, Train F1: 0.7875, Validation F1: 0.7000
# Epoch 166, Training Loss: 0.583429217338562, Train F1: 0.7875, Validation F1: 0.7000
# Epoch 167, Training Loss: 0.5823219418525696, Train F1: 0.7875, Validation F1: 0.7000
# Epoch 168, Training Loss: 0.5812164545059204, Train F1: 0.7875, Validation F1: 0.7000
# Epoch 169, Training Loss: 0.5801142454147339, Train F1: 0.7875, Validation F1: 0.7000
# Epoch 170, Training Loss: 0.5790149569511414, Train F1: 0.7875, Validation F1: 0.7000
# Epoch 171, Training Loss: 0.5779193639755249, Train F1: 0.7875, Validation F1: 0.7000
# Epoch 172, Training Loss: 0.5768269300460815, Train F1: 0.7875, Validation F1: 0.7000
# Epoch 173, Training Loss: 0.5757395029067993, Train F1: 0.7875, Validation F1: 0.7000
# Epoch 174, Training Loss: 0.5746570825576782, Train F1: 0.7875, Validation F1: 0.7000
# Epoch 175, Training Loss: 0.5735802054405212, Train F1: 0.7875, Validation F1: 0.7000
# Epoch 176, Training Loss: 0.5725089311599731, Train F1: 0.7875, Validation F1: 0.7000
# Epoch 177, Training Loss: 0.5714429020881653, Train F1: 0.7875, Validation F1: 0.7000
# Epoch 178, Training Loss: 0.5703823566436768, Train F1: 0.7875, Validation F1: 0.7000
# Epoch 179, Training Loss: 0.5693286657333374, Train F1: 0.7875, Validation F1: 0.7000
# Epoch 180, Training Loss: 0.5682811141014099, Train F1: 0.7875, Validation F1: 0.7000
# Epoch 181, Training Loss: 0.5672391057014465, Train F1: 0.7875, Validation F1: 0.7000
# Epoch 182, Training Loss: 0.566203236579895, Train F1: 0.7875, Validation F1: 0.7000
# Epoch 183, Training Loss: 0.5651743412017822, Train F1: 0.7875, Validation F1: 0.7000
# Epoch 184, Training Loss: 0.5641545057296753, Train F1: 0.7875, Validation F1: 0.7000
# Epoch 185, Training Loss: 0.5631422996520996, Train F1: 0.7875, Validation F1: 0.7000
# Epoch 186, Training Loss: 0.5621379017829895, Train F1: 0.8000, Validation F1: 0.7000
# Epoch 187, Training Loss: 0.5611416101455688, Train F1: 0.8000, Validation F1: 0.7000
# Epoch 188, Training Loss: 0.560153603553772, Train F1: 0.8000, Validation F1: 0.7000
# Epoch 189, Training Loss: 0.5591738820075989, Train F1: 0.8000, Validation F1: 0.7000
# Epoch 190, Training Loss: 0.5582025647163391, Train F1: 0.8000, Validation F1: 0.7000
# Epoch 191, Training Loss: 0.5572404861450195, Train F1: 0.8125, Validation F1: 0.7000
# Epoch 192, Training Loss: 0.5562890768051147, Train F1: 0.8125, Validation F1: 0.7000
# Epoch 193, Training Loss: 0.5553473234176636, Train F1: 0.8125, Validation F1: 0.7000
# Epoch 194, Training Loss: 0.5544157028198242, Train F1: 0.8125, Validation F1: 0.7000
# Epoch 195, Training Loss: 0.5534936189651489, Train F1: 0.8125, Validation F1: 0.7000
# Epoch 196, Training Loss: 0.5525820851325989, Train F1: 0.8125, Validation F1: 0.7000
# Epoch 197, Training Loss: 0.5516833662986755, Train F1: 0.8125, Validation F1: 0.7000
# Epoch 198, Training Loss: 0.5507956743240356, Train F1: 0.8125, Validation F1: 0.7000
# Epoch 199, Training Loss: 0.5499187707901001, Train F1: 0.8125, Validation F1: 0.7000
# Epoch 200, Training Loss: 0.5490533113479614, Train F1: 0.8125, Validation F1: 0.7000
# LayeredGCN(
#   (layers): ModuleList(
#     (0-3): 4 x GCNLayer()
#   )
#   (output_layer): GCNLayer()
# )
# Epoch 1, Training Loss: 0.694295346736908, Train F1: 0.5125, Validation F1: 0.3667
# Epoch 2, Training Loss: 0.6940807104110718, Train F1: 0.5125, Validation F1: 0.3667
# Epoch 3, Training Loss: 0.693867027759552, Train F1: 0.5125, Validation F1: 0.3667
# Epoch 4, Training Loss: 0.6936547756195068, Train F1: 0.5125, Validation F1: 0.3667
# Epoch 5, Training Loss: 0.6934440732002258, Train F1: 0.5125, Validation F1: 0.3667
# Epoch 6, Training Loss: 0.693234384059906, Train F1: 0.5125, Validation F1: 0.3667
# Epoch 7, Training Loss: 0.6930256485939026, Train F1: 0.5125, Validation F1: 0.3667
# Epoch 8, Training Loss: 0.692818284034729, Train F1: 0.5125, Validation F1: 0.3667
# Epoch 9, Training Loss: 0.6926119327545166, Train F1: 0.5125, Validation F1: 0.3667
# Epoch 10, Training Loss: 0.6924059391021729, Train F1: 0.5125, Validation F1: 0.3667
# Epoch 11, Training Loss: 0.6922005414962769, Train F1: 0.5125, Validation F1: 0.3667
# Epoch 12, Training Loss: 0.6919983625411987, Train F1: 0.5125, Validation F1: 0.3667
# Epoch 13, Training Loss: 0.6917981505393982, Train F1: 0.5125, Validation F1: 0.3667
# Epoch 14, Training Loss: 0.6915996074676514, Train F1: 0.5125, Validation F1: 0.3667
# Epoch 15, Training Loss: 0.6914046406745911, Train F1: 0.5125, Validation F1: 0.3667
# Epoch 16, Training Loss: 0.6912120580673218, Train F1: 0.5125, Validation F1: 0.3667
# Epoch 17, Training Loss: 0.6910247206687927, Train F1: 0.5125, Validation F1: 0.3667
# Epoch 18, Training Loss: 0.6908372640609741, Train F1: 0.5125, Validation F1: 0.3667
# Epoch 19, Training Loss: 0.6906492114067078, Train F1: 0.5125, Validation F1: 0.3667
# Epoch 20, Training Loss: 0.6904606819152832, Train F1: 0.5125, Validation F1: 0.3667
# Epoch 21, Training Loss: 0.6902717351913452, Train F1: 0.5125, Validation F1: 0.3667
# Epoch 22, Training Loss: 0.6900825500488281, Train F1: 0.5125, Validation F1: 0.3667
# Epoch 23, Training Loss: 0.6898930668830872, Train F1: 0.5125, Validation F1: 0.3667
# Epoch 24, Training Loss: 0.6897030472755432, Train F1: 0.5125, Validation F1: 0.3667
# Epoch 25, Training Loss: 0.6895120143890381, Train F1: 0.5125, Validation F1: 0.3667
# Epoch 26, Training Loss: 0.689319908618927, Train F1: 0.5125, Validation F1: 0.3667
# Epoch 27, Training Loss: 0.6891601085662842, Train F1: 0.5125, Validation F1: 0.3667
# Epoch 28, Training Loss: 0.6890249252319336, Train F1: 0.5125, Validation F1: 0.3667
# Epoch 29, Training Loss: 0.6888935565948486, Train F1: 0.5125, Validation F1: 0.3667
# Epoch 30, Training Loss: 0.6887611150741577, Train F1: 0.5125, Validation F1: 0.3667
# Epoch 31, Training Loss: 0.6886275410652161, Train F1: 0.5125, Validation F1: 0.3667
# Epoch 32, Training Loss: 0.6884928941726685, Train F1: 0.5125, Validation F1: 0.3667
# Epoch 33, Training Loss: 0.6883574724197388, Train F1: 0.5125, Validation F1: 0.3667
# Epoch 34, Training Loss: 0.6882214546203613, Train F1: 0.5125, Validation F1: 0.3667
# Epoch 35, Training Loss: 0.6880860328674316, Train F1: 0.5125, Validation F1: 0.3667
# Epoch 36, Training Loss: 0.6879503726959229, Train F1: 0.5125, Validation F1: 0.3667
# Epoch 37, Training Loss: 0.6878426671028137, Train F1: 0.5125, Validation F1: 0.3667
# Epoch 38, Training Loss: 0.687748908996582, Train F1: 0.5125, Validation F1: 0.3667
# Epoch 39, Training Loss: 0.6876536011695862, Train F1: 0.5125, Validation F1: 0.3667
# Epoch 40, Training Loss: 0.6875556707382202, Train F1: 0.5125, Validation F1: 0.3667
# Epoch 41, Training Loss: 0.6874555945396423, Train F1: 0.5125, Validation F1: 0.3667
# Epoch 42, Training Loss: 0.6873547434806824, Train F1: 0.5125, Validation F1: 0.3667
# Epoch 43, Training Loss: 0.6872557997703552, Train F1: 0.5125, Validation F1: 0.3667
# Epoch 44, Training Loss: 0.6871559619903564, Train F1: 0.5125, Validation F1: 0.3667
# Epoch 45, Training Loss: 0.6870536208152771, Train F1: 0.5125, Validation F1: 0.3667
# Epoch 46, Training Loss: 0.6869491338729858, Train F1: 0.5125, Validation F1: 0.3667
# Epoch 47, Training Loss: 0.6868443489074707, Train F1: 0.5125, Validation F1: 0.3667
# Epoch 48, Training Loss: 0.686739444732666, Train F1: 0.5125, Validation F1: 0.3667
# Epoch 49, Training Loss: 0.6866329908370972, Train F1: 0.5125, Validation F1: 0.3667
# Epoch 50, Training Loss: 0.6865244507789612, Train F1: 0.5125, Validation F1: 0.3667
# Epoch 51, Training Loss: 0.686414361000061, Train F1: 0.5125, Validation F1: 0.3667
# Epoch 52, Training Loss: 0.6863030791282654, Train F1: 0.5125, Validation F1: 0.3667
# Epoch 53, Training Loss: 0.6861909627914429, Train F1: 0.5125, Validation F1: 0.3667
# Epoch 54, Training Loss: 0.6860772967338562, Train F1: 0.5125, Validation F1: 0.3667
# Epoch 55, Training Loss: 0.6859619617462158, Train F1: 0.5125, Validation F1: 0.3667
# Epoch 56, Training Loss: 0.685844898223877, Train F1: 0.5125, Validation F1: 0.3667
# Epoch 57, Training Loss: 0.6857264637947083, Train F1: 0.5125, Validation F1: 0.3667
# Epoch 58, Training Loss: 0.6856064200401306, Train F1: 0.5125, Validation F1: 0.3667
# Epoch 59, Training Loss: 0.6854841709136963, Train F1: 0.5125, Validation F1: 0.3667
# Epoch 60, Training Loss: 0.6853607296943665, Train F1: 0.5125, Validation F1: 0.3667
# Epoch 61, Training Loss: 0.6852356195449829, Train F1: 0.5125, Validation F1: 0.3667
# Epoch 62, Training Loss: 0.6851086616516113, Train F1: 0.5125, Validation F1: 0.3667
# Epoch 63, Training Loss: 0.6849799156188965, Train F1: 0.5125, Validation F1: 0.3667
# Epoch 64, Training Loss: 0.6848493218421936, Train F1: 0.5125, Validation F1: 0.3667
# Epoch 65, Training Loss: 0.6847168207168579, Train F1: 0.5125, Validation F1: 0.3667
# Epoch 66, Training Loss: 0.6845831274986267, Train F1: 0.5125, Validation F1: 0.3667
# Epoch 67, Training Loss: 0.6844474077224731, Train F1: 0.5125, Validation F1: 0.3667
# Epoch 68, Training Loss: 0.6843100190162659, Train F1: 0.5125, Validation F1: 0.3667
# Epoch 69, Training Loss: 0.6841705441474915, Train F1: 0.5125, Validation F1: 0.3667
# Epoch 70, Training Loss: 0.6840319633483887, Train F1: 0.5125, Validation F1: 0.3667
# Epoch 71, Training Loss: 0.6839011907577515, Train F1: 0.5125, Validation F1: 0.3667
# Epoch 72, Training Loss: 0.6837670207023621, Train F1: 0.5125, Validation F1: 0.3667
# Epoch 73, Training Loss: 0.68363356590271, Train F1: 0.5125, Validation F1: 0.3667
# Epoch 74, Training Loss: 0.6834947466850281, Train F1: 0.5125, Validation F1: 0.3667
# Epoch 75, Training Loss: 0.6833630204200745, Train F1: 0.5125, Validation F1: 0.3667
# Epoch 76, Training Loss: 0.6832285523414612, Train F1: 0.5125, Validation F1: 0.3667
# Epoch 77, Training Loss: 0.6830894351005554, Train F1: 0.5125, Validation F1: 0.3667
# Epoch 78, Training Loss: 0.6829413175582886, Train F1: 0.5125, Validation F1: 0.3667
# Epoch 79, Training Loss: 0.6827502250671387, Train F1: 0.5125, Validation F1: 0.3667
# Epoch 80, Training Loss: 0.6825394034385681, Train F1: 0.5125, Validation F1: 0.3667
# Epoch 81, Training Loss: 0.6823132634162903, Train F1: 0.5125, Validation F1: 0.3667
# Epoch 82, Training Loss: 0.682074248790741, Train F1: 0.5125, Validation F1: 0.3667
# Epoch 83, Training Loss: 0.6818256378173828, Train F1: 0.5125, Validation F1: 0.3667
# Epoch 84, Training Loss: 0.6815687417984009, Train F1: 0.5125, Validation F1: 0.3667
# Epoch 85, Training Loss: 0.681304931640625, Train F1: 0.5125, Validation F1: 0.3667
# Epoch 86, Training Loss: 0.6810383796691895, Train F1: 0.5125, Validation F1: 0.3667
# Epoch 87, Training Loss: 0.6807636618614197, Train F1: 0.5125, Validation F1: 0.3667
# Epoch 88, Training Loss: 0.6804819107055664, Train F1: 0.5125, Validation F1: 0.3667
# Epoch 89, Training Loss: 0.6801979541778564, Train F1: 0.5125, Validation F1: 0.3667
# Epoch 90, Training Loss: 0.6799088716506958, Train F1: 0.5125, Validation F1: 0.3667
# Epoch 91, Training Loss: 0.6796145439147949, Train F1: 0.6875, Validation F1: 0.3667
# Epoch 92, Training Loss: 0.6793199181556702, Train F1: 0.6875, Validation F1: 0.3667
# Epoch 93, Training Loss: 0.6790225505828857, Train F1: 0.6875, Validation F1: 0.3667
# Epoch 94, Training Loss: 0.6787264347076416, Train F1: 0.6875, Validation F1: 0.3667
# Epoch 95, Training Loss: 0.6784321069717407, Train F1: 0.6875, Validation F1: 0.3667
# Epoch 96, Training Loss: 0.6781376600265503, Train F1: 0.6875, Validation F1: 0.3667
# Epoch 97, Training Loss: 0.6778535842895508, Train F1: 0.6875, Validation F1: 0.3667
# Epoch 98, Training Loss: 0.6775665283203125, Train F1: 0.6875, Validation F1: 0.3667
# Epoch 99, Training Loss: 0.677289605140686, Train F1: 0.6875, Validation F1: 0.3667
# Epoch 100, Training Loss: 0.6770126223564148, Train F1: 0.6875, Validation F1: 0.3667
# Epoch 101, Training Loss: 0.6767352819442749, Train F1: 0.6875, Validation F1: 0.3667
# Epoch 102, Training Loss: 0.6764588356018066, Train F1: 0.6875, Validation F1: 0.3667
# Epoch 103, Training Loss: 0.6761780977249146, Train F1: 0.6875, Validation F1: 0.3667
# Epoch 104, Training Loss: 0.6758993864059448, Train F1: 0.6875, Validation F1: 0.3667
# Epoch 105, Training Loss: 0.6756184697151184, Train F1: 0.6875, Validation F1: 0.3667
# Epoch 106, Training Loss: 0.6753326654434204, Train F1: 0.6875, Validation F1: 0.3667
# Epoch 107, Training Loss: 0.6750476956367493, Train F1: 0.6875, Validation F1: 0.3667
# Epoch 108, Training Loss: 0.6747578978538513, Train F1: 0.6875, Validation F1: 0.3667
# Epoch 109, Training Loss: 0.6744734048843384, Train F1: 0.6875, Validation F1: 0.3667
# Epoch 110, Training Loss: 0.6741875410079956, Train F1: 0.6875, Validation F1: 0.3667
# Epoch 111, Training Loss: 0.6739004850387573, Train F1: 0.6875, Validation F1: 0.3667
# Epoch 112, Training Loss: 0.6736081838607788, Train F1: 0.6875, Validation F1: 0.3667
# Epoch 113, Training Loss: 0.6733109354972839, Train F1: 0.6875, Validation F1: 0.3667
# Epoch 114, Training Loss: 0.6730132102966309, Train F1: 0.6875, Validation F1: 0.3667
# Epoch 115, Training Loss: 0.6727092266082764, Train F1: 0.6875, Validation F1: 0.3667
# Epoch 116, Training Loss: 0.6724112033843994, Train F1: 0.6875, Validation F1: 0.3667
# Epoch 117, Training Loss: 0.6721087694168091, Train F1: 0.6875, Validation F1: 0.3667
# Epoch 118, Training Loss: 0.6718074083328247, Train F1: 0.6875, Validation F1: 0.3667
# Epoch 119, Training Loss: 0.6715015172958374, Train F1: 0.6875, Validation F1: 0.3667
# Epoch 120, Training Loss: 0.6711938977241516, Train F1: 0.6875, Validation F1: 0.4000
# Epoch 121, Training Loss: 0.670884907245636, Train F1: 0.6875, Validation F1: 0.4000
# Epoch 122, Training Loss: 0.6705747842788696, Train F1: 0.6875, Validation F1: 0.4000
# Epoch 123, Training Loss: 0.6702837944030762, Train F1: 0.6875, Validation F1: 0.6000
# Epoch 124, Training Loss: 0.669979453086853, Train F1: 0.6875, Validation F1: 0.7000
# Epoch 125, Training Loss: 0.6696885228157043, Train F1: 0.6875, Validation F1: 0.7333
# Epoch 126, Training Loss: 0.6693848967552185, Train F1: 0.6875, Validation F1: 0.7333
# Epoch 127, Training Loss: 0.6690824031829834, Train F1: 0.6875, Validation F1: 0.7333
# Epoch 128, Training Loss: 0.668777585029602, Train F1: 0.6875, Validation F1: 0.7333
# Epoch 129, Training Loss: 0.6684754490852356, Train F1: 0.6875, Validation F1: 0.7333
# Epoch 130, Training Loss: 0.6681686639785767, Train F1: 0.6875, Validation F1: 0.7333
# Epoch 131, Training Loss: 0.6678608655929565, Train F1: 0.6875, Validation F1: 0.7333
# Epoch 132, Training Loss: 0.6675502061843872, Train F1: 0.6875, Validation F1: 0.7333
# Epoch 133, Training Loss: 0.6672399640083313, Train F1: 0.6875, Validation F1: 0.7333
# Epoch 134, Training Loss: 0.6669274568557739, Train F1: 0.6875, Validation F1: 0.7333
# Epoch 135, Training Loss: 0.6666130423545837, Train F1: 0.6875, Validation F1: 0.7333
# Epoch 136, Training Loss: 0.6663001179695129, Train F1: 0.6875, Validation F1: 0.7333
# Epoch 137, Training Loss: 0.6659845113754272, Train F1: 0.6875, Validation F1: 0.7333
# Epoch 138, Training Loss: 0.665668785572052, Train F1: 0.6875, Validation F1: 0.7333
# Epoch 139, Training Loss: 0.6653462648391724, Train F1: 0.6875, Validation F1: 0.7333
# Epoch 140, Training Loss: 0.6650287508964539, Train F1: 0.6875, Validation F1: 0.7333
# Epoch 141, Training Loss: 0.6647058129310608, Train F1: 0.6875, Validation F1: 0.7333
# Epoch 142, Training Loss: 0.6643861532211304, Train F1: 0.6875, Validation F1: 0.7333
# Epoch 143, Training Loss: 0.6640603542327881, Train F1: 0.6875, Validation F1: 0.7333
# Epoch 144, Training Loss: 0.6637391448020935, Train F1: 0.6875, Validation F1: 0.7333
# Epoch 145, Training Loss: 0.6634114980697632, Train F1: 0.6875, Validation F1: 0.7333
# Epoch 146, Training Loss: 0.6630862355232239, Train F1: 0.6875, Validation F1: 0.7333
# Epoch 147, Training Loss: 0.6627572774887085, Train F1: 0.6875, Validation F1: 0.7333
# Epoch 148, Training Loss: 0.6624316573143005, Train F1: 0.6875, Validation F1: 0.7333
# Epoch 149, Training Loss: 0.6621019244194031, Train F1: 0.6875, Validation F1: 0.7333
# Epoch 150, Training Loss: 0.661772608757019, Train F1: 0.6875, Validation F1: 0.7333
# Epoch 151, Training Loss: 0.6614435315132141, Train F1: 0.6875, Validation F1: 0.7333
# Epoch 152, Training Loss: 0.6611092686653137, Train F1: 0.6875, Validation F1: 0.7333
# Epoch 153, Training Loss: 0.6607834100723267, Train F1: 0.6875, Validation F1: 0.7333
# Epoch 154, Training Loss: 0.6604465246200562, Train F1: 0.6875, Validation F1: 0.7333
# Epoch 155, Training Loss: 0.6601174473762512, Train F1: 0.6875, Validation F1: 0.7333
# Epoch 156, Training Loss: 0.6597827672958374, Train F1: 0.6875, Validation F1: 0.7333
# Epoch 157, Training Loss: 0.6594489216804504, Train F1: 0.6875, Validation F1: 0.7333
# Epoch 158, Training Loss: 0.6591170430183411, Train F1: 0.6875, Validation F1: 0.8000
# Epoch 159, Training Loss: 0.6587830185890198, Train F1: 0.6875, Validation F1: 0.8000
# Epoch 160, Training Loss: 0.6584516763687134, Train F1: 0.6875, Validation F1: 0.8000
# Epoch 161, Training Loss: 0.6581165790557861, Train F1: 0.6875, Validation F1: 0.8000
# Epoch 162, Training Loss: 0.6577840447425842, Train F1: 0.6875, Validation F1: 0.8000
# Epoch 163, Training Loss: 0.6574503779411316, Train F1: 0.6875, Validation F1: 0.8000
# Epoch 164, Training Loss: 0.6571179032325745, Train F1: 0.6875, Validation F1: 0.8000
# Epoch 165, Training Loss: 0.6567856073379517, Train F1: 0.6875, Validation F1: 0.8000
# Epoch 166, Training Loss: 0.6564533114433289, Train F1: 0.6875, Validation F1: 0.8000
# Epoch 167, Training Loss: 0.6561214923858643, Train F1: 0.6875, Validation F1: 0.8000
# Epoch 168, Training Loss: 0.6557904481887817, Train F1: 0.6875, Validation F1: 0.8000
# Epoch 169, Training Loss: 0.6554602980613708, Train F1: 0.6875, Validation F1: 0.8000
# Epoch 170, Training Loss: 0.6551312804222107, Train F1: 0.6875, Validation F1: 0.8000
# Epoch 171, Training Loss: 0.6548022627830505, Train F1: 0.6875, Validation F1: 0.8000
# Epoch 172, Training Loss: 0.6544758677482605, Train F1: 0.6875, Validation F1: 0.8000
# Epoch 173, Training Loss: 0.6541483998298645, Train F1: 0.6875, Validation F1: 0.8000
# Epoch 174, Training Loss: 0.6538229584693909, Train F1: 0.6875, Validation F1: 0.8000
# Epoch 175, Training Loss: 0.653499186038971, Train F1: 0.6875, Validation F1: 0.8000
# Epoch 176, Training Loss: 0.6531757712364197, Train F1: 0.6875, Validation F1: 0.8000
# Epoch 177, Training Loss: 0.6528535485267639, Train F1: 0.6875, Validation F1: 0.8000
# Epoch 178, Training Loss: 0.6525336503982544, Train F1: 0.6875, Validation F1: 0.8000
# Epoch 179, Training Loss: 0.6522139310836792, Train F1: 0.6875, Validation F1: 0.8000
# Epoch 180, Training Loss: 0.651896595954895, Train F1: 0.6875, Validation F1: 0.8000
# Epoch 181, Training Loss: 0.6515809297561646, Train F1: 0.6875, Validation F1: 0.8000
# Epoch 182, Training Loss: 0.6512663960456848, Train F1: 0.6875, Validation F1: 0.8000
# Epoch 183, Training Loss: 0.6509532332420349, Train F1: 0.6875, Validation F1: 0.8000
# Epoch 184, Training Loss: 0.6506432890892029, Train F1: 0.6875, Validation F1: 0.8000
# Epoch 185, Training Loss: 0.6503335237503052, Train F1: 0.6875, Validation F1: 0.8000
# Epoch 186, Training Loss: 0.6500269174575806, Train F1: 0.6875, Validation F1: 0.8000
# Epoch 187, Training Loss: 0.6497215032577515, Train F1: 0.6875, Validation F1: 0.8000
# Epoch 188, Training Loss: 0.6494190692901611, Train F1: 0.6875, Validation F1: 0.8000
# Epoch 189, Training Loss: 0.6491183638572693, Train F1: 0.6875, Validation F1: 0.8000
# Epoch 190, Training Loss: 0.6488200426101685, Train F1: 0.6875, Validation F1: 0.8000
# Epoch 191, Training Loss: 0.6485239267349243, Train F1: 0.6875, Validation F1: 0.8000
# Epoch 192, Training Loss: 0.6482301950454712, Train F1: 0.6875, Validation F1: 0.8000
# Epoch 193, Training Loss: 0.6479389667510986, Train F1: 0.6875, Validation F1: 0.8000
# Epoch 194, Training Loss: 0.6476495862007141, Train F1: 0.6875, Validation F1: 0.8000
# Epoch 195, Training Loss: 0.6473637819290161, Train F1: 0.6875, Validation F1: 0.8000
# Epoch 196, Training Loss: 0.647079586982727, Train F1: 0.6875, Validation F1: 0.8000
# Epoch 197, Training Loss: 0.6467986106872559, Train F1: 0.6875, Validation F1: 0.8000
# Epoch 198, Training Loss: 0.6465203166007996, Train F1: 0.6875, Validation F1: 0.8000
# Epoch 199, Training Loss: 0.6462447047233582, Train F1: 0.6875, Validation F1: 0.8000
# Epoch 200, Training Loss: 0.6459718942642212, Train F1: 0.6875, Validation F1: 0.8000

# %% [markdown]
# ### Q3.2.b - Plotting of t-SNE Embeddings for Graph Neural Networks
#
# • Use t-SNE to visualize the node embeddings for the final layer of the GCN for each graph
# for both training and evaluation data, use the labels as class labels for the tsne plot.

# %%
from sklearn.manifold import TSNE

# SOLUTION Q3.5.b
# ####################################################
# MODIFY THE CODE BELOW 
# ####################################################  

def plot_tsne(embeddings, labels=None, layer_to_plot=-1, subject="Node Embeddings"):
    """
    embeddings (list):
        list of embeddings (layer 2, ..., layer N)
        NOTE: for num_layer = 1 there is no embedding (as it is just the input)
    
    labels (list):
        list of labels
    
    layer_to_plot (int):
        which layer to plot (default -1, i.e. the last layer)
    """
    if not embeddings:
        raise ValueError("Embeddings list is empty.")
    
    # Select the embedding for the chosen layer
    chosen_embedding = embeddings[layer_to_plot]
    
    if isinstance(chosen_embedding, torch.Tensor):
        chosen_embedding = chosen_embedding.detach().cpu().numpy()
    
    if not isinstance(chosen_embedding, np.ndarray):
        chosen_embedding = np.array(chosen_embedding)
    
    # Adjust perplexity dynamically
    perplexity = min(30, len(chosen_embedding) - 1)
    
    # Perform t-SNE dimensionality reduction
    tsne = TSNE(n_components=2, random_state=42, perplexity=perplexity)
    reduced_embeddings = tsne.fit_transform(chosen_embedding)
    
    # Plot the embeddings
    plt.figure(figsize=(8, 6))
    
    if labels is not None:
        labels = np.array(labels)
        scatter = plt.scatter(reduced_embeddings[:, 0], reduced_embeddings[:, 1], c=labels, cmap='jet', alpha=0.7)
        plt.colorbar(scatter, label="Labels")
    else:
        plt.scatter(reduced_embeddings[:, 0], reduced_embeddings[:, 1], alpha=0.7)
    
    plt.title(f"t-SNE Visualization of {subject} (Layer {layer_to_plot})")
    plt.xlabel("t-SNE Dim 1")
    plt.ylabel("t-SNE Dim 2")
    plt.show()

# ####################################################
# END OF MODIFICATION
# ####################################################

# %% [markdown]
# ### Plotting the t-SNE embeddings
#
# Adapt as needed.

# %%
set_seed(5)

# Load data
G1_train = read_json_data(G1_TRAIN_DATA_PATH, has_label=True) #returns a list of (X,A,y) - features, Adj Matrix, per Graph label
G1_eval = read_json_data(G1_EVAL_DATA_PATH, has_label=True) #returns a list of (X,A,y) - features, Adj Matrix, per Graph label

G2_train = read_json_data(G2_TRAIN_DATA_PATH, has_label=True) #returns a list of (X,A,y) - features, Adj Matrix, per Graph label
G2_eval = read_json_data(G2_EVAL_DATA_PATH, has_label=True) #returns a list of (X,A,y) - features, Adj Matrix, per Graph label

# Initialising the model
input_dim = 10
hidden_dim = 8
num_layers = 4
model = LayeredGCN(input_dim, hidden_dim, num_layers=num_layers)

losses, _, val_f1, last_embeddings_g1_train = train_model(
    model,
    G1_train,
    G1_eval,
    num_epochs=200,
    lr=0.0005,
    verbose=True,
    return_embeddings = True #NOTE we added this parameter
)
with torch.no_grad():
    _, last_embeddings_g1_eval = model(A=G1_eval[1], X=G1_eval[0], return_embeddings=True)

plot_training_and_validation(losses, val_f1)

model = LayeredGCN(input_dim, hidden_dim, num_layers=num_layers)

_, _, _, last_embeddings_g2_train = train_model(model, G2_train, G2_eval, num_epochs=200, lr=0.0005, verbose=False, return_embeddings=True)

with torch.no_grad():
    _, last_embeddings_g2_eval = model(A=G2_eval[1], X=G2_eval[0], return_embeddings=True)



_,_,y_g1_train = G1_train
_,_,y_g1_eval = G1_eval
_,_,y_g2_train = G2_train
_,_,y_g2_eval = G2_eval

plot_tsne(last_embeddings_g1_train, y_g1_train, layer_to_plot=-1, subject="Node Embeddings")
plot_tsne(last_embeddings_g1_eval, y_g1_eval, layer_to_plot=-1, subject="Node Embeddings")
plot_tsne(last_embeddings_g2_train, y_g2_train, layer_to_plot=-1, subject="Node Embeddings")
plot_tsne(last_embeddings_g2_eval, y_g2_eval, layer_to_plot=-1, subject="Node Embeddings")
# Out:
# Epoch 1, Training Loss: 2.8099539279937744, Train F1: 0.4625, Validation F1: 0.5000
# Epoch 2, Training Loss: 2.755390167236328, Train F1: 0.4625, Validation F1: 0.5000
# Epoch 3, Training Loss: 2.7012524604797363, Train F1: 0.4625, Validation F1: 0.5000
# Epoch 4, Training Loss: 2.647679328918457, Train F1: 0.4625, Validation F1: 0.5000
# Epoch 5, Training Loss: 2.5944905281066895, Train F1: 0.4625, Validation F1: 0.5000
# Epoch 6, Training Loss: 2.541705846786499, Train F1: 0.4625, Validation F1: 0.5000
# Epoch 7, Training Loss: 2.489367961883545, Train F1: 0.4625, Validation F1: 0.5000
# Epoch 8, Training Loss: 2.4370203018188477, Train F1: 0.4625, Validation F1: 0.5000
# Epoch 9, Training Loss: 2.3845534324645996, Train F1: 0.4625, Validation F1: 0.5000
# Epoch 10, Training Loss: 2.3316078186035156, Train F1: 0.4625, Validation F1: 0.5000
# Epoch 11, Training Loss: 2.278528928756714, Train F1: 0.4625, Validation F1: 0.5000
# Epoch 12, Training Loss: 2.225978374481201, Train F1: 0.4625, Validation F1: 0.5000
# Epoch 13, Training Loss: 2.173640489578247, Train F1: 0.4625, Validation F1: 0.5000
# Epoch 14, Training Loss: 2.1203839778900146, Train F1: 0.4625, Validation F1: 0.5000
# Epoch 15, Training Loss: 2.067279577255249, Train F1: 0.4625, Validation F1: 0.5000
# Epoch 16, Training Loss: 2.0145819187164307, Train F1: 0.4625, Validation F1: 0.5000
# Epoch 17, Training Loss: 1.961107611656189, Train F1: 0.4625, Validation F1: 0.5000
# Epoch 18, Training Loss: 1.9081013202667236, Train F1: 0.4625, Validation F1: 0.5000
# Epoch 19, Training Loss: 1.8534479141235352, Train F1: 0.4625, Validation F1: 0.5000
# Epoch 20, Training Loss: 1.7976760864257812, Train F1: 0.4625, Validation F1: 0.5000
# Epoch 21, Training Loss: 1.7377707958221436, Train F1: 0.4625, Validation F1: 0.5000
# Epoch 22, Training Loss: 1.6781429052352905, Train F1: 0.4625, Validation F1: 0.5000
# Epoch 23, Training Loss: 1.618318796157837, Train F1: 0.4625, Validation F1: 0.5000
# Epoch 24, Training Loss: 1.559497356414795, Train F1: 0.4625, Validation F1: 0.5000
# Epoch 25, Training Loss: 1.5000746250152588, Train F1: 0.4625, Validation F1: 0.5000
# Epoch 26, Training Loss: 1.4408518075942993, Train F1: 0.4625, Validation F1: 0.5000
# Epoch 27, Training Loss: 1.3836101293563843, Train F1: 0.4625, Validation F1: 0.5000
# Epoch 28, Training Loss: 1.3289650678634644, Train F1: 0.4625, Validation F1: 0.5000
# Epoch 29, Training Loss: 1.2756507396697998, Train F1: 0.4625, Validation F1: 0.5000
# Epoch 30, Training Loss: 1.2234916687011719, Train F1: 0.4625, Validation F1: 0.5000
# Epoch 31, Training Loss: 1.1739234924316406, Train F1: 0.4625, Validation F1: 0.5000
# Epoch 32, Training Loss: 1.1262696981430054, Train F1: 0.4625, Validation F1: 0.5000
# Epoch 33, Training Loss: 1.0785529613494873, Train F1: 0.4625, Validation F1: 0.5000
# Epoch 34, Training Loss: 1.0327399969100952, Train F1: 0.4625, Validation F1: 0.5000
# Epoch 35, Training Loss: 0.9903586506843567, Train F1: 0.4500, Validation F1: 0.5000
# Epoch 36, Training Loss: 0.9509280323982239, Train F1: 0.5250, Validation F1: 0.5000
# Epoch 37, Training Loss: 0.9136209487915039, Train F1: 0.5375, Validation F1: 0.5000
# Epoch 38, Training Loss: 0.880082905292511, Train F1: 0.5625, Validation F1: 0.5000
# Epoch 39, Training Loss: 0.848414421081543, Train F1: 0.5750, Validation F1: 0.5000
# Epoch 40, Training Loss: 0.8199771642684937, Train F1: 0.6125, Validation F1: 0.5667
# Epoch 41, Training Loss: 0.7941725850105286, Train F1: 0.6125, Validation F1: 0.5667
# Epoch 42, Training Loss: 0.7702666521072388, Train F1: 0.6625, Validation F1: 0.5333
# Epoch 43, Training Loss: 0.7481257319450378, Train F1: 0.6625, Validation F1: 0.5333
# Epoch 44, Training Loss: 0.7276613116264343, Train F1: 0.6625, Validation F1: 0.6000
# Epoch 45, Training Loss: 0.7087510228157043, Train F1: 0.6750, Validation F1: 0.6333
# Epoch 46, Training Loss: 0.691105306148529, Train F1: 0.7125, Validation F1: 0.6333
# Epoch 47, Training Loss: 0.6747981309890747, Train F1: 0.7250, Validation F1: 0.6333
# Epoch 48, Training Loss: 0.6596771478652954, Train F1: 0.7875, Validation F1: 0.6333
# Epoch 49, Training Loss: 0.6457597613334656, Train F1: 0.8000, Validation F1: 0.6667
# Epoch 50, Training Loss: 0.6329489946365356, Train F1: 0.8000, Validation F1: 0.7000
# Epoch 51, Training Loss: 0.621202826499939, Train F1: 0.8000, Validation F1: 0.7000
# Epoch 52, Training Loss: 0.610657811164856, Train F1: 0.8250, Validation F1: 0.7000
# Epoch 53, Training Loss: 0.6009653210639954, Train F1: 0.8250, Validation F1: 0.7667
# Epoch 54, Training Loss: 0.5921530723571777, Train F1: 0.8250, Validation F1: 0.7667
# Epoch 55, Training Loss: 0.5841524600982666, Train F1: 0.8375, Validation F1: 0.7667
# Epoch 56, Training Loss: 0.5770487785339355, Train F1: 0.8375, Validation F1: 0.7667
# Epoch 57, Training Loss: 0.5705633759498596, Train F1: 0.8375, Validation F1: 0.7667
# Epoch 58, Training Loss: 0.5646049976348877, Train F1: 0.8375, Validation F1: 0.7667
# Epoch 59, Training Loss: 0.5591609477996826, Train F1: 0.8375, Validation F1: 0.7667
# Epoch 60, Training Loss: 0.5541630983352661, Train F1: 0.8375, Validation F1: 0.7667
# Epoch 61, Training Loss: 0.5495336651802063, Train F1: 0.8375, Validation F1: 0.7667
# Epoch 62, Training Loss: 0.5453529357910156, Train F1: 0.8375, Validation F1: 0.7667
# Epoch 63, Training Loss: 0.5415514707565308, Train F1: 0.8375, Validation F1: 0.7667
# Epoch 64, Training Loss: 0.5380943417549133, Train F1: 0.8375, Validation F1: 0.7667
# Epoch 65, Training Loss: 0.5350064635276794, Train F1: 0.8500, Validation F1: 0.7333
# Epoch 66, Training Loss: 0.5321683883666992, Train F1: 0.8375, Validation F1: 0.7000
# Epoch 67, Training Loss: 0.5295514464378357, Train F1: 0.8375, Validation F1: 0.7000
# Epoch 68, Training Loss: 0.5271482467651367, Train F1: 0.8375, Validation F1: 0.7000
# Epoch 69, Training Loss: 0.5249563455581665, Train F1: 0.8375, Validation F1: 0.7000
# Epoch 70, Training Loss: 0.5229636430740356, Train F1: 0.8375, Validation F1: 0.7000
# Epoch 71, Training Loss: 0.5211220979690552, Train F1: 0.8375, Validation F1: 0.7000
# Epoch 72, Training Loss: 0.5194411277770996, Train F1: 0.8375, Validation F1: 0.7000
# Epoch 73, Training Loss: 0.5180259943008423, Train F1: 0.8375, Validation F1: 0.7000
# Epoch 74, Training Loss: 0.5167590975761414, Train F1: 0.8375, Validation F1: 0.7000
# Epoch 75, Training Loss: 0.5155840516090393, Train F1: 0.8375, Validation F1: 0.7000
# Epoch 76, Training Loss: 0.5144950151443481, Train F1: 0.8375, Validation F1: 0.7000
# Epoch 77, Training Loss: 0.5134877562522888, Train F1: 0.8375, Validation F1: 0.7000
# Epoch 78, Training Loss: 0.512542188167572, Train F1: 0.8375, Validation F1: 0.7000
# Epoch 79, Training Loss: 0.5116631388664246, Train F1: 0.8375, Validation F1: 0.7000
# Epoch 80, Training Loss: 0.5108534693717957, Train F1: 0.8375, Validation F1: 0.7000
# Epoch 81, Training Loss: 0.5101073384284973, Train F1: 0.8375, Validation F1: 0.7000
# Epoch 82, Training Loss: 0.5094024538993835, Train F1: 0.8375, Validation F1: 0.7000
# Epoch 83, Training Loss: 0.5087169408798218, Train F1: 0.8375, Validation F1: 0.7000
# Epoch 84, Training Loss: 0.5080664157867432, Train F1: 0.8375, Validation F1: 0.7000
# Epoch 85, Training Loss: 0.5074483156204224, Train F1: 0.8375, Validation F1: 0.7000
# Epoch 86, Training Loss: 0.5068565607070923, Train F1: 0.8375, Validation F1: 0.7000
# Epoch 87, Training Loss: 0.50629723072052, Train F1: 0.8375, Validation F1: 0.7000
# Epoch 88, Training Loss: 0.5057711005210876, Train F1: 0.8375, Validation F1: 0.7000
# Epoch 89, Training Loss: 0.5052683353424072, Train F1: 0.8375, Validation F1: 0.7000
# Epoch 90, Training Loss: 0.5047819018363953, Train F1: 0.8375, Validation F1: 0.7000
# Epoch 91, Training Loss: 0.5043096542358398, Train F1: 0.8375, Validation F1: 0.7000
# Epoch 92, Training Loss: 0.5038491487503052, Train F1: 0.8375, Validation F1: 0.7000
# Epoch 93, Training Loss: 0.5033987164497375, Train F1: 0.8375, Validation F1: 0.7000
# Epoch 94, Training Loss: 0.5029569268226624, Train F1: 0.8375, Validation F1: 0.7000
# Epoch 95, Training Loss: 0.5025227069854736, Train F1: 0.8375, Validation F1: 0.7000
# Epoch 96, Training Loss: 0.5020949244499207, Train F1: 0.8375, Validation F1: 0.7000
# Epoch 97, Training Loss: 0.5016723871231079, Train F1: 0.8375, Validation F1: 0.7000
# Epoch 98, Training Loss: 0.501254677772522, Train F1: 0.8375, Validation F1: 0.7000
# Epoch 99, Training Loss: 0.5008412599563599, Train F1: 0.8375, Validation F1: 0.7000
# Epoch 100, Training Loss: 0.5004314184188843, Train F1: 0.8375, Validation F1: 0.7000
# Epoch 101, Training Loss: 0.5000249743461609, Train F1: 0.8375, Validation F1: 0.7000
# Epoch 102, Training Loss: 0.4996202886104584, Train F1: 0.8375, Validation F1: 0.7000
# Epoch 103, Training Loss: 0.49921512603759766, Train F1: 0.8375, Validation F1: 0.7000
# Epoch 104, Training Loss: 0.49882078170776367, Train F1: 0.8375, Validation F1: 0.7000
# Epoch 105, Training Loss: 0.4984280467033386, Train F1: 0.8375, Validation F1: 0.7000
# Epoch 106, Training Loss: 0.4980388581752777, Train F1: 0.8375, Validation F1: 0.7000
# Epoch 107, Training Loss: 0.4976482391357422, Train F1: 0.8375, Validation F1: 0.7000
# Epoch 108, Training Loss: 0.497257798910141, Train F1: 0.8375, Validation F1: 0.7000
# Epoch 109, Training Loss: 0.496873676776886, Train F1: 0.8375, Validation F1: 0.7000
# Epoch 110, Training Loss: 0.4964902997016907, Train F1: 0.8375, Validation F1: 0.7000
# Epoch 111, Training Loss: 0.49610695242881775, Train F1: 0.8375, Validation F1: 0.7000
# Epoch 112, Training Loss: 0.49572300910949707, Train F1: 0.8375, Validation F1: 0.7000
# Epoch 113, Training Loss: 0.4953404366970062, Train F1: 0.8375, Validation F1: 0.7000
# Epoch 114, Training Loss: 0.4949648380279541, Train F1: 0.8375, Validation F1: 0.7000
# Epoch 115, Training Loss: 0.4945996403694153, Train F1: 0.8375, Validation F1: 0.7000
# Epoch 116, Training Loss: 0.49423107504844666, Train F1: 0.8375, Validation F1: 0.7000
# Epoch 117, Training Loss: 0.49385547637939453, Train F1: 0.8375, Validation F1: 0.7000
# Epoch 118, Training Loss: 0.49347931146621704, Train F1: 0.8375, Validation F1: 0.7000
# Epoch 119, Training Loss: 0.4931027293205261, Train F1: 0.8375, Validation F1: 0.7000
# Epoch 120, Training Loss: 0.49272584915161133, Train F1: 0.8375, Validation F1: 0.7000
# Epoch 121, Training Loss: 0.492348849773407, Train F1: 0.8375, Validation F1: 0.7000
# Epoch 122, Training Loss: 0.49196869134902954, Train F1: 0.8375, Validation F1: 0.7000
# Epoch 123, Training Loss: 0.49158328771591187, Train F1: 0.8375, Validation F1: 0.7000
# Epoch 124, Training Loss: 0.4911922812461853, Train F1: 0.8375, Validation F1: 0.7000
# Epoch 125, Training Loss: 0.49079638719558716, Train F1: 0.8375, Validation F1: 0.7000
# Epoch 126, Training Loss: 0.49039226770401, Train F1: 0.8375, Validation F1: 0.7000
# Epoch 127, Training Loss: 0.4899846911430359, Train F1: 0.8375, Validation F1: 0.7000
# Epoch 128, Training Loss: 0.48957425355911255, Train F1: 0.8375, Validation F1: 0.7000
# Epoch 129, Training Loss: 0.48916110396385193, Train F1: 0.8375, Validation F1: 0.7000
# Epoch 130, Training Loss: 0.4887455105781555, Train F1: 0.8375, Validation F1: 0.7000
# Epoch 131, Training Loss: 0.4883275628089905, Train F1: 0.8375, Validation F1: 0.7000
# Epoch 132, Training Loss: 0.48790764808654785, Train F1: 0.8375, Validation F1: 0.7000
# Epoch 133, Training Loss: 0.48748594522476196, Train F1: 0.8375, Validation F1: 0.7000
# Epoch 134, Training Loss: 0.48706135153770447, Train F1: 0.8375, Validation F1: 0.7000
# Epoch 135, Training Loss: 0.4866350293159485, Train F1: 0.8375, Validation F1: 0.7000
# Epoch 136, Training Loss: 0.48620954155921936, Train F1: 0.8375, Validation F1: 0.7000
# Epoch 137, Training Loss: 0.4857828617095947, Train F1: 0.8375, Validation F1: 0.7000
# Epoch 138, Training Loss: 0.48534297943115234, Train F1: 0.8375, Validation F1: 0.7000
# Epoch 139, Training Loss: 0.4848872125148773, Train F1: 0.8375, Validation F1: 0.7000
# Epoch 140, Training Loss: 0.4844263195991516, Train F1: 0.8375, Validation F1: 0.7000
# Epoch 141, Training Loss: 0.4839697480201721, Train F1: 0.8375, Validation F1: 0.7000
# Epoch 142, Training Loss: 0.4835148751735687, Train F1: 0.8375, Validation F1: 0.7000
# Epoch 143, Training Loss: 0.4830563962459564, Train F1: 0.8375, Validation F1: 0.7000
# Epoch 144, Training Loss: 0.48259496688842773, Train F1: 0.8375, Validation F1: 0.7000
# Epoch 145, Training Loss: 0.48213085532188416, Train F1: 0.8375, Validation F1: 0.7000
# Epoch 146, Training Loss: 0.48166385293006897, Train F1: 0.8375, Validation F1: 0.7000
# Epoch 147, Training Loss: 0.48119527101516724, Train F1: 0.8375, Validation F1: 0.7000
# Epoch 148, Training Loss: 0.48072800040245056, Train F1: 0.8375, Validation F1: 0.7000
# Epoch 149, Training Loss: 0.48025912046432495, Train F1: 0.8375, Validation F1: 0.7000
# Epoch 150, Training Loss: 0.4797915816307068, Train F1: 0.8375, Validation F1: 0.7000
# Epoch 151, Training Loss: 0.4793251156806946, Train F1: 0.8375, Validation F1: 0.7000
# Epoch 152, Training Loss: 0.47886162996292114, Train F1: 0.8375, Validation F1: 0.7000
# Epoch 153, Training Loss: 0.47840213775634766, Train F1: 0.8375, Validation F1: 0.7000
# Epoch 154, Training Loss: 0.4779326021671295, Train F1: 0.8375, Validation F1: 0.7000
# Epoch 155, Training Loss: 0.4774664044380188, Train F1: 0.8375, Validation F1: 0.7000
# Epoch 156, Training Loss: 0.47700804471969604, Train F1: 0.8375, Validation F1: 0.7000
# Epoch 157, Training Loss: 0.4765542149543762, Train F1: 0.8375, Validation F1: 0.7000
# Epoch 158, Training Loss: 0.4760972559452057, Train F1: 0.8375, Validation F1: 0.7000
# Epoch 159, Training Loss: 0.47563809156417847, Train F1: 0.8375, Validation F1: 0.7000
# Epoch 160, Training Loss: 0.4751926362514496, Train F1: 0.8375, Validation F1: 0.7000
# Epoch 161, Training Loss: 0.47475919127464294, Train F1: 0.8375, Validation F1: 0.7000
# Epoch 162, Training Loss: 0.4743269979953766, Train F1: 0.8375, Validation F1: 0.7000
# Epoch 163, Training Loss: 0.47389596700668335, Train F1: 0.8375, Validation F1: 0.7000
# Epoch 164, Training Loss: 0.473470538854599, Train F1: 0.8375, Validation F1: 0.7000
# Epoch 165, Training Loss: 0.47306013107299805, Train F1: 0.8375, Validation F1: 0.7000
# Epoch 166, Training Loss: 0.4726533889770508, Train F1: 0.8375, Validation F1: 0.7000
# Epoch 167, Training Loss: 0.472248375415802, Train F1: 0.8375, Validation F1: 0.7000
# Epoch 168, Training Loss: 0.4718448519706726, Train F1: 0.8375, Validation F1: 0.7000
# Epoch 169, Training Loss: 0.4714428782463074, Train F1: 0.8375, Validation F1: 0.7000
# Epoch 170, Training Loss: 0.4710422158241272, Train F1: 0.8375, Validation F1: 0.7000
# Epoch 171, Training Loss: 0.47064265608787537, Train F1: 0.8375, Validation F1: 0.7000
# Epoch 172, Training Loss: 0.4702441096305847, Train F1: 0.8375, Validation F1: 0.7000
# Epoch 173, Training Loss: 0.46984657645225525, Train F1: 0.8375, Validation F1: 0.7000
# Epoch 174, Training Loss: 0.46948686242103577, Train F1: 0.8375, Validation F1: 0.7000
# Epoch 175, Training Loss: 0.469125896692276, Train F1: 0.8375, Validation F1: 0.7000
# Epoch 176, Training Loss: 0.4687604308128357, Train F1: 0.8375, Validation F1: 0.7000
# Epoch 177, Training Loss: 0.46839556097984314, Train F1: 0.8375, Validation F1: 0.7000
# Epoch 178, Training Loss: 0.46802806854248047, Train F1: 0.8375, Validation F1: 0.7000
# Epoch 179, Training Loss: 0.4676581919193268, Train F1: 0.8375, Validation F1: 0.7000
# Epoch 180, Training Loss: 0.46729427576065063, Train F1: 0.8375, Validation F1: 0.7000
# Epoch 181, Training Loss: 0.4669302999973297, Train F1: 0.8375, Validation F1: 0.7000
# Epoch 182, Training Loss: 0.46656641364097595, Train F1: 0.8375, Validation F1: 0.7000
# Epoch 183, Training Loss: 0.46620163321495056, Train F1: 0.8375, Validation F1: 0.7000
# Epoch 184, Training Loss: 0.46584072709083557, Train F1: 0.8375, Validation F1: 0.7000
# Epoch 185, Training Loss: 0.4654816687107086, Train F1: 0.8375, Validation F1: 0.7000
# Epoch 186, Training Loss: 0.4651382565498352, Train F1: 0.8375, Validation F1: 0.7000
# Epoch 187, Training Loss: 0.4647997319698334, Train F1: 0.8375, Validation F1: 0.7000
# Epoch 188, Training Loss: 0.4644685387611389, Train F1: 0.8375, Validation F1: 0.7000
# Epoch 189, Training Loss: 0.464172899723053, Train F1: 0.8375, Validation F1: 0.7000
# Epoch 190, Training Loss: 0.4638802409172058, Train F1: 0.8375, Validation F1: 0.7000
# Epoch 191, Training Loss: 0.4635887145996094, Train F1: 0.8375, Validation F1: 0.7000
# Epoch 192, Training Loss: 0.4632972180843353, Train F1: 0.8375, Validation F1: 0.7000
# Epoch 193, Training Loss: 0.4630056321620941, Train F1: 0.8375, Validation F1: 0.7000
# Epoch 194, Training Loss: 0.4627140164375305, Train F1: 0.8375, Validation F1: 0.7000
# Epoch 195, Training Loss: 0.4624423384666443, Train F1: 0.8375, Validation F1: 0.7000
# Epoch 196, Training Loss: 0.46217507123947144, Train F1: 0.8375, Validation F1: 0.7000
# Epoch 197, Training Loss: 0.4619077146053314, Train F1: 0.8375, Validation F1: 0.7000
# Epoch 198, Training Loss: 0.4616401195526123, Train F1: 0.8375, Validation F1: 0.7000
# Epoch 199, Training Loss: 0.46137237548828125, Train F1: 0.8375, Validation F1: 0.7000
# Epoch 200, Training Loss: 0.46110019087791443, Train F1: 0.8375, Validation F1: 0.7000

# %% [markdown]
# ### Q3.2.c - Training the Model on Merged Graphs G = G1 ∪ G
#
# • Implement a GCN that trains on both graphs at once. Plot the training curve.
#
# • Compare the performance of G = G1 ∪ G2 against training on G1 and G2, respectively.
#
# • Plot TSNE plots.

# %%
# SOLUTION Q3.2.c
# ####################################################
# MODIFY THE CODE BELOW 
# ####################################################  

# Implement the training of G = {G1 U G2}
def combine_graphs(G1, G2):
    X1, A1, y1 = G1
    X2, A2, y2 = G2

    X_combined = torch.cat([X1, X2], dim=0)

    # Combine the adjacency matrices
    size1, size2 = A1.shape[0], A2.shape[0]
    new_size = size1 + size2  # Assuming nodes are indexed 0,1,2,...

    # Expand matrices to the new unified size
    expanded_A = torch.zeros((new_size, new_size))

    expanded_A[:size1, :size1] = A1
    expanded_A[size1:, size1:] = A2

    y_combined = torch.cat([y1, y2], dim=0)

    return X_combined, expanded_A, y_combined

# In the end return a single function:
def train_G1UG2(G1_train, G1_eval, G2_train, G2_eval, num_epochs=200, lr=0.001, verbose=True):
    """"""
    G_train_combined = combine_graphs(G1_train, G2_train)
    G_eval_combined = combine_graphs(G1_eval, G2_eval)

    input_dim = G_train_combined[0].shape[1]
    hidden_dim = 8
    num_layers = 4

    model = LayeredGCN(input_dim, hidden_dim, num_layers=num_layers)

    losses, train_f1, val_f1 = train_model(
        model,
        G_train_combined,
        G_eval_combined,
        num_epochs=num_epochs,
        lr=lr,
        verbose=verbose,
        return_embeddings=False
    )

    return losses, train_f1, val_f1

# ####################################################
# END OF MODIFICATION
# ####################################################

# %% [markdown]
# ### Running the evaluation.

# %%
# Load data
G1_train = read_json_data(G1_TRAIN_DATA_PATH, has_label=True) #returns a list of (X,A,y) - features, Adj Matrix, per Graph label
G1_eval = read_json_data(G1_EVAL_DATA_PATH, has_label=True) #returns a list of (X,A,y) - features, Adj Matrix, per Graph label

G2_train = read_json_data(G2_TRAIN_DATA_PATH, has_label=True) #returns a list of (X,A,y) - features, Adj Matrix, per Graph label
G2_eval = read_json_data(G2_EVAL_DATA_PATH, has_label=True) #returns a list of (X,A,y) - features, Adj Matrix, per Graph label

losses, train_f1, val_f1 = train_G1UG2(G1_train, G1_eval, G2_train, G2_eval, num_epochs=200, lr=0.001, verbose=True)

plot_training_and_validation(losses, val_f1)
# Out:
# Epoch 1, Training Loss: 30.322513580322266, Train F1: 0.5125, Validation F1: 0.5667
# Epoch 2, Training Loss: 29.699386596679688, Train F1: 0.5125, Validation F1: 0.5667
# Epoch 3, Training Loss: 29.593387603759766, Train F1: 0.5125, Validation F1: 0.5667
# Epoch 4, Training Loss: 28.970138549804688, Train F1: 0.5125, Validation F1: 0.5667
# Epoch 5, Training Loss: 28.345123291015625, Train F1: 0.5125, Validation F1: 0.5667
# Epoch 6, Training Loss: 27.719310760498047, Train F1: 0.5125, Validation F1: 0.5667
# Epoch 7, Training Loss: 27.615310668945312, Train F1: 0.5125, Validation F1: 0.5667
# Epoch 8, Training Loss: 27.51276206970215, Train F1: 0.5125, Validation F1: 0.5667
# Epoch 9, Training Loss: 27.41379737854004, Train F1: 0.5125, Validation F1: 0.5667
# Epoch 10, Training Loss: 27.320049285888672, Train F1: 0.5125, Validation F1: 0.5667
# Epoch 11, Training Loss: 27.235107421875, Train F1: 0.5125, Validation F1: 0.5667
# Epoch 12, Training Loss: 27.15609359741211, Train F1: 0.5125, Validation F1: 0.5667
# Epoch 13, Training Loss: 27.08246421813965, Train F1: 0.5125, Validation F1: 0.5667
# Epoch 14, Training Loss: 27.012832641601562, Train F1: 0.5125, Validation F1: 0.5667
# Epoch 15, Training Loss: 26.94759178161621, Train F1: 0.5125, Validation F1: 0.5667
# Epoch 16, Training Loss: 26.885345458984375, Train F1: 0.5125, Validation F1: 0.5667
# Epoch 17, Training Loss: 26.825122833251953, Train F1: 0.5125, Validation F1: 0.5667
# Epoch 18, Training Loss: 26.766536712646484, Train F1: 0.5125, Validation F1: 0.5667
# Epoch 19, Training Loss: 26.710342407226562, Train F1: 0.5125, Validation F1: 0.5667
# Epoch 20, Training Loss: 26.656497955322266, Train F1: 0.5125, Validation F1: 0.5667
# Epoch 21, Training Loss: 26.604095458984375, Train F1: 0.5125, Validation F1: 0.5667
# Epoch 22, Training Loss: 26.55255699157715, Train F1: 0.5125, Validation F1: 0.5667
# Epoch 23, Training Loss: 26.502044677734375, Train F1: 0.5125, Validation F1: 0.5667
# Epoch 24, Training Loss: 26.452905654907227, Train F1: 0.5125, Validation F1: 0.5667
# Epoch 25, Training Loss: 26.40481948852539, Train F1: 0.5125, Validation F1: 0.5667
# Epoch 26, Training Loss: 26.357757568359375, Train F1: 0.5125, Validation F1: 0.5667
# Epoch 27, Training Loss: 26.312301635742188, Train F1: 0.5125, Validation F1: 0.5667
# Epoch 28, Training Loss: 26.269018173217773, Train F1: 0.5125, Validation F1: 0.5667
# Epoch 29, Training Loss: 26.227651596069336, Train F1: 0.5125, Validation F1: 0.5667
# Epoch 30, Training Loss: 26.188106536865234, Train F1: 0.5125, Validation F1: 0.5667
# Epoch 31, Training Loss: 26.150569915771484, Train F1: 0.5125, Validation F1: 0.5667
# Epoch 32, Training Loss: 26.115304946899414, Train F1: 0.5125, Validation F1: 0.5667
# Epoch 33, Training Loss: 26.083202362060547, Train F1: 0.5250, Validation F1: 0.5667
# Epoch 34, Training Loss: 26.054458618164062, Train F1: 0.5312, Validation F1: 0.5667
# Epoch 35, Training Loss: 26.029144287109375, Train F1: 0.5500, Validation F1: 0.5833
# Epoch 36, Training Loss: 26.007198333740234, Train F1: 0.5563, Validation F1: 0.5833
# Epoch 37, Training Loss: 25.98880958557129, Train F1: 0.5687, Validation F1: 0.6167
# Epoch 38, Training Loss: 25.972469329833984, Train F1: 0.5625, Validation F1: 0.6333
# Epoch 39, Training Loss: 25.958240509033203, Train F1: 0.5750, Validation F1: 0.6333
# Epoch 40, Training Loss: 25.945714950561523, Train F1: 0.5750, Validation F1: 0.6500
# Epoch 41, Training Loss: 25.93619155883789, Train F1: 0.5875, Validation F1: 0.6500
# Epoch 42, Training Loss: 25.92820167541504, Train F1: 0.5938, Validation F1: 0.6833
# Epoch 43, Training Loss: 25.921497344970703, Train F1: 0.6000, Validation F1: 0.6833
# Epoch 44, Training Loss: 25.915552139282227, Train F1: 0.6250, Validation F1: 0.6833
# Epoch 45, Training Loss: 25.910852432250977, Train F1: 0.6312, Validation F1: 0.6833
# Epoch 46, Training Loss: 25.907812118530273, Train F1: 0.6375, Validation F1: 0.6833
# Epoch 47, Training Loss: 25.905681610107422, Train F1: 0.6375, Validation F1: 0.6667
# Epoch 48, Training Loss: 25.90425682067871, Train F1: 0.6375, Validation F1: 0.6667
# Epoch 49, Training Loss: 25.902990341186523, Train F1: 0.6438, Validation F1: 0.6667
# Epoch 50, Training Loss: 25.9018611907959, Train F1: 0.6438, Validation F1: 0.6667
# Epoch 51, Training Loss: 25.900955200195312, Train F1: 0.6438, Validation F1: 0.6667
# Epoch 52, Training Loss: 25.900360107421875, Train F1: 0.6562, Validation F1: 0.6667
# Epoch 53, Training Loss: 25.899826049804688, Train F1: 0.6562, Validation F1: 0.6667
# Epoch 54, Training Loss: 25.899444580078125, Train F1: 0.6562, Validation F1: 0.6667
# Epoch 55, Training Loss: 25.899246215820312, Train F1: 0.6562, Validation F1: 0.6667
# Epoch 56, Training Loss: 25.89906883239746, Train F1: 0.6562, Validation F1: 0.6667
# Epoch 57, Training Loss: 25.898910522460938, Train F1: 0.6562, Validation F1: 0.6667
# Epoch 58, Training Loss: 25.89876937866211, Train F1: 0.6562, Validation F1: 0.6667
# Epoch 59, Training Loss: 25.898639678955078, Train F1: 0.6562, Validation F1: 0.6667
# Epoch 60, Training Loss: 25.898523330688477, Train F1: 0.6562, Validation F1: 0.6667
# Epoch 61, Training Loss: 25.898412704467773, Train F1: 0.6562, Validation F1: 0.6667
# Epoch 62, Training Loss: 25.8983154296875, Train F1: 0.6562, Validation F1: 0.6667
# Epoch 63, Training Loss: 25.898223876953125, Train F1: 0.6562, Validation F1: 0.6667
# Epoch 64, Training Loss: 25.898136138916016, Train F1: 0.6562, Validation F1: 0.6667
# Epoch 65, Training Loss: 25.898056030273438, Train F1: 0.6562, Validation F1: 0.6667
# Epoch 66, Training Loss: 25.897979736328125, Train F1: 0.6562, Validation F1: 0.6667
# Epoch 67, Training Loss: 25.897903442382812, Train F1: 0.6562, Validation F1: 0.6667
# Epoch 68, Training Loss: 25.897830963134766, Train F1: 0.6562, Validation F1: 0.6667
# Epoch 69, Training Loss: 25.89776039123535, Train F1: 0.6562, Validation F1: 0.6667
# Epoch 70, Training Loss: 25.897693634033203, Train F1: 0.6562, Validation F1: 0.6667
# Epoch 71, Training Loss: 25.897624969482422, Train F1: 0.6562, Validation F1: 0.6667
# Epoch 72, Training Loss: 25.897558212280273, Train F1: 0.6562, Validation F1: 0.6667
# Epoch 73, Training Loss: 25.897491455078125, Train F1: 0.6562, Validation F1: 0.6667
# Epoch 74, Training Loss: 25.897424697875977, Train F1: 0.6562, Validation F1: 0.6667
# Epoch 75, Training Loss: 25.89735984802246, Train F1: 0.6562, Validation F1: 0.6667
# Epoch 76, Training Loss: 25.897293090820312, Train F1: 0.6562, Validation F1: 0.6667
# Epoch 77, Training Loss: 25.897226333618164, Train F1: 0.6562, Validation F1: 0.6667
# Epoch 78, Training Loss: 25.89716148376465, Train F1: 0.6562, Validation F1: 0.6667
# Epoch 79, Training Loss: 25.897090911865234, Train F1: 0.6562, Validation F1: 0.6667
# Epoch 80, Training Loss: 25.89702796936035, Train F1: 0.6562, Validation F1: 0.6667
# Epoch 81, Training Loss: 25.896957397460938, Train F1: 0.6562, Validation F1: 0.6667
# Epoch 82, Training Loss: 25.89689064025879, Train F1: 0.6562, Validation F1: 0.6667
# Epoch 83, Training Loss: 25.896820068359375, Train F1: 0.6562, Validation F1: 0.6667
# Epoch 84, Training Loss: 25.89674949645996, Train F1: 0.6562, Validation F1: 0.6667
# Epoch 85, Training Loss: 25.896678924560547, Train F1: 0.6562, Validation F1: 0.6667
# Epoch 86, Training Loss: 25.8966064453125, Train F1: 0.6562, Validation F1: 0.6667
# Epoch 87, Training Loss: 25.89653968811035, Train F1: 0.6562, Validation F1: 0.6667
# Epoch 88, Training Loss: 25.896465301513672, Train F1: 0.6562, Validation F1: 0.6667
# Epoch 89, Training Loss: 25.89639663696289, Train F1: 0.6562, Validation F1: 0.6667
# Epoch 90, Training Loss: 25.89632225036621, Train F1: 0.6562, Validation F1: 0.6667
# Epoch 91, Training Loss: 25.896251678466797, Train F1: 0.6562, Validation F1: 0.6667
# Epoch 92, Training Loss: 25.896175384521484, Train F1: 0.6562, Validation F1: 0.6667
# Epoch 93, Training Loss: 25.896102905273438, Train F1: 0.6562, Validation F1: 0.6667
# Epoch 94, Training Loss: 25.89603042602539, Train F1: 0.6562, Validation F1: 0.6667
# Epoch 95, Training Loss: 25.895954132080078, Train F1: 0.6562, Validation F1: 0.6667
# Epoch 96, Training Loss: 25.8958797454834, Train F1: 0.6562, Validation F1: 0.6667
# Epoch 97, Training Loss: 25.89580726623535, Train F1: 0.6562, Validation F1: 0.6667
# Epoch 98, Training Loss: 25.895732879638672, Train F1: 0.6562, Validation F1: 0.6667
# Epoch 99, Training Loss: 25.89565658569336, Train F1: 0.6562, Validation F1: 0.6667
# Epoch 100, Training Loss: 25.895580291748047, Train F1: 0.6562, Validation F1: 0.6667
# Epoch 101, Training Loss: 25.8955078125, Train F1: 0.6562, Validation F1: 0.6667
# Epoch 102, Training Loss: 25.895431518554688, Train F1: 0.6562, Validation F1: 0.6667
# Epoch 103, Training Loss: 25.89535140991211, Train F1: 0.6562, Validation F1: 0.6667
# Epoch 104, Training Loss: 25.895275115966797, Train F1: 0.6562, Validation F1: 0.6667
# Epoch 105, Training Loss: 25.89520263671875, Train F1: 0.6562, Validation F1: 0.6667
# Epoch 106, Training Loss: 25.895122528076172, Train F1: 0.6562, Validation F1: 0.6667
# Epoch 107, Training Loss: 25.89504623413086, Train F1: 0.6562, Validation F1: 0.6667
# Epoch 108, Training Loss: 25.894969940185547, Train F1: 0.6562, Validation F1: 0.6667
# Epoch 109, Training Loss: 25.894893646240234, Train F1: 0.6562, Validation F1: 0.6667
# Epoch 110, Training Loss: 25.894811630249023, Train F1: 0.6562, Validation F1: 0.6667
# Epoch 111, Training Loss: 25.89473533630371, Train F1: 0.6562, Validation F1: 0.6667
# Epoch 112, Training Loss: 25.8946590423584, Train F1: 0.6562, Validation F1: 0.6667
# Epoch 113, Training Loss: 25.894582748413086, Train F1: 0.6562, Validation F1: 0.6667
# Epoch 114, Training Loss: 25.89450454711914, Train F1: 0.6562, Validation F1: 0.6667
# Epoch 115, Training Loss: 25.894424438476562, Train F1: 0.6562, Validation F1: 0.6667
# Epoch 116, Training Loss: 25.894344329833984, Train F1: 0.6562, Validation F1: 0.6667
# Epoch 117, Training Loss: 25.894268035888672, Train F1: 0.6562, Validation F1: 0.6667
# Epoch 118, Training Loss: 25.894189834594727, Train F1: 0.6562, Validation F1: 0.6667
# Epoch 119, Training Loss: 25.89410972595215, Train F1: 0.6562, Validation F1: 0.6667
# Epoch 120, Training Loss: 25.894031524658203, Train F1: 0.6562, Validation F1: 0.6667
# Epoch 121, Training Loss: 25.89394760131836, Train F1: 0.6562, Validation F1: 0.6667
# Epoch 122, Training Loss: 25.893871307373047, Train F1: 0.6562, Validation F1: 0.6667
# Epoch 123, Training Loss: 25.8937931060791, Train F1: 0.6562, Validation F1: 0.6667
# Epoch 124, Training Loss: 25.893712997436523, Train F1: 0.6562, Validation F1: 0.6667
# Epoch 125, Training Loss: 25.893630981445312, Train F1: 0.6562, Validation F1: 0.6667
# Epoch 126, Training Loss: 25.8935546875, Train F1: 0.6562, Validation F1: 0.6667
# Epoch 127, Training Loss: 25.89347267150879, Train F1: 0.6562, Validation F1: 0.6667
# Epoch 128, Training Loss: 25.893396377563477, Train F1: 0.6562, Validation F1: 0.6667
# Epoch 129, Training Loss: 25.893314361572266, Train F1: 0.6562, Validation F1: 0.6667
# Epoch 130, Training Loss: 25.893230438232422, Train F1: 0.6562, Validation F1: 0.6667
# Epoch 131, Training Loss: 25.89314842224121, Train F1: 0.6562, Validation F1: 0.6667
# Epoch 132, Training Loss: 25.893070220947266, Train F1: 0.6562, Validation F1: 0.6667
# Epoch 133, Training Loss: 25.892990112304688, Train F1: 0.6562, Validation F1: 0.6667
# Epoch 134, Training Loss: 25.89291000366211, Train F1: 0.6562, Validation F1: 0.6667
# Epoch 135, Training Loss: 25.8928279876709, Train F1: 0.6562, Validation F1: 0.6667
# Epoch 136, Training Loss: 25.892749786376953, Train F1: 0.6562, Validation F1: 0.6667
# Epoch 137, Training Loss: 25.89266586303711, Train F1: 0.6562, Validation F1: 0.6667
# Epoch 138, Training Loss: 25.8925838470459, Train F1: 0.6562, Validation F1: 0.6667
# Epoch 139, Training Loss: 25.892501831054688, Train F1: 0.6562, Validation F1: 0.6667
# Epoch 140, Training Loss: 25.892419815063477, Train F1: 0.6562, Validation F1: 0.6667
# Epoch 141, Training Loss: 25.8923397064209, Train F1: 0.6562, Validation F1: 0.6667
# Epoch 142, Training Loss: 25.892257690429688, Train F1: 0.6562, Validation F1: 0.6667
# Epoch 143, Training Loss: 25.892175674438477, Train F1: 0.6562, Validation F1: 0.6667
# Epoch 144, Training Loss: 25.8920955657959, Train F1: 0.6562, Validation F1: 0.6667
# Epoch 145, Training Loss: 25.892009735107422, Train F1: 0.6562, Validation F1: 0.6667
# Epoch 146, Training Loss: 25.89192771911621, Train F1: 0.6562, Validation F1: 0.6667
# Epoch 147, Training Loss: 25.891845703125, Train F1: 0.6562, Validation F1: 0.6667
# Epoch 148, Training Loss: 25.89176368713379, Train F1: 0.6562, Validation F1: 0.6667
# Epoch 149, Training Loss: 25.891681671142578, Train F1: 0.6562, Validation F1: 0.6667
# Epoch 150, Training Loss: 25.8916015625, Train F1: 0.6562, Validation F1: 0.6667
# Epoch 151, Training Loss: 25.891530990600586, Train F1: 0.6562, Validation F1: 0.6667
# Epoch 152, Training Loss: 25.89145851135254, Train F1: 0.6562, Validation F1: 0.6667
# Epoch 153, Training Loss: 25.891387939453125, Train F1: 0.6562, Validation F1: 0.6667
# Epoch 154, Training Loss: 25.89131736755371, Train F1: 0.6562, Validation F1: 0.6667
# Epoch 155, Training Loss: 25.891244888305664, Train F1: 0.6562, Validation F1: 0.6667
# Epoch 156, Training Loss: 25.89117431640625, Train F1: 0.6562, Validation F1: 0.6667
# Epoch 157, Training Loss: 25.891103744506836, Train F1: 0.6562, Validation F1: 0.6667
# Epoch 158, Training Loss: 25.891033172607422, Train F1: 0.6562, Validation F1: 0.6667
# Epoch 159, Training Loss: 25.890960693359375, Train F1: 0.6562, Validation F1: 0.6667
# Epoch 160, Training Loss: 25.890893936157227, Train F1: 0.6562, Validation F1: 0.6667
# Epoch 161, Training Loss: 25.890827178955078, Train F1: 0.6562, Validation F1: 0.6667
# Epoch 162, Training Loss: 25.890756607055664, Train F1: 0.6562, Validation F1: 0.6667
# Epoch 163, Training Loss: 25.89068603515625, Train F1: 0.6562, Validation F1: 0.6667
# Epoch 164, Training Loss: 25.8906192779541, Train F1: 0.6562, Validation F1: 0.6667
# Epoch 165, Training Loss: 25.890548706054688, Train F1: 0.6562, Validation F1: 0.6667
# Epoch 166, Training Loss: 25.890478134155273, Train F1: 0.6562, Validation F1: 0.6667
# Epoch 167, Training Loss: 25.890411376953125, Train F1: 0.6562, Validation F1: 0.6667
# Epoch 168, Training Loss: 25.89034080505371, Train F1: 0.6562, Validation F1: 0.6667
# Epoch 169, Training Loss: 25.890274047851562, Train F1: 0.6562, Validation F1: 0.6667
# Epoch 170, Training Loss: 25.89020347595215, Train F1: 0.6562, Validation F1: 0.6667
# Epoch 171, Training Loss: 25.890132904052734, Train F1: 0.6562, Validation F1: 0.6667
# Epoch 172, Training Loss: 25.89006996154785, Train F1: 0.6562, Validation F1: 0.6667
# Epoch 173, Training Loss: 25.889999389648438, Train F1: 0.6562, Validation F1: 0.6667
# Epoch 174, Training Loss: 25.889928817749023, Train F1: 0.6562, Validation F1: 0.6667
# Epoch 175, Training Loss: 25.88985824584961, Train F1: 0.6562, Validation F1: 0.6667
# Epoch 176, Training Loss: 25.889789581298828, Train F1: 0.6562, Validation F1: 0.6667
# Epoch 177, Training Loss: 25.889720916748047, Train F1: 0.6562, Validation F1: 0.6667
# Epoch 178, Training Loss: 25.889652252197266, Train F1: 0.6562, Validation F1: 0.6667
# Epoch 179, Training Loss: 25.88958168029785, Train F1: 0.6562, Validation F1: 0.6667
# Epoch 180, Training Loss: 25.889511108398438, Train F1: 0.6562, Validation F1: 0.6667
# Epoch 181, Training Loss: 25.88944435119629, Train F1: 0.6562, Validation F1: 0.6667
# Epoch 182, Training Loss: 25.889373779296875, Train F1: 0.6562, Validation F1: 0.6667
# Epoch 183, Training Loss: 25.88930320739746, Train F1: 0.6562, Validation F1: 0.6667
# Epoch 184, Training Loss: 25.889232635498047, Train F1: 0.6562, Validation F1: 0.6667
# Epoch 185, Training Loss: 25.88916015625, Train F1: 0.6562, Validation F1: 0.6667
# Epoch 186, Training Loss: 25.88909339904785, Train F1: 0.6562, Validation F1: 0.6667
# Epoch 187, Training Loss: 25.889022827148438, Train F1: 0.6562, Validation F1: 0.6667
# Epoch 188, Training Loss: 25.88895034790039, Train F1: 0.6562, Validation F1: 0.6667
# Epoch 189, Training Loss: 25.88888168334961, Train F1: 0.6562, Validation F1: 0.6667
# Epoch 190, Training Loss: 25.888809204101562, Train F1: 0.6562, Validation F1: 0.6667
# Epoch 191, Training Loss: 25.88873863220215, Train F1: 0.6562, Validation F1: 0.6667
# Epoch 192, Training Loss: 25.888668060302734, Train F1: 0.6562, Validation F1: 0.6667
# Epoch 193, Training Loss: 25.888599395751953, Train F1: 0.6562, Validation F1: 0.6667
# Epoch 194, Training Loss: 25.888525009155273, Train F1: 0.6562, Validation F1: 0.6667
# Epoch 195, Training Loss: 25.888452529907227, Train F1: 0.6562, Validation F1: 0.6667
# Epoch 196, Training Loss: 25.888385772705078, Train F1: 0.6562, Validation F1: 0.6667
# Epoch 197, Training Loss: 25.8883113861084, Train F1: 0.6562, Validation F1: 0.6667
# Epoch 198, Training Loss: 25.888240814208984, Train F1: 0.6562, Validation F1: 0.6667
# Epoch 199, Training Loss: 25.888172149658203, Train F1: 0.6562, Validation F1: 0.6667
# Epoch 200, Training Loss: 25.888097763061523, Train F1: 0.6562, Validation F1: 0.6667

# %% [markdown]
# ### Q3.2.d Implement & discuss what you observe.
#
# • Compare training results, embeddings, and overall observations between independent and
# merged training.
#
# • Formulate a hypothesis explaining your observations.
#
# • Discuss different implementation options for training on both graphs, including your choice.
# (e.g. what model modifications are possible; what training modifications are possible?)
#
# • Provide relevant plots and tables where appropriate.
#
# • Bonus: Implement a modification (or alternative approach) for training on G1 ∪ G2 and
# compare outcomes.

# %%
# SOLUTION Q3.2.d
# ####################################################
# MODIFY THE CODE BELOW 
# ####################################################  

# Implement the training of G = {G1 U G2}

# In the end return a single function:
def train_G1UG2_v2(G1_train, G1_eval, G2_train, G2_eval, num_epochs=200, lr=0.001, verbose=True):
    """"""
    # INSERT necessary things
    return losses, train_f1, val_f1

# ####################################################
# END OF MODIFICATION
# ####################################################

# %% [markdown]
# ### Runnning the evaluation.
#
# Note: It is optional to run this particular evaluation. You can modify it as needed.

# %%
# Load data
G1_train = read_json_data(G1_TRAIN_DATA_PATH, has_label=True) #returns a list of (X,A,y) - features, Adj Matrix, per Graph label
G1_eval = read_json_data(G1_EVAL_DATA_PATH, has_label=True) #returns a list of (X,A,y) - features, Adj Matrix, per Graph label

G2_train = read_json_data(G2_TRAIN_DATA_PATH, has_label=True) #returns a list of (X,A,y) - features, Adj Matrix, per Graph label
G2_eval = read_json_data(G2_EVAL_DATA_PATH, has_label=True) #returns a list of (X,A,y) - features, Adj Matrix, per Graph label

losses, train_f1, val_f1 = train_G1UG2_v2(G1_train, G1_eval, G2_train, G2_eval, num_epochs=200, lr=0.001, verbose=True)

plot_training_and_validation(losses, val_f1)

# %% [markdown]
# ## 3.3 Topological changes to improve training

# %% [markdown]
# ### Q3.3.a - Plot the Ricci Curvature for each edge.
#
# • Plot a barplot of the the Ricci curvature per edge, where the x-axis are the edges and y-axis
# is the ricci curvature.

# %%
# SOLUTION Q3.3.a
# ####################################################
# MODIFY THE CODE BELOW 
# ####################################################  


# Load data
G1_train = read_json_data(G1_TRAIN_DATA_PATH, has_label=True) #returns a list of (X,A,y) - features, Adj Matrix, per Graph label
G1_eval = read_json_data(G1_EVAL_DATA_PATH, has_label=True) #returns a list of (X,A,y) - features, Adj Matrix, per Graph label

G2_train = read_json_data(G2_TRAIN_DATA_PATH, has_label=True) #returns a list of (X,A,y) - features, Adj Matrix, per Graph label
G2_eval = read_json_data(G2_EVAL_DATA_PATH, has_label=True) #returns a list of (X,A,y) - features, Adj Matrix, per Graph label


# Plot curvature against edges
from graph_ricci_curvature import GraphRicciCurvature 

# plot_ricci_per_edge()


# ####################################################
# END OF MODIFICATION
# ####################################################

# %% [markdown]
# ### Q3.3.b Investigate the extreme case topologies.
#
# • How would you modify a topology so that the graph structure is ignored, making the GNN
# behave like an MLP?
#
# • What would an ideal graph structure be for optimal training and testing if labels were
# available (both during training and testing)?
#
# • What are you observations? Analyze the scores and what does it mean about the dataset?
#
# • Provide relevant plots and results.

# %%
# SOLUTION Q3.3.b
# ####################################################
# MODIFY THE CODE BELOW 
# ####################################################  

def augment_graph_gold_labels(G):
    """Augment graph to return A that would be 'perfect'"""
    X,A,y = G
    return X,A,y

def augment_graph_no_effect(G):
    """Modify graph to return A that has no 'effect'"""
    X,A,y = G
    return X,A,y

    
def improved_training(
        G_train,
        G_eval,
        model_params,
        num_epochs=200,
        lr=0.0005,
        verbose=True,
        return_embeddings = True,
        change_topology_params = {},
    ):
    """
    How can you improve the topologies to train better.
    """
    if change_topology_params["augmentation_strategy"] == "no_effect":
        augmentation_function = augment_graph_no_effect
    elif change_topology_params["augmentation_strategy"] == "gold":
        augmentation_function = augment_graph_gold_labels
    else:
        raise NotImplementedError("This augmentation setting is not implemented.")

    G_train = augmentation_function(G_train)
    G_train = G_train[0],symmetric_normalize(G_train[1]),G_train[2]

    G_eval = augmentation_function(G_eval)
    G_eval = G_eval[0],symmetric_normalize(G_eval[1]),G_eval[2]

    # Initialising the model
    model = GraphNeuralNetwork(**model_params)
    print(model)

    losses, train_f1, val_f1, last_embeddings = train_model(
        model,
        G_train,
        G_eval,
        num_epochs=num_epochs,
        lr=lr,
        verbose=verbose,
        return_embeddings = True
    )
    return losses, train_f1, val_f1, last_embeddings

# ####################################################
# END OF MODIFICATION
# ####################################################

# %% [markdown]
# ### Code to run improvement
# Note: run it a few times to see what performance can be reached on the eval dataset.

# %%
# Load data
G1_train = read_json_data(G1_TRAIN_DATA_PATH, has_label=True) #returns a list of (X,A,y) - features, Adj Matrix, per Graph label
G1_eval = read_json_data(G1_EVAL_DATA_PATH, has_label=True) #returns a list of (X,A,y) - features, Adj Matrix, per Graph label

G2_train = read_json_data(G2_TRAIN_DATA_PATH, has_label=True) #returns a list of (X,A,y) - features, Adj Matrix, per Graph label
G2_eval = read_json_data(G2_EVAL_DATA_PATH, has_label=True) #returns a list of (X,A,y) - features, Adj Matrix, per Graph label

model_params = {    
    "input_dim":10, 
    "hidden_dim":8,
    "num_layers":4,
}

change_topology_params = {
    "augmentation_strategy":"no_effect",
    "normalise" : False,
}

# change_topology_params = {
#     "augmentation_strategy":"gold",
#     "normalise" : True,

# }

losses, train_f1, val_f1, last_embeddings = improved_training(
    G2_train,
    G2_eval,
    model_params=model_params,
    num_epochs=250,
    lr=0.0005,
    verbose=True,
    return_embeddings = True,
    change_topology_params = change_topology_params #change as needed
)
plot_training_and_validation(losses, val_f1)

X,A,y = G1_train
print(len(last_embeddings))
plot_tsne(last_embeddings, y)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[83], line 25
#      14 change_topology_params = {
#      15     "augmentation_strategy":"no_effect",
#      16     "normalise" : False,
#      17 }
#      19 # change_topology_params = {
#      20 #     "augmentation_strategy":"gold",
#      21 #     "normalise" : True,
#      22
#      23 # }
# ---> 25 losses, train_f1, val_f1, last_embeddings = improved_training(
#      26     G2_train,
#      27     G2_eval,
#      28     model_params=model_params,
#      29     num_epochs=250,
#      30     lr=0.0005,
#      31     verbose=True,
#      32     return_embeddings = True,
#      33     change_topology_params = change_topology_params #change as needed
#      34 )
#      35 plot_training_and_validation(losses, val_f1)
#      37 X,A,y = G1_train
#
# Cell In[82], line 44, in improved_training(G_train, G_eval, model_params, num_epochs, lr, verbose, return_embeddings, change_topology_params)
#      41 G_eval = G_eval[0],symmetric_normalize(G_eval[1]),G_eval[2]
#      43 # Initialising the model
# ---> 44 model = GraphNeuralNetwork(**model_params)
#      45 print(model)
#      47 losses, train_f1, val_f1, last_embeddings = train_model(
#      48     model,
#      49     G_train,
#    (...)
#      54     return_embeddings = True
#      55 )
#
# TypeError: GraphNeuralNetwork.__init__() got an unexpected keyword argument 'num_layers'

# %% [markdown]
# ### Q3.3.C Improving Graph Topology for Better Learning
#
# • Implement two graph modifications.
#
# • Describe your modifications.
#
# • What motivated your implementation?
#
# • If it helped give a hypothesis on why you think that is? If it did not give a hypothesis why
# you think it did not help.
#
# • Provide relevant plots and results

# %%
# SOLUTION Q3.3.c
# ####################################################
# MODIFY THE CODE BELOW 
# ####################################################  

def augment_graph(G):
    """Augments the graph."""
    X,A,y = G

    return X,A,y
    
def improved_training(
        G_train,
        G_eval,
        model_params,
        num_epochs=200,
        lr=0.0005,
        verbose=True,
        return_embeddings = True,
        change_topology_params = {},
    ):
    """
    How can you improve the topologies to train better.
    """

    G_train = augment_graph(G_train)
    G_train = G_train[0],symmetric_normalize(G_train[1]),G_train[2]

    G_eval = augment_graph(G_eval)
    G_eval = G_eval[0],symmetric_normalize(G_eval[1]),G_eval[2]

    # Initialising the model
    model = GraphNeuralNetwork(**model_params)
    print(model)

    losses, train_f1, val_f1, last_embeddings = train_model(
        model,
        G_train,
        G_eval,
        num_epochs=num_epochs,
        lr=lr,
        verbose=verbose,
        return_embeddings = True
    )
    return losses, train_f1, val_f1, last_embeddings

# ####################################################
# END OF MODIFICATION
# ####################################################

# %% [markdown]
# ### Code to run improvement

# %%
# Load data
G1_train = read_json_data(G1_TRAIN_DATA_PATH, has_label=True) #returns a list of (X,A,y) - features, Adj Matrix, per Graph label
G1_eval = read_json_data(G1_EVAL_DATA_PATH, has_label=True) #returns a list of (X,A,y) - features, Adj Matrix, per Graph label

G2_train = read_json_data(G2_TRAIN_DATA_PATH, has_label=True) #returns a list of (X,A,y) - features, Adj Matrix, per Graph label
G2_eval = read_json_data(G2_EVAL_DATA_PATH, has_label=True) #returns a list of (X,A,y) - features, Adj Matrix, per Graph label


model_params = {    
    "input_dim":10, 
    "hidden_dim":8,
    "num_layers":4,
}

change_topology_params = {
    "augmentation_strategy":"eval",
}

losses, train_f1, val_f1, last_embeddings = improved_training(
    G2_train,
    G2_eval,
    model_params=model_params,
    num_epochs=200,
    lr=0.0005,
    verbose=True,
    return_embeddings = True,
    change_topology_params = change_topology_params #change as needed
)
plot_training_and_validation(losses, val_f1)

X,A,y = G1_train
print(len(last_embeddings))
plot_tsne(last_embeddings, y)
